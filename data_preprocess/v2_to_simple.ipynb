# %%
import os
import numpy as np
import matplotlib.pyplot as plt
os.chdir("..")

# %%
DIR = "preprocessed_dataset/midkar_v2_simple"
for file_name in os.listdir(DIR):
    if file_name.endswith(".ans.npy"):
        p = os.path.join(DIR, file_name)
        a = np.load(p)
        np.save(p, a[:,:53])

# %%
plt.imshow(np.load("preprocessed_dataset/irealpro_dataset_v2_simple/9.20 Special_p1.mid.ans.npy").T, aspect="auto", interpolation=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/tom/Desktop/coding/ML_Final/ML-Final-Project/_private_space/v2_to_simple.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tom/Desktop/coding/ML_Final/ML-Final-Project/_private_space/v2_to_simple.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> plt.imshow(np.load("preprocessed_dataset/irealpro_dataset_v2_simple/9.20 Special_p1.mid.ans.npy").T, aspect="auto", interpolation=None)
#
# File /usr/local/lib/python3.10/site-packages/numpy/lib/npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
! zip -r irealpro_dataset_v2_simple.zip preprocessed_dataset/irealpro_dataset_v2_simple/
# Out:
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/ (stored 0%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/I've Told Eve'ry Little Star_d5.mid.npy (deflated 97%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/High Fly_p3.mid.ans.npy (deflated 99%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/All Blues_p2.mid.npy (deflated 97%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/How Deep Is The Ocean_p4.mid.npy (deflated 96%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/Be Careful It's My Heart_d2.mid.npy (deflated 97%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/Epistrophy_d1.mid.npy (deflated 97%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/I Can't Give You Anything But Love_p6.mid.ans.npy (deflated 99%)
#   adding: preprocessed_dataset/irealpro_dataset_v2_simple/Black Narcissus_p6.mid.ans.npy (deflated 99%)
# ...
