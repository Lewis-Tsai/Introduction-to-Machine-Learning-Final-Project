# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')

# %%
EXPERIMENT_DIR = "experiments/08_BDLSTM_1024-50/"

BATCH_SIZE = 512
PIECE_LEN = 1024
n_feature = 43
n_hidden = 50
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1024, 43)]        0
#
#  mask (Masking)              (None, 1024, 43)          0
#
#  input (TimeDistributed)     (None, 1024, 50)          2200
#
#  bidirectional_7 (Bidirectio  (None, 1024, 100)        40400
#  nal)
#
#  output (TimeDistributed)    (None, 1024, 53)          5353
#
# =================================================================
# Total params: 47,953
# Trainable params: 47,953
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/08_BDLSTM_1024-50'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
train_start = time.time()
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)

print(time.time() - train_start)
# Out:
# Epoch 1 Loss 2.7681 Acc 0.1448
# Validation Loss 2.4583 Acc 0.1610
# Time taken for 1 epoch 172.46367049217224 sec
#
# Epoch 2 Loss 2.3048 Acc 0.1927
# Validation Loss 2.2594 Acc 0.1790
# Time taken for 1 epoch 10.296771049499512 sec
#
# Epoch 3 Loss 2.1789 Acc 0.2034
# Validation Loss 2.1975 Acc 0.1882
# Time taken for 1 epoch 10.203529119491577 sec
#
# Epoch 4 Loss 2.1271 Acc 0.2094
# Validation Loss 2.1662 Acc 0.1921
# Time taken for 1 epoch 10.316275835037231 sec
#
# Epoch 5 Loss 2.0973 Acc 0.2131
# Validation Loss 2.1434 Acc 0.1950
# Time taken for 1 epoch 10.267023801803589 sec
#
# Epoch 6 Loss 2.0755 Acc 0.2158
# Validation Loss 2.1259 Acc 0.1964
# Time taken for 1 epoch 10.277411699295044 sec
#
# Epoch 7 Loss 2.0590 Acc 0.2176
# Validation Loss 2.1085 Acc 0.1986
# Time taken for 1 epoch 10.327717304229736 sec
#
# Epoch 8 Loss 2.0456 Acc 0.2194
# Validation Loss 2.0981 Acc 0.1993
# Time taken for 1 epoch 10.308083534240723 sec
#
# Epoch 9 Loss 2.0340 Acc 0.2206
# Validation Loss 2.0857 Acc 0.2016
# Time taken for 1 epoch 10.337142944335938 sec
#
# Epoch 10 Loss 2.0247 Acc 0.2218
# Validation Loss 2.0741 Acc 0.2033
# Time taken for 1 epoch 10.331419706344604 sec
#
# Epoch 11 Loss 2.0157 Acc 0.2230
# Validation Loss 2.0666 Acc 0.2051
# Time taken for 1 epoch 10.321659088134766 sec
#
# Epoch 12 Loss 2.0086 Acc 0.2237
# Validation Loss 2.0591 Acc 0.2055
# Time taken for 1 epoch 10.284241914749146 sec
#
# Epoch 13 Loss 2.0016 Acc 0.2250
# Validation Loss 2.0533 Acc 0.2079
# Time taken for 1 epoch 10.317505359649658 sec
#
# Epoch 14 Loss 1.9962 Acc 0.2259
# Validation Loss 2.0530 Acc 0.2064
# Time taken for 1 epoch 10.305806159973145 sec
#
# Epoch 15 Loss 1.9927 Acc 0.2266
# Validation Loss 2.0451 Acc 0.2090
# Time taken for 1 epoch 10.356830358505249 sec
#
# Epoch 16 Loss 1.9867 Acc 0.2274
# Validation Loss 2.0376 Acc 0.2109
# Time taken for 1 epoch 10.316906690597534 sec
#
# Epoch 17 Loss 1.9824 Acc 0.2280
# Validation Loss 2.0381 Acc 0.2103
# Time taken for 1 epoch 10.354233264923096 sec
#
# Epoch 18 Loss 1.9805 Acc 0.2285
# Validation Loss 2.0335 Acc 0.2123
# Time taken for 1 epoch 10.344078540802002 sec
#
# Epoch 19 Loss 1.9755 Acc 0.2298
# Validation Loss 2.0233 Acc 0.2145
# Time taken for 1 epoch 10.340210199356079 sec
#
# Epoch 20 Loss 1.9712 Acc 0.2304
# Validation Loss 2.0214 Acc 0.2171
# Time taken for 1 epoch 10.340291976928711 sec
#
# Epoch 21 Loss 1.9674 Acc 0.2314
# Validation Loss 2.0140 Acc 0.2192
# Time taken for 1 epoch 10.318292617797852 sec
#
# Epoch 22 Loss 1.9623 Acc 0.2329
# Validation Loss 2.0096 Acc 0.2214
# Time taken for 1 epoch 10.311110258102417 sec
#
# Epoch 23 Loss 1.9589 Acc 0.2339
# Validation Loss 2.0047 Acc 0.2219
# Time taken for 1 epoch 10.330776453018188 sec
#
# Epoch 24 Loss 1.9562 Acc 0.2350
# Validation Loss 2.0015 Acc 0.2245
# Time taken for 1 epoch 10.375975370407104 sec
#
# Epoch 25 Loss 1.9533 Acc 0.2357
# Validation Loss 1.9991 Acc 0.2218
# Time taken for 1 epoch 10.333484172821045 sec
#
# Epoch 26 Loss 1.9480 Acc 0.2377
# Validation Loss 1.9912 Acc 0.2255
# Time taken for 1 epoch 10.336691856384277 sec
#
# Epoch 27 Loss 1.9429 Acc 0.2391
# Validation Loss 2.0152 Acc 0.2205
# Time taken for 1 epoch 10.343514680862427 sec
#
# Epoch 28 Loss 1.9409 Acc 0.2400
# Validation Loss 1.9814 Acc 0.2269
# Time taken for 1 epoch 10.340595960617065 sec
#
# Epoch 29 Loss 1.9481 Acc 0.2381
# Validation Loss 2.0151 Acc 0.2137
# Time taken for 1 epoch 10.32891035079956 sec
#
# Epoch 30 Loss 1.9396 Acc 0.2424
# Validation Loss 1.9818 Acc 0.2264
# Time taken for 1 epoch 10.293751239776611 sec
#
# Epoch 31 Loss 1.9359 Acc 0.2419
# Validation Loss 1.9983 Acc 0.2176
# Time taken for 1 epoch 10.329434633255005 sec
#
# Epoch 32 Loss 1.9285 Acc 0.2450
# Validation Loss 1.9768 Acc 0.2244
# Time taken for 1 epoch 10.36496353149414 sec
#
# Epoch 33 Loss 1.9289 Acc 0.2448
# Validation Loss 1.9693 Acc 0.2286
# Time taken for 1 epoch 10.353665113449097 sec
#
# Epoch 34 Loss 1.9211 Acc 0.2471
# Validation Loss 1.9666 Acc 0.2371
# Time taken for 1 epoch 10.34653639793396 sec
#
# Epoch 35 Loss 1.9190 Acc 0.2475
# Validation Loss 2.0010 Acc 0.2246
# Time taken for 1 epoch 10.320435047149658 sec
#
# Epoch 36 Loss 1.9213 Acc 0.2458
# Validation Loss 1.9671 Acc 0.2317
# Time taken for 1 epoch 10.347410678863525 sec
#
# Epoch 37 Loss 1.9070 Acc 0.2518
# Validation Loss 1.9613 Acc 0.2375
# Time taken for 1 epoch 10.332249402999878 sec
#
# Epoch 38 Loss 1.9156 Acc 0.2486
# Validation Loss 1.9790 Acc 0.2260
# Time taken for 1 epoch 10.278325080871582 sec
#
# Epoch 39 Loss 1.9132 Acc 0.2502
# Validation Loss 1.9651 Acc 0.2285
# Time taken for 1 epoch 10.34346604347229 sec
#
# Epoch 40 Loss 1.9109 Acc 0.2504
# Validation Loss 1.9735 Acc 0.2308
# Time taken for 1 epoch 10.330134630203247 sec
#
# Epoch 41 Loss 1.9080 Acc 0.2513
# Validation Loss 1.9535 Acc 0.2345
# Time taken for 1 epoch 10.31481671333313 sec
#
# Epoch 42 Loss 1.8965 Acc 0.2546
# Validation Loss 1.9494 Acc 0.2362
# Time taken for 1 epoch 10.326328754425049 sec
#
# Epoch 43 Loss 1.8945 Acc 0.2551
# Validation Loss 1.9474 Acc 0.2351
# Time taken for 1 epoch 10.369774341583252 sec
#
# Epoch 44 Loss 1.8932 Acc 0.2552
# Validation Loss 1.9599 Acc 0.2327
# Time taken for 1 epoch 10.334748268127441 sec
#
# Epoch 45 Loss 1.8961 Acc 0.2547
# Validation Loss 1.9427 Acc 0.2406
# Time taken for 1 epoch 10.32813835144043 sec
#
# Epoch 46 Loss 1.8854 Acc 0.2576
# Validation Loss 1.9412 Acc 0.2418
# Time taken for 1 epoch 10.319868326187134 sec
#
# Epoch 47 Loss 1.8972 Acc 0.2540
# Validation Loss 1.9401 Acc 0.2409
# Time taken for 1 epoch 10.311156272888184 sec
#
# Epoch 48 Loss 1.8854 Acc 0.2581
# Validation Loss 1.9391 Acc 0.2404
# Time taken for 1 epoch 10.320564031600952 sec
#
# Epoch 49 Loss 1.8792 Acc 0.2596
# Validation Loss 1.9356 Acc 0.2424
# Time taken for 1 epoch 10.346575021743774 sec
#
# Epoch 50 Loss 1.8784 Acc 0.2596
# Validation Loss 1.9355 Acc 0.2417
# Time taken for 1 epoch 10.348925113677979 sec
#
# Epoch 51 Loss 1.8853 Acc 0.2574
# Validation Loss 1.9887 Acc 0.2237
# Time taken for 1 epoch 10.341611862182617 sec
#
# Epoch 52 Loss 1.8981 Acc 0.2543
# Validation Loss 1.9452 Acc 0.2361
# Time taken for 1 epoch 10.371144533157349 sec
#
# Epoch 53 Loss 1.8793 Acc 0.2598
# Validation Loss 1.9355 Acc 0.2411
# Time taken for 1 epoch 10.315939664840698 sec
#
# Epoch 54 Loss 1.8762 Acc 0.2605
# Validation Loss 1.9331 Acc 0.2422
# Time taken for 1 epoch 10.288695812225342 sec
#
# Epoch 55 Loss 1.8757 Acc 0.2605
# Validation Loss 1.9331 Acc 0.2416
# Time taken for 1 epoch 10.386443614959717 sec
#
# Epoch 56 Loss 1.8744 Acc 0.2609
# Validation Loss 1.9314 Acc 0.2422
# Time taken for 1 epoch 10.33055567741394 sec
#
# Epoch 57 Loss 1.8721 Acc 0.2615
# Validation Loss 1.9308 Acc 0.2422
# Time taken for 1 epoch 10.335710763931274 sec
#
# Epoch 58 Loss 1.8717 Acc 0.2616
# Validation Loss 1.9304 Acc 0.2426
# Time taken for 1 epoch 10.335602045059204 sec
#
# Epoch 59 Loss 1.8693 Acc 0.2623
# Validation Loss 1.9293 Acc 0.2437
# Time taken for 1 epoch 10.346737146377563 sec
#
# Epoch 60 Loss 1.8710 Acc 0.2615
# Validation Loss 1.9299 Acc 0.2426
# Time taken for 1 epoch 10.632880449295044 sec
#
# Epoch 61 Loss 1.8694 Acc 0.2621
# Validation Loss 1.9298 Acc 0.2420
# Time taken for 1 epoch 10.382452249526978 sec
#
# Epoch 62 Loss 1.8674 Acc 0.2626
# Validation Loss 1.9289 Acc 0.2433
# Time taken for 1 epoch 10.350441217422485 sec
#
# Epoch 63 Loss 1.8659 Acc 0.2630
# Validation Loss 1.9287 Acc 0.2430
# Time taken for 1 epoch 10.359193563461304 sec
#
# Epoch 64 Loss 1.8658 Acc 0.2630
# Validation Loss 1.9272 Acc 0.2424
# Time taken for 1 epoch 10.329005241394043 sec
#
# Epoch 65 Loss 1.8645 Acc 0.2634
# Validation Loss 1.9266 Acc 0.2435
# Time taken for 1 epoch 10.335608005523682 sec
#
# Epoch 66 Loss 1.8673 Acc 0.2625
# Validation Loss 1.9349 Acc 0.2420
# Time taken for 1 epoch 10.3542160987854 sec
#
# Epoch 67 Loss 1.8695 Acc 0.2622
# Validation Loss 1.9273 Acc 0.2434
# Time taken for 1 epoch 10.344249486923218 sec
#
# Epoch 68 Loss 1.8632 Acc 0.2636
# Validation Loss 1.9261 Acc 0.2426
# Time taken for 1 epoch 10.359155416488647 sec
#
# Epoch 69 Loss 1.8616 Acc 0.2638
# Validation Loss 1.9254 Acc 0.2430
# Time taken for 1 epoch 10.283069849014282 sec
#
# Epoch 70 Loss 1.8605 Acc 0.2640
# Validation Loss 1.9238 Acc 0.2426
# Time taken for 1 epoch 10.381587505340576 sec
#
# Epoch 71 Loss 1.8602 Acc 0.2641
# Validation Loss 1.9230 Acc 0.2432
# Time taken for 1 epoch 10.294177293777466 sec
#
# Epoch 72 Loss 1.8587 Acc 0.2644
# Validation Loss 1.9225 Acc 0.2444
# Time taken for 1 epoch 10.34904408454895 sec
#
# Epoch 73 Loss 1.8566 Acc 0.2651
# Validation Loss 1.9389 Acc 0.2394
# Time taken for 1 epoch 10.360366821289062 sec
#
# Epoch 74 Loss 1.8842 Acc 0.2567
# Validation Loss 1.9301 Acc 0.2426
# Time taken for 1 epoch 10.333764791488647 sec
#
# Epoch 75 Loss 1.8672 Acc 0.2616
# Validation Loss 1.9225 Acc 0.2435
# Time taken for 1 epoch 10.35990023612976 sec
#
# Epoch 76 Loss 1.8566 Acc 0.2652
# Validation Loss 1.9263 Acc 0.2432
# Time taken for 1 epoch 10.369200468063354 sec
#
# Epoch 77 Loss 1.8547 Acc 0.2656
# Validation Loss 1.9215 Acc 0.2442
# Time taken for 1 epoch 10.388672113418579 sec
#
# Epoch 78 Loss 1.8564 Acc 0.2650
# Validation Loss 1.9253 Acc 0.2402
# Time taken for 1 epoch 10.314528942108154 sec
#
# Epoch 79 Loss 1.8554 Acc 0.2653
# Validation Loss 1.9215 Acc 0.2431
# Time taken for 1 epoch 10.36539363861084 sec
#
# Epoch 80 Loss 1.8592 Acc 0.2639
# Validation Loss 1.9443 Acc 0.2344
# Time taken for 1 epoch 10.376280307769775 sec
#
# Epoch 81 Loss 1.8809 Acc 0.2572
# Validation Loss 1.9482 Acc 0.2384
# Time taken for 1 epoch 10.352853536605835 sec
#
# Epoch 82 Loss 1.8658 Acc 0.2640
# Validation Loss 1.9261 Acc 0.2436
# Time taken for 1 epoch 10.349289655685425 sec
#
# Epoch 83 Loss 1.8622 Acc 0.2643
# Validation Loss 1.9234 Acc 0.2432
# Time taken for 1 epoch 10.393787860870361 sec
#
# Epoch 84 Loss 1.8603 Acc 0.2644
# Validation Loss 1.9474 Acc 0.2370
# Time taken for 1 epoch 10.311699628829956 sec
#
# Epoch 85 Loss 1.8580 Acc 0.2646
# Validation Loss 1.9391 Acc 0.2390
# Time taken for 1 epoch 10.310267210006714 sec
#
# Epoch 86 Loss 1.8847 Acc 0.2558
# Validation Loss 1.9293 Acc 0.2409
# Time taken for 1 epoch 10.367972135543823 sec
#
# Epoch 87 Loss 1.8564 Acc 0.2653
# Validation Loss 1.9187 Acc 0.2450
# Time taken for 1 epoch 10.362910747528076 sec
#
# Epoch 88 Loss 1.8569 Acc 0.2652
# Validation Loss 1.9179 Acc 0.2451
# Time taken for 1 epoch 10.32076644897461 sec
#
# Epoch 89 Loss 1.8516 Acc 0.2663
# Validation Loss 1.9257 Acc 0.2432
# Time taken for 1 epoch 10.339173316955566 sec
#
# Epoch 90 Loss 1.8607 Acc 0.2628
# Validation Loss 1.9244 Acc 0.2434
# Time taken for 1 epoch 10.308259963989258 sec
#
# Epoch 91 Loss 1.8491 Acc 0.2667
# Validation Loss 1.9279 Acc 0.2421
# Time taken for 1 epoch 10.328782081604004 sec
#
# Epoch 92 Loss 1.8504 Acc 0.2661
# Validation Loss 1.9168 Acc 0.2443
# Time taken for 1 epoch 10.342323780059814 sec
#
# Epoch 93 Loss 1.8525 Acc 0.2656
# Validation Loss 1.9240 Acc 0.2424
# Time taken for 1 epoch 10.385330200195312 sec
#
# Epoch 94 Loss 1.9208 Acc 0.2456
# Validation Loss 1.9471 Acc 0.2384
# Time taken for 1 epoch 10.353260278701782 sec
#
# Epoch 95 Loss 1.8708 Acc 0.2627
# Validation Loss 1.9283 Acc 0.2432
# Time taken for 1 epoch 10.32469391822815 sec
#
# Epoch 96 Loss 1.8597 Acc 0.2652
# Validation Loss 1.9273 Acc 0.2435
# Time taken for 1 epoch 10.325793981552124 sec
#
# Epoch 97 Loss 1.8752 Acc 0.2606
# Validation Loss 2.0234 Acc 0.2195
# Time taken for 1 epoch 10.352075576782227 sec
#
# Epoch 98 Loss 1.9292 Acc 0.2455
# Validation Loss 1.9678 Acc 0.2332
# Time taken for 1 epoch 10.389994144439697 sec
#
# Epoch 99 Loss 1.9067 Acc 0.2527
# Validation Loss 1.9556 Acc 0.2343
# Time taken for 1 epoch 10.317025899887085 sec
#
# Epoch 100 Loss 1.8942 Acc 0.2561
# Validation Loss 1.9503 Acc 0.2334
# Time taken for 1 epoch 10.303263664245605 sec
#
# 1196.492071390152

# %% [markdown]
# 19m 56.5s used

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 32ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1536, 53)
