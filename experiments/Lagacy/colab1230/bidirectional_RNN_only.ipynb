# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp -r /content/drive/MyDrive/ML_Final_Project/midi_np_translation .
! cp -r /content/drive/MyDrive/ML_Final_Project/preprocessed_dataset .
! cp -r /content/drive/MyDrive/ML_Final_Project/input_midi .

# %%
! unzip /content/preprocessed_dataset/irealpro_midi.zip
! unzip /content/input_midi/irealpro_transposed.zip
! pip install pretty_midi
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: irealpro_midi/Four In One_d2.mid.npy
#   inflating: irealpro_midi/Fly Me To The Moon_o0.mid.ans.npy
#   inflating: irealpro_midi/Heyoke_p6.mid.npy
#   inflating: irealpro_midi/Ecaroh_p2.mid.npy
#   inflating: irealpro_midi/52nd Street Theme_p4.mid.ans.npy
#   inflating: irealpro_midi/All Of You_o0.mid.ans.npy
#   inflating: irealpro_midi/A Kiss To Build A Dream On_d1.mid.ans.npy
#   inflating: irealpro_midi/Freckle Face_p5.mid.npy
#   inflating: irealpro_midi/Day In, Day Out_d2.mid.ans.npy
#   inflating: irealpro_midi/Evidence_p1.mid.ans.npy
#   inflating: irealpro_midi/Copenhagen_d5.mid.ans.npy
#   inflating: irealpro_midi/Heart And Soul_p1.mid.npy
#   inflating: irealpro_midi/I May Be Wrong_d3.mid.npy
#   inflating: irealpro_midi/I'm Old Fashioned_p6.mid.ans.npy
#   inflating: irealpro_midi/I Found A New Baby_d2.mid.npy
#   inflating: irealpro_midi/As Long As I Live_d3.mid.npy
#   inflating: irealpro_midi/Good Bait_p6.mid.npy
#   inflating: irealpro_midi/A Foggy Day_p5.mid.ans.npy
#   inflating: irealpro_midi/Dream Dancing_p3.mid.npy
#   inflating: irealpro_midi/I May Be Wrong_p3.mid.ans.npy
#   inflating: irealpro_midi/In Love In Vain_p3.mid.ans.npy
#   inflating: irealpro_midi/I'll Remember April_p5.mid.npy
#   inflating: irealpro_midi/If You Ever Should Leave_p2.mid.ans.npy
#   inflating: irealpro_midi/Flying Home_p1.mid.ans.npy
#   inflating: irealpro_midi/502 Blues_d1.mid.npy
#   inflating: irealpro_midi/I'll Only Miss Her When I Think Of Her_d2.mid.npy
#   inflating: irealpro_midi/A Foggy Day_d3.mid.npy
#   inflating: irealpro_midi/The Frim Fram Sauce_d2.mid.ans.npy
#   inflating: irealpro_midi/Begin The Beguine_p1.mid.npy
#   inflating: irealpro_midi/Alfie's Theme_d4.mid.npy
#   inflating: irealpro_midi/I'm All Smiles_p5.mid.ans.npy
#   inflating: irealpro_midi/Don't Be That Way_p3.mid.ans.npy
#   inflating: irealpro_midi/As Long As I Live_p4.mid.ans.npy
#   inflating: irealpro_midi/A Taste Of Honey_o0.mid.ans.npy
#   inflating: irealpro_midi/Booker's Waltz_p5.mid.npy
#   inflating: irealpro_midi/If I Should Lose You_p2.mid.ans.npy
#   inflating: irealpro_midi/Cyclic Episode_p4.mid.npy
#   inflating: irealpro_midi/I'm Sitting On Top Of The World_p1.mid.npy
#   inflating: irealpro_midi/Conception_d3.mid.npy
#   inflating: irealpro_midi/Elora_d1.mid.ans.npy
#   inflating: irealpro_midi/Django_o0.mid.npy
#   inflating: irealpro_midi/Freddie Freeloader_p4.mid.npy
#   inflating: irealpro_midi/I Mean You_p3.mid.npy
#   inflating: irealpro_midi/Golden Earring_d5.mid.npy
#   inflating: irealpro_midi/Copenhagen_o0.mid.ans.npy
#   inflating: irealpro_midi/Crisis_p1.mid.npy
#   inflating: irealpro_midi/All Of You_p3.mid.npy
#   inflating: irealpro_midi/Cute_p4.mid.npy
#   inflating: irealpro_midi/All Of You_d5.mid.ans.npy
#   inflating: irealpro_midi/I Used To Be Color Blind_d4.mid.npy
#   inflating: irealpro_midi/Close Your Eyes_p6.mid.ans.npy
#   inflating: irealpro_midi/A Pretty Girl Is Like A Melody_p6.mid.ans.npy
#   inflating: irealpro_midi/Day In, Day Out_p5.mid.npy
#   inflating: irealpro_midi/I Can't Believe...You're In Love..._d2.mid.ans.npy
#   inflating: irealpro_midi/Hackensack_d3.mid.ans.npy
#   inflating: irealpro_midi/Backstage Sally_p1.mid.ans.npy
#   inflating: irealpro_midi/Hallelujah I Just Love Him So_o0.mid.npy
#   inflating: irealpro_midi/A Certain Smile_d3.mid.ans.npy
#   inflating: irealpro_midi/Baubles, Bangles and Beads_d2.mid.npy
#   inflating: irealpro_midi/Fly Me To The Moon_d5.mid.ans.npy
#   inflating: irealpro_midi/Bidin' My Time_o0.mid.ans.npy
#   inflating: irealpro_midi/I've Heard That Song Before_d5.mid.ans.npy
#   inflating: irealpro_midi/If I Didn't Care_d2.mid.npy
#   inflating: irealpro_midi/Black Narcissus_p6.mid.npy
#   inflating: irealpro_midi/I Don't Want To Miss Mississippi_d3.mid.npy
#   inflating: irealpro_midi/I'm Sitting On Top Of The World_p3.mid.npy
#   inflating: irealpro_midi/Cyclic Episode_p6.mid.npy
#   inflating: irealpro_midi/Glad To Be Unhappy_p5.mid.npy
#   inflating: irealpro_midi/Down By The Riverside_d4.mid.npy
#   inflating: irealpro_midi/Cottage For Sale_p5.mid.npy
#   inflating: irealpro_midi/Conception_d1.mid.npy
#   inflating: irealpro_midi/Blue Sphere_d4.mid.ans.npy
# ...
#   inflating: irealpro_transposed/In Love In Vain_d5.mid
#   inflating: irealpro_transposed/Blueberry Hill_p5.mid
#   inflating: irealpro_transposed/I Got The Sun In The Morning_d1.mid
#   inflating: irealpro_transposed/I've Heard That Song Before_d1.mid
#   inflating: irealpro_transposed/I Used To Be Color Blind_p1.mid
#   inflating: irealpro_transposed/I Let A Song Go Out Of My Heart_d5.mid
#   inflating: irealpro_transposed/Dream Dancing_p5.mid
#   inflating: irealpro_transposed/Hello Dolly_d5.mid
#   inflating: irealpro_transposed/I'll Never Be The Same_p2.mid
#   inflating: irealpro_transposed/Blues Five Spot_p6.mid
#   inflating: irealpro_transposed/Cute_d1.mid
#   inflating: irealpro_transposed/Along Came Betty_p6.mid
#   inflating: irealpro_transposed/I Wish You Love_p3.mid
#   inflating: irealpro_transposed/Brilliant Corners_p4.mid
#   inflating: irealpro_transposed/Cute_d3.mid
#   inflating: irealpro_transposed/Blue (And Broken Hearted)_d4.mid
#   inflating: irealpro_transposed/Blues Five Spot_p4.mid
#   inflating: irealpro_transposed/All Blues_d5.mid
#   inflating: irealpro_transposed/Brilliant Corners_p6.mid
#   inflating: irealpro_transposed/I Wish You Love_p1.mid
#   inflating: irealpro_transposed/Along Came Betty_p4.mid
#   inflating: irealpro_transposed/High Fly_d5.mid
#   inflating: irealpro_transposed/Booker's Waltz_d4.mid
#   inflating: irealpro_transposed/Emily_p5.mid
#   inflating: irealpro_transposed/I've Found A New Baby_p2.mid
#   inflating: irealpro_transposed/Flying Home_d2.mid
#   inflating: irealpro_transposed/As Long As I Live_p2.mid
#   inflating: irealpro_transposed/I Used To Be Color Blind_p3.mid
#   inflating: irealpro_transposed/The Duke_p5.mid
#   inflating: irealpro_transposed/I've Heard That Song Before_d3.mid
#   inflating: irealpro_transposed/I Got The Sun In The Morning_d3.mid
#   inflating: irealpro_transposed/Am I Blue__d3.mid
#   inflating: irealpro_transposed/Easy Street_d5.mid
#   inflating: irealpro_transposed/Boplicity_p4.mid
#   inflating: irealpro_transposed/Baubles, Bangles and Beads_p4.mid
#   inflating: irealpro_transposed/Horace-Scope_d3.mid
#   inflating: irealpro_transposed/Gloria's Step_p1.mid
#   inflating: irealpro_transposed/Ecaroh_p5.mid
#   inflating: irealpro_transposed/Deep Purple_p1.mid
#   inflating: irealpro_transposed/Contemplation_p1.mid
#   inflating: irealpro_transposed/In A Little Spanish Town_d3.mid
#   inflating: irealpro_transposed/Down By The Riverside_d1.mid
#   inflating: irealpro_transposed/Butterfly Dreams_o0.mid
#   inflating: irealpro_transposed/A Kiss To Build A Dream On_p2.mid
#   inflating: irealpro_transposed/9.20 Special_p5.mid
#   inflating: irealpro_transposed/I've Never Been In Love Before_d3.mid
#   inflating: irealpro_transposed/Call Me Irresponsible_d1.mid
#   inflating: irealpro_transposed/I'll Get By (As Long As I Have You)_d1.mid
#   inflating: irealpro_transposed/He's A Tramp_p2.mid
#   inflating: irealpro_transposed/Freddie Freeloader_p3.mid
#   inflating: irealpro_transposed/Gloria's Step_d4.mid
#   inflating: irealpro_transposed/Horace-Scope_p6.mid
#   inflating: irealpro_transposed/Am I Blue__p6.mid
#   inflating: irealpro_transposed/A Foggy Day_p5.mid
#   inflating: irealpro_transposed/Baubles, Bangles and Beads_d1.mid
#   inflating: irealpro_transposed/Boplicity_d1.mid
#   inflating: irealpro_transposed/In A Little Spanish Town_p6.mid
#   inflating: irealpro_transposed/Down By The Riverside_p4.mid
#   inflating: irealpro_transposed/Deep Purple_d4.mid
#   inflating: irealpro_transposed/Contemplation_d4.mid
#   inflating: irealpro_transposed/I'll Get By (As Long As I Have You)_p4.mid
#   inflating: irealpro_transposed/I Wish I Were In Love Again_d2.mid
#   inflating: irealpro_transposed/I've Never Been In Love Before_p6.mid
#   inflating: irealpro_transposed/A Child Is Born_o0.mid
#   inflating: irealpro_transposed/Call Me Irresponsible_p4.mid
#   inflating: irealpro_transposed/I'll Never Be The Same_d5.mid
#   inflating: irealpro_transposed/Hello Dolly_p2.mid
#   inflating: irealpro_transposed/Blue (And Broken Hearted)_p1.mid
#   inflating: irealpro_transposed/Cute_p6.mid
#   inflating: irealpro_transposed/Blues Five Spot_d1.mid
#   inflating: irealpro_transposed/Along Came Betty_d1.mid
#   inflating: irealpro_transposed/Brilliant Corners_d3.mid
#   inflating: irealpro_transposed/I Wish You Love_d4.mid
#   inflating: irealpro_transposed/In Love In Vain_p2.mid
#   inflating: irealpro_transposed/Booker's Waltz_p1.mid
#   inflating: irealpro_transposed/I've Heard That Song Before_p6.mid
#   inflating: irealpro_transposed/I Got The Sun In The Morning_p6.mid
#   inflating: irealpro_transposed/Blueberry Hill_d2.mid
#   inflating: irealpro_transposed/I Let A Song Go Out Of My Heart_p2.mid
#   inflating: irealpro_transposed/Dream Dancing_d2.mid
#   inflating: irealpro_transposed/I Can't Believe...You're In Love..._p6.mid
#   inflating: irealpro_transposed/I Think Of You_o0.mid
#   inflating: irealpro_transposed/Don't Fence Me In_d3.mid
#   inflating: irealpro_transposed/I'll Remember April_p1.mid
#   inflating: irealpro_transposed/I've Got My Love To Keep Me Warm_p3.mid
#   inflating: irealpro_transposed/All Alone_o0.mid
#   inflating: irealpro_transposed/Criss Cross_d1.mid
#   inflating: irealpro_transposed/Cheryl_d2.mid
#   inflating: irealpro_transposed/Cheers_p1.mid
#   inflating: irealpro_transposed/And The Angels Sing_d1.mid
#   inflating: irealpro_transposed/I Was Doing All Right_p1.mid
#   inflating: irealpro_transposed/Cyclic Episode_p3.mid
#   inflating: irealpro_transposed/Alice In Wonderland_p2.mid
#   inflating: irealpro_transposed/Full House_d5.mid
#   inflating: irealpro_transposed/The Best Is Yet To Come (Page 1)_p6.mid
#   inflating: irealpro_transposed/Boo Boo's Birthday_p2.mid
#   inflating: irealpro_transposed/Blue Monk_p6.mid
#   inflating: irealpro_transposed/502 Blues_d3.mid
#   inflating: irealpro_transposed/Fascination_d1.mid
#   inflating: irealpro_transposed/I Mean You_p4.mid
#   inflating: irealpro_transposed/Alone Together_p2.mid
#   inflating: irealpro_transposed/Don't Misunderstand_d2.mid
#   inflating: irealpro_transposed/I'll Close My Eyes_d4.mid
#   inflating: irealpro_transposed/Get Out Of Town_d1.mid
#   inflating: irealpro_transposed/I Didn't Know What Time It Was_p1.mid
#   inflating: irealpro_transposed/Better Than Anything_p5.mid
#   inflating: irealpro_transposed/Beyond The Sea_d5.mid
#   inflating: irealpro_transposed/Daybreak_d5.mid
#   inflating: irealpro_transposed/Fascination_p4.mid
#   inflating: irealpro_transposed/502 Blues_p6.mid
#   inflating: irealpro_transposed/Home Cookin'_d2.mid
#   inflating: irealpro_transposed/Black And Tan Fantasy_p3.mid
#   inflating: irealpro_transposed/The Best Is Yet To Come (Page 1)_d3.mid
#   inflating: irealpro_transposed/Blue Monk_d3.mid
#   inflating: irealpro_transposed/Dienda_o0.mid
#   inflating: irealpro_transposed/All Through The Day_p2.mid
#   inflating: irealpro_transposed/Evidence_d2.mid
#   inflating: irealpro_transposed/Doxy_d2.mid
#   inflating: irealpro_transposed/I Mean You_d1.mid
#   inflating: irealpro_transposed/Deed I Do_p2.mid
#   inflating: irealpro_transposed/Get Out Of Town_p4.mid
#   inflating: irealpro_transposed/Eronel_p2.mid
#   inflating: irealpro_transposed/I Didn't Know What Time It Was_d4.mid
#   inflating: irealpro_transposed/I'll Close My Eyes_p1.mid
#   inflating: irealpro_transposed/In The Cool, Cool, Cool Of The Evening_p3.mid
#   inflating: irealpro_transposed/Confessin' (That I Love You)_o0.mid
#   inflating: irealpro_transposed/I'll Remember April_d4.mid
#   inflating: irealpro_transposed/Don't Fence Me In_p6.mid
#   inflating: irealpro_transposed/Criss Cross_p4.mid
#   inflating: irealpro_transposed/Days Of Wine And Roses_d2.mid
#   inflating: irealpro_transposed/I Can't Believe...You're In Love..._d3.mid
#   inflating: irealpro_transposed/I'm Old Fashioned_d2.mid
#   inflating: irealpro_transposed/Good Bait_p5.mid
#   inflating: irealpro_transposed/And The Angels Sing_p4.mid
#   inflating: irealpro_transposed/Cheers_d4.mid
#   inflating: irealpro_transposed/Driftin'_d2.mid
#   inflating: irealpro_transposed/Blues March_d2.mid
#   inflating: irealpro_transposed/I Was Doing All Right_d4.mid
#   inflating: irealpro_transposed/I'm All Smiles_p5.mid
#   inflating: irealpro_transposed/Full House_p1.mid
#   inflating: irealpro_transposed/I'm All Smiles_p4.mid
#   inflating: irealpro_transposed/I Was Doing All Right_d5.mid
#   inflating: irealpro_transposed/Cheers_d5.mid
#   inflating: irealpro_transposed/And The Angels Sing_p5.mid
#   inflating: irealpro_transposed/Cheryl_p6.mid
#   inflating: irealpro_transposed/Blues March_d3.mid
#   inflating: irealpro_transposed/Driftin'_d3.mid
#   inflating: irealpro_transposed/Criss Cross_p5.mid
#   inflating: irealpro_transposed/I'll Remember April_d5.mid
#   inflating: irealpro_transposed/Good Bait_p4.mid
#   inflating: irealpro_transposed/I'm Old Fashioned_d3.mid
#   inflating: irealpro_transposed/Days Of Wine And Roses_d3.mid
#   inflating: irealpro_transposed/I Can't Believe...You're In Love..._d2.mid
#   inflating: irealpro_transposed/In The Cool, Cool, Cool Of The Evening_p2.mid
#   inflating: irealpro_transposed/Beyond The Sea_p1.mid
#   inflating: irealpro_transposed/Daybreak_p1.mid
#   inflating: irealpro_transposed/Better Than Anything_d1.mid
#   inflating: irealpro_transposed/I Didn't Know What Time It Was_d5.mid
#   inflating: irealpro_transposed/Eronel_p3.mid
#   inflating: irealpro_transposed/Get Out Of Town_p5.mid
#   inflating: irealpro_transposed/Deed I Do_p3.mid
#   inflating: irealpro_transposed/Doxy_d3.mid
#   inflating: irealpro_transposed/Don't Misunderstand_p6.mid
#   inflating: irealpro_transposed/Evidence_d3.mid
#   inflating: irealpro_transposed/All Through The Day_p3.mid
#   inflating: irealpro_transposed/Fascination_p5.mid
#   inflating: irealpro_transposed/Blue Monk_d2.mid
#   inflating: irealpro_transposed/The Best Is Yet To Come (Page 1)_d2.mid
#   inflating: irealpro_transposed/Black And Tan Fantasy_p2.mid
#   inflating: irealpro_transposed/Home Cookin'_d3.mid
#   inflating: irealpro_transposed/Daybreak_d4.mid
#   inflating: irealpro_transposed/Beyond The Sea_d4.mid
#   inflating: irealpro_transposed/I'll Close My Eyes_d5.mid
#   inflating: irealpro_transposed/Better Than Anything_p4.mid
#   inflating: irealpro_transposed/I Mean You_p5.mid
#   inflating: irealpro_transposed/Don't Misunderstand_d3.mid
#   inflating: irealpro_transposed/Doxy_p6.mid
#   inflating: irealpro_transposed/Alone Together_p3.mid
#   inflating: irealpro_transposed/Evidence_p6.mid
#   inflating: irealpro_transposed/Boo Boo's Birthday_p3.mid
#   inflating: irealpro_transposed/Home Cookin'_p6.mid
#   inflating: irealpro_transposed/502 Blues_d2.mid
#   inflating: irealpro_transposed/Full House_d4.mid
#   inflating: irealpro_transposed/Alice In Wonderland_p3.mid
#   inflating: irealpro_transposed/I'm All Smiles_d1.mid
#   inflating: irealpro_transposed/Cyclic Episode_p2.mid
#   inflating: irealpro_transposed/Blues March_p6.mid
#   inflating: irealpro_transposed/Driftin'_p6.mid
#   inflating: irealpro_transposed/Cheryl_d3.mid
#   inflating: irealpro_transposed/Good Bait_d1.mid
#   inflating: irealpro_transposed/Days Of Wine And Roses_p6.mid
#   inflating: irealpro_transposed/I'm Old Fashioned_p6.mid
#   inflating: irealpro_transposed/I've Got My Love To Keep Me Warm_p2.mid
#   inflating: irealpro_transposed/Don't Fence Me In_d2.mid
#   inflating: irealpro_transposed/Blueberry Hill_d3.mid
#   inflating: irealpro_transposed/The Duke_d1.mid
#   inflating: irealpro_transposed/Dream Dancing_d3.mid
#   inflating: irealpro_transposed/I Let A Song Go Out Of My Heart_p3.mid
#   inflating: irealpro_transposed/Flying Home_p6.mid
#   inflating: irealpro_transposed/Emily_d1.mid
#   inflating: irealpro_transposed/In Love In Vain_p3.mid
#   inflating: irealpro_transposed/High Fly_p1.mid
#   inflating: irealpro_transposed/I Wish You Love_d5.mid
#   inflating: irealpro_transposed/All Blues_p1.mid
#   inflating: irealpro_transposed/Brilliant Corners_d2.mid
#   inflating: irealpro_transposed/Hello Dolly_p3.mid
#   inflating: irealpro_transposed/I'll Never Be The Same_d4.mid
#   inflating: irealpro_transposed/I Wish I Were In Love Again_d3.mid
#   inflating: irealpro_transposed/I'll Get By (As Long As I Have You)_p5.mid
#   inflating: irealpro_transposed/Call Me Irresponsible_p5.mid
#   inflating: irealpro_transposed/9.20 Special_d1.mid
#   inflating: irealpro_transposed/Down By The Riverside_p5.mid
#   inflating: irealpro_transposed/Contemplation_d5.mid
#   inflating: irealpro_transposed/Deep Purple_d5.mid
#   inflating: irealpro_transposed/Ecaroh_d1.mid
#   inflating: irealpro_transposed/Gloria's Step_d5.mid
#   inflating: irealpro_transposed/Easy Street_p1.mid
#   inflating: irealpro_transposed/A Foggy Day_p4.mid
#   inflating: irealpro_transposed/I've Never Been In Love Before_d2.mid
#   inflating: irealpro_transposed/I Wish I Were In Love Again_p6.mid
#   inflating: irealpro_transposed/Freddie Freeloader_p2.mid
#   inflating: irealpro_transposed/He's A Tramp_p3.mid
#   inflating: irealpro_transposed/9.20 Special_p4.mid
#   inflating: irealpro_transposed/A Kiss To Build A Dream On_p3.mid
#   inflating: irealpro_transposed/In A Little Spanish Town_d2.mid
#   inflating: irealpro_transposed/Boplicity_p5.mid
#   inflating: irealpro_transposed/Baubles, Bangles and Beads_p5.mid
#   inflating: irealpro_transposed/A Foggy Day_d1.mid
#   inflating: irealpro_transposed/Easy Street_d4.mid
#   inflating: irealpro_transposed/Am I Blue__d2.mid
#   inflating: irealpro_transposed/Bye-Ya_o0.mid
#   inflating: irealpro_transposed/Ecaroh_p4.mid
#   inflating: irealpro_transposed/Horace-Scope_d2.mid
#   inflating: irealpro_transposed/As Long As I Live_p3.mid
#   inflating: irealpro_transposed/Dream Dancing_p6.mid
#   inflating: irealpro_transposed/Blueberry Hill_p6.mid
#   inflating: irealpro_transposed/I Got The Sun In The Morning_d2.mid
#   inflating: irealpro_transposed/I've Heard That Song Before_d2.mid
#   inflating: irealpro_transposed/I Used To Be Color Blind_p2.mid
#   inflating: irealpro_transposed/The Duke_p4.mid
#   inflating: irealpro_transposed/I've Found A New Baby_p3.mid
#   inflating: irealpro_transposed/Emily_p4.mid
#   inflating: irealpro_transposed/Booker's Waltz_d5.mid
#   inflating: irealpro_transposed/Flying Home_d3.mid
#   inflating: irealpro_transposed/All Blues_d4.mid
#   inflating: irealpro_transposed/High Fly_d4.mid
#   inflating: irealpro_transposed/Along Came Betty_p5.mid
#   inflating: irealpro_transposed/Blues Five Spot_p5.mid
#   inflating: irealpro_transposed/Blue (And Broken Hearted)_d5.mid
#   inflating: irealpro_transposed/Cute_d2.mid
#   inflating: irealpro_transposed/I'll Never Be The Same_p1.mid
#   inflating: irealpro_transposed/Do Nothin' Til You Hear From Me_o0.mid
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.2 MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from pretty_midi) (1.21.6)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pretty_midi) (1.15.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591954 sha256=fa5cdba545b427279d93e30fde63cc0c514fd0d7832ce3acb02d7bb6a53a484b
#   Stored in directory: /root/.cache/pip/wheels/2a/5a/e3/30eeb9a99350f3f7e21258fcb132743eef1a4f49b3505e76b6
# Successfully built pretty-midi
# Installing collected packages: mido, pretty-midi
# Successfully installed mido-1.2.10 pretty-midi-0.2.9

# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation

# %%
BATCH_SIZE = 256
VALIDATION_RATIO = 0.1

PIECE_LEN = 1024
n_feature = 42
n_hidden = 200
n_pitch = 52
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
train_dataset = generate_dataset("/content/irealpro_midi")

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature))(input) # Ignore Padded Data
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax"))(x)
model = tf.keras.Model(inputs=input, outputs=x)

# model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
#                 optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#                 metrics=tf.keras.metrics.CategoricalAccuracy())
print(model.summary())

optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024, 42)]        0
#
#  masking (Masking)           (None, 1024, 42)          0
#
#  bidirectional (Bidirectiona  (None, 1024, 400)        388800
#  l)
#
#  time_distributed (TimeDistr  (None, 1024, 52)         20852
#  ibuted)
#
# =================================================================
# Total params: 409,652
# Trainable params: 409,652
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
! cp -r /content/drive/MyDrive/ML_Final_Project/saved_model/checkpoints_1024 .
! mv checkpoints_1024 checkpoints

# %%
checkpoint_dir = './checkpoints/Bidirectional_LSTM'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
# set the epochs for training
EPOCHS = 200
loss_history = []

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(total_loss / steps_per_epoch)
# Out:
# Epoch 1 Loss 0.2623 Acc 0.6662
# Time taken for 1 epoch 54.379414558410645 sec
#
# Epoch 2 Loss 0.2496 Acc 0.6715
# Time taken for 1 epoch 10.298807382583618 sec
#
# Epoch 3 Loss 0.2467 Acc 0.6728
# Time taken for 1 epoch 9.976363182067871 sec
#
# Epoch 4 Loss 0.2457 Acc 0.6733
# Time taken for 1 epoch 9.762989282608032 sec
#
# Epoch 5 Loss 0.2446 Acc 0.6738
# Time taken for 1 epoch 10.094513893127441 sec
#
# Epoch 6 Loss 0.2445 Acc 0.6738
# Time taken for 1 epoch 9.88956880569458 sec
#
# Epoch 7 Loss 0.2440 Acc 0.6740
# Time taken for 1 epoch 9.684703826904297 sec
#
# Epoch 8 Loss 0.2463 Acc 0.6729
# Time taken for 1 epoch 10.225905895233154 sec
#
# Epoch 9 Loss 0.2473 Acc 0.6723
# Time taken for 1 epoch 9.563478946685791 sec
#
# Epoch 10 Loss 0.2478 Acc 0.6722
# Time taken for 1 epoch 9.561127662658691 sec
#
# Epoch 11 Loss 0.2476 Acc 0.6723
# Time taken for 1 epoch 9.625629901885986 sec
#
# Epoch 12 Loss 0.2445 Acc 0.6737
# Time taken for 1 epoch 9.844700813293457 sec
#
# Epoch 13 Loss 0.2438 Acc 0.6740
# Time taken for 1 epoch 9.894095659255981 sec
#
# Epoch 14 Loss 0.2423 Acc 0.6748
# Time taken for 1 epoch 9.702746629714966 sec
#
# Epoch 15 Loss 0.2411 Acc 0.6752
# Time taken for 1 epoch 9.659388065338135 sec
#
# Epoch 16 Loss 0.2396 Acc 0.6760
# Time taken for 1 epoch 9.863325834274292 sec
#
# Epoch 17 Loss 0.2385 Acc 0.6764
# Time taken for 1 epoch 9.625050783157349 sec
#
# Epoch 18 Loss 0.2382 Acc 0.6766
# Time taken for 1 epoch 9.745988368988037 sec
#
# Epoch 19 Loss 0.2378 Acc 0.6768
# Time taken for 1 epoch 9.6393461227417 sec
#
# Epoch 20 Loss 0.2382 Acc 0.6766
# Time taken for 1 epoch 9.655388593673706 sec
#
# Epoch 21 Loss 0.2381 Acc 0.6767
# Time taken for 1 epoch 9.67290997505188 sec
#
# Epoch 22 Loss 0.2375 Acc 0.6768
# Time taken for 1 epoch 9.931688070297241 sec
#
# Epoch 23 Loss 0.2382 Acc 0.6765
# Time taken for 1 epoch 9.754307508468628 sec
#
# Epoch 24 Loss 0.2390 Acc 0.6760
# Time taken for 1 epoch 9.676063776016235 sec
#
# Epoch 25 Loss 0.2405 Acc 0.6754
# Time taken for 1 epoch 9.777564525604248 sec
#
# Epoch 26 Loss 0.2410 Acc 0.6752
# Time taken for 1 epoch 9.652783632278442 sec
#
# Epoch 27 Loss 0.2434 Acc 0.6741
# Time taken for 1 epoch 10.037224054336548 sec
#
# Epoch 28 Loss 0.2425 Acc 0.6745
# Time taken for 1 epoch 11.697670936584473 sec
#
# Epoch 29 Loss 0.2410 Acc 0.6751
# Time taken for 1 epoch 9.67099666595459 sec
#
# Epoch 30 Loss 0.2383 Acc 0.6764
# Time taken for 1 epoch 9.639663934707642 sec
#
# Epoch 31 Loss 0.2363 Acc 0.6775
# Time taken for 1 epoch 9.64750623703003 sec
#
# Epoch 32 Loss 0.2349 Acc 0.6781
# Time taken for 1 epoch 9.645719528198242 sec
#
# Epoch 33 Loss 0.2334 Acc 0.6787
# Time taken for 1 epoch 9.635111808776855 sec
#
# Epoch 34 Loss 0.2319 Acc 0.6793
# Time taken for 1 epoch 9.64350414276123 sec
#
# Epoch 35 Loss 0.2317 Acc 0.6795
# Time taken for 1 epoch 9.654024839401245 sec
#
# Epoch 36 Loss 0.2317 Acc 0.6795
# Time taken for 1 epoch 9.624122619628906 sec
#
# Epoch 37 Loss 0.2317 Acc 0.6795
# Time taken for 1 epoch 9.640504360198975 sec
#
# Epoch 38 Loss 0.2314 Acc 0.6795
# Time taken for 1 epoch 9.64592957496643 sec
#
# Epoch 39 Loss 0.2321 Acc 0.6792
# Time taken for 1 epoch 9.655542850494385 sec
#
# Epoch 40 Loss 0.2324 Acc 0.6790
# Time taken for 1 epoch 9.636468410491943 sec
#
# Epoch 41 Loss 0.2330 Acc 0.6787
# Time taken for 1 epoch 9.655706644058228 sec
#
# Epoch 42 Loss 0.2337 Acc 0.6785
# Time taken for 1 epoch 9.644924640655518 sec
#
# Epoch 43 Loss 0.2347 Acc 0.6781
# Time taken for 1 epoch 9.64828372001648 sec
#
# Epoch 44 Loss 0.2366 Acc 0.6772
# Time taken for 1 epoch 9.640286445617676 sec
#
# Epoch 45 Loss 0.2382 Acc 0.6764
# Time taken for 1 epoch 9.640637636184692 sec
#
# Epoch 46 Loss 0.2383 Acc 0.6762
# Time taken for 1 epoch 9.636871576309204 sec
#
# Epoch 47 Loss 0.2437 Acc 0.6738
# Time taken for 1 epoch 9.645121335983276 sec
#
# Epoch 48 Loss 0.2466 Acc 0.6727
# Time taken for 1 epoch 9.623262643814087 sec
#
# Epoch 49 Loss 0.2409 Acc 0.6753
# Time taken for 1 epoch 9.65392518043518 sec
#
# Epoch 50 Loss 0.2367 Acc 0.6771
# Time taken for 1 epoch 9.629548072814941 sec
#
# Epoch 51 Loss 0.2323 Acc 0.6791
# Time taken for 1 epoch 9.63823413848877 sec
#
# Epoch 52 Loss 0.2299 Acc 0.6802
# Time taken for 1 epoch 9.719133377075195 sec
#
# Epoch 53 Loss 0.2290 Acc 0.6807
# Time taken for 1 epoch 9.64107370376587 sec
#
# Epoch 54 Loss 0.2278 Acc 0.6813
# Time taken for 1 epoch 9.629468441009521 sec
#
# Epoch 55 Loss 0.2268 Acc 0.6817
# Time taken for 1 epoch 9.62651515007019 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-30e7e9ca9645> in <module>
#      12
#      13     for x, y in train_dataset:
# ---> 14         batch_loss, batch_acc = train_step(x, y)
#      15         total_loss += batch_loss
#      16         total_acc += batch_acc
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.plot(loss_history)

# %%
checkpoint.save(checkpoint_prefix)
# Out:
# './checkpoints/Bidirectional_LSTM/ckpt-2'

# %% [markdown]
# ## predict

# %%
def slice_per_step(a, step=PIECE_LEN):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    pad_count = step - (a.shape[0] % step)
    # print(a.shape, end=' ')
    if pad_count!=step : 
        # print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, step, a.shape[1]))
    # print('to',a.shape)
    return a

# %%
import midi_np_translation.output2midi as output2midi

# %%
PATH = "test_input"
# load np file
test_file = np.load("irealpro_midi/Autumn Leaves_o0.mid.npy")
# test_file_truth = np.load(PATH + "/" + "4on6.mid.ans.npy")
# output2midi.output_to_midi(bass_ndarr=test_file_truth, output_path="4on6_truth.mid")
test_result = model.predict(slice_per_step(test_file))
# test_result = np.argmax(test_result, axis=2)
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="irealpro_transposed/Autumn Leaves_o0.mid", output_path="yo_al.mid")
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
PATH = "test_input"
# load np file
test_file = np.load("irealpro_midi/Fly Me To The Moon_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="irealpro_transposed/Fly Me To The Moon_o0.mid", output_path="moon.mid")
# Out:
# 1/1 [==============================] - 0s 81ms/step

# %% [markdown]
# ## phase 2

# %%
! unzip /content/preprocessed_dataset/dense_jazz.zip
! unzip input_midi/transpose_augmentation.zip

# %%
train_dataset = generate_dataset("/content/dense_jazz/")

# %%
checkpoint_dir = './checkpoints/Bidirectional_LSTM_Real'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
! cp -r "/content/drive/MyDrive/ML_Final_Project/saved_model/checkpoints_1230-1812" .
! mv "checkpoints_1230-1812" "checkpoints"

# %%
checkpoint.restore(checkpoint_prefix+"-1")

# %%
# set the epochs for training
EPOCHS = 200
loss_history = []

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(total_loss / steps_per_epoch)
# Out:
# Epoch 1 Loss 1.0775 Acc 0.4268
# Time taken for 1 epoch 15.457767724990845 sec
#
# Epoch 2 Loss 1.0717 Acc 0.4289
# Time taken for 1 epoch 15.259926557540894 sec
#
# Epoch 3 Loss 1.0725 Acc 0.4285
# Time taken for 1 epoch 14.995627641677856 sec
#
# Epoch 4 Loss 1.0789 Acc 0.4260
# Time taken for 1 epoch 14.830582618713379 sec
#
# Epoch 5 Loss 1.0815 Acc 0.4252
# Time taken for 1 epoch 14.828281879425049 sec
#
# Epoch 6 Loss 1.0723 Acc 0.4290
# Time taken for 1 epoch 14.908663272857666 sec
#
# Epoch 7 Loss 1.0582 Acc 0.4339
# Time taken for 1 epoch 14.986649990081787 sec
#
# Epoch 8 Loss 1.0515 Acc 0.4364
# Time taken for 1 epoch 15.08856987953186 sec
#
# Epoch 9 Loss 1.0359 Acc 0.4420
# Time taken for 1 epoch 14.98063063621521 sec
#
# Epoch 10 Loss 1.0271 Acc 0.4452
# Time taken for 1 epoch 14.909509181976318 sec
#
# Epoch 11 Loss 1.0214 Acc 0.4473
# Time taken for 1 epoch 14.924076318740845 sec
#
# Epoch 12 Loss 1.0182 Acc 0.4484
# Time taken for 1 epoch 14.915481328964233 sec
#
# Epoch 13 Loss 1.0160 Acc 0.4491
# Time taken for 1 epoch 14.951359033584595 sec
#
# Epoch 14 Loss 1.0151 Acc 0.4494
# Time taken for 1 epoch 14.956808805465698 sec
#
# Epoch 15 Loss 1.0143 Acc 0.4495
# Time taken for 1 epoch 14.951860189437866 sec
#
# Epoch 16 Loss 1.0137 Acc 0.4498
# Time taken for 1 epoch 14.958194017410278 sec
#
# Epoch 17 Loss 1.0130 Acc 0.4498
# Time taken for 1 epoch 14.941144704818726 sec
#
# Epoch 18 Loss 1.0130 Acc 0.4500
# Time taken for 1 epoch 14.95488715171814 sec
#
# Epoch 19 Loss 1.0130 Acc 0.4499
# Time taken for 1 epoch 14.945547819137573 sec
#
# Epoch 20 Loss 1.0134 Acc 0.4497
# Time taken for 1 epoch 14.944273471832275 sec
#
# Epoch 21 Loss 1.0137 Acc 0.4497
# Time taken for 1 epoch 14.93211054801941 sec
#
# Epoch 22 Loss 1.0136 Acc 0.4498
# Time taken for 1 epoch 14.928057193756104 sec
#
# Epoch 23 Loss 1.0160 Acc 0.4489
# Time taken for 1 epoch 14.933838844299316 sec
#
# Epoch 24 Loss 1.0148 Acc 0.4493
# Time taken for 1 epoch 14.942517042160034 sec
#
# Epoch 25 Loss 1.0154 Acc 0.4489
# Time taken for 1 epoch 15.008137226104736 sec
#
# Epoch 26 Loss 1.0143 Acc 0.4492
# Time taken for 1 epoch 15.009734153747559 sec
#
# Epoch 27 Loss 1.0136 Acc 0.4496
# Time taken for 1 epoch 14.96490478515625 sec
#
# Epoch 28 Loss 1.0131 Acc 0.4496
# Time taken for 1 epoch 14.962653636932373 sec
#
# Epoch 29 Loss 1.0147 Acc 0.4492
# Time taken for 1 epoch 14.957301616668701 sec
#
# Epoch 30 Loss 1.0178 Acc 0.4480
# Time taken for 1 epoch 14.949403524398804 sec
#
# Epoch 31 Loss 1.0197 Acc 0.4474
# Time taken for 1 epoch 14.973994970321655 sec
#
# Epoch 32 Loss 1.0209 Acc 0.4469
# Time taken for 1 epoch 14.951199531555176 sec
#
# Epoch 33 Loss 1.0220 Acc 0.4467
# Time taken for 1 epoch 14.950804471969604 sec
#
# Epoch 34 Loss 1.0241 Acc 0.4455
# Time taken for 1 epoch 14.963048458099365 sec
#
# Epoch 35 Loss 1.0269 Acc 0.4446
# Time taken for 1 epoch 14.952220678329468 sec
#
# Epoch 36 Loss 1.0291 Acc 0.4438
# Time taken for 1 epoch 14.972769975662231 sec
#
# Epoch 37 Loss 1.0294 Acc 0.4436
# Time taken for 1 epoch 14.95435118675232 sec
#
# Epoch 38 Loss 1.0299 Acc 0.4433
# Time taken for 1 epoch 14.948493242263794 sec
#
# Epoch 39 Loss 1.0302 Acc 0.4435
# Time taken for 1 epoch 14.963315963745117 sec
#
# Epoch 40 Loss 1.0296 Acc 0.4437
# Time taken for 1 epoch 14.963716506958008 sec
#
# Epoch 41 Loss 1.0256 Acc 0.4452
# Time taken for 1 epoch 14.940245866775513 sec
#
# Epoch 42 Loss 1.0220 Acc 0.4464
# Time taken for 1 epoch 15.068696975708008 sec
#
# Epoch 43 Loss 1.0209 Acc 0.4469
# Time taken for 1 epoch 14.9890296459198 sec
#
# Epoch 44 Loss 1.0194 Acc 0.4474
# Time taken for 1 epoch 14.938060998916626 sec
#
# Epoch 45 Loss 1.0199 Acc 0.4472
# Time taken for 1 epoch 14.951109886169434 sec
#
# Epoch 46 Loss 1.0210 Acc 0.4468
# Time taken for 1 epoch 14.9592866897583 sec
#
# Epoch 47 Loss 1.0230 Acc 0.4459
# Time taken for 1 epoch 14.953768730163574 sec
#
# Epoch 48 Loss 1.0239 Acc 0.4458
# Time taken for 1 epoch 14.958442211151123 sec
#
# Epoch 49 Loss 1.0256 Acc 0.4451
# Time taken for 1 epoch 14.96162223815918 sec
#
# Epoch 50 Loss 1.0281 Acc 0.4444
# Time taken for 1 epoch 14.95153284072876 sec
#
# Epoch 51 Loss 1.0297 Acc 0.4438
# Time taken for 1 epoch 14.961440086364746 sec
#
# Epoch 52 Loss 1.0333 Acc 0.4424
# Time taken for 1 epoch 14.933576583862305 sec
#
# Epoch 53 Loss 1.0380 Acc 0.4409
# Time taken for 1 epoch 14.948881149291992 sec
#
# Epoch 54 Loss 1.0410 Acc 0.4397
# Time taken for 1 epoch 14.93631362915039 sec
#
# Epoch 55 Loss 1.0491 Acc 0.4370
# Time taken for 1 epoch 14.930876731872559 sec
#
# Epoch 56 Loss 1.0562 Acc 0.4348
# Time taken for 1 epoch 14.929661989212036 sec
#
# Epoch 57 Loss 1.0596 Acc 0.4337
# Time taken for 1 epoch 14.936609983444214 sec
#
# Epoch 58 Loss 1.0571 Acc 0.4340
# Time taken for 1 epoch 14.923773288726807 sec
#
# Epoch 59 Loss 1.0710 Acc 0.4293
# Time taken for 1 epoch 15.072540521621704 sec
#
# Epoch 60 Loss 1.0877 Acc 0.4239
# Time taken for 1 epoch 14.947520971298218 sec
#
# Epoch 61 Loss 1.0898 Acc 0.4225
# Time taken for 1 epoch 14.938878774642944 sec
#
# Epoch 62 Loss 1.0788 Acc 0.4267
# Time taken for 1 epoch 14.94316577911377 sec
#
# Epoch 63 Loss 1.0681 Acc 0.4304
# Time taken for 1 epoch 14.928263187408447 sec
#
# Epoch 64 Loss 1.0480 Acc 0.4374
# Time taken for 1 epoch 14.944375991821289 sec
#
# Epoch 65 Loss 1.0352 Acc 0.4420
# Time taken for 1 epoch 14.951539278030396 sec
#
# Epoch 66 Loss 1.0234 Acc 0.4463
# Time taken for 1 epoch 14.943137645721436 sec
#
# Epoch 67 Loss 1.0158 Acc 0.4489
# Time taken for 1 epoch 14.957682847976685 sec
#
# Epoch 68 Loss 1.0101 Acc 0.4509
# Time taken for 1 epoch 14.95321273803711 sec
#
# Epoch 69 Loss 1.0065 Acc 0.4522
# Time taken for 1 epoch 14.965628862380981 sec
#
# Epoch 70 Loss 1.0055 Acc 0.4526
# Time taken for 1 epoch 14.954186201095581 sec
#
# Epoch 71 Loss 1.0048 Acc 0.4528
# Time taken for 1 epoch 14.95716404914856 sec
#
# Epoch 72 Loss 1.0068 Acc 0.4523
# Time taken for 1 epoch 14.958500862121582 sec
#
# Epoch 73 Loss 1.0070 Acc 0.4520
# Time taken for 1 epoch 14.955673217773438 sec
#
# Epoch 74 Loss 1.0073 Acc 0.4518
# Time taken for 1 epoch 14.956859350204468 sec
#
# Epoch 75 Loss 1.0084 Acc 0.4515
# Time taken for 1 epoch 14.96653151512146 sec
#
# Epoch 76 Loss 1.0112 Acc 0.4503
# Time taken for 1 epoch 15.094692468643188 sec
#
# Epoch 77 Loss 1.0111 Acc 0.4507
# Time taken for 1 epoch 14.946989059448242 sec
#
# Epoch 78 Loss 1.0103 Acc 0.4506
# Time taken for 1 epoch 14.985150814056396 sec
#
# Epoch 79 Loss 1.0095 Acc 0.4509
# Time taken for 1 epoch 14.960321187973022 sec
#
# Epoch 80 Loss 1.0086 Acc 0.4512
# Time taken for 1 epoch 14.959809064865112 sec
#
# Epoch 81 Loss 1.0073 Acc 0.4516
# Time taken for 1 epoch 14.951553344726562 sec
#
# Epoch 82 Loss 1.0127 Acc 0.4498
# Time taken for 1 epoch 14.937905550003052 sec
#
# Epoch 83 Loss 1.0144 Acc 0.4494
# Time taken for 1 epoch 14.95409607887268 sec
#
# Epoch 84 Loss 1.0187 Acc 0.4478
# Time taken for 1 epoch 14.951255559921265 sec
#
# Epoch 85 Loss 1.0112 Acc 0.4503
# Time taken for 1 epoch 14.956430196762085 sec
#
# Epoch 86 Loss 1.0102 Acc 0.4506
# Time taken for 1 epoch 14.95860242843628 sec
#
# Epoch 87 Loss 1.0107 Acc 0.4506
# Time taken for 1 epoch 14.963917016983032 sec
#
# Epoch 88 Loss 1.0085 Acc 0.4511
# Time taken for 1 epoch 14.956862688064575 sec
#
# Epoch 89 Loss 1.0057 Acc 0.4521
# Time taken for 1 epoch 14.957431554794312 sec
#
# Epoch 90 Loss 1.0050 Acc 0.4522
# Time taken for 1 epoch 14.96257209777832 sec
#
# Epoch 91 Loss 1.0050 Acc 0.4524
# Time taken for 1 epoch 14.965114116668701 sec
#
# Epoch 92 Loss 1.0066 Acc 0.4518
# Time taken for 1 epoch 14.954144477844238 sec
#
# Epoch 93 Loss 1.0067 Acc 0.4517
# Time taken for 1 epoch 15.048039674758911 sec
#
# Epoch 94 Loss 1.0069 Acc 0.4517
# Time taken for 1 epoch 14.954102993011475 sec
#
# Epoch 95 Loss 1.0072 Acc 0.4514
# Time taken for 1 epoch 14.959666728973389 sec
#
# Epoch 96 Loss 1.0080 Acc 0.4512
# Time taken for 1 epoch 14.952148675918579 sec
#
# Epoch 97 Loss 1.0081 Acc 0.4512
# Time taken for 1 epoch 14.956708908081055 sec
#
# Epoch 98 Loss 1.0057 Acc 0.4520
# Time taken for 1 epoch 14.962558031082153 sec
#
# Epoch 99 Loss 1.0063 Acc 0.4517
# Time taken for 1 epoch 14.953817129135132 sec
#
# Epoch 100 Loss 1.0063 Acc 0.4518
# Time taken for 1 epoch 14.94992733001709 sec
#
# Epoch 101 Loss 1.0066 Acc 0.4518
# Time taken for 1 epoch 14.953977584838867 sec
#
# Epoch 102 Loss 1.0069 Acc 0.4517
# Time taken for 1 epoch 14.962125539779663 sec
#
# Epoch 103 Loss 1.0082 Acc 0.4511
# Time taken for 1 epoch 14.944964408874512 sec
#
# Epoch 104 Loss 1.0072 Acc 0.4512
# Time taken for 1 epoch 14.955633163452148 sec
#
# Epoch 105 Loss 1.0083 Acc 0.4510
# Time taken for 1 epoch 14.951969861984253 sec
#
# Epoch 106 Loss 1.0131 Acc 0.4497
# Time taken for 1 epoch 14.947505235671997 sec
#
# Epoch 107 Loss 1.0168 Acc 0.4482
# Time taken for 1 epoch 14.94597339630127 sec
#
# Epoch 108 Loss 1.0161 Acc 0.4483
# Time taken for 1 epoch 14.948045015335083 sec
#
# Epoch 109 Loss 1.0121 Acc 0.4499
# Time taken for 1 epoch 14.946481466293335 sec
#
# Epoch 110 Loss 1.0130 Acc 0.4494
# Time taken for 1 epoch 15.096946954727173 sec
#
# Epoch 111 Loss 1.0128 Acc 0.4494
# Time taken for 1 epoch 14.935930967330933 sec
#
# Epoch 112 Loss 1.0121 Acc 0.4496
# Time taken for 1 epoch 14.949257850646973 sec
#
# Epoch 113 Loss 1.0091 Acc 0.4509
# Time taken for 1 epoch 14.944393157958984 sec
#
# Epoch 114 Loss 1.0103 Acc 0.4502
# Time taken for 1 epoch 14.960990905761719 sec
#
# Epoch 115 Loss 1.0117 Acc 0.4499
# Time taken for 1 epoch 14.946835994720459 sec
#
# Epoch 116 Loss 1.0120 Acc 0.4498
# Time taken for 1 epoch 14.948479413986206 sec
#
# Epoch 117 Loss 1.0142 Acc 0.4491
# Time taken for 1 epoch 14.951102018356323 sec
#
# Epoch 118 Loss 1.0158 Acc 0.4484
# Time taken for 1 epoch 14.931602001190186 sec
#
# Epoch 119 Loss 1.0180 Acc 0.4476
# Time taken for 1 epoch 14.959611415863037 sec
#
# Epoch 120 Loss 1.0218 Acc 0.4466
# Time taken for 1 epoch 14.954307317733765 sec
#
# Epoch 121 Loss 1.0262 Acc 0.4449
# Time taken for 1 epoch 14.938393831253052 sec
#
# Epoch 122 Loss 1.0280 Acc 0.4443
# Time taken for 1 epoch 14.938956260681152 sec
#
# Epoch 123 Loss 1.0286 Acc 0.4442
# Time taken for 1 epoch 14.92771315574646 sec
#
# Epoch 124 Loss 1.0307 Acc 0.4436
# Time taken for 1 epoch 14.942336797714233 sec
#
# Epoch 125 Loss 1.0306 Acc 0.4435
# Time taken for 1 epoch 14.944195747375488 sec
#
# Epoch 126 Loss 1.0305 Acc 0.4435
# Time taken for 1 epoch 14.939265966415405 sec
#
# Epoch 127 Loss 1.0372 Acc 0.4410
# Time taken for 1 epoch 14.94225788116455 sec
#
# Epoch 128 Loss 1.0465 Acc 0.4378
# Time taken for 1 epoch 15.153471231460571 sec
#
# Epoch 129 Loss 1.0823 Acc 0.4259
# Time taken for 1 epoch 14.94947075843811 sec
#
# Epoch 130 Loss 1.0607 Acc 0.4332
# Time taken for 1 epoch 14.93185544013977 sec
#
# Epoch 131 Loss 1.0529 Acc 0.4359
# Time taken for 1 epoch 14.939911127090454 sec
#
# Epoch 132 Loss 1.0563 Acc 0.4347
# Time taken for 1 epoch 14.967258214950562 sec
#
# Epoch 133 Loss 1.0443 Acc 0.4386
# Time taken for 1 epoch 14.927749156951904 sec
#
# Epoch 134 Loss 1.0400 Acc 0.4399
# Time taken for 1 epoch 14.942906856536865 sec
#
# Epoch 135 Loss 1.0375 Acc 0.4406
# Time taken for 1 epoch 14.969558954238892 sec
#
# Epoch 136 Loss 1.0368 Acc 0.4409
# Time taken for 1 epoch 14.961375713348389 sec
#
# Epoch 137 Loss 1.0338 Acc 0.4421
# Time taken for 1 epoch 14.952864408493042 sec
#
# Epoch 138 Loss 1.0297 Acc 0.4435
# Time taken for 1 epoch 14.9598867893219 sec
#
# Epoch 139 Loss 1.0228 Acc 0.4459
# Time taken for 1 epoch 14.936720848083496 sec
#
# Epoch 140 Loss 1.0149 Acc 0.4487
# Time taken for 1 epoch 14.949834108352661 sec
#
# Epoch 141 Loss 1.0097 Acc 0.4507
# Time taken for 1 epoch 14.942410945892334 sec
#
# Epoch 142 Loss 1.0030 Acc 0.4531
# Time taken for 1 epoch 14.93213438987732 sec
#
# Epoch 143 Loss 0.9991 Acc 0.4546
# Time taken for 1 epoch 14.950170516967773 sec
#
# Epoch 144 Loss 0.9948 Acc 0.4560
# Time taken for 1 epoch 14.94271969795227 sec
#
# Epoch 145 Loss 0.9923 Acc 0.4570
# Time taken for 1 epoch 15.047680139541626 sec
#
# Epoch 146 Loss 0.9907 Acc 0.4575
# Time taken for 1 epoch 14.968407154083252 sec
#
# Epoch 147 Loss 0.9897 Acc 0.4578
# Time taken for 1 epoch 14.957468271255493 sec
#
# Epoch 148 Loss 0.9885 Acc 0.4583
# Time taken for 1 epoch 14.96097707748413 sec
#
# Epoch 149 Loss 0.9885 Acc 0.4582
# Time taken for 1 epoch 14.974383354187012 sec
#
# Epoch 150 Loss 0.9874 Acc 0.4587
# Time taken for 1 epoch 14.956244707107544 sec
#
# Epoch 151 Loss 0.9872 Acc 0.4587
# Time taken for 1 epoch 14.944868803024292 sec
#
# Epoch 152 Loss 0.9859 Acc 0.4593
# Time taken for 1 epoch 14.952766180038452 sec
#
# Epoch 153 Loss 0.9862 Acc 0.4591
# Time taken for 1 epoch 14.947470903396606 sec
#
# Epoch 154 Loss 0.9862 Acc 0.4591
# Time taken for 1 epoch 14.947698831558228 sec
#
# Epoch 155 Loss 0.9867 Acc 0.4588
# Time taken for 1 epoch 14.948860168457031 sec
#
# Epoch 156 Loss 0.9882 Acc 0.4585
# Time taken for 1 epoch 14.945260763168335 sec
#
# Epoch 157 Loss 0.9876 Acc 0.4586
# Time taken for 1 epoch 14.955194234848022 sec
#
# Epoch 158 Loss 0.9880 Acc 0.4584
# Time taken for 1 epoch 14.943195343017578 sec
#
# Epoch 159 Loss 0.9885 Acc 0.4582
# Time taken for 1 epoch 14.951891422271729 sec
#
# Epoch 160 Loss 0.9888 Acc 0.4581
# Time taken for 1 epoch 14.935804605484009 sec
#
# Epoch 161 Loss 0.9883 Acc 0.4583
# Time taken for 1 epoch 14.932933330535889 sec
#
# Epoch 162 Loss 0.9877 Acc 0.4586
# Time taken for 1 epoch 15.033716678619385 sec
#
# Epoch 163 Loss 0.9889 Acc 0.4579
# Time taken for 1 epoch 14.94586992263794 sec
#
# Epoch 164 Loss 0.9908 Acc 0.4573
# Time taken for 1 epoch 14.931556701660156 sec
#
# Epoch 165 Loss 0.9899 Acc 0.4576
# Time taken for 1 epoch 14.926247835159302 sec
#
# Epoch 166 Loss 0.9896 Acc 0.4576
# Time taken for 1 epoch 14.932904720306396 sec
#
# Epoch 167 Loss 0.9933 Acc 0.4564
# Time taken for 1 epoch 14.934873819351196 sec
#
# Epoch 168 Loss 0.9956 Acc 0.4557
# Time taken for 1 epoch 14.92236042022705 sec
#
# Epoch 169 Loss 0.9948 Acc 0.4558
# Time taken for 1 epoch 14.942107439041138 sec
#
# Epoch 170 Loss 0.9925 Acc 0.4566
# Time taken for 1 epoch 14.96474003791809 sec
#
# Epoch 171 Loss 0.9935 Acc 0.4565
# Time taken for 1 epoch 14.943699359893799 sec
#
# Epoch 172 Loss 0.9938 Acc 0.4563
# Time taken for 1 epoch 14.938416004180908 sec
#
# Epoch 173 Loss 0.9944 Acc 0.4558
# Time taken for 1 epoch 14.954507112503052 sec
#
# Epoch 174 Loss 0.9928 Acc 0.4564
# Time taken for 1 epoch 14.937432050704956 sec
#
# Epoch 175 Loss 0.9931 Acc 0.4563
# Time taken for 1 epoch 14.931925296783447 sec
#
# Epoch 176 Loss 0.9950 Acc 0.4556
# Time taken for 1 epoch 14.951846599578857 sec
#
# Epoch 177 Loss 0.9960 Acc 0.4552
# Time taken for 1 epoch 14.938100337982178 sec
#
# Epoch 178 Loss 0.9994 Acc 0.4542
# Time taken for 1 epoch 14.951051712036133 sec
#
# Epoch 179 Loss 1.0115 Acc 0.4500
# Time taken for 1 epoch 14.950647115707397 sec
#
# Epoch 180 Loss 1.0131 Acc 0.4491
# Time taken for 1 epoch 14.988085508346558 sec
#
# Epoch 181 Loss 1.0086 Acc 0.4507
# Time taken for 1 epoch 14.93035364151001 sec
#
# Epoch 182 Loss 1.0104 Acc 0.4501
# Time taken for 1 epoch 14.93126106262207 sec
#
# Epoch 183 Loss 1.0172 Acc 0.4478
# Time taken for 1 epoch 14.919057369232178 sec
#
# Epoch 184 Loss 1.0282 Acc 0.4440
# Time taken for 1 epoch 14.927768230438232 sec
#
# Epoch 185 Loss 1.0332 Acc 0.4417
# Time taken for 1 epoch 14.929510116577148 sec
#
# Epoch 186 Loss 1.0356 Acc 0.4411
# Time taken for 1 epoch 14.932132959365845 sec
#
# Epoch 187 Loss 1.0459 Acc 0.4382
# Time taken for 1 epoch 14.929425716400146 sec
#
# Epoch 188 Loss 1.0382 Acc 0.4407
# Time taken for 1 epoch 14.92701768875122 sec
#
# Epoch 189 Loss 1.0252 Acc 0.4448
# Time taken for 1 epoch 14.928914546966553 sec
#
# Epoch 190 Loss 1.0277 Acc 0.4443
# Time taken for 1 epoch 14.946404695510864 sec
#
# Epoch 191 Loss 1.0304 Acc 0.4436
# Time taken for 1 epoch 14.948036193847656 sec
#
# Epoch 192 Loss 1.0182 Acc 0.4476
# Time taken for 1 epoch 14.932130098342896 sec
#
# Epoch 193 Loss 1.0096 Acc 0.4503
# Time taken for 1 epoch 14.926090955734253 sec
#
# Epoch 194 Loss 1.0085 Acc 0.4506
# Time taken for 1 epoch 14.926204919815063 sec
#
# Epoch 195 Loss 1.0087 Acc 0.4504
# Time taken for 1 epoch 14.956801652908325 sec
#
# Epoch 196 Loss 1.0077 Acc 0.4509
# Time taken for 1 epoch 14.938033103942871 sec
#
# Epoch 197 Loss 1.0103 Acc 0.4500
# Time taken for 1 epoch 15.045274257659912 sec
#
# Epoch 198 Loss 1.0144 Acc 0.4486
# Time taken for 1 epoch 14.954326868057251 sec
#
# Epoch 199 Loss 1.0215 Acc 0.4459
# Time taken for 1 epoch 14.931279182434082 sec
#
# Epoch 200 Loss 1.0258 Acc 0.4444
# Time taken for 1 epoch 14.94461178779602 sec

# %%
plt.plot(loss_history)

# %%
plt.plot(loss_history)

# %%
test_file = np.load("irealpro_midi/Autumn Leaves_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="irealpro_transposed/Autumn Leaves_o0.mid", output_path="yo_al.mid")
# Out:
# 1/1 [==============================] - 0s 117ms/step

# %%
test_file = np.load("/content/dense_jazz/AutumnLeaves_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="/content/transpose_augmentation/AutumnLeaves_o0.mid", output_path="autumn_real.mid")
# Out:
# 1/1 [==============================] - 0s 86ms/step

# %%
test_file = np.load("/content/dense_jazz/PieceOfMyWish_p1.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="/content/transpose_augmentation/PieceOfMyWish_p1.mid", output_path="pow.mid")
# Out:
# 1/1 [==============================] - 0s 62ms/step

# %%
test_file = np.load("/content/55Dive_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), ref_midi_path="/content/55Dive_o0.mid", output_path="55d.mid")
# Out:
# 1/1 [==============================] - 0s 56ms/step

# %%
checkpoint.save(checkpoint_prefix)
# Out:
# './checkpoints/Bidirectional_LSTM_Real/ckpt-1'

# %%
! cp -r "/content/checkpoints" "/content/drive/MyDrive/ML_Final_Project/saved_model"
