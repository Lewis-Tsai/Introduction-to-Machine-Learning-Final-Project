# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation
# Out:
# 2022-12-31 22:30:12.357717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-31 22:30:16.137612: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-31 22:30:16.137901: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-31 22:30:16.137940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BATCH_SIZE = 256
VALIDATION_RATIO = 0.1

PIECE_LEN = 1024
n_feature = 42
n_hidden = 200
n_pitch = 52
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
train_dataset = generate_dataset("./preprocessed_dataset/augmentation/")
# Out:
# 2022-12-31 22:31:04.954037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:05.007822: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:05.008410: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:05.009811: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-31 22:31:05.011330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:05.021425: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:05.021934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:07.687932: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:07.704955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:07.705191: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-31 22:31:07.705289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature))(input) # Ignore Padded Data
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax"))(x)
model = tf.keras.Model(inputs=input, outputs=x)

# model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
#                 optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#                 metrics=tf.keras.metrics.CategoricalAccuracy())
print(model.summary())

optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024, 42)]        0
#
#  masking (Masking)           (None, 1024, 42)          0
#
#  bidirectional (Bidirectiona  (None, 1024, 400)        388800
#  l)
#
#  time_distributed (TimeDistr  (None, 1024, 52)         20852
#  ibuted)
#
# =================================================================
# Total params: 409,652
# Trainable params: 409,652
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/BDLSTM_Full'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
checkpoint.restore(checkpoint_prefix+"-1")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
# set the epochs for training
EPOCHS = 500
loss_history = []

for epoch in range(175,EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
# Out:
# 2022-12-31 22:33:13.908300: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_20/output/_23'
# 2022-12-31 22:33:14.287768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2022-12-31 22:33:14.684196: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f88e315f810 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-12-31 22:33:14.684241: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2022-12-31 22:33:14.699139: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2022-12-31 22:33:14.821059: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2022-12-31 22:33:14.856990: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2022-12-31 22:33:14.857025: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2022-12-31 22:33:14.858057: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2022-12-31 22:33:14.940614: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2022-12-31 22:33:15.273079: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2022-12-31 22:33:15.325930: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2022-12-31 22:33:15.325992: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# Epoch 176 Loss 1.1592 Acc 0.3977
# Time taken for 1 epoch 97.81735825538635 sec
#
# Epoch 177 Loss 1.1636 Acc 0.3961
# Time taken for 1 epoch 21.35425639152527 sec
#
# Epoch 178 Loss 1.1633 Acc 0.3961
# Time taken for 1 epoch 21.385268449783325 sec
#
# Epoch 179 Loss 1.1532 Acc 0.3999
# Time taken for 1 epoch 21.432565212249756 sec
#
# Epoch 180 Loss 1.1541 Acc 0.3995
# Time taken for 1 epoch 21.504517555236816 sec
#
# Epoch 181 Loss 1.1485 Acc 0.4012
# Time taken for 1 epoch 21.505663871765137 sec
#
# Epoch 182 Loss 1.1448 Acc 0.4024
# Time taken for 1 epoch 21.48742175102234 sec
#
# Epoch 183 Loss 1.1406 Acc 0.4040
# Time taken for 1 epoch 21.587393045425415 sec
#
# Epoch 184 Loss 1.1395 Acc 0.4042
# Time taken for 1 epoch 21.652249813079834 sec
#
# Epoch 185 Loss 1.1388 Acc 0.4044
# Time taken for 1 epoch 21.61669611930847 sec
#
# Epoch 186 Loss 1.1791 Acc 0.3909
# Time taken for 1 epoch 21.716660261154175 sec
#
# Epoch 187 Loss 1.1542 Acc 0.3991
# Time taken for 1 epoch 21.720736265182495 sec
#
# Epoch 188 Loss 1.1416 Acc 0.4032
# Time taken for 1 epoch 21.727909564971924 sec
#
# Epoch 189 Loss 1.1427 Acc 0.4032
# Time taken for 1 epoch 21.712356090545654 sec
#
# Epoch 190 Loss 1.1510 Acc 0.4003
# Time taken for 1 epoch 21.79837918281555 sec
#
# Epoch 191 Loss 1.1409 Acc 0.4035
# Time taken for 1 epoch 21.736071825027466 sec
#
# Epoch 192 Loss 1.1382 Acc 0.4045
# Time taken for 1 epoch 21.77919840812683 sec
#
# Epoch 193 Loss 1.1331 Acc 0.4062
# Time taken for 1 epoch 21.719253301620483 sec
#
# Epoch 194 Loss 1.1369 Acc 0.4049
# Time taken for 1 epoch 21.81437849998474 sec
#
# Epoch 195 Loss 1.1309 Acc 0.4072
# Time taken for 1 epoch 21.750555276870728 sec
#
# Epoch 196 Loss 1.1343 Acc 0.4059
# Time taken for 1 epoch 21.77719020843506 sec
#
# Epoch 197 Loss 1.1323 Acc 0.4066
# Time taken for 1 epoch 21.74095606803894 sec
#
# Epoch 198 Loss 1.1259 Acc 0.4090
# Time taken for 1 epoch 21.666208744049072 sec
#
# Epoch 199 Loss 1.1286 Acc 0.4078
# Time taken for 1 epoch 21.810852527618408 sec
#
# Epoch 200 Loss 1.1240 Acc 0.4096
# Time taken for 1 epoch 21.764079093933105 sec
#
# Epoch 201 Loss 1.1336 Acc 0.4060
# Time taken for 1 epoch 21.797581434249878 sec
#
# Epoch 202 Loss 1.1531 Acc 0.3990
# Time taken for 1 epoch 21.76711344718933 sec
#
# Epoch 203 Loss 1.1391 Acc 0.4038
# Time taken for 1 epoch 21.826143980026245 sec
#
# Epoch 204 Loss 1.1351 Acc 0.4055
# Time taken for 1 epoch 21.773091554641724 sec
#
# Epoch 205 Loss 1.1277 Acc 0.4081
# Time taken for 1 epoch 21.811768770217896 sec
#
# Epoch 206 Loss 1.1241 Acc 0.4095
# Time taken for 1 epoch 21.81279492378235 sec
#
# Epoch 207 Loss 1.1231 Acc 0.4100
# Time taken for 1 epoch 21.87878179550171 sec
#
# Epoch 208 Loss 1.1231 Acc 0.4098
# Time taken for 1 epoch 21.714893341064453 sec
#
# Epoch 209 Loss 1.1247 Acc 0.4094
# Time taken for 1 epoch 21.940765380859375 sec
#
# Epoch 210 Loss 1.1241 Acc 0.4096
# Time taken for 1 epoch 21.74173069000244 sec
#
# Epoch 211 Loss 1.1283 Acc 0.4084
# Time taken for 1 epoch 21.8051335811615 sec
#
# Epoch 212 Loss 1.1254 Acc 0.4092
# Time taken for 1 epoch 21.773967742919922 sec
#
# Epoch 213 Loss 1.1241 Acc 0.4096
# Time taken for 1 epoch 21.858392477035522 sec
#
# Epoch 214 Loss 1.1198 Acc 0.4112
# Time taken for 1 epoch 21.79335880279541 sec
#
# Epoch 215 Loss 1.1216 Acc 0.4106
# Time taken for 1 epoch 21.82000970840454 sec
#
# Epoch 216 Loss 1.1365 Acc 0.4055
# Time taken for 1 epoch 21.83869981765747 sec
#
# Epoch 217 Loss 1.1336 Acc 0.4064
# Time taken for 1 epoch 21.842928171157837 sec
#
# Epoch 218 Loss 1.1403 Acc 0.4040
# Time taken for 1 epoch 21.77474617958069 sec
#
# Epoch 219 Loss 1.1489 Acc 0.4011
# Time taken for 1 epoch 21.74928903579712 sec
#
# Epoch 220 Loss 1.1380 Acc 0.4044
# Time taken for 1 epoch 21.795627117156982 sec
#
# Epoch 221 Loss 1.1234 Acc 0.4099
# Time taken for 1 epoch 21.822401523590088 sec
#
# Epoch 222 Loss 1.1262 Acc 0.4086
# Time taken for 1 epoch 21.77094864845276 sec
#
# Epoch 223 Loss 1.1203 Acc 0.4107
# Time taken for 1 epoch 21.818376064300537 sec
#
# Epoch 224 Loss 1.1134 Acc 0.4131
# Time taken for 1 epoch 21.83098578453064 sec
#
# Epoch 225 Loss 1.1153 Acc 0.4127
# Time taken for 1 epoch 21.707335710525513 sec
#
# Epoch 226 Loss 1.1121 Acc 0.4140
# Time taken for 1 epoch 21.71405553817749 sec
#
# Epoch 227 Loss 1.1100 Acc 0.4145
# Time taken for 1 epoch 21.779398918151855 sec
#
# Epoch 228 Loss 1.1119 Acc 0.4138
# Time taken for 1 epoch 21.844369649887085 sec
#
# Epoch 229 Loss 1.1156 Acc 0.4124
# Time taken for 1 epoch 21.885878324508667 sec
#
# Epoch 230 Loss 1.1121 Acc 0.4134
# Time taken for 1 epoch 21.701597690582275 sec
#
# Epoch 231 Loss 1.1080 Acc 0.4149
# Time taken for 1 epoch 21.792566299438477 sec
#
# Epoch 232 Loss 1.1079 Acc 0.4151
# Time taken for 1 epoch 21.96552324295044 sec
#
# Epoch 233 Loss 1.1060 Acc 0.4160
# Time taken for 1 epoch 21.789045095443726 sec
#
# Epoch 234 Loss 1.1098 Acc 0.4146
# Time taken for 1 epoch 21.923713445663452 sec
#
# Epoch 235 Loss 1.1129 Acc 0.4132
# Time taken for 1 epoch 21.776252508163452 sec
#
# Epoch 236 Loss 1.1188 Acc 0.4116
# Time taken for 1 epoch 21.852757692337036 sec
#
# Epoch 237 Loss 1.1156 Acc 0.4126
# Time taken for 1 epoch 21.735407829284668 sec
#
# Epoch 238 Loss 1.1059 Acc 0.4159
# Time taken for 1 epoch 21.977370023727417 sec
#
# Epoch 239 Loss 1.1015 Acc 0.4175
# Time taken for 1 epoch 21.795178413391113 sec
#
# Epoch 240 Loss 1.1014 Acc 0.4173
# Time taken for 1 epoch 21.754921197891235 sec
#
# Epoch 241 Loss 1.1012 Acc 0.4177
# Time taken for 1 epoch 21.87459421157837 sec
#
# Epoch 242 Loss 1.1052 Acc 0.4160
# Time taken for 1 epoch 21.808566093444824 sec
#
# Epoch 243 Loss 1.1312 Acc 0.4074
# Time taken for 1 epoch 21.857816696166992 sec
#
# Epoch 244 Loss 1.1230 Acc 0.4102
# Time taken for 1 epoch 22.022608757019043 sec
#
# Epoch 245 Loss 1.1136 Acc 0.4132
# Time taken for 1 epoch 21.75456404685974 sec
#
# Epoch 246 Loss 1.1093 Acc 0.4147
# Time taken for 1 epoch 21.828787565231323 sec
#
# Epoch 247 Loss 1.1025 Acc 0.4168
# Time taken for 1 epoch 21.81177043914795 sec
#
# Epoch 248 Loss 1.0978 Acc 0.4187
# Time taken for 1 epoch 21.757976770401 sec
#
# Epoch 249 Loss 1.1003 Acc 0.4175
# Time taken for 1 epoch 21.869060277938843 sec
#
# Epoch 250 Loss 1.0990 Acc 0.4184
# Time taken for 1 epoch 21.844767332077026 sec
#
# Epoch 251 Loss 1.0953 Acc 0.4196
# Time taken for 1 epoch 21.88314962387085 sec
#
# Epoch 252 Loss 1.0943 Acc 0.4200
# Time taken for 1 epoch 21.81794762611389 sec
#
# Epoch 253 Loss 1.0949 Acc 0.4198
# Time taken for 1 epoch 21.924527883529663 sec
#
# Epoch 254 Loss 1.0948 Acc 0.4197
# Time taken for 1 epoch 21.731842756271362 sec
#
# Epoch 255 Loss 1.1052 Acc 0.4161
# Time taken for 1 epoch 21.916738986968994 sec
#
# Epoch 256 Loss 1.1122 Acc 0.4137
# Time taken for 1 epoch 21.777692794799805 sec
#
# Epoch 257 Loss 1.1234 Acc 0.4092
# Time taken for 1 epoch 21.895002365112305 sec
#
# Epoch 258 Loss 1.1185 Acc 0.4112
# Time taken for 1 epoch 21.681175708770752 sec
#
# Epoch 259 Loss 1.1101 Acc 0.4141
# Time taken for 1 epoch 21.94278573989868 sec
#
# Epoch 260 Loss 1.1010 Acc 0.4174
# Time taken for 1 epoch 21.839073419570923 sec
#
# Epoch 261 Loss 1.0969 Acc 0.4188
# Time taken for 1 epoch 21.81823468208313 sec
#
# Epoch 262 Loss 1.0954 Acc 0.4195
# Time taken for 1 epoch 21.78431797027588 sec
#
# Epoch 263 Loss 1.0957 Acc 0.4192
# Time taken for 1 epoch 21.8395254611969 sec
#
# Epoch 264 Loss 1.0949 Acc 0.4195
# Time taken for 1 epoch 21.944602489471436 sec
#
# Epoch 265 Loss 1.1040 Acc 0.4165
# Time taken for 1 epoch 21.820476293563843 sec
#
# Epoch 266 Loss 1.1064 Acc 0.4155
# Time taken for 1 epoch 21.727587938308716 sec
#
# Epoch 267 Loss 1.1136 Acc 0.4131
# Time taken for 1 epoch 21.863460063934326 sec
#
# Epoch 268 Loss 1.1054 Acc 0.4159
# Time taken for 1 epoch 21.800421476364136 sec
#
# Epoch 269 Loss 1.1071 Acc 0.4151
# Time taken for 1 epoch 21.769121408462524 sec
#
# Epoch 270 Loss 1.1142 Acc 0.4125
# Time taken for 1 epoch 21.91605281829834 sec
#
# Epoch 271 Loss 1.1141 Acc 0.4124
# Time taken for 1 epoch 21.705726623535156 sec
#
# Epoch 272 Loss 1.1164 Acc 0.4119
# Time taken for 1 epoch 21.86931562423706 sec
#
# Epoch 273 Loss 1.1137 Acc 0.4130
# Time taken for 1 epoch 21.890644073486328 sec
#
# Epoch 274 Loss 1.1146 Acc 0.4124
# Time taken for 1 epoch 21.88569450378418 sec
#
# Epoch 275 Loss 1.1290 Acc 0.4084
# Time taken for 1 epoch 21.88696312904358 sec
#
# Epoch 276 Loss 1.1408 Acc 0.4043
# Time taken for 1 epoch 21.759808778762817 sec
#
# Epoch 277 Loss 1.1342 Acc 0.4066
# Time taken for 1 epoch 21.775962829589844 sec
#
# Epoch 278 Loss 1.1240 Acc 0.4097
# Time taken for 1 epoch 21.879743576049805 sec
#
# Epoch 279 Loss 1.1140 Acc 0.4132
# Time taken for 1 epoch 21.763360500335693 sec
#
# Epoch 280 Loss 1.1025 Acc 0.4170
# Time taken for 1 epoch 21.964014768600464 sec
#
# Epoch 281 Loss 1.0951 Acc 0.4195
# Time taken for 1 epoch 21.85320210456848 sec
#
# Epoch 282 Loss 1.0917 Acc 0.4206
# Time taken for 1 epoch 21.864859104156494 sec
#
# Epoch 283 Loss 1.0900 Acc 0.4211
# Time taken for 1 epoch 21.850227117538452 sec
#
# Epoch 284 Loss 1.0946 Acc 0.4196
# Time taken for 1 epoch 21.950108289718628 sec
#
# Epoch 285 Loss 1.0906 Acc 0.4207
# Time taken for 1 epoch 21.780779361724854 sec
#
# Epoch 286 Loss 1.0958 Acc 0.4193
# Time taken for 1 epoch 21.87192153930664 sec
#
# Epoch 287 Loss 1.1060 Acc 0.4159
# Time taken for 1 epoch 21.840247869491577 sec
#
# Epoch 288 Loss 1.1005 Acc 0.4177
# Time taken for 1 epoch 21.83440375328064 sec
#
# Epoch 289 Loss 1.0932 Acc 0.4202
# Time taken for 1 epoch 21.861297607421875 sec
#
# Epoch 290 Loss 1.0940 Acc 0.4197
# Time taken for 1 epoch 21.78423833847046 sec
#
# Epoch 291 Loss 1.0963 Acc 0.4192
# Time taken for 1 epoch 21.85540223121643 sec
#
# Epoch 292 Loss 1.0921 Acc 0.4206
# Time taken for 1 epoch 21.744558811187744 sec
#
# Epoch 293 Loss 1.0874 Acc 0.4222
# Time taken for 1 epoch 21.81757354736328 sec
#
# Epoch 294 Loss 1.0929 Acc 0.4200
# Time taken for 1 epoch 21.81214451789856 sec
#
# Epoch 295 Loss 1.0882 Acc 0.4217
# Time taken for 1 epoch 21.920342683792114 sec
#
# Epoch 296 Loss 1.0853 Acc 0.4230
# Time taken for 1 epoch 21.876783847808838 sec
#
# Epoch 297 Loss 1.0866 Acc 0.4224
# Time taken for 1 epoch 21.84717297554016 sec
#
# Epoch 298 Loss 1.0865 Acc 0.4223
# Time taken for 1 epoch 21.838202714920044 sec
#
# Epoch 299 Loss 1.0865 Acc 0.4227
# Time taken for 1 epoch 21.803669691085815 sec
#
# Epoch 300 Loss 1.0849 Acc 0.4229
# Time taken for 1 epoch 21.691684246063232 sec
#
# Epoch 301 Loss 1.0857 Acc 0.4225
# Time taken for 1 epoch 21.92307710647583 sec
#
# Epoch 302 Loss 1.0893 Acc 0.4212
# Time taken for 1 epoch 21.8639919757843 sec
#
# Epoch 303 Loss 1.0858 Acc 0.4225
# Time taken for 1 epoch 21.84653949737549 sec
#
# Epoch 304 Loss 1.0869 Acc 0.4224
# Time taken for 1 epoch 21.96434211730957 sec
#
# Epoch 305 Loss 1.0927 Acc 0.4202
# Time taken for 1 epoch 21.802403211593628 sec
#
# Epoch 306 Loss 1.0853 Acc 0.4228
# Time taken for 1 epoch 21.78315019607544 sec
#
# Epoch 307 Loss 1.0886 Acc 0.4215
# Time taken for 1 epoch 21.9329674243927 sec
#
# Epoch 308 Loss 1.0832 Acc 0.4235
# Time taken for 1 epoch 21.925928592681885 sec
#
# Epoch 309 Loss 1.0896 Acc 0.4213
# Time taken for 1 epoch 21.810415267944336 sec
#
# Epoch 310 Loss 1.0854 Acc 0.4228
# Time taken for 1 epoch 21.76801872253418 sec
#
# Epoch 311 Loss 1.0892 Acc 0.4214
# Time taken for 1 epoch 21.872189044952393 sec
#
# Epoch 312 Loss 1.0855 Acc 0.4225
# Time taken for 1 epoch 21.894359350204468 sec
#
# Epoch 313 Loss 1.0907 Acc 0.4210
# Time taken for 1 epoch 21.995046854019165 sec
#
# Epoch 314 Loss 1.0900 Acc 0.4215
# Time taken for 1 epoch 21.729676246643066 sec
#
# Epoch 315 Loss 1.0864 Acc 0.4226
# Time taken for 1 epoch 21.807880878448486 sec
#
# Epoch 316 Loss 1.0867 Acc 0.4226
# Time taken for 1 epoch 21.968255281448364 sec
#
# Epoch 317 Loss 1.0844 Acc 0.4233
# Time taken for 1 epoch 21.899553298950195 sec
#
# Epoch 318 Loss 1.0853 Acc 0.4232
# Time taken for 1 epoch 21.889105319976807 sec
#
# Epoch 319 Loss 1.0914 Acc 0.4211
# Time taken for 1 epoch 21.891579627990723 sec
#
# Epoch 320 Loss 1.0987 Acc 0.4186
# Time taken for 1 epoch 21.819114208221436 sec
#
# Epoch 321 Loss 1.0963 Acc 0.4191
# Time taken for 1 epoch 21.768989324569702 sec
#
# Epoch 322 Loss 1.1004 Acc 0.4179
# Time taken for 1 epoch 21.94310688972473 sec
#
# Epoch 323 Loss 1.0890 Acc 0.4218
# Time taken for 1 epoch 21.78822135925293 sec
#
# Epoch 324 Loss 1.0825 Acc 0.4241
# Time taken for 1 epoch 21.939895391464233 sec
#
# Epoch 325 Loss 1.0867 Acc 0.4226
# Time taken for 1 epoch 21.78538703918457 sec
#
# Epoch 326 Loss 1.1263 Acc 0.4102
# Time taken for 1 epoch 21.72232460975647 sec
#
# Epoch 327 Loss 1.1092 Acc 0.4154
# Time taken for 1 epoch 21.829801559448242 sec
#
# Epoch 328 Loss 1.1002 Acc 0.4185
# Time taken for 1 epoch 21.793318033218384 sec
#
# Epoch 329 Loss 1.0963 Acc 0.4197
# Time taken for 1 epoch 21.834675073623657 sec
#
# Epoch 330 Loss 1.0924 Acc 0.4209
# Time taken for 1 epoch 21.70857000350952 sec
#
# Epoch 331 Loss 1.0923 Acc 0.4206
# Time taken for 1 epoch 21.864585638046265 sec
#
# Epoch 332 Loss 1.0882 Acc 0.4222
# Time taken for 1 epoch 21.929123163223267 sec
#
# Epoch 333 Loss 1.0849 Acc 0.4231
# Time taken for 1 epoch 21.863261699676514 sec
#
# Epoch 334 Loss 1.0873 Acc 0.4226
# Time taken for 1 epoch 21.734058380126953 sec
#
# Epoch 335 Loss 1.0896 Acc 0.4215
# Time taken for 1 epoch 22.006319522857666 sec
#
# Epoch 336 Loss 1.0946 Acc 0.4198
# Time taken for 1 epoch 21.860242128372192 sec
#
# Epoch 337 Loss 1.0896 Acc 0.4218
# Time taken for 1 epoch 21.819210529327393 sec
#
# Epoch 338 Loss 1.0839 Acc 0.4236
# Time taken for 1 epoch 21.915332555770874 sec
#
# Epoch 339 Loss 1.0845 Acc 0.4232
# Time taken for 1 epoch 21.83868384361267 sec
#
# Epoch 340 Loss 1.0935 Acc 0.4201
# Time taken for 1 epoch 21.760448694229126 sec
#
# Epoch 341 Loss 1.0919 Acc 0.4203
# Time taken for 1 epoch 21.762713193893433 sec
#
# Epoch 342 Loss 1.0849 Acc 0.4230
# Time taken for 1 epoch 22.036821126937866 sec
#
# Epoch 343 Loss 1.0771 Acc 0.4257
# Time taken for 1 epoch 21.823578357696533 sec
#
# Epoch 344 Loss 1.0725 Acc 0.4275
# Time taken for 1 epoch 21.836386680603027 sec
#
# Epoch 345 Loss 1.0700 Acc 0.4284
# Time taken for 1 epoch 21.930947303771973 sec
#
# Epoch 346 Loss 1.0694 Acc 0.4284
# Time taken for 1 epoch 21.811602115631104 sec
#
# Epoch 347 Loss 1.0722 Acc 0.4274
# Time taken for 1 epoch 21.930917263031006 sec
#
# Epoch 348 Loss 1.0644 Acc 0.4303
# Time taken for 1 epoch 21.797295093536377 sec
#
# Epoch 349 Loss 1.0613 Acc 0.4314
# Time taken for 1 epoch 21.81377625465393 sec
#
# Epoch 350 Loss 1.0647 Acc 0.4302
# Time taken for 1 epoch 21.83549666404724 sec
#
# Epoch 351 Loss 1.0687 Acc 0.4288
# Time taken for 1 epoch 21.877636194229126 sec
#
# Epoch 352 Loss 1.0752 Acc 0.4267
# Time taken for 1 epoch 21.909724950790405 sec
#
# Epoch 353 Loss 1.0778 Acc 0.4255
# Time taken for 1 epoch 21.75024104118347 sec
#
# Epoch 354 Loss 1.0798 Acc 0.4251
# Time taken for 1 epoch 21.76047372817993 sec
#
# Epoch 355 Loss 1.0751 Acc 0.4267
# Time taken for 1 epoch 21.906026124954224 sec
#
# Epoch 356 Loss 1.0752 Acc 0.4264
# Time taken for 1 epoch 21.912118911743164 sec
#
# Epoch 357 Loss 1.0967 Acc 0.4197
# Time taken for 1 epoch 21.767693042755127 sec
#
# Epoch 358 Loss 1.1384 Acc 0.4060
# Time taken for 1 epoch 21.876828908920288 sec
#
# Epoch 359 Loss 1.1158 Acc 0.4131
# Time taken for 1 epoch 21.794734239578247 sec
#
# Epoch 360 Loss 1.0987 Acc 0.4188
# Time taken for 1 epoch 21.952874660491943 sec
#
# Epoch 361 Loss 1.0809 Acc 0.4248
# Time taken for 1 epoch 21.871214389801025 sec
#
# Epoch 362 Loss 1.0717 Acc 0.4278
# Time taken for 1 epoch 21.85734486579895 sec
#
# Epoch 363 Loss 1.0694 Acc 0.4288
# Time taken for 1 epoch 21.81830668449402 sec
#
# Epoch 364 Loss 1.0677 Acc 0.4293
# Time taken for 1 epoch 21.871782064437866 sec
#
# Epoch 365 Loss 1.0756 Acc 0.4265
# Time taken for 1 epoch 21.813288688659668 sec
#
# Epoch 366 Loss 1.0833 Acc 0.4234
# Time taken for 1 epoch 21.818731784820557 sec
#
# Epoch 367 Loss 1.0834 Acc 0.4235
# Time taken for 1 epoch 21.95925498008728 sec
#
# Epoch 368 Loss 1.0715 Acc 0.4274
# Time taken for 1 epoch 21.720930099487305 sec
#
# Epoch 369 Loss 1.0852 Acc 0.4229
# Time taken for 1 epoch 21.888318300247192 sec
#
# Epoch 370 Loss 1.0838 Acc 0.4234
# Time taken for 1 epoch 21.967332124710083 sec
#
# Epoch 371 Loss 1.0715 Acc 0.4279
# Time taken for 1 epoch 21.757282257080078 sec
#
# Epoch 372 Loss 1.0640 Acc 0.4303
# Time taken for 1 epoch 21.95100998878479 sec
#
# Epoch 373 Loss 1.0589 Acc 0.4323
# Time taken for 1 epoch 21.89407992362976 sec
#
# Epoch 374 Loss 1.0556 Acc 0.4334
# Time taken for 1 epoch 21.859024047851562 sec
#
# Epoch 375 Loss 1.0567 Acc 0.4331
# Time taken for 1 epoch 21.82341766357422 sec
#
# Epoch 376 Loss 1.0578 Acc 0.4326
# Time taken for 1 epoch 21.99725890159607 sec
#
# Epoch 377 Loss 1.0550 Acc 0.4336
# Time taken for 1 epoch 21.8420991897583 sec
#
# Epoch 378 Loss 1.0557 Acc 0.4334
# Time taken for 1 epoch 21.893709897994995 sec
#
# Epoch 379 Loss 1.0570 Acc 0.4329
# Time taken for 1 epoch 21.918510913848877 sec
#
# Epoch 380 Loss 1.0583 Acc 0.4325
# Time taken for 1 epoch 21.702497959136963 sec
#
# Epoch 381 Loss 1.0640 Acc 0.4303
# Time taken for 1 epoch 21.969096899032593 sec
#
# Epoch 382 Loss 1.0652 Acc 0.4299
# Time taken for 1 epoch 21.75733971595764 sec
#
# Epoch 383 Loss 1.1412 Acc 0.4056
# Time taken for 1 epoch 21.852662801742554 sec
#
# Epoch 384 Loss 1.1429 Acc 0.4047
# Time taken for 1 epoch 21.94290804862976 sec
#
# Epoch 385 Loss 1.1179 Acc 0.4122
# Time taken for 1 epoch 21.846147775650024 sec
#
# Epoch 386 Loss 1.1147 Acc 0.4133
# Time taken for 1 epoch 21.839919328689575 sec
#
# Epoch 387 Loss 1.0986 Acc 0.4187
# Time taken for 1 epoch 21.779083728790283 sec
#
# Epoch 388 Loss 1.0803 Acc 0.4249
# Time taken for 1 epoch 21.902785301208496 sec
#
# Epoch 389 Loss 1.0693 Acc 0.4287
# Time taken for 1 epoch 21.879867792129517 sec
#
# Epoch 390 Loss 1.0621 Acc 0.4311
# Time taken for 1 epoch 21.869518756866455 sec
#
# Epoch 391 Loss 1.0626 Acc 0.4309
# Time taken for 1 epoch 21.850151300430298 sec
#
# Epoch 392 Loss 1.1149 Acc 0.4143
# Time taken for 1 epoch 21.913886308670044 sec
#
# Epoch 393 Loss 1.0944 Acc 0.4205
# Time taken for 1 epoch 21.965028524398804 sec
#
# Epoch 394 Loss 1.0818 Acc 0.4247
# Time taken for 1 epoch 21.8272385597229 sec
#
# Epoch 395 Loss 1.0722 Acc 0.4277
# Time taken for 1 epoch 21.923194646835327 sec
#
# Epoch 396 Loss 1.0703 Acc 0.4285
# Time taken for 1 epoch 21.909224033355713 sec
#
# Epoch 397 Loss 1.1070 Acc 0.4165
# Time taken for 1 epoch 21.904804944992065 sec
#
# Epoch 398 Loss 1.0942 Acc 0.4198
# Time taken for 1 epoch 21.848893642425537 sec
#
# Epoch 399 Loss 1.0850 Acc 0.4229
# Time taken for 1 epoch 21.893834829330444 sec
#
# Epoch 400 Loss 1.0705 Acc 0.4278
# Time taken for 1 epoch 21.84336280822754 sec
#
# Epoch 401 Loss 1.0608 Acc 0.4312
# Time taken for 1 epoch 21.85647964477539 sec
#
# Epoch 402 Loss 1.0601 Acc 0.4317
# Time taken for 1 epoch 21.90776562690735 sec
#
# Epoch 403 Loss 1.0557 Acc 0.4332
# Time taken for 1 epoch 21.719833850860596 sec
#
# Epoch 404 Loss 1.0549 Acc 0.4334
# Time taken for 1 epoch 21.754037141799927 sec
#
# Epoch 405 Loss 1.0572 Acc 0.4324
# Time taken for 1 epoch 21.754868984222412 sec
#
# Epoch 406 Loss 1.0548 Acc 0.4334
# Time taken for 1 epoch 21.93255352973938 sec
#
# Epoch 407 Loss 1.0522 Acc 0.4345
# Time taken for 1 epoch 21.88727831840515 sec
#
# Epoch 408 Loss 1.0546 Acc 0.4336
# Time taken for 1 epoch 21.80925416946411 sec
#
# Epoch 409 Loss 1.0521 Acc 0.4343
# Time taken for 1 epoch 21.871145486831665 sec
#
# Epoch 410 Loss 1.0617 Acc 0.4310
# Time taken for 1 epoch 21.919835090637207 sec
#
# Epoch 411 Loss 1.0725 Acc 0.4273
# Time taken for 1 epoch 21.85282611846924 sec
#
# Epoch 412 Loss 1.0652 Acc 0.4298
# Time taken for 1 epoch 21.844432830810547 sec
#
# Epoch 413 Loss 1.0661 Acc 0.4293
# Time taken for 1 epoch 21.793086051940918 sec
#
# Epoch 414 Loss 1.0646 Acc 0.4302
# Time taken for 1 epoch 21.735544204711914 sec
#
# Epoch 415 Loss 1.0881 Acc 0.4218
# Time taken for 1 epoch 21.896583795547485 sec
#
# Epoch 416 Loss 1.1693 Acc 0.3964
# Time taken for 1 epoch 21.760669708251953 sec
#
# Epoch 417 Loss 1.1745 Acc 0.3938
# Time taken for 1 epoch 21.855782985687256 sec
#
# Epoch 418 Loss 1.1537 Acc 0.4007
# Time taken for 1 epoch 21.85978126525879 sec
#
# Epoch 419 Loss 1.1315 Acc 0.4084
# Time taken for 1 epoch 21.84015679359436 sec
#
# Epoch 420 Loss 1.1285 Acc 0.4090
# Time taken for 1 epoch 21.884464740753174 sec
#
# Epoch 421 Loss 1.1490 Acc 0.4017
# Time taken for 1 epoch 21.784813165664673 sec
#
# Epoch 422 Loss 1.1300 Acc 0.4080
# Time taken for 1 epoch 21.944320917129517 sec
#
# Epoch 423 Loss 1.1083 Acc 0.4158
# Time taken for 1 epoch 21.928251028060913 sec
#
# Epoch 424 Loss 1.0971 Acc 0.4196
# Time taken for 1 epoch 21.82340669631958 sec
#
# Epoch 425 Loss 1.0936 Acc 0.4208
# Time taken for 1 epoch 21.768968105316162 sec
#
# Epoch 426 Loss 1.0925 Acc 0.4209
# Time taken for 1 epoch 21.829702854156494 sec
#
# Epoch 427 Loss 1.0899 Acc 0.4217
# Time taken for 1 epoch 21.90373134613037 sec
#
# Epoch 428 Loss 1.0850 Acc 0.4235
# Time taken for 1 epoch 21.797197818756104 sec
#
# Epoch 429 Loss 1.0851 Acc 0.4233
# Time taken for 1 epoch 21.949743270874023 sec
#
# Epoch 430 Loss 1.0792 Acc 0.4254
# Time taken for 1 epoch 21.955429792404175 sec
#
# Epoch 431 Loss 1.0814 Acc 0.4247
# Time taken for 1 epoch 21.841713190078735 sec
#
# Epoch 432 Loss 1.0827 Acc 0.4244
# Time taken for 1 epoch 21.893283367156982 sec
#
# Epoch 433 Loss 1.0795 Acc 0.4256
# Time taken for 1 epoch 21.81256413459778 sec
#
# Epoch 434 Loss 1.0765 Acc 0.4265
# Time taken for 1 epoch 21.983502626419067 sec
#
# Epoch 435 Loss 1.0806 Acc 0.4247
# Time taken for 1 epoch 21.8556170463562 sec
#
# Epoch 436 Loss 1.0823 Acc 0.4242
# Time taken for 1 epoch 21.904538869857788 sec
#
# Epoch 437 Loss 1.0706 Acc 0.4284
# Time taken for 1 epoch 21.918867588043213 sec
#
# Epoch 438 Loss 1.0670 Acc 0.4294
# Time taken for 1 epoch 21.897141695022583 sec
#
# Epoch 439 Loss 1.0614 Acc 0.4315
# Time taken for 1 epoch 21.922751903533936 sec
#
# Epoch 440 Loss 1.0626 Acc 0.4308
# Time taken for 1 epoch 21.913546562194824 sec
#
# Epoch 441 Loss 1.0608 Acc 0.4316
# Time taken for 1 epoch 21.83232307434082 sec
#
# Epoch 442 Loss 1.0593 Acc 0.4321
# Time taken for 1 epoch 21.90107750892639 sec
#
# Epoch 443 Loss 1.0595 Acc 0.4322
# Time taken for 1 epoch 21.8620662689209 sec
#
# Epoch 444 Loss 1.0591 Acc 0.4321
# Time taken for 1 epoch 21.9018771648407 sec
#
# Epoch 445 Loss 1.0557 Acc 0.4331
# Time taken for 1 epoch 21.876952409744263 sec
#
# Epoch 446 Loss 1.0555 Acc 0.4333
# Time taken for 1 epoch 21.82357954978943 sec
#
# Epoch 447 Loss 1.0611 Acc 0.4314
# Time taken for 1 epoch 21.915215253829956 sec
#
# Epoch 448 Loss 1.0569 Acc 0.4326
# Time taken for 1 epoch 21.92062735557556 sec
#
# Epoch 449 Loss 1.0549 Acc 0.4333
# Time taken for 1 epoch 21.894051551818848 sec
#
# Epoch 450 Loss 1.0578 Acc 0.4325
# Time taken for 1 epoch 21.872435331344604 sec
#
# Epoch 451 Loss 1.0585 Acc 0.4324
# Time taken for 1 epoch 21.862463235855103 sec
#
# Epoch 452 Loss 1.0577 Acc 0.4325
# Time taken for 1 epoch 21.94452953338623 sec
#
# Epoch 453 Loss 1.0669 Acc 0.4295
# Time taken for 1 epoch 21.859973669052124 sec
#
# Epoch 454 Loss 1.0683 Acc 0.4288
# Time taken for 1 epoch 21.829486846923828 sec
#
# Epoch 455 Loss 1.0600 Acc 0.4316
# Time taken for 1 epoch 21.92832326889038 sec
#
# Epoch 456 Loss 1.0606 Acc 0.4314
# Time taken for 1 epoch 21.983842611312866 sec
#
# Epoch 457 Loss 1.0557 Acc 0.4332
# Time taken for 1 epoch 21.90879511833191 sec
#
# Epoch 458 Loss 1.0532 Acc 0.4340
# Time taken for 1 epoch 21.82775115966797 sec
#
# Epoch 459 Loss 1.0541 Acc 0.4337
# Time taken for 1 epoch 21.907958984375 sec
#
# Epoch 460 Loss 1.0515 Acc 0.4346
# Time taken for 1 epoch 21.901221990585327 sec
#
# Epoch 461 Loss 1.0507 Acc 0.4346
# Time taken for 1 epoch 21.84744930267334 sec
#
# Epoch 462 Loss 1.0497 Acc 0.4350
# Time taken for 1 epoch 21.762187004089355 sec
#
# Epoch 463 Loss 1.0516 Acc 0.4346
# Time taken for 1 epoch 21.95891571044922 sec
#
# Epoch 464 Loss 1.0519 Acc 0.4344
# Time taken for 1 epoch 21.911551237106323 sec
#
# Epoch 465 Loss 1.0585 Acc 0.4319
# Time taken for 1 epoch 21.745670080184937 sec
#
# Epoch 466 Loss 1.0580 Acc 0.4321
# Time taken for 1 epoch 21.90677833557129 sec
#
# Epoch 467 Loss 1.0530 Acc 0.4340
# Time taken for 1 epoch 21.947554349899292 sec
#
# Epoch 468 Loss 1.0525 Acc 0.4341
# Time taken for 1 epoch 21.74892282485962 sec
#
# Epoch 469 Loss 1.0503 Acc 0.4346
# Time taken for 1 epoch 21.82051706314087 sec
#
# Epoch 470 Loss 1.0578 Acc 0.4323
# Time taken for 1 epoch 21.999847888946533 sec
#
# Epoch 471 Loss 1.0765 Acc 0.4260
# Time taken for 1 epoch 21.794647693634033 sec
#
# Epoch 472 Loss 1.0687 Acc 0.4288
# Time taken for 1 epoch 21.68132710456848 sec
#
# Epoch 473 Loss 1.0789 Acc 0.4250
# Time taken for 1 epoch 21.910468101501465 sec
#
# Epoch 474 Loss 1.0781 Acc 0.4254
# Time taken for 1 epoch 21.9709894657135 sec
#
# Epoch 475 Loss 1.0734 Acc 0.4267
# Time taken for 1 epoch 21.918190956115723 sec
#
# Epoch 476 Loss 1.0646 Acc 0.4295
# Time taken for 1 epoch 21.83186650276184 sec
#
# Epoch 477 Loss 1.0675 Acc 0.4286
# Time taken for 1 epoch 21.866931438446045 sec
#
# Epoch 478 Loss 1.0644 Acc 0.4301
# Time taken for 1 epoch 21.959765434265137 sec
#
# Epoch 479 Loss 1.0645 Acc 0.4296
# Time taken for 1 epoch 21.787006616592407 sec
#
# Epoch 480 Loss 1.0645 Acc 0.4297
# Time taken for 1 epoch 21.905453205108643 sec
#
# Epoch 481 Loss 1.1320 Acc 0.4055
# Time taken for 1 epoch 21.873157501220703 sec
#
# Epoch 482 Loss 1.1449 Acc 0.4022
# Time taken for 1 epoch 21.88497233390808 sec
#
# Epoch 483 Loss 1.1212 Acc 0.4097
# Time taken for 1 epoch 21.98415756225586 sec
#
# Epoch 484 Loss 1.1042 Acc 0.4154
# Time taken for 1 epoch 21.912519216537476 sec
#
# Epoch 485 Loss 1.0931 Acc 0.4196
# Time taken for 1 epoch 21.799411296844482 sec
#
# Epoch 486 Loss 1.0826 Acc 0.4230
# Time taken for 1 epoch 21.715070962905884 sec
#
# Epoch 487 Loss 1.0805 Acc 0.4236
# Time taken for 1 epoch 21.752530813217163 sec
#
# Epoch 488 Loss 1.0826 Acc 0.4232
# Time taken for 1 epoch 22.095197916030884 sec
#
# Epoch 489 Loss 1.0770 Acc 0.4255
# Time taken for 1 epoch 21.771574020385742 sec
#
# Epoch 490 Loss 1.0752 Acc 0.4260
# Time taken for 1 epoch 21.964428424835205 sec
#
# Epoch 491 Loss 1.1257 Acc 0.4082
# Time taken for 1 epoch 21.8376042842865 sec
#
# Epoch 492 Loss 1.1105 Acc 0.4135
# Time taken for 1 epoch 21.91813564300537 sec
#
# Epoch 493 Loss 1.0995 Acc 0.4174
# Time taken for 1 epoch 21.75098419189453 sec
#
# Epoch 494 Loss 1.0948 Acc 0.4191
# Time taken for 1 epoch 21.803534030914307 sec
#
# Epoch 495 Loss 1.0902 Acc 0.4205
# Time taken for 1 epoch 21.952149629592896 sec
#
# Epoch 496 Loss 1.0897 Acc 0.4209
# Time taken for 1 epoch 21.84223747253418 sec
#
# Epoch 497 Loss 1.0911 Acc 0.4206
# Time taken for 1 epoch 21.77321743965149 sec
#
# Epoch 498 Loss 1.0928 Acc 0.4200
# Time taken for 1 epoch 21.77161741256714 sec
#
# Epoch 499 Loss 1.0985 Acc 0.4180
# Time taken for 1 epoch 21.894857168197632 sec
#
# Epoch 500 Loss 1.0947 Acc 0.4192
# Time taken for 1 epoch 21.962374687194824 sec

# %%
plt.plot(loss_history)

# %%
checkpoint.save(checkpoint_prefix)
# Out:
# './checkpoints/full/ckpt-2'

# %%
np.save("full_500.npy", np.array(loss_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a, step=PIECE_LEN):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    pad_count = step - (a.shape[0] % step)
    # print(a.shape, end=' ')
    if pad_count!=step : 
        # print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, step, a.shape[1]))
    # print('to',a.shape)
    return a

# %%
import midi_np_translation.output2midi as output2midi

# %%
test_file = np.load("preprocessed_dataset/irealpro_midi/Autumn Leaves_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), 
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid", 
                           output_path="experiments/BDLSTM_Full/autumn_irealpro.mid")
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
test_file = np.load("preprocessed_dataset/dense_jazz/AutumnLeaves_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), 
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid", 
                           output_path="experiments/BDLSTM_Full/autumn_arr.mid")
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
test_file = np.load("preprocessed_dataset/dense_jazz/PieceOfMyWish_p1.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), 
                           ref_midi_path="input_midi/transpose_augmentation/PieceOfMyWish_p1.mid", 
                           output_path="experiments/BDLSTM_Full/PieceOfMyWish.mid")
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
test_file = np.load("preprocessed_dataset/augmentation/55Dive_o0.mid.npy")
test_result = model.predict(slice_per_step(test_file))
output2midi.output_to_midi(bass_ndarr=test_result.reshape(-1,52), 
                           ref_midi_path="input_midi/transpose_augmentation/55Dive_o0.mid", 
                           output_path="experiments/BDLSTM_Full/55Dive.mid")
# Out:
# 1/1 [==============================] - 0s 70ms/step
