# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-18 03:27:52.305020: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 03:27:52.881635: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-18 03:27:52.881718: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-18 03:27:52.881725: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
EXPERIMENT_TITLE = "13_BDLSTM_16-50/"
EXPERIMENT_DIR = "experiments/" + EXPERIMENT_TITLE

BATCH_SIZE = 4096
PIECE_LEN = 16
n_feature = 43
n_hidden = 50
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# 2023-01-18 03:27:57.294075: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.299434: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.299672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.300175: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 03:27:57.300653: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.300955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.301130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.759635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.759822: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.759937: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 03:27:57.760030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 16, 43)]          0
#
#  mask (Masking)              (None, 16, 43)            0
#
#  input (TimeDistributed)     (None, 16, 50)            2200
#
#  bidirectional (Bidirectiona  (None, 16, 100)          40400
#  l)
#
#  output (TimeDistributed)    (None, 16, 53)            5353
#
# =================================================================
# Total params: 47,953
# Trainable params: 47,953
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/' + EXPERIMENT_TITLE
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# 2023-01-18 03:28:35.521721: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_20/output/_23'
# 2023-01-18 03:28:36.370488: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-01-18 03:28:36.956204: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fa90102d600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-18 03:28:36.956247: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-01-18 03:28:37.225652: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-18 03:28:38.448826: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:38.492239: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2023-01-18 03:28:38.492276: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-01-18 03:28:38.494184: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-01-18 03:28:38.597612: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:38.745561: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:38.881484: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.031600: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.164008: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.301916: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.430842: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.568095: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-18 03:28:39.701105: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# Epoch 1 Loss 2.8424 Acc 0.2512
# Validation Loss 2.6871 Acc 0.2506
# Time taken for 1 epoch 826.3281373977661 sec
#
# Epoch 2 Loss 2.5754 Acc 0.2829
# Validation Loss 2.6078 Acc 0.2622
# Time taken for 1 epoch 15.759775400161743 sec
#
# Epoch 3 Loss 2.5233 Acc 0.2916
# Validation Loss 2.5617 Acc 0.2740
# Time taken for 1 epoch 15.76781678199768 sec
#
# Epoch 4 Loss 2.4921 Acc 0.3004
# Validation Loss 2.5282 Acc 0.2848
# Time taken for 1 epoch 15.822340726852417 sec
#
# Epoch 5 Loss 2.4589 Acc 0.3099
# Validation Loss 2.4921 Acc 0.2936
# Time taken for 1 epoch 15.883819103240967 sec
#
# Epoch 6 Loss 2.4345 Acc 0.3177
# Validation Loss 2.5056 Acc 0.2782
# Time taken for 1 epoch 15.87652850151062 sec
#
# Epoch 7 Loss 2.4099 Acc 0.3244
# Validation Loss 2.4597 Acc 0.3019
# Time taken for 1 epoch 15.954767942428589 sec
#
# Epoch 8 Loss 2.4034 Acc 0.3265
# Validation Loss 2.4575 Acc 0.3047
# Time taken for 1 epoch 15.991644144058228 sec
#
# Epoch 9 Loss 2.4107 Acc 0.3256
# Validation Loss 2.5007 Acc 0.2846
# Time taken for 1 epoch 15.96342134475708 sec
#
# Epoch 10 Loss 2.4120 Acc 0.3236
# Validation Loss 2.4579 Acc 0.3012
# Time taken for 1 epoch 15.998631000518799 sec
#
# Epoch 11 Loss 2.3894 Acc 0.3303
# Validation Loss 2.4567 Acc 0.3066
# Time taken for 1 epoch 15.977674961090088 sec
#
# Epoch 12 Loss 2.3798 Acc 0.3331
# Validation Loss 2.4504 Acc 0.3079
# Time taken for 1 epoch 15.974049806594849 sec
#
# Epoch 13 Loss 2.3724 Acc 0.3348
# Validation Loss 2.4439 Acc 0.3008
# Time taken for 1 epoch 15.970247030258179 sec
#
# Epoch 14 Loss 2.3805 Acc 0.3325
# Validation Loss 2.4476 Acc 0.2980
# Time taken for 1 epoch 15.974058628082275 sec
#
# Epoch 15 Loss 2.3680 Acc 0.3356
# Validation Loss 2.4468 Acc 0.2996
# Time taken for 1 epoch 16.013758420944214 sec
#
# Epoch 16 Loss 2.3656 Acc 0.3359
# Validation Loss 2.4329 Acc 0.3076
# Time taken for 1 epoch 15.997079849243164 sec
#
# Epoch 17 Loss 2.3610 Acc 0.3371
# Validation Loss 2.4381 Acc 0.3032
# Time taken for 1 epoch 16.04419708251953 sec
#
# Epoch 18 Loss 2.3586 Acc 0.3373
# Validation Loss 2.4357 Acc 0.3091
# Time taken for 1 epoch 16.03363299369812 sec
#
# Epoch 19 Loss 2.3569 Acc 0.3375
# Validation Loss 2.4304 Acc 0.3060
# Time taken for 1 epoch 16.021371364593506 sec
#
# Epoch 20 Loss 2.3593 Acc 0.3368
# Validation Loss 2.4274 Acc 0.3101
# Time taken for 1 epoch 16.013325691223145 sec
#
# Epoch 21 Loss 2.3570 Acc 0.3370
# Validation Loss 2.4279 Acc 0.3103
# Time taken for 1 epoch 16.01647162437439 sec
#
# Epoch 22 Loss 2.3512 Acc 0.3385
# Validation Loss 2.4253 Acc 0.3108
# Time taken for 1 epoch 16.038552284240723 sec
#
# Epoch 23 Loss 2.3661 Acc 0.3343
# Validation Loss 2.4243 Acc 0.3110
# Time taken for 1 epoch 16.040100574493408 sec
#
# Epoch 24 Loss 2.3490 Acc 0.3390
# Validation Loss 2.4247 Acc 0.3108
# Time taken for 1 epoch 16.10006809234619 sec
#
# Epoch 25 Loss 2.3597 Acc 0.3362
# Validation Loss 2.4500 Acc 0.2928
# Time taken for 1 epoch 15.979947328567505 sec
#
# Epoch 26 Loss 2.3467 Acc 0.3390
# Validation Loss 2.4217 Acc 0.3107
# Time taken for 1 epoch 16.077044248580933 sec
#
# Epoch 27 Loss 2.3746 Acc 0.3320
# Validation Loss 2.4310 Acc 0.3094
# Time taken for 1 epoch 16.10649609565735 sec
#
# Epoch 28 Loss 2.3509 Acc 0.3382
# Validation Loss 2.4254 Acc 0.3066
# Time taken for 1 epoch 16.060024976730347 sec
#
# Epoch 29 Loss 2.3442 Acc 0.3396
# Validation Loss 2.4290 Acc 0.3091
# Time taken for 1 epoch 15.98789358139038 sec
#
# Epoch 30 Loss 2.3485 Acc 0.3385
# Validation Loss 2.4345 Acc 0.2981
# Time taken for 1 epoch 16.04718852043152 sec
#
# Epoch 31 Loss 2.3443 Acc 0.3393
# Validation Loss 2.4230 Acc 0.3097
# Time taken for 1 epoch 16.035159826278687 sec
#
# Epoch 32 Loss 2.3497 Acc 0.3379
# Validation Loss 2.4185 Acc 0.3100
# Time taken for 1 epoch 16.073310136795044 sec
#
# Epoch 33 Loss 2.3469 Acc 0.3387
# Validation Loss 2.4813 Acc 0.2932
# Time taken for 1 epoch 16.069716215133667 sec
#
# Epoch 34 Loss 2.3508 Acc 0.3376
# Validation Loss 2.4193 Acc 0.3064
# Time taken for 1 epoch 16.068868160247803 sec
#
# Epoch 35 Loss 2.3402 Acc 0.3400
# Validation Loss 2.4150 Acc 0.3093
# Time taken for 1 epoch 16.038928747177124 sec
#
# Epoch 36 Loss 2.3838 Acc 0.3295
# Validation Loss 2.4276 Acc 0.3083
# Time taken for 1 epoch 16.017320156097412 sec
#
# Epoch 37 Loss 2.3501 Acc 0.3379
# Validation Loss 2.4355 Acc 0.2976
# Time taken for 1 epoch 15.9986252784729 sec
#
# Epoch 38 Loss 2.3436 Acc 0.3394
# Validation Loss 2.4154 Acc 0.3108
# Time taken for 1 epoch 16.074259281158447 sec
#
# Epoch 39 Loss 2.3405 Acc 0.3399
# Validation Loss 2.4308 Acc 0.2983
# Time taken for 1 epoch 16.08759570121765 sec
#
# Epoch 40 Loss 2.3378 Acc 0.3404
# Validation Loss 2.4127 Acc 0.3100
# Time taken for 1 epoch 16.000853300094604 sec
#
# Epoch 41 Loss 2.3392 Acc 0.3397
# Validation Loss 2.4290 Acc 0.3044
# Time taken for 1 epoch 16.02912974357605 sec
#
# Epoch 42 Loss 2.3371 Acc 0.3403
# Validation Loss 2.4107 Acc 0.3110
# Time taken for 1 epoch 16.0396089553833 sec
#
# Epoch 43 Loss 2.3339 Acc 0.3412
# Validation Loss 2.4263 Acc 0.2989
# Time taken for 1 epoch 16.08009648323059 sec
#
# Epoch 44 Loss 2.3562 Acc 0.3352
# Validation Loss 2.4260 Acc 0.3003
# Time taken for 1 epoch 16.008849620819092 sec
#
# Epoch 45 Loss 2.3368 Acc 0.3400
# Validation Loss 2.4121 Acc 0.3083
# Time taken for 1 epoch 15.988577127456665 sec
#
# Epoch 46 Loss 2.3343 Acc 0.3410
# Validation Loss 2.4106 Acc 0.3103
# Time taken for 1 epoch 16.061578035354614 sec
#
# Epoch 47 Loss 2.3382 Acc 0.3398
# Validation Loss 2.4258 Acc 0.2995
# Time taken for 1 epoch 16.032105207443237 sec
#
# Epoch 48 Loss 2.3335 Acc 0.3410
# Validation Loss 2.4077 Acc 0.3108
# Time taken for 1 epoch 16.098246574401855 sec
#
# Epoch 49 Loss 2.3319 Acc 0.3412
# Validation Loss 2.4135 Acc 0.3056
# Time taken for 1 epoch 15.98013162612915 sec
#
# Epoch 50 Loss 2.3297 Acc 0.3417
# Validation Loss 2.4214 Acc 0.3032
# Time taken for 1 epoch 16.032008409500122 sec
#
# Epoch 51 Loss 2.3363 Acc 0.3397
# Validation Loss 2.4073 Acc 0.3101
# Time taken for 1 epoch 16.10547399520874 sec
#
# Epoch 52 Loss 2.3311 Acc 0.3412
# Validation Loss 2.4459 Acc 0.2874
# Time taken for 1 epoch 15.957569360733032 sec
#
# Epoch 53 Loss 2.3327 Acc 0.3407
# Validation Loss 2.4083 Acc 0.3104
# Time taken for 1 epoch 16.117908000946045 sec
#
# Epoch 54 Loss 2.3523 Acc 0.3366
# Validation Loss 2.4183 Acc 0.3052
# Time taken for 1 epoch 15.9828622341156 sec
#
# Epoch 55 Loss 2.3425 Acc 0.3384
# Validation Loss 2.4225 Acc 0.3034
# Time taken for 1 epoch 16.09837508201599 sec
#
# Epoch 56 Loss 2.3292 Acc 0.3419
# Validation Loss 2.4128 Acc 0.3073
# Time taken for 1 epoch 16.106919527053833 sec
#
# Epoch 57 Loss 2.3269 Acc 0.3428
# Validation Loss 2.4107 Acc 0.3081
# Time taken for 1 epoch 16.07542085647583 sec
#
# Epoch 58 Loss 2.3329 Acc 0.3411
# Validation Loss 2.4100 Acc 0.3084
# Time taken for 1 epoch 16.084007740020752 sec
#
# Epoch 59 Loss 2.3273 Acc 0.3424
# Validation Loss 2.4203 Acc 0.3012
# Time taken for 1 epoch 16.017831563949585 sec
#
# Epoch 60 Loss 2.3588 Acc 0.3348
# Validation Loss 2.4265 Acc 0.3002
# Time taken for 1 epoch 16.078241109848022 sec
#
# Epoch 61 Loss 2.3303 Acc 0.3419
# Validation Loss 2.4307 Acc 0.2990
# Time taken for 1 epoch 16.028136730194092 sec
#
# Epoch 62 Loss 2.3253 Acc 0.3432
# Validation Loss 2.4079 Acc 0.3094
# Time taken for 1 epoch 16.15558409690857 sec
#
# Epoch 63 Loss 2.3212 Acc 0.3444
# Validation Loss 2.4074 Acc 0.3097
# Time taken for 1 epoch 16.072412729263306 sec
#
# Epoch 64 Loss 2.3296 Acc 0.3418
# Validation Loss 2.4221 Acc 0.3009
# Time taken for 1 epoch 16.14254093170166 sec
#
# Epoch 65 Loss 2.3555 Acc 0.3361
# Validation Loss 2.4236 Acc 0.3032
# Time taken for 1 epoch 16.057774305343628 sec
#
# Epoch 66 Loss 2.3313 Acc 0.3425
# Validation Loss 2.4208 Acc 0.3011
# Time taken for 1 epoch 16.122779369354248 sec
#
# Epoch 67 Loss 2.3305 Acc 0.3421
# Validation Loss 2.4090 Acc 0.3098
# Time taken for 1 epoch 16.09204912185669 sec
#
# Epoch 68 Loss 2.3343 Acc 0.3414
# Validation Loss 2.4568 Acc 0.2911
# Time taken for 1 epoch 16.0472252368927 sec
#
# Epoch 69 Loss 2.3264 Acc 0.3430
# Validation Loss 2.4086 Acc 0.3085
# Time taken for 1 epoch 15.989153385162354 sec
#
# Epoch 70 Loss 2.3221 Acc 0.3444
# Validation Loss 2.4163 Acc 0.3036
# Time taken for 1 epoch 16.1396427154541 sec
#
# Epoch 71 Loss 2.3406 Acc 0.3400
# Validation Loss 2.4221 Acc 0.2997
# Time taken for 1 epoch 15.991209745407104 sec
#
# Epoch 72 Loss 2.3423 Acc 0.3401
# Validation Loss 2.4135 Acc 0.3065
# Time taken for 1 epoch 16.050500631332397 sec
#
# Epoch 73 Loss 2.3236 Acc 0.3450
# Validation Loss 2.4281 Acc 0.2966
# Time taken for 1 epoch 16.032867431640625 sec
#
# Epoch 74 Loss 2.3211 Acc 0.3454
# Validation Loss 2.4068 Acc 0.3097
# Time taken for 1 epoch 16.066186666488647 sec
#
# Epoch 75 Loss 2.3441 Acc 0.3395
# Validation Loss 2.4213 Acc 0.3004
# Time taken for 1 epoch 16.068336009979248 sec
#
# Epoch 76 Loss 2.3218 Acc 0.3449
# Validation Loss 2.4071 Acc 0.3077
# Time taken for 1 epoch 16.106077194213867 sec
#
# Epoch 77 Loss 2.3280 Acc 0.3434
# Validation Loss 2.4241 Acc 0.2990
# Time taken for 1 epoch 15.957789182662964 sec
#
# Epoch 78 Loss 2.3213 Acc 0.3446
# Validation Loss 2.4110 Acc 0.3053
# Time taken for 1 epoch 16.082871913909912 sec
#
# Epoch 79 Loss 2.3160 Acc 0.3464
# Validation Loss 2.4106 Acc 0.3085
# Time taken for 1 epoch 16.03276777267456 sec
#
# Epoch 80 Loss 2.3162 Acc 0.3460
# Validation Loss 2.4308 Acc 0.2936
# Time taken for 1 epoch 16.079702615737915 sec
#
# Epoch 81 Loss 2.3165 Acc 0.3457
# Validation Loss 2.4014 Acc 0.3093
# Time taken for 1 epoch 16.079110860824585 sec
#
# Epoch 82 Loss 2.3288 Acc 0.3426
# Validation Loss 2.4131 Acc 0.3048
# Time taken for 1 epoch 16.062166213989258 sec
#
# Epoch 83 Loss 2.3225 Acc 0.3441
# Validation Loss 2.4085 Acc 0.3089
# Time taken for 1 epoch 15.996954441070557 sec
#
# Epoch 84 Loss 2.3151 Acc 0.3461
# Validation Loss 2.4178 Acc 0.3007
# Time taken for 1 epoch 16.10964608192444 sec
#
# Epoch 85 Loss 2.3311 Acc 0.3425
# Validation Loss 2.4509 Acc 0.2991
# Time taken for 1 epoch 15.994028568267822 sec
#
# Epoch 86 Loss 2.3336 Acc 0.3421
# Validation Loss 2.4160 Acc 0.2995
# Time taken for 1 epoch 16.081924438476562 sec
#
# Epoch 87 Loss 2.3161 Acc 0.3460
# Validation Loss 2.4046 Acc 0.3076
# Time taken for 1 epoch 16.045727014541626 sec
#
# Epoch 88 Loss 2.3142 Acc 0.3465
# Validation Loss 2.4224 Acc 0.2972
# Time taken for 1 epoch 16.058215618133545 sec
#
# Epoch 89 Loss 2.3143 Acc 0.3465
# Validation Loss 2.4157 Acc 0.3007
# Time taken for 1 epoch 16.14534878730774 sec
#
# Epoch 90 Loss 2.3098 Acc 0.3478
# Validation Loss 2.4138 Acc 0.3011
# Time taken for 1 epoch 16.030651330947876 sec
#
# Epoch 91 Loss 2.3246 Acc 0.3436
# Validation Loss 2.4144 Acc 0.3031
# Time taken for 1 epoch 16.098259687423706 sec
#
# Epoch 92 Loss 2.3121 Acc 0.3470
# Validation Loss 2.4105 Acc 0.3043
# Time taken for 1 epoch 16.080355405807495 sec
#
# Epoch 93 Loss 2.3301 Acc 0.3431
# Validation Loss 2.4129 Acc 0.3028
# Time taken for 1 epoch 15.992507457733154 sec
#
# Epoch 94 Loss 2.3154 Acc 0.3463
# Validation Loss 2.4094 Acc 0.3046
# Time taken for 1 epoch 16.127009391784668 sec
#
# Epoch 95 Loss 2.3383 Acc 0.3408
# Validation Loss 2.4067 Acc 0.3089
# Time taken for 1 epoch 16.1479070186615 sec
#
# Epoch 96 Loss 2.3119 Acc 0.3479
# Validation Loss 2.4151 Acc 0.3017
# Time taken for 1 epoch 16.029401302337646 sec
#
# Epoch 97 Loss 2.3159 Acc 0.3466
# Validation Loss 2.4258 Acc 0.2953
# Time taken for 1 epoch 16.15250277519226 sec
#
# Epoch 98 Loss 2.3263 Acc 0.3440
# Validation Loss 2.4141 Acc 0.3014
# Time taken for 1 epoch 16.084412336349487 sec
#
# Epoch 99 Loss 2.3122 Acc 0.3473
# Validation Loss 2.4065 Acc 0.3092
# Time taken for 1 epoch 16.07013440132141 sec
#
# Epoch 100 Loss 2.3126 Acc 0.3472
# Validation Loss 2.4037 Acc 0.3097
# Time taken for 1 epoch 16.099557161331177 sec

# %% [markdown]
# 40m 14.6s used

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 8 to (98, 16, 43)
# 4/4 [==============================] - 2s 3ms/step
# (1560, 53)
# (1712, 43) to (107, 16, 43)
# 4/4 [==============================] - 0s 2ms/step
# (1712, 53)
# (3731, 43) pad by 13 to (234, 16, 43)
# 8/8 [==============================] - 0s 2ms/step
# (3731, 53)
# (3137, 43) pad by 15 to (197, 16, 43)
# 7/7 [==============================] - 0s 2ms/step
# (3137, 53)
# (1536, 43) to (96, 16, 43)
# 3/3 [==============================] - 0s 2ms/step
# (1536, 53)
