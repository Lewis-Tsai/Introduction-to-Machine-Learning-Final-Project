# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-16 01:25:41.129837: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 01:25:43.243393: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-16 01:25:43.243456: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-16 01:25:43.243463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BATCH_SIZE = 512
VALIDATION_RATIO = 0.1

PIECE_LEN = 1024
n_feature = 43
n_hidden = 100
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-01-16 01:26:18.888038: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:18.901596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:18.901745: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:18.902263: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 01:26:18.902823: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:18.902950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:18.903065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:22.253741: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:22.254052: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:22.254283: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 01:26:22.254450: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature))(input) # Ignore Padded Data
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, ))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax"))(x)
model = tf.keras.Model(inputs=input, outputs=x)

print(model.summary())

# optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024, 43)]        0
#
#  masking (Masking)           (None, 1024, 43)          0
#
#  bidirectional (Bidirectiona  (None, 1024, 200)        115200
#  l)
#
#  time_distributed (TimeDistr  (None, 1024, 53)         10653
#  ibuted)
#
# =================================================================
# Total params: 125,853
# Trainable params: 125,853
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/01_BDLSTM_naive_adam'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 300

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))
# Out:
# Epoch 1 Loss 2.4712 Acc 0.1578
# Validation Loss 2.1736 Acc 0.1749
# Time taken for 1 epoch 125.87885427474976 sec
#
# Epoch 2 Loss 2.0575 Acc 0.2046
# Validation Loss 2.0666 Acc 0.1904
# Time taken for 1 epoch 13.046898126602173 sec
#
# Epoch 3 Loss 1.9921 Acc 0.2133
# Validation Loss 2.0325 Acc 0.1971
# Time taken for 1 epoch 13.017701625823975 sec
#
# Epoch 4 Loss 1.9647 Acc 0.2184
# Validation Loss 2.0126 Acc 0.2015
# Time taken for 1 epoch 13.141621828079224 sec
#
# Epoch 5 Loss 1.9476 Acc 0.2217
# Validation Loss 1.9988 Acc 0.2054
# Time taken for 1 epoch 13.069517135620117 sec
#
# Epoch 6 Loss 1.9348 Acc 0.2245
# Validation Loss 1.9868 Acc 0.2088
# Time taken for 1 epoch 13.138393640518188 sec
#
# Epoch 7 Loss 1.9235 Acc 0.2267
# Validation Loss 1.9784 Acc 0.2114
# Time taken for 1 epoch 13.153818368911743 sec
#
# Epoch 8 Loss 1.9138 Acc 0.2290
# Validation Loss 1.9696 Acc 0.2140
# Time taken for 1 epoch 13.234074831008911 sec
#
# Epoch 9 Loss 1.9048 Acc 0.2313
# Validation Loss 1.9625 Acc 0.2156
# Time taken for 1 epoch 13.105607509613037 sec
#
# Epoch 10 Loss 1.8980 Acc 0.2334
# Validation Loss 1.9552 Acc 0.2181
# Time taken for 1 epoch 13.14024567604065 sec
#
# Epoch 11 Loss 1.8902 Acc 0.2353
# Validation Loss 1.9479 Acc 0.2196
# Time taken for 1 epoch 13.125380992889404 sec
#
# Epoch 12 Loss 1.8816 Acc 0.2378
# Validation Loss 1.9374 Acc 0.2225
# Time taken for 1 epoch 13.07201886177063 sec
#
# Epoch 13 Loss 1.8688 Acc 0.2423
# Validation Loss 1.9261 Acc 0.2264
# Time taken for 1 epoch 13.174373626708984 sec
#
# Epoch 14 Loss 1.8562 Acc 0.2465
# Validation Loss 1.9185 Acc 0.2281
# Time taken for 1 epoch 13.140310764312744 sec
#
# Epoch 15 Loss 1.8441 Acc 0.2502
# Validation Loss 1.9138 Acc 0.2290
# Time taken for 1 epoch 13.177380800247192 sec
#
# Epoch 16 Loss 1.8332 Acc 0.2531
# Validation Loss 1.9022 Acc 0.2331
# Time taken for 1 epoch 13.128153324127197 sec
#
# Epoch 17 Loss 1.8191 Acc 0.2577
# Validation Loss 1.8968 Acc 0.2353
# Time taken for 1 epoch 13.161402702331543 sec
#
# Epoch 18 Loss 1.8081 Acc 0.2608
# Validation Loss 1.8832 Acc 0.2383
# Time taken for 1 epoch 13.15967082977295 sec
#
# Epoch 19 Loss 1.7986 Acc 0.2633
# Validation Loss 1.8791 Acc 0.2401
# Time taken for 1 epoch 13.07235860824585 sec
#
# Epoch 20 Loss 1.7919 Acc 0.2650
# Validation Loss 1.8719 Acc 0.2412
# Time taken for 1 epoch 13.184204816818237 sec
#
# Epoch 21 Loss 1.7887 Acc 0.2653
# Validation Loss 1.8748 Acc 0.2386
# Time taken for 1 epoch 13.126298904418945 sec
#
# Epoch 22 Loss 1.7844 Acc 0.2663
# Validation Loss 1.8698 Acc 0.2400
# Time taken for 1 epoch 13.163298845291138 sec
#
# Epoch 23 Loss 1.7985 Acc 0.2610
# Validation Loss 1.8880 Acc 0.2349
# Time taken for 1 epoch 13.140844345092773 sec
#
# Epoch 24 Loss 1.7876 Acc 0.2649
# Validation Loss 1.8672 Acc 0.2402
# Time taken for 1 epoch 13.187514781951904 sec
#
# Epoch 25 Loss 1.7721 Acc 0.2693
# Validation Loss 1.8643 Acc 0.2411
# Time taken for 1 epoch 13.111029148101807 sec
#
# Epoch 26 Loss 1.7687 Acc 0.2702
# Validation Loss 1.8637 Acc 0.2415
# Time taken for 1 epoch 13.188250064849854 sec
#
# Epoch 27 Loss 1.7675 Acc 0.2702
# Validation Loss 1.8609 Acc 0.2416
# Time taken for 1 epoch 13.100528478622437 sec
#
# Epoch 28 Loss 1.7632 Acc 0.2714
# Validation Loss 1.8626 Acc 0.2410
# Time taken for 1 epoch 13.128632068634033 sec
#
# Epoch 29 Loss 1.7608 Acc 0.2720
# Validation Loss 1.8599 Acc 0.2414
# Time taken for 1 epoch 13.162750244140625 sec
#
# Epoch 30 Loss 1.7587 Acc 0.2726
# Validation Loss 1.8584 Acc 0.2420
# Time taken for 1 epoch 13.085587739944458 sec
#
# Epoch 31 Loss 1.7565 Acc 0.2730
# Validation Loss 1.8585 Acc 0.2419
# Time taken for 1 epoch 13.188708782196045 sec
#
# Epoch 32 Loss 1.7549 Acc 0.2733
# Validation Loss 1.8569 Acc 0.2422
# Time taken for 1 epoch 13.167822360992432 sec
#
# Epoch 33 Loss 1.7557 Acc 0.2729
# Validation Loss 1.8653 Acc 0.2381
# Time taken for 1 epoch 13.128489017486572 sec
#
# Epoch 34 Loss 1.7535 Acc 0.2735
# Validation Loss 1.8558 Acc 0.2419
# Time taken for 1 epoch 13.104060173034668 sec
#
# Epoch 35 Loss 1.7499 Acc 0.2745
# Validation Loss 1.8561 Acc 0.2415
# Time taken for 1 epoch 13.140099048614502 sec
#
# Epoch 36 Loss 1.7475 Acc 0.2751
# Validation Loss 1.8530 Acc 0.2422
# Time taken for 1 epoch 13.121922731399536 sec
#
# Epoch 37 Loss 1.7445 Acc 0.2760
# Validation Loss 1.8530 Acc 0.2425
# Time taken for 1 epoch 13.22041654586792 sec
#
# Epoch 38 Loss 1.7433 Acc 0.2763
# Validation Loss 1.8511 Acc 0.2429
# Time taken for 1 epoch 13.286153316497803 sec
#
# Epoch 39 Loss 1.7434 Acc 0.2762
# Validation Loss 1.8666 Acc 0.2392
# Time taken for 1 epoch 13.124683380126953 sec
#
# Epoch 40 Loss 1.7459 Acc 0.2755
# Validation Loss 1.8520 Acc 0.2431
# Time taken for 1 epoch 13.13343620300293 sec
#
# Epoch 41 Loss 1.7394 Acc 0.2773
# Validation Loss 1.8486 Acc 0.2441
# Time taken for 1 epoch 13.141221046447754 sec
#
# Epoch 42 Loss 1.7376 Acc 0.2777
# Validation Loss 1.8495 Acc 0.2436
# Time taken for 1 epoch 13.16938853263855 sec
#
# Epoch 43 Loss 1.7360 Acc 0.2781
# Validation Loss 1.8504 Acc 0.2433
# Time taken for 1 epoch 13.174480199813843 sec
#
# Epoch 44 Loss 1.7341 Acc 0.2787
# Validation Loss 1.8474 Acc 0.2447
# Time taken for 1 epoch 13.0536630153656 sec
#
# Epoch 45 Loss 1.7327 Acc 0.2790
# Validation Loss 1.8487 Acc 0.2438
# Time taken for 1 epoch 13.19697904586792 sec
#
# Epoch 46 Loss 1.7312 Acc 0.2794
# Validation Loss 1.8489 Acc 0.2436
# Time taken for 1 epoch 13.152466535568237 sec
#
# Epoch 47 Loss 1.7299 Acc 0.2797
# Validation Loss 1.8478 Acc 0.2435
# Time taken for 1 epoch 13.162553310394287 sec
#
# Epoch 48 Loss 1.7289 Acc 0.2799
# Validation Loss 1.8477 Acc 0.2440
# Time taken for 1 epoch 13.176103353500366 sec
#
# Epoch 49 Loss 1.7294 Acc 0.2798
# Validation Loss 1.8479 Acc 0.2442
# Time taken for 1 epoch 13.139305591583252 sec
#
# Epoch 50 Loss 1.7270 Acc 0.2802
# Validation Loss 1.8482 Acc 0.2436
# Time taken for 1 epoch 13.159279346466064 sec
#
# Epoch 51 Loss 1.7252 Acc 0.2808
# Validation Loss 1.8506 Acc 0.2430
# Time taken for 1 epoch 13.198439598083496 sec
#
# Epoch 52 Loss 1.7246 Acc 0.2809
# Validation Loss 1.8508 Acc 0.2430
# Time taken for 1 epoch 13.088519811630249 sec
#
# Epoch 53 Loss 1.7235 Acc 0.2812
# Validation Loss 1.8502 Acc 0.2436
# Time taken for 1 epoch 13.187309503555298 sec
#
# Epoch 54 Loss 1.7603 Acc 0.2707
# Validation Loss 1.8617 Acc 0.2412
# Time taken for 1 epoch 13.08431601524353 sec
#
# Epoch 55 Loss 1.7344 Acc 0.2788
# Validation Loss 1.8506 Acc 0.2439
# Time taken for 1 epoch 13.141454696655273 sec
#
# Epoch 56 Loss 1.7271 Acc 0.2803
# Validation Loss 1.8518 Acc 0.2430
# Time taken for 1 epoch 13.142189025878906 sec
#
# Epoch 57 Loss 1.7245 Acc 0.2807
# Validation Loss 1.8511 Acc 0.2429
# Time taken for 1 epoch 13.1794912815094 sec
#
# Epoch 58 Loss 1.7197 Acc 0.2822
# Validation Loss 1.8491 Acc 0.2438
# Time taken for 1 epoch 13.124661207199097 sec
#
# Epoch 59 Loss 1.7178 Acc 0.2826
# Validation Loss 1.8500 Acc 0.2434
# Time taken for 1 epoch 13.159395694732666 sec
#
# Epoch 60 Loss 1.7166 Acc 0.2829
# Validation Loss 1.8516 Acc 0.2431
# Time taken for 1 epoch 13.131994724273682 sec
#
# Epoch 61 Loss 1.7166 Acc 0.2827
# Validation Loss 1.8523 Acc 0.2425
# Time taken for 1 epoch 13.129788637161255 sec
#
# Epoch 62 Loss 1.7161 Acc 0.2826
# Validation Loss 1.8534 Acc 0.2422
# Time taken for 1 epoch 13.17339038848877 sec
#
# Epoch 63 Loss 1.7145 Acc 0.2833
# Validation Loss 1.8505 Acc 0.2433
# Time taken for 1 epoch 13.106218814849854 sec
#
# Epoch 64 Loss 1.7126 Acc 0.2839
# Validation Loss 1.8499 Acc 0.2440
# Time taken for 1 epoch 13.121084928512573 sec
#
# Epoch 65 Loss 1.7114 Acc 0.2841
# Validation Loss 1.8514 Acc 0.2428
# Time taken for 1 epoch 13.176810264587402 sec
#
# Epoch 66 Loss 1.7107 Acc 0.2842
# Validation Loss 1.8504 Acc 0.2436
# Time taken for 1 epoch 13.127691745758057 sec
#
# Epoch 67 Loss 1.7095 Acc 0.2846
# Validation Loss 1.8521 Acc 0.2428
# Time taken for 1 epoch 13.136930704116821 sec
#
# Epoch 68 Loss 1.7095 Acc 0.2844
# Validation Loss 1.8506 Acc 0.2429
# Time taken for 1 epoch 13.175727128982544 sec
#
# Epoch 69 Loss 1.7136 Acc 0.2826
# Validation Loss 1.8486 Acc 0.2435
# Time taken for 1 epoch 13.089566230773926 sec
#
# Epoch 70 Loss 1.7148 Acc 0.2823
# Validation Loss 1.8494 Acc 0.2434
# Time taken for 1 epoch 13.16453766822815 sec
#
# Epoch 71 Loss 1.7127 Acc 0.2828
# Validation Loss 1.8527 Acc 0.2418
# Time taken for 1 epoch 13.109961032867432 sec
#
# Epoch 72 Loss 1.7075 Acc 0.2844
# Validation Loss 1.8521 Acc 0.2426
# Time taken for 1 epoch 13.18236231803894 sec
#
# Epoch 73 Loss 1.7071 Acc 0.2847
# Validation Loss 1.8508 Acc 0.2425
# Time taken for 1 epoch 13.15058445930481 sec
#
# Epoch 74 Loss 1.7056 Acc 0.2850
# Validation Loss 1.8511 Acc 0.2429
# Time taken for 1 epoch 13.13711142539978 sec
#
# Epoch 75 Loss 1.7043 Acc 0.2853
# Validation Loss 1.8502 Acc 0.2433
# Time taken for 1 epoch 13.118602514266968 sec
#
# Epoch 76 Loss 1.7034 Acc 0.2855
# Validation Loss 1.8501 Acc 0.2433
# Time taken for 1 epoch 13.136343240737915 sec
#
# Epoch 77 Loss 1.7024 Acc 0.2858
# Validation Loss 1.8496 Acc 0.2436
# Time taken for 1 epoch 13.200857639312744 sec
#
# Epoch 78 Loss 1.7015 Acc 0.2861
# Validation Loss 1.8489 Acc 0.2439
# Time taken for 1 epoch 13.161145687103271 sec
#
# Epoch 79 Loss 1.7002 Acc 0.2863
# Validation Loss 1.8498 Acc 0.2438
# Time taken for 1 epoch 13.119441986083984 sec
#
# Epoch 80 Loss 1.6988 Acc 0.2867
# Validation Loss 1.8500 Acc 0.2436
# Time taken for 1 epoch 13.10845947265625 sec
#
# Epoch 81 Loss 1.6976 Acc 0.2871
# Validation Loss 1.8473 Acc 0.2446
# Time taken for 1 epoch 13.138390302658081 sec
#
# Epoch 82 Loss 1.6969 Acc 0.2875
# Validation Loss 1.8470 Acc 0.2450
# Time taken for 1 epoch 13.180620670318604 sec
#
# Epoch 83 Loss 1.6954 Acc 0.2878
# Validation Loss 1.8464 Acc 0.2453
# Time taken for 1 epoch 13.209582567214966 sec
#
# Epoch 84 Loss 1.6949 Acc 0.2879
# Validation Loss 1.8484 Acc 0.2448
# Time taken for 1 epoch 13.143593072891235 sec
#
# Epoch 85 Loss 1.6940 Acc 0.2882
# Validation Loss 1.8469 Acc 0.2455
# Time taken for 1 epoch 13.123900890350342 sec
#
# Epoch 86 Loss 1.6927 Acc 0.2886
# Validation Loss 1.8460 Acc 0.2458
# Time taken for 1 epoch 13.126573085784912 sec
#
# Epoch 87 Loss 1.6930 Acc 0.2885
# Validation Loss 1.8551 Acc 0.2432
# Time taken for 1 epoch 13.13939380645752 sec
#
# Epoch 88 Loss 1.6952 Acc 0.2879
# Validation Loss 1.8480 Acc 0.2455
# Time taken for 1 epoch 13.181149244308472 sec
#
# Epoch 89 Loss 1.6948 Acc 0.2878
# Validation Loss 1.8544 Acc 0.2444
# Time taken for 1 epoch 13.102537393569946 sec
#
# Epoch 90 Loss 1.6941 Acc 0.2879
# Validation Loss 1.8480 Acc 0.2457
# Time taken for 1 epoch 13.163355827331543 sec
#
# Epoch 91 Loss 1.6914 Acc 0.2887
# Validation Loss 1.8511 Acc 0.2442
# Time taken for 1 epoch 13.179787158966064 sec
#
# Epoch 92 Loss 1.6897 Acc 0.2889
# Validation Loss 1.8479 Acc 0.2452
# Time taken for 1 epoch 13.151510238647461 sec
#
# Epoch 93 Loss 1.6912 Acc 0.2888
# Validation Loss 1.8434 Acc 0.2468
# Time taken for 1 epoch 13.269791841506958 sec
#
# Epoch 94 Loss 1.6870 Acc 0.2898
# Validation Loss 1.8458 Acc 0.2463
# Time taken for 1 epoch 13.140090942382812 sec
#
# Epoch 95 Loss 1.6865 Acc 0.2899
# Validation Loss 1.8457 Acc 0.2462
# Time taken for 1 epoch 13.210077047348022 sec
#
# Epoch 96 Loss 1.6844 Acc 0.2906
# Validation Loss 1.8439 Acc 0.2461
# Time taken for 1 epoch 13.13806676864624 sec
#
# Epoch 97 Loss 1.6837 Acc 0.2908
# Validation Loss 1.8465 Acc 0.2456
# Time taken for 1 epoch 13.162155389785767 sec
#
# Epoch 98 Loss 1.6853 Acc 0.2903
# Validation Loss 1.8560 Acc 0.2434
# Time taken for 1 epoch 13.144768476486206 sec
#
# Epoch 99 Loss 1.6869 Acc 0.2898
# Validation Loss 1.8463 Acc 0.2459
# Time taken for 1 epoch 13.171783447265625 sec
#
# Epoch 100 Loss 1.6828 Acc 0.2907
# Validation Loss 1.8489 Acc 0.2454
# Time taken for 1 epoch 13.08890962600708 sec
#
# Epoch 101 Loss 1.6812 Acc 0.2913
# Validation Loss 1.8461 Acc 0.2459
# Time taken for 1 epoch 13.12657380104065 sec
#
# Epoch 102 Loss 1.6820 Acc 0.2911
# Validation Loss 1.8507 Acc 0.2447
# Time taken for 1 epoch 13.161330699920654 sec
#
# Epoch 103 Loss 1.6825 Acc 0.2904
# Validation Loss 1.8507 Acc 0.2449
# Time taken for 1 epoch 13.162460565567017 sec
#
# Epoch 104 Loss 1.6829 Acc 0.2904
# Validation Loss 1.8515 Acc 0.2448
# Time taken for 1 epoch 13.223363399505615 sec
#
# Epoch 105 Loss 1.6813 Acc 0.2910
# Validation Loss 1.8488 Acc 0.2456
# Time taken for 1 epoch 13.145674228668213 sec
#
# Epoch 106 Loss 1.6817 Acc 0.2911
# Validation Loss 1.8522 Acc 0.2444
# Time taken for 1 epoch 13.201020002365112 sec
#
# Epoch 107 Loss 1.6811 Acc 0.2912
# Validation Loss 1.8529 Acc 0.2444
# Time taken for 1 epoch 13.111540794372559 sec
#
# Epoch 108 Loss 1.6818 Acc 0.2910
# Validation Loss 1.8654 Acc 0.2420
# Time taken for 1 epoch 13.171199560165405 sec
#
# Epoch 109 Loss 1.6907 Acc 0.2893
# Validation Loss 1.8514 Acc 0.2453
# Time taken for 1 epoch 13.14667558670044 sec
#
# Epoch 110 Loss 1.6790 Acc 0.2921
# Validation Loss 1.8512 Acc 0.2453
# Time taken for 1 epoch 13.120664834976196 sec
#
# Epoch 111 Loss 1.6784 Acc 0.2923
# Validation Loss 1.8528 Acc 0.2443
# Time taken for 1 epoch 13.119019985198975 sec
#
# Epoch 112 Loss 1.6787 Acc 0.2921
# Validation Loss 1.8524 Acc 0.2452
# Time taken for 1 epoch 13.16620397567749 sec
#
# Epoch 113 Loss 1.6772 Acc 0.2926
# Validation Loss 1.8501 Acc 0.2458
# Time taken for 1 epoch 13.110219955444336 sec
#
# Epoch 114 Loss 1.6753 Acc 0.2930
# Validation Loss 1.8536 Acc 0.2449
# Time taken for 1 epoch 13.134267807006836 sec
#
# Epoch 115 Loss 1.6791 Acc 0.2918
# Validation Loss 1.8482 Acc 0.2461
# Time taken for 1 epoch 13.180625200271606 sec
#
# Epoch 116 Loss 1.6746 Acc 0.2932
# Validation Loss 1.8480 Acc 0.2469
# Time taken for 1 epoch 13.102569580078125 sec
#
# Epoch 117 Loss 1.6771 Acc 0.2922
# Validation Loss 1.8505 Acc 0.2455
# Time taken for 1 epoch 13.191030263900757 sec
#
# Epoch 118 Loss 1.6734 Acc 0.2931
# Validation Loss 1.8558 Acc 0.2448
# Time taken for 1 epoch 13.085058689117432 sec
#
# Epoch 119 Loss 1.6746 Acc 0.2930
# Validation Loss 1.8532 Acc 0.2448
# Time taken for 1 epoch 13.135252714157104 sec
#
# Epoch 120 Loss 1.6738 Acc 0.2928
# Validation Loss 1.8473 Acc 0.2460
# Time taken for 1 epoch 13.123544692993164 sec
#
# Epoch 121 Loss 1.6726 Acc 0.2934
# Validation Loss 1.8493 Acc 0.2461
# Time taken for 1 epoch 13.169023036956787 sec
#
# Epoch 122 Loss 1.6715 Acc 0.2935
# Validation Loss 1.8521 Acc 0.2444
# Time taken for 1 epoch 13.193607330322266 sec
#
# Epoch 123 Loss 1.6780 Acc 0.2920
# Validation Loss 1.8468 Acc 0.2470
# Time taken for 1 epoch 13.173437118530273 sec
#
# Epoch 124 Loss 1.6707 Acc 0.2938
# Validation Loss 1.8507 Acc 0.2461
# Time taken for 1 epoch 13.130432844161987 sec
#
# Epoch 125 Loss 1.6696 Acc 0.2941
# Validation Loss 1.8511 Acc 0.2447
# Time taken for 1 epoch 13.167121648788452 sec
#
# Epoch 126 Loss 1.6705 Acc 0.2937
# Validation Loss 1.8520 Acc 0.2451
# Time taken for 1 epoch 13.177332878112793 sec
#
# Epoch 127 Loss 1.6688 Acc 0.2944
# Validation Loss 1.8482 Acc 0.2458
# Time taken for 1 epoch 13.179024457931519 sec
#
# Epoch 128 Loss 1.6700 Acc 0.2939
# Validation Loss 1.8530 Acc 0.2442
# Time taken for 1 epoch 13.13017201423645 sec
#
# Epoch 129 Loss 1.6747 Acc 0.2924
# Validation Loss 1.8545 Acc 0.2444
# Time taken for 1 epoch 13.200926303863525 sec
#
# Epoch 130 Loss 1.6748 Acc 0.2924
# Validation Loss 1.8611 Acc 0.2419
# Time taken for 1 epoch 13.119107723236084 sec
#
# Epoch 131 Loss 1.6729 Acc 0.2928
# Validation Loss 1.8522 Acc 0.2453
# Time taken for 1 epoch 13.100435972213745 sec
#
# Epoch 132 Loss 1.6754 Acc 0.2920
# Validation Loss 1.8603 Acc 0.2429
# Time taken for 1 epoch 13.175203800201416 sec
#
# Epoch 133 Loss 1.6733 Acc 0.2928
# Validation Loss 1.8604 Acc 0.2424
# Time taken for 1 epoch 13.117417097091675 sec
#
# Epoch 134 Loss 1.6700 Acc 0.2938
# Validation Loss 1.8607 Acc 0.2428
# Time taken for 1 epoch 13.098603248596191 sec
#
# Epoch 135 Loss 1.6679 Acc 0.2942
# Validation Loss 1.8585 Acc 0.2437
# Time taken for 1 epoch 13.078073501586914 sec
#
# Epoch 136 Loss 1.6645 Acc 0.2949
# Validation Loss 1.8589 Acc 0.2436
# Time taken for 1 epoch 13.171471357345581 sec
#
# Epoch 137 Loss 1.6640 Acc 0.2951
# Validation Loss 1.8551 Acc 0.2446
# Time taken for 1 epoch 13.148365020751953 sec
#
# Epoch 138 Loss 1.6633 Acc 0.2951
# Validation Loss 1.8589 Acc 0.2437
# Time taken for 1 epoch 13.069722890853882 sec
#
# Epoch 139 Loss 1.6632 Acc 0.2954
# Validation Loss 1.8556 Acc 0.2439
# Time taken for 1 epoch 13.072477102279663 sec
#
# Epoch 140 Loss 1.6619 Acc 0.2956
# Validation Loss 1.8567 Acc 0.2442
# Time taken for 1 epoch 13.158346176147461 sec
#
# Epoch 141 Loss 1.6620 Acc 0.2955
# Validation Loss 1.8556 Acc 0.2442
# Time taken for 1 epoch 13.138044595718384 sec
#
# Epoch 142 Loss 1.6621 Acc 0.2953
# Validation Loss 1.8583 Acc 0.2437
# Time taken for 1 epoch 13.143867254257202 sec
#
# Epoch 143 Loss 1.6604 Acc 0.2960
# Validation Loss 1.8604 Acc 0.2432
# Time taken for 1 epoch 13.177372932434082 sec
#
# Epoch 144 Loss 1.6604 Acc 0.2959
# Validation Loss 1.8549 Acc 0.2446
# Time taken for 1 epoch 13.141373634338379 sec
#
# Epoch 145 Loss 1.6588 Acc 0.2964
# Validation Loss 1.8592 Acc 0.2431
# Time taken for 1 epoch 13.125455141067505 sec
#
# Epoch 146 Loss 1.6595 Acc 0.2962
# Validation Loss 1.8597 Acc 0.2430
# Time taken for 1 epoch 13.166338205337524 sec
#
# Epoch 147 Loss 1.6590 Acc 0.2963
# Validation Loss 1.8668 Acc 0.2412
# Time taken for 1 epoch 13.150107383728027 sec
#
# Epoch 148 Loss 1.6609 Acc 0.2957
# Validation Loss 1.8571 Acc 0.2440
# Time taken for 1 epoch 13.082990884780884 sec
#
# Epoch 149 Loss 1.6595 Acc 0.2961
# Validation Loss 1.8633 Acc 0.2419
# Time taken for 1 epoch 13.124227523803711 sec
#
# Epoch 150 Loss 1.6594 Acc 0.2961
# Validation Loss 1.8736 Acc 0.2405
# Time taken for 1 epoch 13.190546989440918 sec
#
# Epoch 151 Loss 1.6612 Acc 0.2956
# Validation Loss 1.8732 Acc 0.2403
# Time taken for 1 epoch 13.19472861289978 sec
#
# Epoch 152 Loss 1.6640 Acc 0.2951
# Validation Loss 1.8631 Acc 0.2422
# Time taken for 1 epoch 13.085090398788452 sec
#
# Epoch 153 Loss 1.6689 Acc 0.2940
# Validation Loss 1.8727 Acc 0.2398
# Time taken for 1 epoch 13.263484954833984 sec
#
# Epoch 154 Loss 1.6691 Acc 0.2940
# Validation Loss 1.8629 Acc 0.2423
# Time taken for 1 epoch 13.216931104660034 sec
#
# Epoch 155 Loss 1.6656 Acc 0.2948
# Validation Loss 1.8660 Acc 0.2415
# Time taken for 1 epoch 13.225334167480469 sec
#
# Epoch 156 Loss 1.6618 Acc 0.2956
# Validation Loss 1.8599 Acc 0.2428
# Time taken for 1 epoch 13.145355224609375 sec
#
# Epoch 157 Loss 1.6671 Acc 0.2944
# Validation Loss 1.8794 Acc 0.2387
# Time taken for 1 epoch 13.120815515518188 sec
#
# Epoch 158 Loss 1.6845 Acc 0.2904
# Validation Loss 1.8700 Acc 0.2410
# Time taken for 1 epoch 13.252603769302368 sec
#
# Epoch 159 Loss 1.6733 Acc 0.2927
# Validation Loss 1.8623 Acc 0.2423
# Time taken for 1 epoch 13.212418556213379 sec
#
# Epoch 160 Loss 1.6684 Acc 0.2940
# Validation Loss 1.8607 Acc 0.2434
# Time taken for 1 epoch 13.174849271774292 sec
#
# Epoch 161 Loss 1.6645 Acc 0.2950
# Validation Loss 1.8663 Acc 0.2418
# Time taken for 1 epoch 13.138720035552979 sec
#
# Epoch 162 Loss 1.6635 Acc 0.2951
# Validation Loss 1.8636 Acc 0.2425
# Time taken for 1 epoch 13.100785732269287 sec
#
# Epoch 163 Loss 1.6597 Acc 0.2960
# Validation Loss 1.8657 Acc 0.2416
# Time taken for 1 epoch 13.157212972640991 sec
#
# Epoch 164 Loss 1.6573 Acc 0.2966
# Validation Loss 1.8665 Acc 0.2417
# Time taken for 1 epoch 13.149703741073608 sec
#
# Epoch 165 Loss 1.6577 Acc 0.2964
# Validation Loss 1.8664 Acc 0.2419
# Time taken for 1 epoch 13.180579662322998 sec
#
# Epoch 166 Loss 1.6560 Acc 0.2970
# Validation Loss 1.8689 Acc 0.2411
# Time taken for 1 epoch 13.217467784881592 sec
#
# Epoch 167 Loss 1.6548 Acc 0.2973
# Validation Loss 1.8654 Acc 0.2422
# Time taken for 1 epoch 13.154473066329956 sec
#
# Epoch 168 Loss 1.6552 Acc 0.2969
# Validation Loss 1.8713 Acc 0.2402
# Time taken for 1 epoch 13.104615211486816 sec
#
# Epoch 169 Loss 1.6559 Acc 0.2968
# Validation Loss 1.8708 Acc 0.2410
# Time taken for 1 epoch 13.148642301559448 sec
#
# Epoch 170 Loss 1.6523 Acc 0.2978
# Validation Loss 1.8693 Acc 0.2411
# Time taken for 1 epoch 13.098983526229858 sec
#
# Epoch 171 Loss 1.6517 Acc 0.2977
# Validation Loss 1.8797 Acc 0.2387
# Time taken for 1 epoch 13.205982208251953 sec
#
# Epoch 172 Loss 1.6537 Acc 0.2972
# Validation Loss 1.8690 Acc 0.2419
# Time taken for 1 epoch 13.129596710205078 sec
#
# Epoch 173 Loss 1.6503 Acc 0.2981
# Validation Loss 1.8750 Acc 0.2401
# Time taken for 1 epoch 13.156277418136597 sec
#
# Epoch 174 Loss 1.6564 Acc 0.2967
# Validation Loss 1.8640 Acc 0.2432
# Time taken for 1 epoch 13.255885362625122 sec
#
# Epoch 175 Loss 1.6506 Acc 0.2982
# Validation Loss 1.8696 Acc 0.2418
# Time taken for 1 epoch 13.125890731811523 sec
#
# Epoch 176 Loss 1.6476 Acc 0.2989
# Validation Loss 1.8727 Acc 0.2406
# Time taken for 1 epoch 13.055761098861694 sec
#
# Epoch 177 Loss 1.6472 Acc 0.2989
# Validation Loss 1.8693 Acc 0.2417
# Time taken for 1 epoch 13.159727573394775 sec
#
# Epoch 178 Loss 1.6466 Acc 0.2991
# Validation Loss 1.8777 Acc 0.2395
# Time taken for 1 epoch 13.144334316253662 sec
#
# Epoch 179 Loss 1.6464 Acc 0.2991
# Validation Loss 1.8736 Acc 0.2403
# Time taken for 1 epoch 13.216288566589355 sec
#
# Epoch 180 Loss 1.6469 Acc 0.2991
# Validation Loss 1.8720 Acc 0.2409
# Time taken for 1 epoch 13.132311582565308 sec
#
# Epoch 181 Loss 1.6462 Acc 0.2992
# Validation Loss 1.8736 Acc 0.2404
# Time taken for 1 epoch 13.128548383712769 sec
#
# Epoch 182 Loss 1.6456 Acc 0.2993
# Validation Loss 1.8706 Acc 0.2407
# Time taken for 1 epoch 13.132707595825195 sec
#
# Epoch 183 Loss 1.6465 Acc 0.2990
# Validation Loss 1.8748 Acc 0.2399
# Time taken for 1 epoch 13.150554418563843 sec
#
# Epoch 184 Loss 1.6457 Acc 0.2992
# Validation Loss 1.8699 Acc 0.2414
# Time taken for 1 epoch 13.206713438034058 sec
#
# Epoch 185 Loss 1.6434 Acc 0.2999
# Validation Loss 1.8692 Acc 0.2420
# Time taken for 1 epoch 13.119393825531006 sec
#
# Epoch 186 Loss 1.6422 Acc 0.3001
# Validation Loss 1.8659 Acc 0.2428
# Time taken for 1 epoch 13.204925298690796 sec
#
# Epoch 187 Loss 1.6415 Acc 0.3003
# Validation Loss 1.8678 Acc 0.2425
# Time taken for 1 epoch 13.197659969329834 sec
#
# Epoch 188 Loss 1.6434 Acc 0.2998
# Validation Loss 1.8691 Acc 0.2425
# Time taken for 1 epoch 13.194892883300781 sec
#
# Epoch 189 Loss 1.6426 Acc 0.2999
# Validation Loss 1.8738 Acc 0.2407
# Time taken for 1 epoch 13.172380447387695 sec
#
# Epoch 190 Loss 1.6438 Acc 0.2996
# Validation Loss 1.8796 Acc 0.2384
# Time taken for 1 epoch 13.129936218261719 sec
#
# Epoch 191 Loss 1.6459 Acc 0.2991
# Validation Loss 1.8760 Acc 0.2403
# Time taken for 1 epoch 13.138778686523438 sec
#
# Epoch 192 Loss 1.6469 Acc 0.2988
# Validation Loss 1.8630 Acc 0.2444
# Time taken for 1 epoch 13.188552141189575 sec
#
# Epoch 193 Loss 1.6439 Acc 0.2994
# Validation Loss 1.8678 Acc 0.2429
# Time taken for 1 epoch 13.144055843353271 sec
#
# Epoch 194 Loss 1.6412 Acc 0.3001
# Validation Loss 1.8773 Acc 0.2407
# Time taken for 1 epoch 13.181816339492798 sec
#
# Epoch 195 Loss 1.6425 Acc 0.3000
# Validation Loss 1.8697 Acc 0.2433
# Time taken for 1 epoch 13.172736644744873 sec
#
# Epoch 196 Loss 1.6402 Acc 0.3004
# Validation Loss 1.8668 Acc 0.2443
# Time taken for 1 epoch 13.14231562614441 sec
#
# Epoch 197 Loss 1.6400 Acc 0.3006
# Validation Loss 1.8664 Acc 0.2439
# Time taken for 1 epoch 13.148167848587036 sec
#
# Epoch 198 Loss 1.6401 Acc 0.3005
# Validation Loss 1.8664 Acc 0.2444
# Time taken for 1 epoch 13.147541522979736 sec
#
# Epoch 199 Loss 1.6408 Acc 0.3003
# Validation Loss 1.8693 Acc 0.2434
# Time taken for 1 epoch 13.155290842056274 sec
#
# Epoch 200 Loss 1.6440 Acc 0.2994
# Validation Loss 1.8678 Acc 0.2434
# Time taken for 1 epoch 13.187767505645752 sec
#
# Epoch 201 Loss 1.6499 Acc 0.2980
# Validation Loss 1.8894 Acc 0.2372
# Time taken for 1 epoch 13.192079544067383 sec
#
# Epoch 202 Loss 1.6463 Acc 0.2990
# Validation Loss 1.8706 Acc 0.2417
# Time taken for 1 epoch 13.166524887084961 sec
#
# Epoch 203 Loss 1.6415 Acc 0.3001
# Validation Loss 1.8760 Acc 0.2414
# Time taken for 1 epoch 13.160768508911133 sec
#
# Epoch 204 Loss 1.6410 Acc 0.3003
# Validation Loss 1.8754 Acc 0.2410
# Time taken for 1 epoch 13.207670211791992 sec
#
# Epoch 205 Loss 1.6400 Acc 0.3006
# Validation Loss 1.8808 Acc 0.2389
# Time taken for 1 epoch 13.125205278396606 sec
#
# Epoch 206 Loss 1.6400 Acc 0.3007
# Validation Loss 1.8760 Acc 0.2409
# Time taken for 1 epoch 13.164574146270752 sec
#
# Epoch 207 Loss 1.6378 Acc 0.3011
# Validation Loss 1.8812 Acc 0.2389
# Time taken for 1 epoch 13.096846580505371 sec
#
# Epoch 208 Loss 1.6371 Acc 0.3015
# Validation Loss 1.8802 Acc 0.2400
# Time taken for 1 epoch 13.199568748474121 sec
#
# Epoch 209 Loss 1.6359 Acc 0.3019
# Validation Loss 1.8810 Acc 0.2398
# Time taken for 1 epoch 13.203959465026855 sec
#
# Epoch 210 Loss 1.6352 Acc 0.3018
# Validation Loss 1.8760 Acc 0.2409
# Time taken for 1 epoch 13.14756965637207 sec
#
# Epoch 211 Loss 1.6355 Acc 0.3018
# Validation Loss 1.8778 Acc 0.2404
# Time taken for 1 epoch 13.169795513153076 sec
#
# Epoch 212 Loss 1.6443 Acc 0.2997
# Validation Loss 1.8837 Acc 0.2393
# Time taken for 1 epoch 13.239744424819946 sec
#
# Epoch 213 Loss 1.6478 Acc 0.2989
# Validation Loss 1.8791 Acc 0.2396
# Time taken for 1 epoch 13.114940643310547 sec
#
# Epoch 214 Loss 1.6406 Acc 0.3007
# Validation Loss 1.8765 Acc 0.2411
# Time taken for 1 epoch 13.128585815429688 sec
#
# Epoch 215 Loss 1.6374 Acc 0.3014
# Validation Loss 1.8775 Acc 0.2404
# Time taken for 1 epoch 13.135093450546265 sec
#
# Epoch 216 Loss 1.6364 Acc 0.3015
# Validation Loss 1.8818 Acc 0.2403
# Time taken for 1 epoch 13.15345573425293 sec
#
# Epoch 217 Loss 1.6362 Acc 0.3017
# Validation Loss 1.8821 Acc 0.2403
# Time taken for 1 epoch 13.2374849319458 sec
#
# Epoch 218 Loss 1.6344 Acc 0.3020
# Validation Loss 1.8840 Acc 0.2393
# Time taken for 1 epoch 13.119571208953857 sec
#
# Epoch 219 Loss 1.6357 Acc 0.3017
# Validation Loss 1.8840 Acc 0.2392
# Time taken for 1 epoch 13.105698823928833 sec
#
# Epoch 220 Loss 1.6409 Acc 0.3004
# Validation Loss 1.8822 Acc 0.2401
# Time taken for 1 epoch 13.141454696655273 sec
#
# Epoch 221 Loss 1.6387 Acc 0.3011
# Validation Loss 1.8888 Acc 0.2381
# Time taken for 1 epoch 13.080287456512451 sec
#
# Epoch 222 Loss 1.6369 Acc 0.3013
# Validation Loss 1.8817 Acc 0.2396
# Time taken for 1 epoch 13.136540174484253 sec
#
# Epoch 223 Loss 1.6376 Acc 0.3010
# Validation Loss 1.8894 Acc 0.2368
# Time taken for 1 epoch 13.195940017700195 sec
#
# Epoch 224 Loss 1.6373 Acc 0.3012
# Validation Loss 1.8857 Acc 0.2385
# Time taken for 1 epoch 13.184334754943848 sec
#
# Epoch 225 Loss 1.6325 Acc 0.3025
# Validation Loss 1.8866 Acc 0.2387
# Time taken for 1 epoch 13.134688377380371 sec
#
# Epoch 226 Loss 1.6327 Acc 0.3025
# Validation Loss 1.8898 Acc 0.2373
# Time taken for 1 epoch 13.197044610977173 sec
#
# Epoch 227 Loss 1.6320 Acc 0.3025
# Validation Loss 1.8932 Acc 0.2377
# Time taken for 1 epoch 13.237775802612305 sec
#
# Epoch 228 Loss 1.6321 Acc 0.3026
# Validation Loss 1.8829 Acc 0.2390
# Time taken for 1 epoch 13.08983588218689 sec
#
# Epoch 229 Loss 1.6352 Acc 0.3018
# Validation Loss 1.8961 Acc 0.2363
# Time taken for 1 epoch 13.196636438369751 sec
#
# Epoch 230 Loss 1.6405 Acc 0.3003
# Validation Loss 1.8941 Acc 0.2367
# Time taken for 1 epoch 13.20209527015686 sec
#
# Epoch 231 Loss 1.6467 Acc 0.2993
# Validation Loss 1.8987 Acc 0.2355
# Time taken for 1 epoch 13.11904764175415 sec
#
# Epoch 232 Loss 1.6483 Acc 0.2986
# Validation Loss 1.9188 Acc 0.2312
# Time taken for 1 epoch 13.223708152770996 sec
#
# Epoch 233 Loss 1.6547 Acc 0.2969
# Validation Loss 1.8708 Acc 0.2414
# Time taken for 1 epoch 13.193112850189209 sec
#
# Epoch 234 Loss 1.6448 Acc 0.2993
# Validation Loss 1.8751 Acc 0.2405
# Time taken for 1 epoch 13.190201044082642 sec
#
# Epoch 235 Loss 1.6395 Acc 0.3005
# Validation Loss 1.8766 Acc 0.2402
# Time taken for 1 epoch 13.134841442108154 sec
#
# Epoch 236 Loss 1.6385 Acc 0.3008
# Validation Loss 1.8726 Acc 0.2415
# Time taken for 1 epoch 13.162373065948486 sec
#
# Epoch 237 Loss 1.6367 Acc 0.3013
# Validation Loss 1.8645 Acc 0.2432
# Time taken for 1 epoch 13.145314455032349 sec
#
# Epoch 238 Loss 1.6343 Acc 0.3021
# Validation Loss 1.8653 Acc 0.2430
# Time taken for 1 epoch 13.171972036361694 sec
#
# Epoch 239 Loss 1.6311 Acc 0.3027
# Validation Loss 1.8765 Acc 0.2407
# Time taken for 1 epoch 13.275760412216187 sec
#
# Epoch 240 Loss 1.6292 Acc 0.3032
# Validation Loss 1.8792 Acc 0.2405
# Time taken for 1 epoch 13.160068035125732 sec
#
# Epoch 241 Loss 1.6296 Acc 0.3033
# Validation Loss 1.8852 Acc 0.2391
# Time taken for 1 epoch 13.211730480194092 sec
#
# Epoch 242 Loss 1.6274 Acc 0.3037
# Validation Loss 1.8900 Acc 0.2382
# Time taken for 1 epoch 13.226186752319336 sec
#
# Epoch 243 Loss 1.6275 Acc 0.3037
# Validation Loss 1.8909 Acc 0.2382
# Time taken for 1 epoch 13.092055797576904 sec
#
# Epoch 244 Loss 1.6277 Acc 0.3037
# Validation Loss 1.8928 Acc 0.2378
# Time taken for 1 epoch 13.195886135101318 sec
#
# Epoch 245 Loss 1.6305 Acc 0.3028
# Validation Loss 1.8929 Acc 0.2376
# Time taken for 1 epoch 13.103553771972656 sec
#
# Epoch 246 Loss 1.6355 Acc 0.3017
# Validation Loss 1.8804 Acc 0.2407
# Time taken for 1 epoch 13.049718856811523 sec
#
# Epoch 247 Loss 1.6400 Acc 0.3003
# Validation Loss 1.8639 Acc 0.2438
# Time taken for 1 epoch 13.161855220794678 sec
#
# Epoch 248 Loss 1.6324 Acc 0.3024
# Validation Loss 1.8639 Acc 0.2446
# Time taken for 1 epoch 13.15685224533081 sec
#
# Epoch 249 Loss 1.6276 Acc 0.3037
# Validation Loss 1.8691 Acc 0.2431
# Time taken for 1 epoch 13.133721351623535 sec
#
# Epoch 250 Loss 1.6254 Acc 0.3040
# Validation Loss 1.8783 Acc 0.2417
# Time taken for 1 epoch 13.233325242996216 sec
#
# Epoch 251 Loss 1.6226 Acc 0.3049
# Validation Loss 1.8797 Acc 0.2411
# Time taken for 1 epoch 13.157147407531738 sec
#
# Epoch 252 Loss 1.6221 Acc 0.3047
# Validation Loss 1.8816 Acc 0.2411
# Time taken for 1 epoch 13.174747467041016 sec
#
# Epoch 253 Loss 1.6228 Acc 0.3047
# Validation Loss 1.8826 Acc 0.2402
# Time taken for 1 epoch 13.133629560470581 sec
#
# Epoch 254 Loss 1.6226 Acc 0.3048
# Validation Loss 1.8877 Acc 0.2390
# Time taken for 1 epoch 13.103591918945312 sec
#
# Epoch 255 Loss 1.6223 Acc 0.3049
# Validation Loss 1.8880 Acc 0.2392
# Time taken for 1 epoch 13.234991312026978 sec
#
# Epoch 256 Loss 1.6221 Acc 0.3050
# Validation Loss 1.8868 Acc 0.2396
# Time taken for 1 epoch 13.0811185836792 sec
#
# Epoch 257 Loss 1.6214 Acc 0.3048
# Validation Loss 1.8846 Acc 0.2401
# Time taken for 1 epoch 12.997302055358887 sec
#
# Epoch 258 Loss 1.6177 Acc 0.3058
# Validation Loss 1.8845 Acc 0.2406
# Time taken for 1 epoch 13.033230066299438 sec
#
# Epoch 259 Loss 1.6170 Acc 0.3060
# Validation Loss 1.8844 Acc 0.2402
# Time taken for 1 epoch 13.189029216766357 sec
#
# Epoch 260 Loss 1.6167 Acc 0.3060
# Validation Loss 1.8849 Acc 0.2405
# Time taken for 1 epoch 13.223660469055176 sec
#
# Epoch 261 Loss 1.6178 Acc 0.3059
# Validation Loss 1.8888 Acc 0.2389
# Time taken for 1 epoch 13.204588651657104 sec
#
# Epoch 262 Loss 1.6252 Acc 0.3039
# Validation Loss 1.8873 Acc 0.2398
# Time taken for 1 epoch 13.157247066497803 sec
#
# Epoch 263 Loss 1.6164 Acc 0.3063
# Validation Loss 1.8862 Acc 0.2403
# Time taken for 1 epoch 13.103535890579224 sec
#
# Epoch 264 Loss 1.6155 Acc 0.3066
# Validation Loss 1.8882 Acc 0.2396
# Time taken for 1 epoch 13.179037809371948 sec
#
# Epoch 265 Loss 1.6161 Acc 0.3062
# Validation Loss 1.8881 Acc 0.2393
# Time taken for 1 epoch 13.183273792266846 sec
#
# Epoch 266 Loss 1.6168 Acc 0.3059
# Validation Loss 1.8941 Acc 0.2387
# Time taken for 1 epoch 13.114134550094604 sec
#
# Epoch 267 Loss 1.6149 Acc 0.3064
# Validation Loss 1.8887 Acc 0.2394
# Time taken for 1 epoch 13.139923810958862 sec
#
# Epoch 268 Loss 1.6148 Acc 0.3064
# Validation Loss 1.8817 Acc 0.2408
# Time taken for 1 epoch 13.171303272247314 sec
#
# Epoch 269 Loss 1.6167 Acc 0.3059
# Validation Loss 1.8888 Acc 0.2398
# Time taken for 1 epoch 13.154804944992065 sec
#
# Epoch 270 Loss 1.6149 Acc 0.3065
# Validation Loss 1.8951 Acc 0.2386
# Time taken for 1 epoch 13.173768520355225 sec
#
# Epoch 271 Loss 1.6129 Acc 0.3072
# Validation Loss 1.8900 Acc 0.2393
# Time taken for 1 epoch 13.195247888565063 sec
#
# Epoch 272 Loss 1.6129 Acc 0.3073
# Validation Loss 1.8922 Acc 0.2391
# Time taken for 1 epoch 13.180843830108643 sec
#
# Epoch 273 Loss 1.6134 Acc 0.3071
# Validation Loss 1.8952 Acc 0.2390
# Time taken for 1 epoch 13.170658111572266 sec
#
# Epoch 274 Loss 1.6111 Acc 0.3075
# Validation Loss 1.8877 Acc 0.2395
# Time taken for 1 epoch 13.164753437042236 sec
#
# Epoch 275 Loss 1.6114 Acc 0.3072
# Validation Loss 1.8884 Acc 0.2404
# Time taken for 1 epoch 13.13334584236145 sec
#
# Epoch 276 Loss 1.6129 Acc 0.3069
# Validation Loss 1.8968 Acc 0.2382
# Time taken for 1 epoch 13.121184349060059 sec
#
# Epoch 277 Loss 1.6109 Acc 0.3072
# Validation Loss 1.9024 Acc 0.2376
# Time taken for 1 epoch 13.219205141067505 sec
#
# Epoch 278 Loss 1.6110 Acc 0.3073
# Validation Loss 1.8968 Acc 0.2391
# Time taken for 1 epoch 13.224879264831543 sec
#
# Epoch 279 Loss 1.6105 Acc 0.3073
# Validation Loss 1.8864 Acc 0.2406
# Time taken for 1 epoch 13.167519330978394 sec
#
# Epoch 280 Loss 1.6131 Acc 0.3065
# Validation Loss 1.8852 Acc 0.2410
# Time taken for 1 epoch 13.225804567337036 sec
#
# Epoch 281 Loss 1.6102 Acc 0.3073
# Validation Loss 1.8951 Acc 0.2395
# Time taken for 1 epoch 13.153228521347046 sec
#
# Epoch 282 Loss 1.6088 Acc 0.3078
# Validation Loss 1.8999 Acc 0.2383
# Time taken for 1 epoch 13.134217023849487 sec
#
# Epoch 283 Loss 1.6127 Acc 0.3068
# Validation Loss 1.9027 Acc 0.2380
# Time taken for 1 epoch 13.200150489807129 sec
#
# Epoch 284 Loss 1.6142 Acc 0.3063
# Validation Loss 1.8987 Acc 0.2386
# Time taken for 1 epoch 13.137659311294556 sec
#
# Epoch 285 Loss 1.6119 Acc 0.3072
# Validation Loss 1.8902 Acc 0.2407
# Time taken for 1 epoch 13.169642686843872 sec
#
# Epoch 286 Loss 1.6099 Acc 0.3075
# Validation Loss 1.8979 Acc 0.2396
# Time taken for 1 epoch 13.210317611694336 sec
#
# Epoch 287 Loss 1.6086 Acc 0.3077
# Validation Loss 1.9001 Acc 0.2391
# Time taken for 1 epoch 13.147573232650757 sec
#
# Epoch 288 Loss 1.6075 Acc 0.3080
# Validation Loss 1.8995 Acc 0.2390
# Time taken for 1 epoch 13.185465812683105 sec
#
# Epoch 289 Loss 1.6073 Acc 0.3084
# Validation Loss 1.8920 Acc 0.2395
# Time taken for 1 epoch 13.174820899963379 sec
#
# Epoch 290 Loss 1.6056 Acc 0.3087
# Validation Loss 1.8938 Acc 0.2393
# Time taken for 1 epoch 13.189938306808472 sec
#
# Epoch 291 Loss 1.6078 Acc 0.3079
# Validation Loss 1.8972 Acc 0.2391
# Time taken for 1 epoch 13.152599334716797 sec
#
# Epoch 292 Loss 1.6066 Acc 0.3082
# Validation Loss 1.8992 Acc 0.2383
# Time taken for 1 epoch 13.088470697402954 sec
#
# Epoch 293 Loss 1.6065 Acc 0.3083
# Validation Loss 1.8965 Acc 0.2386
# Time taken for 1 epoch 13.192187070846558 sec
#
# Epoch 294 Loss 1.6058 Acc 0.3084
# Validation Loss 1.9044 Acc 0.2379
# Time taken for 1 epoch 13.124526977539062 sec
#
# Epoch 295 Loss 1.6048 Acc 0.3089
# Validation Loss 1.9015 Acc 0.2384
# Time taken for 1 epoch 13.161051511764526 sec
#
# Epoch 296 Loss 1.6045 Acc 0.3089
# Validation Loss 1.8961 Acc 0.2385
# Time taken for 1 epoch 13.14877700805664 sec
#
# Epoch 297 Loss 1.6041 Acc 0.3091
# Validation Loss 1.9082 Acc 0.2373
# Time taken for 1 epoch 13.095566749572754 sec
#
# Epoch 298 Loss 1.6052 Acc 0.3088
# Validation Loss 1.8911 Acc 0.2397
# Time taken for 1 epoch 13.173879146575928 sec
#
# Epoch 299 Loss 1.6059 Acc 0.3087
# Validation Loss 1.8977 Acc 0.2388
# Time taken for 1 epoch 13.145413637161255 sec
#
# Epoch 300 Loss 1.6048 Acc 0.3089
# Validation Loss 1.8986 Acc 0.2389
# Time taken for 1 epoch 13.177851915359497 sec

# %%
plt.plot(loss_history)
plt.plot(val_loss_history)

# %%
plt.plot(acc_history)
plt.plot(val_acc_history)

# %%
checkpoint.save(checkpoint_prefix)
np.save("experiments/01_BDLSTM_naive_adam/loss_history.npy", np.array(loss_history))
np.save("experiments/01_BDLSTM_naive_adam/acc_history.npy", np.array(acc_history))
np.save("experiments/01_BDLSTM_naive_adam/val_loss_history.npy", np.array(val_loss_history))
np.save("experiments/01_BDLSTM_naive_adam/val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
TEST_OUTPUT_DIR = "experiments/01_BDLSTM_naive_adam/"
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_irealpro.mid")

test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=TEST_OUTPUT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=TEST_OUTPUT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 33ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 32ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1536, 53)
