# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')

# %%
EXPERIMENT_DIR = "experiments/03_BDLSTM_NadamReg/"

BATCH_SIZE = 512
PIECE_LEN = 1024
n_feature = 43
n_hidden = 100
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.01)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())

optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1024, 43)]        0
#
#  mask (Masking)              (None, 1024, 43)          0
#
#  bidirectional_3 (Bidirectio  (None, 1024, 200)        115200
#  nal)
#
#  output (TimeDistributed)    (None, 1024, 53)          10653
#
# =================================================================
# Total params: 125,853
# Trainable params: 125,853
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/03_BDLSTM_NadamReg'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-1")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 300

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# Epoch 1 Loss 3.4040 Acc 0.1506
# Validation Loss 2.9183 Acc 0.1743
# Time taken for 1 epoch 21.578959703445435 sec
#
# Epoch 2 Loss 2.6754 Acc 0.2020
# Validation Loss 2.5552 Acc 0.1864
# Time taken for 1 epoch 12.805639266967773 sec
#
# Epoch 3 Loss 2.4096 Acc 0.2101
# Validation Loss 2.3696 Acc 0.1954
# Time taken for 1 epoch 12.791704416275024 sec
#
# Epoch 4 Loss 2.2682 Acc 0.2154
# Validation Loss 2.2654 Acc 0.2001
# Time taken for 1 epoch 12.82932996749878 sec
#
# Epoch 5 Loss 2.1871 Acc 0.2189
# Validation Loss 2.2040 Acc 0.2044
# Time taken for 1 epoch 12.80416464805603 sec
#
# Epoch 6 Loss 2.1378 Acc 0.2210
# Validation Loss 2.1640 Acc 0.2075
# Time taken for 1 epoch 12.83621335029602 sec
#
# Epoch 7 Loss 2.1058 Acc 0.2228
# Validation Loss 2.1358 Acc 0.2097
# Time taken for 1 epoch 12.857598543167114 sec
#
# Epoch 8 Loss 2.0811 Acc 0.2246
# Validation Loss 2.1142 Acc 0.2130
# Time taken for 1 epoch 12.85135293006897 sec
#
# Epoch 9 Loss 2.0627 Acc 0.2264
# Validation Loss 2.0974 Acc 0.2156
# Time taken for 1 epoch 12.896713733673096 sec
#
# Epoch 10 Loss 2.0504 Acc 0.2280
# Validation Loss 2.0860 Acc 0.2180
# Time taken for 1 epoch 12.919488191604614 sec
#
# Epoch 11 Loss 2.0369 Acc 0.2309
# Validation Loss 2.0743 Acc 0.2225
# Time taken for 1 epoch 12.939586877822876 sec
#
# Epoch 12 Loss 2.0281 Acc 0.2323
# Validation Loss 2.0714 Acc 0.2191
# Time taken for 1 epoch 12.925057649612427 sec
#
# Epoch 13 Loss 2.0194 Acc 0.2345
# Validation Loss 2.0510 Acc 0.2269
# Time taken for 1 epoch 12.869692325592041 sec
#
# Epoch 14 Loss 2.0091 Acc 0.2369
# Validation Loss 2.0483 Acc 0.2256
# Time taken for 1 epoch 12.868318796157837 sec
#
# Epoch 15 Loss 2.0015 Acc 0.2403
# Validation Loss 2.0367 Acc 0.2270
# Time taken for 1 epoch 12.88087773323059 sec
#
# Epoch 16 Loss 1.9889 Acc 0.2433
# Validation Loss 2.0251 Acc 0.2328
# Time taken for 1 epoch 12.847313165664673 sec
#
# Epoch 17 Loss 1.9845 Acc 0.2440
# Validation Loss 2.0184 Acc 0.2346
# Time taken for 1 epoch 12.82265019416809 sec
#
# Epoch 18 Loss 1.9714 Acc 0.2476
# Validation Loss 2.0155 Acc 0.2306
# Time taken for 1 epoch 12.874619483947754 sec
#
# Epoch 19 Loss 1.9615 Acc 0.2510
# Validation Loss 2.0089 Acc 0.2352
# Time taken for 1 epoch 12.895256519317627 sec
#
# Epoch 20 Loss 1.9615 Acc 0.2513
# Validation Loss 2.0046 Acc 0.2399
# Time taken for 1 epoch 12.88325834274292 sec
#
# Epoch 21 Loss 1.9552 Acc 0.2525
# Validation Loss 2.0049 Acc 0.2386
# Time taken for 1 epoch 12.921030759811401 sec
#
# Epoch 22 Loss 1.9448 Acc 0.2561
# Validation Loss 1.9971 Acc 0.2391
# Time taken for 1 epoch 12.855352640151978 sec
#
# Epoch 23 Loss 1.9411 Acc 0.2571
# Validation Loss 1.9962 Acc 0.2373
# Time taken for 1 epoch 12.84548568725586 sec
#
# Epoch 24 Loss 1.9328 Acc 0.2594
# Validation Loss 1.9917 Acc 0.2415
# Time taken for 1 epoch 12.851375102996826 sec
#
# Epoch 25 Loss 1.9384 Acc 0.2568
# Validation Loss 2.0150 Acc 0.2297
# Time taken for 1 epoch 12.903730869293213 sec
#
# Epoch 26 Loss 1.9397 Acc 0.2573
# Validation Loss 1.9881 Acc 0.2414
# Time taken for 1 epoch 12.897496461868286 sec
#
# Epoch 27 Loss 1.9263 Acc 0.2616
# Validation Loss 1.9870 Acc 0.2422
# Time taken for 1 epoch 12.906955480575562 sec
#
# Epoch 28 Loss 1.9240 Acc 0.2614
# Validation Loss 1.9905 Acc 0.2423
# Time taken for 1 epoch 12.927475690841675 sec
#
# Epoch 29 Loss 1.9282 Acc 0.2609
# Validation Loss 1.9959 Acc 0.2358
# Time taken for 1 epoch 12.908296823501587 sec
#
# Epoch 30 Loss 1.9238 Acc 0.2606
# Validation Loss 1.9775 Acc 0.2427
# Time taken for 1 epoch 12.958322048187256 sec
#
# Epoch 31 Loss 1.9151 Acc 0.2637
# Validation Loss 1.9751 Acc 0.2420
# Time taken for 1 epoch 12.862388849258423 sec
#
# Epoch 32 Loss 1.9211 Acc 0.2612
# Validation Loss 1.9818 Acc 0.2405
# Time taken for 1 epoch 12.916829109191895 sec
#
# Epoch 33 Loss 1.9202 Acc 0.2615
# Validation Loss 1.9768 Acc 0.2433
# Time taken for 1 epoch 12.836202144622803 sec
#
# Epoch 34 Loss 1.9109 Acc 0.2647
# Validation Loss 1.9801 Acc 0.2420
# Time taken for 1 epoch 12.923050165176392 sec
#
# Epoch 35 Loss 1.9105 Acc 0.2647
# Validation Loss 1.9723 Acc 0.2451
# Time taken for 1 epoch 12.913531064987183 sec
#
# Epoch 36 Loss 1.9094 Acc 0.2650
# Validation Loss 1.9780 Acc 0.2424
# Time taken for 1 epoch 12.872835874557495 sec
#
# Epoch 37 Loss 1.9308 Acc 0.2590
# Validation Loss 1.9803 Acc 0.2423
# Time taken for 1 epoch 12.87508773803711 sec
#
# Epoch 38 Loss 1.9110 Acc 0.2652
# Validation Loss 1.9733 Acc 0.2442
# Time taken for 1 epoch 12.849279165267944 sec
#
# Epoch 39 Loss 1.9068 Acc 0.2658
# Validation Loss 1.9720 Acc 0.2457
# Time taken for 1 epoch 12.876778841018677 sec
#
# Epoch 40 Loss 1.9047 Acc 0.2661
# Validation Loss 1.9717 Acc 0.2430
# Time taken for 1 epoch 12.854867696762085 sec
#
# Epoch 41 Loss 1.9010 Acc 0.2669
# Validation Loss 1.9656 Acc 0.2464
# Time taken for 1 epoch 12.845137596130371 sec
#
# Epoch 42 Loss 1.9184 Acc 0.2613
# Validation Loss 1.9692 Acc 0.2451
# Time taken for 1 epoch 12.877035856246948 sec
#
# Epoch 43 Loss 1.9047 Acc 0.2655
# Validation Loss 1.9687 Acc 0.2457
# Time taken for 1 epoch 12.899712085723877 sec
#
# Epoch 44 Loss 1.9298 Acc 0.2610
# Validation Loss 1.9898 Acc 0.2411
# Time taken for 1 epoch 12.895130395889282 sec
#
# Epoch 45 Loss 1.9205 Acc 0.2636
# Validation Loss 1.9811 Acc 0.2429
# Time taken for 1 epoch 12.87143850326538 sec
#
# Epoch 46 Loss 1.9107 Acc 0.2657
# Validation Loss 1.9727 Acc 0.2448
# Time taken for 1 epoch 12.9017813205719 sec
#
# Epoch 47 Loss 1.9049 Acc 0.2669
# Validation Loss 1.9706 Acc 0.2452
# Time taken for 1 epoch 12.870924234390259 sec
#
# Epoch 48 Loss 1.9054 Acc 0.2665
# Validation Loss 1.9690 Acc 0.2448
# Time taken for 1 epoch 12.901674509048462 sec
#
# Epoch 49 Loss 1.9073 Acc 0.2660
# Validation Loss 1.9748 Acc 0.2429
# Time taken for 1 epoch 12.8387930393219 sec
#
# Epoch 50 Loss 1.9022 Acc 0.2675
# Validation Loss 1.9706 Acc 0.2442
# Time taken for 1 epoch 12.914729833602905 sec
#
# Epoch 51 Loss 1.9407 Acc 0.2539
# Validation Loss 1.9787 Acc 0.2433
# Time taken for 1 epoch 12.872276544570923 sec
#
# Epoch 52 Loss 1.9085 Acc 0.2655
# Validation Loss 1.9681 Acc 0.2454
# Time taken for 1 epoch 12.889732122421265 sec
#
# Epoch 53 Loss 1.9027 Acc 0.2665
# Validation Loss 1.9662 Acc 0.2455
# Time taken for 1 epoch 12.89161491394043 sec
#
# Epoch 54 Loss 1.8974 Acc 0.2677
# Validation Loss 1.9696 Acc 0.2436
# Time taken for 1 epoch 12.838223457336426 sec
#
# Epoch 55 Loss 1.9009 Acc 0.2662
# Validation Loss 1.9629 Acc 0.2452
# Time taken for 1 epoch 12.888720512390137 sec
#
# Epoch 56 Loss 1.8959 Acc 0.2670
# Validation Loss 1.9608 Acc 0.2460
# Time taken for 1 epoch 12.869773864746094 sec
#
# Epoch 57 Loss 1.9119 Acc 0.2619
# Validation Loss 1.9724 Acc 0.2422
# Time taken for 1 epoch 12.869111061096191 sec
#
# Epoch 58 Loss 1.9035 Acc 0.2655
# Validation Loss 1.9692 Acc 0.2433
# Time taken for 1 epoch 12.904137372970581 sec
#
# Epoch 59 Loss 1.8955 Acc 0.2677
# Validation Loss 1.9584 Acc 0.2458
# Time taken for 1 epoch 12.887674570083618 sec
#
# Epoch 60 Loss 1.8902 Acc 0.2690
# Validation Loss 1.9603 Acc 0.2458
# Time taken for 1 epoch 12.876956462860107 sec
#
# Epoch 61 Loss 1.8904 Acc 0.2688
# Validation Loss 1.9573 Acc 0.2460
# Time taken for 1 epoch 12.94255781173706 sec
#
# Epoch 62 Loss 1.8868 Acc 0.2698
# Validation Loss 1.9609 Acc 0.2463
# Time taken for 1 epoch 12.840705394744873 sec
#
# Epoch 63 Loss 1.8883 Acc 0.2692
# Validation Loss 1.9797 Acc 0.2331
# Time taken for 1 epoch 12.897640228271484 sec
#
# Epoch 64 Loss 1.8892 Acc 0.2688
# Validation Loss 1.9532 Acc 0.2477
# Time taken for 1 epoch 12.865854024887085 sec
#
# Epoch 65 Loss 1.8874 Acc 0.2690
# Validation Loss 1.9591 Acc 0.2455
# Time taken for 1 epoch 12.875697135925293 sec
#
# Epoch 66 Loss 1.8922 Acc 0.2676
# Validation Loss 1.9585 Acc 0.2465
# Time taken for 1 epoch 12.883073806762695 sec
#
# Epoch 67 Loss 1.8873 Acc 0.2689
# Validation Loss 1.9567 Acc 0.2462
# Time taken for 1 epoch 12.901546239852905 sec
#
# Epoch 68 Loss 1.8837 Acc 0.2704
# Validation Loss 1.9560 Acc 0.2464
# Time taken for 1 epoch 12.879117488861084 sec
#
# Epoch 69 Loss 1.8905 Acc 0.2679
# Validation Loss 1.9567 Acc 0.2458
# Time taken for 1 epoch 12.887164115905762 sec
#
# Epoch 70 Loss 1.8868 Acc 0.2695
# Validation Loss 1.9587 Acc 0.2463
# Time taken for 1 epoch 12.887240171432495 sec
#
# Epoch 71 Loss 1.8915 Acc 0.2683
# Validation Loss 1.9712 Acc 0.2434
# Time taken for 1 epoch 12.922486066818237 sec
#
# Epoch 72 Loss 1.8961 Acc 0.2684
# Validation Loss 1.9672 Acc 0.2437
# Time taken for 1 epoch 12.8500337600708 sec
#
# Epoch 73 Loss 1.8912 Acc 0.2691
# Validation Loss 1.9606 Acc 0.2451
# Time taken for 1 epoch 12.865349769592285 sec
#
# Epoch 74 Loss 1.8882 Acc 0.2688
# Validation Loss 1.9611 Acc 0.2437
# Time taken for 1 epoch 12.855026245117188 sec
#
# Epoch 75 Loss 1.8889 Acc 0.2692
# Validation Loss 1.9573 Acc 0.2456
# Time taken for 1 epoch 12.94381594657898 sec
#
# Epoch 76 Loss 1.8907 Acc 0.2683
# Validation Loss 2.0032 Acc 0.2290
# Time taken for 1 epoch 12.917235136032104 sec
#
# Epoch 77 Loss 1.9087 Acc 0.2619
# Validation Loss 1.9614 Acc 0.2433
# Time taken for 1 epoch 12.912368774414062 sec
#
# Epoch 78 Loss 1.8874 Acc 0.2688
# Validation Loss 1.9579 Acc 0.2456
# Time taken for 1 epoch 12.812789678573608 sec
#
# Epoch 79 Loss 1.8963 Acc 0.2661
# Validation Loss 1.9597 Acc 0.2459
# Time taken for 1 epoch 12.861675500869751 sec
#
# Epoch 80 Loss 1.8837 Acc 0.2701
# Validation Loss 1.9560 Acc 0.2455
# Time taken for 1 epoch 12.897809028625488 sec
#
# Epoch 81 Loss 1.8808 Acc 0.2708
# Validation Loss 1.9541 Acc 0.2462
# Time taken for 1 epoch 12.884912729263306 sec
#
# Epoch 82 Loss 1.8783 Acc 0.2714
# Validation Loss 1.9546 Acc 0.2462
# Time taken for 1 epoch 12.888883590698242 sec
#
# Epoch 83 Loss 1.9273 Acc 0.2583
# Validation Loss 1.9673 Acc 0.2440
# Time taken for 1 epoch 12.89634919166565 sec
#
# Epoch 84 Loss 1.8929 Acc 0.2686
# Validation Loss 1.9582 Acc 0.2456
# Time taken for 1 epoch 12.913494348526001 sec
#
# Epoch 85 Loss 1.8856 Acc 0.2702
# Validation Loss 1.9549 Acc 0.2462
# Time taken for 1 epoch 12.881587982177734 sec
#
# Epoch 86 Loss 1.8813 Acc 0.2710
# Validation Loss 1.9582 Acc 0.2452
# Time taken for 1 epoch 12.894531488418579 sec
#
# Epoch 87 Loss 1.8831 Acc 0.2704
# Validation Loss 1.9511 Acc 0.2472
# Time taken for 1 epoch 12.928319454193115 sec
#
# Epoch 88 Loss 1.8830 Acc 0.2699
# Validation Loss 1.9791 Acc 0.2351
# Time taken for 1 epoch 12.898613452911377 sec
#
# Epoch 89 Loss 1.8912 Acc 0.2679
# Validation Loss 1.9594 Acc 0.2462
# Time taken for 1 epoch 12.888813257217407 sec
#
# Epoch 90 Loss 1.8834 Acc 0.2702
# Validation Loss 1.9504 Acc 0.2475
# Time taken for 1 epoch 12.915678024291992 sec
#
# Epoch 91 Loss 1.8792 Acc 0.2712
# Validation Loss 1.9516 Acc 0.2471
# Time taken for 1 epoch 12.87995433807373 sec
#
# Epoch 92 Loss 1.8755 Acc 0.2721
# Validation Loss 1.9478 Acc 0.2477
# Time taken for 1 epoch 12.938761711120605 sec
#
# Epoch 93 Loss 1.8761 Acc 0.2717
# Validation Loss 1.9469 Acc 0.2478
# Time taken for 1 epoch 12.883341789245605 sec
#
# Epoch 94 Loss 1.8737 Acc 0.2723
# Validation Loss 1.9476 Acc 0.2470
# Time taken for 1 epoch 12.922573566436768 sec
#
# Epoch 95 Loss 1.8815 Acc 0.2707
# Validation Loss 1.9518 Acc 0.2469
# Time taken for 1 epoch 12.868469715118408 sec
#
# Epoch 96 Loss 1.8811 Acc 0.2698
# Validation Loss 1.9504 Acc 0.2469
# Time taken for 1 epoch 12.907620429992676 sec
#
# Epoch 97 Loss 1.8763 Acc 0.2716
# Validation Loss 1.9473 Acc 0.2482
# Time taken for 1 epoch 12.892104387283325 sec
#
# Epoch 98 Loss 1.8706 Acc 0.2730
# Validation Loss 1.9461 Acc 0.2479
# Time taken for 1 epoch 12.85662317276001 sec
#
# Epoch 99 Loss 1.8726 Acc 0.2723
# Validation Loss 1.9488 Acc 0.2475
# Time taken for 1 epoch 12.914393424987793 sec
#
# Epoch 100 Loss 1.8732 Acc 0.2723
# Validation Loss 1.9457 Acc 0.2479
# Time taken for 1 epoch 12.898823499679565 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 16
#      13 val_steps_per_epoch = 0
#      15 for x, y in train_dataset:
# ---> 16     batch_loss, batch_acc = train_step(x, y)
#      17     total_loss += batch_loss
#      18     total_acc += batch_acc
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
total_loss = 0
total_acc = 0
steps_per_epoch = 0
val_total_loss = 0
val_total_acc = 0
val_steps_per_epoch = 0

for x, y in train_dataset:
    batch_loss, batch_acc = val_step(x, y)
    total_loss += batch_loss
    total_acc += batch_acc
    steps_per_epoch += 1
    
for x, y in validation_dataset:
    val_batch_loss, val_batch_acc = val_step(x, y)
    val_total_loss += val_batch_loss
    val_total_acc += val_batch_acc
    val_steps_per_epoch += 1

print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
# Out:
# Training Loss 1.8680 Acc 0.2733
# Validation Loss 1.9465 Acc 0.2471

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"/loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"/acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"/val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"/val_acc_history.npy", np.array(val_acc_history))

# %%
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 33ms/step
# (1536, 53)
