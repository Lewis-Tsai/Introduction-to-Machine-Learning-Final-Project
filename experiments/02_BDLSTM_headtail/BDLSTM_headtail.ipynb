# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')

# %%
BATCH_SIZE = 512
VALIDATION_RATIO = 0.1

PIECE_LEN = 1024
n_feature = 43
n_hidden = 100
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-01-16 13:07:55.695493: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:55.710322: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:55.710528: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:55.720148: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-16 13:07:55.720758: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:55.720944: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:55.721110: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:58.846942: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:58.847243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:58.847475: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-16 13:07:58.847646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(tf.keras.layers.Dense(n_feature, activation="relu", kernel_regularizer=L2(0.001)), input_shape=(1, n_feature), name="head_dense1")(x)
x = TimeDistributed(Dense(n_feature, activation="relu", kernel_regularizer=L2(0.001)), input_shape=(1, n_feature), name="head_dense2")(x)
x = TimeDistributed(BatchNormalization(), name="head_bn")(x)
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001)))(x)
x = TimeDistributed(BatchNormalization(), name="tail_bn")(x)
x = TimeDistributed(Dense(n_pitch, activation="relu", kernel_regularizer=L2(0.001)), name="tail_dense1")(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)

print(model.summary())

optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024, 43)]        0
#
#  mask (Masking)              (None, 1024, 43)          0
#
#  head_dense1 (TimeDistribute  (None, 1024, 43)         1892
#  d)
#
#  head_dense2 (TimeDistribute  (None, 1024, 43)         1892
#  d)
#
#  head_bn (TimeDistributed)   (None, 1024, 43)          172
#
#  bidirectional (Bidirectiona  (None, 1024, 200)        115200
#  l)
#
#  tail_bn (TimeDistributed)   (None, 1024, 200)         800
#
#  tail_dense1 (TimeDistribute  (None, 1024, 53)         10653
#  d)
#
#  output (TimeDistributed)    (None, 1024, 53)          2862
#
# =================================================================
# Total params: 133,471
# Trainable params: 132,985
# Non-trainable params: 486
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/02_BDLSTM_headtail'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-1")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 300

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))
# Out:
# Epoch 1 Loss 2.3025 Acc 0.2000
# Validation Loss 2.0825 Acc 0.1900
# Time taken for 1 epoch 22.05986714363098 sec
#
# Epoch 2 Loss 2.2046 Acc 0.2101
# Validation Loss 2.0431 Acc 0.1967
# Time taken for 1 epoch 14.461558103561401 sec
#
# Epoch 3 Loss 2.1562 Acc 0.2144
# Validation Loss 2.0232 Acc 0.2012
# Time taken for 1 epoch 14.591271162033081 sec
#
# Epoch 4 Loss 2.1252 Acc 0.2168
# Validation Loss 2.0075 Acc 0.2048
# Time taken for 1 epoch 14.593877077102661 sec
#
# Epoch 5 Loss 2.1013 Acc 0.2190
# Validation Loss 1.9969 Acc 0.2071
# Time taken for 1 epoch 14.643450736999512 sec
#
# Epoch 6 Loss 2.0827 Acc 0.2204
# Validation Loss 1.9892 Acc 0.2094
# Time taken for 1 epoch 14.664405822753906 sec
#
# Epoch 7 Loss 2.0680 Acc 0.2217
# Validation Loss 1.9828 Acc 0.2116
# Time taken for 1 epoch 14.674574136734009 sec
#
# Epoch 8 Loss 2.0544 Acc 0.2230
# Validation Loss 1.9787 Acc 0.2128
# Time taken for 1 epoch 14.678258180618286 sec
#
# Epoch 9 Loss 2.0461 Acc 0.2233
# Validation Loss 1.9729 Acc 0.2137
# Time taken for 1 epoch 14.708322525024414 sec
#
# Epoch 10 Loss 2.0347 Acc 0.2248
# Validation Loss 1.9683 Acc 0.2150
# Time taken for 1 epoch 14.689872026443481 sec
#
# Epoch 11 Loss 2.0251 Acc 0.2260
# Validation Loss 1.9629 Acc 0.2163
# Time taken for 1 epoch 14.630456924438477 sec
#
# Epoch 12 Loss 2.0169 Acc 0.2270
# Validation Loss 1.9585 Acc 0.2173
# Time taken for 1 epoch 14.680777549743652 sec
#
# Epoch 13 Loss 2.0101 Acc 0.2279
# Validation Loss 1.9558 Acc 0.2177
# Time taken for 1 epoch 14.667738437652588 sec
#
# Epoch 14 Loss 2.0030 Acc 0.2292
# Validation Loss 1.9543 Acc 0.2186
# Time taken for 1 epoch 14.654587984085083 sec
#
# Epoch 15 Loss 1.9968 Acc 0.2300
# Validation Loss 1.9518 Acc 0.2192
# Time taken for 1 epoch 14.63586688041687 sec
#
# Epoch 16 Loss 1.9900 Acc 0.2310
# Validation Loss 1.9477 Acc 0.2197
# Time taken for 1 epoch 14.631268978118896 sec
#
# Epoch 17 Loss 1.9848 Acc 0.2320
# Validation Loss 1.9427 Acc 0.2201
# Time taken for 1 epoch 14.67459750175476 sec
#
# Epoch 18 Loss 1.9809 Acc 0.2326
# Validation Loss 1.9422 Acc 0.2203
# Time taken for 1 epoch 14.724009275436401 sec
#
# Epoch 19 Loss 1.9742 Acc 0.2341
# Validation Loss 1.9378 Acc 0.2211
# Time taken for 1 epoch 14.737043619155884 sec
#
# Epoch 20 Loss 1.9701 Acc 0.2348
# Validation Loss 1.9354 Acc 0.2224
# Time taken for 1 epoch 14.685131549835205 sec
#
# Epoch 21 Loss 1.9661 Acc 0.2356
# Validation Loss 1.9321 Acc 0.2225
# Time taken for 1 epoch 14.743909120559692 sec
#
# Epoch 22 Loss 1.9613 Acc 0.2366
# Validation Loss 1.9274 Acc 0.2237
# Time taken for 1 epoch 14.709285020828247 sec
#
# Epoch 23 Loss 1.9568 Acc 0.2376
# Validation Loss 1.9203 Acc 0.2248
# Time taken for 1 epoch 14.668551683425903 sec
#
# Epoch 24 Loss 1.9615 Acc 0.2368
# Validation Loss 1.9298 Acc 0.2234
# Time taken for 1 epoch 14.718196630477905 sec
#
# Epoch 25 Loss 1.9510 Acc 0.2392
# Validation Loss 1.9130 Acc 0.2257
# Time taken for 1 epoch 14.66674280166626 sec
#
# Epoch 26 Loss 1.9523 Acc 0.2393
# Validation Loss 1.9232 Acc 0.2240
# Time taken for 1 epoch 14.69121503829956 sec
#
# Epoch 27 Loss 1.9438 Acc 0.2407
# Validation Loss 1.9070 Acc 0.2272
# Time taken for 1 epoch 14.729203939437866 sec
#
# Epoch 28 Loss 1.9935 Acc 0.2291
# Validation Loss 1.9447 Acc 0.2184
# Time taken for 1 epoch 14.621253490447998 sec
#
# Epoch 29 Loss 1.9598 Acc 0.2378
# Validation Loss 1.9302 Acc 0.2227
# Time taken for 1 epoch 14.659740209579468 sec
#
# Epoch 30 Loss 1.9463 Acc 0.2403
# Validation Loss 1.9204 Acc 0.2253
# Time taken for 1 epoch 14.728607892990112 sec
#
# Epoch 31 Loss 1.9392 Acc 0.2417
# Validation Loss 1.9177 Acc 0.2259
# Time taken for 1 epoch 14.686896562576294 sec
#
# Epoch 32 Loss 1.9341 Acc 0.2429
# Validation Loss 1.9054 Acc 0.2283
# Time taken for 1 epoch 14.691889762878418 sec
#
# Epoch 33 Loss 1.9297 Acc 0.2443
# Validation Loss 1.9099 Acc 0.2285
# Time taken for 1 epoch 14.698080062866211 sec
#
# Epoch 34 Loss 1.9270 Acc 0.2448
# Validation Loss 1.8978 Acc 0.2297
# Time taken for 1 epoch 14.608249425888062 sec
#
# Epoch 35 Loss 1.9233 Acc 0.2458
# Validation Loss 1.8938 Acc 0.2303
# Time taken for 1 epoch 14.633512496948242 sec
#
# Epoch 36 Loss 1.9186 Acc 0.2472
# Validation Loss 1.8895 Acc 0.2335
# Time taken for 1 epoch 14.807070970535278 sec
#
# Epoch 37 Loss 1.9168 Acc 0.2473
# Validation Loss 1.8925 Acc 0.2319
# Time taken for 1 epoch 14.74337911605835 sec
#
# Epoch 38 Loss 1.9117 Acc 0.2497
# Validation Loss 1.9058 Acc 0.2286
# Time taken for 1 epoch 14.648846864700317 sec
#
# Epoch 39 Loss 1.9059 Acc 0.2507
# Validation Loss 1.8780 Acc 0.2361
# Time taken for 1 epoch 14.756961345672607 sec
#
# Epoch 40 Loss 1.9123 Acc 0.2489
# Validation Loss 1.8765 Acc 0.2350
# Time taken for 1 epoch 14.642301082611084 sec
#
# Epoch 41 Loss 1.9019 Acc 0.2517
# Validation Loss 1.8732 Acc 0.2370
# Time taken for 1 epoch 14.607872724533081 sec
#
# Epoch 42 Loss 1.8950 Acc 0.2538
# Validation Loss 1.8941 Acc 0.2254
# Time taken for 1 epoch 14.700857162475586 sec
#
# Epoch 43 Loss 1.9395 Acc 0.2426
# Validation Loss 2.0045 Acc 0.2014
# Time taken for 1 epoch 14.769635200500488 sec
#
# Epoch 44 Loss 1.9906 Acc 0.2286
# Validation Loss 1.9428 Acc 0.2197
# Time taken for 1 epoch 14.76099157333374 sec
#
# Epoch 45 Loss 1.9534 Acc 0.2394
# Validation Loss 1.9268 Acc 0.2247
# Time taken for 1 epoch 14.739961624145508 sec
#
# Epoch 46 Loss 1.9336 Acc 0.2451
# Validation Loss 1.9093 Acc 0.2304
# Time taken for 1 epoch 14.71445631980896 sec
#
# Epoch 47 Loss 1.9228 Acc 0.2475
# Validation Loss 1.8930 Acc 0.2336
# Time taken for 1 epoch 14.79192304611206 sec
#
# Epoch 48 Loss 1.9152 Acc 0.2501
# Validation Loss 1.8844 Acc 0.2352
# Time taken for 1 epoch 14.732043504714966 sec
#
# Epoch 49 Loss 1.9054 Acc 0.2520
# Validation Loss 1.8801 Acc 0.2353
# Time taken for 1 epoch 14.767193078994751 sec
#
# Epoch 50 Loss 1.8970 Acc 0.2538
# Validation Loss 1.8715 Acc 0.2375
# Time taken for 1 epoch 14.666817903518677 sec
#
# Epoch 51 Loss 1.8924 Acc 0.2558
# Validation Loss 1.8651 Acc 0.2410
# Time taken for 1 epoch 14.694278478622437 sec
#
# Epoch 52 Loss 1.8811 Acc 0.2587
# Validation Loss 1.8710 Acc 0.2402
# Time taken for 1 epoch 14.749280214309692 sec
#
# Epoch 53 Loss 1.8799 Acc 0.2588
# Validation Loss 1.8586 Acc 0.2431
# Time taken for 1 epoch 14.748019933700562 sec
#
# Epoch 54 Loss 1.8958 Acc 0.2543
# Validation Loss 1.8632 Acc 0.2412
# Time taken for 1 epoch 14.639747619628906 sec
#
# Epoch 55 Loss 1.8754 Acc 0.2605
# Validation Loss 1.8580 Acc 0.2429
# Time taken for 1 epoch 14.732484579086304 sec
#
# Epoch 56 Loss 1.8777 Acc 0.2592
# Validation Loss 1.8788 Acc 0.2389
# Time taken for 1 epoch 14.715792417526245 sec
#
# Epoch 57 Loss 1.8859 Acc 0.2569
# Validation Loss 1.8612 Acc 0.2423
# Time taken for 1 epoch 14.767571210861206 sec
#
# Epoch 58 Loss 1.8683 Acc 0.2626
# Validation Loss 1.8473 Acc 0.2454
# Time taken for 1 epoch 14.749641418457031 sec
#
# Epoch 59 Loss 1.8518 Acc 0.2673
# Validation Loss 1.8553 Acc 0.2433
# Time taken for 1 epoch 14.68713927268982 sec
#
# Epoch 60 Loss 1.8552 Acc 0.2664
# Validation Loss 1.8472 Acc 0.2455
# Time taken for 1 epoch 14.653550148010254 sec
#
# Epoch 61 Loss 1.8519 Acc 0.2669
# Validation Loss 1.8719 Acc 0.2387
# Time taken for 1 epoch 14.76809549331665 sec
#
# Epoch 62 Loss 1.8487 Acc 0.2676
# Validation Loss 1.8525 Acc 0.2438
# Time taken for 1 epoch 14.771835803985596 sec
#
# Epoch 63 Loss 1.8546 Acc 0.2656
# Validation Loss 1.8626 Acc 0.2407
# Time taken for 1 epoch 14.702400922775269 sec
#
# Epoch 64 Loss 1.8409 Acc 0.2702
# Validation Loss 1.8437 Acc 0.2448
# Time taken for 1 epoch 14.77907109260559 sec
#
# Epoch 65 Loss 1.8391 Acc 0.2704
# Validation Loss 1.8456 Acc 0.2447
# Time taken for 1 epoch 14.677061080932617 sec
#
# Epoch 66 Loss 1.8364 Acc 0.2713
# Validation Loss 1.8387 Acc 0.2461
# Time taken for 1 epoch 14.681366920471191 sec
#
# Epoch 67 Loss 1.8316 Acc 0.2728
# Validation Loss 1.8408 Acc 0.2455
# Time taken for 1 epoch 14.724117279052734 sec
#
# Epoch 68 Loss 1.8830 Acc 0.2569
# Validation Loss 1.9288 Acc 0.2229
# Time taken for 1 epoch 14.71638798713684 sec
#
# Epoch 69 Loss 1.9045 Acc 0.2525
# Validation Loss 1.8663 Acc 0.2411
# Time taken for 1 epoch 14.730749607086182 sec
#
# Epoch 70 Loss 1.8609 Acc 0.2641
# Validation Loss 1.8536 Acc 0.2388
# Time taken for 1 epoch 14.772214889526367 sec
#
# Epoch 71 Loss 1.8374 Acc 0.2704
# Validation Loss 1.8367 Acc 0.2467
# Time taken for 1 epoch 14.758213758468628 sec
#
# Epoch 72 Loss 1.8264 Acc 0.2744
# Validation Loss 1.8661 Acc 0.2399
# Time taken for 1 epoch 14.748605251312256 sec
#
# Epoch 73 Loss 1.8612 Acc 0.2628
# Validation Loss 1.8703 Acc 0.2388
# Time taken for 1 epoch 14.698087215423584 sec
#
# Epoch 74 Loss 1.8300 Acc 0.2724
# Validation Loss 1.8377 Acc 0.2466
# Time taken for 1 epoch 14.689184188842773 sec
#
# Epoch 75 Loss 1.8262 Acc 0.2738
# Validation Loss 1.8376 Acc 0.2469
# Time taken for 1 epoch 14.695657014846802 sec
#
# Epoch 76 Loss 1.8261 Acc 0.2735
# Validation Loss 1.8389 Acc 0.2462
# Time taken for 1 epoch 14.722443103790283 sec
#
# Epoch 77 Loss 1.8261 Acc 0.2728
# Validation Loss 1.8454 Acc 0.2441
# Time taken for 1 epoch 14.768521785736084 sec
#
# Epoch 78 Loss 1.8199 Acc 0.2751
# Validation Loss 1.8362 Acc 0.2470
# Time taken for 1 epoch 14.70771598815918 sec
#
# Epoch 79 Loss 1.8192 Acc 0.2753
# Validation Loss 1.8432 Acc 0.2455
# Time taken for 1 epoch 14.830662488937378 sec
#
# Epoch 80 Loss 1.8469 Acc 0.2665
# Validation Loss 1.8424 Acc 0.2449
# Time taken for 1 epoch 14.75409460067749 sec
#
# Epoch 81 Loss 1.8134 Acc 0.2771
# Validation Loss 1.8345 Acc 0.2468
# Time taken for 1 epoch 14.77872347831726 sec
#
# Epoch 82 Loss 1.8201 Acc 0.2741
# Validation Loss 1.8471 Acc 0.2432
# Time taken for 1 epoch 14.684169292449951 sec
#
# Epoch 83 Loss 1.8198 Acc 0.2742
# Validation Loss 1.8363 Acc 0.2466
# Time taken for 1 epoch 14.677427291870117 sec
#
# Epoch 84 Loss 1.8083 Acc 0.2783
# Validation Loss 1.8367 Acc 0.2460
# Time taken for 1 epoch 14.739217758178711 sec
#
# Epoch 85 Loss 1.8491 Acc 0.2649
# Validation Loss 1.8947 Acc 0.2319
# Time taken for 1 epoch 14.741859912872314 sec
#
# Epoch 86 Loss 1.8872 Acc 0.2552
# Validation Loss 1.9139 Acc 0.2267
# Time taken for 1 epoch 14.7488272190094 sec
#
# Epoch 87 Loss 1.8772 Acc 0.2578
# Validation Loss 1.8436 Acc 0.2443
# Time taken for 1 epoch 14.737754821777344 sec
#
# Epoch 88 Loss 1.8300 Acc 0.2718
# Validation Loss 1.8347 Acc 0.2471
# Time taken for 1 epoch 14.730746507644653 sec
#
# Epoch 89 Loss 1.8170 Acc 0.2748
# Validation Loss 1.8433 Acc 0.2441
# Time taken for 1 epoch 14.79293704032898 sec
#
# Epoch 90 Loss 1.8165 Acc 0.2747
# Validation Loss 1.8555 Acc 0.2407
# Time taken for 1 epoch 14.692254781723022 sec
#
# Epoch 91 Loss 1.8030 Acc 0.2793
# Validation Loss 1.8304 Acc 0.2474
# Time taken for 1 epoch 14.710011005401611 sec
#
# Epoch 92 Loss 1.8060 Acc 0.2776
# Validation Loss 1.8307 Acc 0.2472
# Time taken for 1 epoch 14.65942120552063 sec
#
# Epoch 93 Loss 1.7995 Acc 0.2803
# Validation Loss 1.8247 Acc 0.2490
# Time taken for 1 epoch 14.785837650299072 sec
#
# Epoch 94 Loss 1.7972 Acc 0.2808
# Validation Loss 1.8280 Acc 0.2480
# Time taken for 1 epoch 14.72224760055542 sec
#
# Epoch 95 Loss 1.7988 Acc 0.2801
# Validation Loss 1.8278 Acc 0.2483
# Time taken for 1 epoch 14.822807550430298 sec
#
# Epoch 96 Loss 1.8053 Acc 0.2778
# Validation Loss 1.8316 Acc 0.2471
# Time taken for 1 epoch 14.655354499816895 sec
#
# Epoch 97 Loss 1.8266 Acc 0.2701
# Validation Loss 1.8383 Acc 0.2449
# Time taken for 1 epoch 14.809252738952637 sec
#
# Epoch 98 Loss 1.7961 Acc 0.2809
# Validation Loss 1.8272 Acc 0.2488
# Time taken for 1 epoch 14.656966924667358 sec
#
# Epoch 99 Loss 1.7940 Acc 0.2819
# Validation Loss 1.8342 Acc 0.2462
# Time taken for 1 epoch 14.765980243682861 sec
#
# Epoch 100 Loss 1.7960 Acc 0.2802
# Validation Loss 1.8540 Acc 0.2408
# Time taken for 1 epoch 14.692623138427734 sec
#
# Epoch 101 Loss 1.7976 Acc 0.2792
# Validation Loss 1.8254 Acc 0.2491
# Time taken for 1 epoch 14.685942888259888 sec
#
# Epoch 102 Loss 1.7915 Acc 0.2816
# Validation Loss 1.8313 Acc 0.2481
# Time taken for 1 epoch 14.723042488098145 sec
#
# Epoch 103 Loss 1.7870 Acc 0.2832
# Validation Loss 1.8299 Acc 0.2479
# Time taken for 1 epoch 14.794644594192505 sec
#
# Epoch 104 Loss 1.8403 Acc 0.2645
# Validation Loss 1.8415 Acc 0.2441
# Time taken for 1 epoch 14.752668619155884 sec
#
# Epoch 105 Loss 1.7958 Acc 0.2801
# Validation Loss 1.8271 Acc 0.2485
# Time taken for 1 epoch 14.792892932891846 sec
#
# Epoch 106 Loss 1.7938 Acc 0.2816
# Validation Loss 1.8268 Acc 0.2489
# Time taken for 1 epoch 14.738790035247803 sec
#
# Epoch 107 Loss 1.8039 Acc 0.2788
# Validation Loss 1.8294 Acc 0.2474
# Time taken for 1 epoch 14.674185514450073 sec
#
# Epoch 108 Loss 1.7996 Acc 0.2780
# Validation Loss 1.8315 Acc 0.2469
# Time taken for 1 epoch 14.801146745681763 sec
#
# Epoch 109 Loss 1.7874 Acc 0.2824
# Validation Loss 1.8271 Acc 0.2486
# Time taken for 1 epoch 14.74288821220398 sec
#
# Epoch 110 Loss 1.7844 Acc 0.2833
# Validation Loss 1.8298 Acc 0.2469
# Time taken for 1 epoch 14.68020248413086 sec
#
# Epoch 111 Loss 1.7851 Acc 0.2828
# Validation Loss 1.8317 Acc 0.2469
# Time taken for 1 epoch 14.72675633430481 sec
#
# Epoch 112 Loss 1.8894 Acc 0.2518
# Validation Loss 1.8841 Acc 0.2324
# Time taken for 1 epoch 14.747953176498413 sec
#
# Epoch 113 Loss 1.8542 Acc 0.2624
# Validation Loss 1.8447 Acc 0.2447
# Time taken for 1 epoch 14.645294666290283 sec
#
# Epoch 114 Loss 1.8279 Acc 0.2693
# Validation Loss 1.8309 Acc 0.2466
# Time taken for 1 epoch 14.78477692604065 sec
#
# Epoch 115 Loss 1.7870 Acc 0.2820
# Validation Loss 1.8296 Acc 0.2473
# Time taken for 1 epoch 14.781929016113281 sec
#
# Epoch 116 Loss 1.8364 Acc 0.2669
# Validation Loss 1.8893 Acc 0.2344
# Time taken for 1 epoch 14.741195440292358 sec
#
# Epoch 117 Loss 1.8290 Acc 0.2700
# Validation Loss 1.8224 Acc 0.2503
# Time taken for 1 epoch 14.684845924377441 sec
#
# Epoch 118 Loss 1.7841 Acc 0.2829
# Validation Loss 1.8331 Acc 0.2475
# Time taken for 1 epoch 14.75135850906372 sec
#
# Epoch 119 Loss 1.7812 Acc 0.2838
# Validation Loss 1.8300 Acc 0.2478
# Time taken for 1 epoch 14.67824101448059 sec
#
# Epoch 120 Loss 1.7848 Acc 0.2824
# Validation Loss 1.8387 Acc 0.2456
# Time taken for 1 epoch 14.739879369735718 sec
#
# Epoch 121 Loss 1.7860 Acc 0.2827
# Validation Loss 1.8268 Acc 0.2480
# Time taken for 1 epoch 14.69078278541565 sec
#
# Epoch 122 Loss 1.7803 Acc 0.2834
# Validation Loss 1.8540 Acc 0.2410
# Time taken for 1 epoch 14.66079568862915 sec
#
# Epoch 123 Loss 1.8644 Acc 0.2579
# Validation Loss 1.8680 Acc 0.2369
# Time taken for 1 epoch 14.66410207748413 sec
#
# Epoch 124 Loss 1.8136 Acc 0.2740
# Validation Loss 1.8297 Acc 0.2474
# Time taken for 1 epoch 14.676707983016968 sec
#
# Epoch 125 Loss 1.7828 Acc 0.2829
# Validation Loss 1.8342 Acc 0.2467
# Time taken for 1 epoch 14.69810438156128 sec
#
# Epoch 126 Loss 1.7729 Acc 0.2857
# Validation Loss 1.8273 Acc 0.2480
# Time taken for 1 epoch 14.714550971984863 sec
#
# Epoch 127 Loss 1.7861 Acc 0.2808
# Validation Loss 1.8363 Acc 0.2462
# Time taken for 1 epoch 14.712296485900879 sec
#
# Epoch 128 Loss 1.7713 Acc 0.2863
# Validation Loss 1.8318 Acc 0.2472
# Time taken for 1 epoch 14.661983251571655 sec
#
# Epoch 129 Loss 1.7746 Acc 0.2845
# Validation Loss 1.8324 Acc 0.2466
# Time taken for 1 epoch 14.683812141418457 sec
#
# Epoch 130 Loss 1.7692 Acc 0.2865
# Validation Loss 1.8431 Acc 0.2442
# Time taken for 1 epoch 14.718355655670166 sec
#
# Epoch 131 Loss 1.8272 Acc 0.2685
# Validation Loss 1.8344 Acc 0.2408
# Time taken for 1 epoch 14.707136392593384 sec
#
# Epoch 132 Loss 1.7736 Acc 0.2848
# Validation Loss 1.8206 Acc 0.2500
# Time taken for 1 epoch 14.73457956314087 sec
#
# Epoch 133 Loss 1.7670 Acc 0.2871
# Validation Loss 1.8338 Acc 0.2465
# Time taken for 1 epoch 14.672827243804932 sec
#
# Epoch 134 Loss 1.7669 Acc 0.2872
# Validation Loss 1.8308 Acc 0.2458
# Time taken for 1 epoch 14.66746187210083 sec
#
# Epoch 135 Loss 1.7770 Acc 0.2835
# Validation Loss 1.8539 Acc 0.2401
# Time taken for 1 epoch 14.642025470733643 sec
#
# Epoch 136 Loss 1.8168 Acc 0.2710
# Validation Loss 1.8692 Acc 0.2365
# Time taken for 1 epoch 14.69190502166748 sec
#
# Epoch 137 Loss 1.8236 Acc 0.2688
# Validation Loss 1.8280 Acc 0.2472
# Time taken for 1 epoch 14.705405712127686 sec
#
# Epoch 138 Loss 1.7687 Acc 0.2866
# Validation Loss 1.8200 Acc 0.2500
# Time taken for 1 epoch 14.688102006912231 sec
#
# Epoch 139 Loss 1.7618 Acc 0.2882
# Validation Loss 1.8270 Acc 0.2487
# Time taken for 1 epoch 14.643755912780762 sec
#
# Epoch 140 Loss 1.7668 Acc 0.2864
# Validation Loss 1.8253 Acc 0.2490
# Time taken for 1 epoch 14.712873935699463 sec
#
# Epoch 141 Loss 1.7597 Acc 0.2889
# Validation Loss 1.8172 Acc 0.2509
# Time taken for 1 epoch 14.695369005203247 sec
#
# Epoch 142 Loss 1.7724 Acc 0.2839
# Validation Loss 1.8369 Acc 0.2452
# Time taken for 1 epoch 14.811664342880249 sec
#
# Epoch 143 Loss 1.7587 Acc 0.2891
# Validation Loss 1.8355 Acc 0.2461
# Time taken for 1 epoch 14.79394268989563 sec
#
# Epoch 144 Loss 1.7560 Acc 0.2896
# Validation Loss 1.8314 Acc 0.2477
# Time taken for 1 epoch 14.68984866142273 sec
#
# Epoch 145 Loss 1.7744 Acc 0.2831
# Validation Loss 1.8234 Acc 0.2495
# Time taken for 1 epoch 14.702701807022095 sec
#
# Epoch 146 Loss 1.7556 Acc 0.2896
# Validation Loss 1.8304 Acc 0.2462
# Time taken for 1 epoch 14.751147747039795 sec
#
# Epoch 147 Loss 1.8019 Acc 0.2740
# Validation Loss 1.8443 Acc 0.2425
# Time taken for 1 epoch 14.7117178440094 sec
#
# Epoch 148 Loss 1.7595 Acc 0.2887
# Validation Loss 1.8347 Acc 0.2456
# Time taken for 1 epoch 14.730007886886597 sec
#
# Epoch 149 Loss 1.7750 Acc 0.2849
# Validation Loss 1.8257 Acc 0.2480
# Time taken for 1 epoch 14.691638469696045 sec
#
# Epoch 150 Loss 1.7776 Acc 0.2823
# Validation Loss 1.8521 Acc 0.2436
# Time taken for 1 epoch 14.74362301826477 sec
#
# Epoch 151 Loss 1.7688 Acc 0.2866
# Validation Loss 1.8303 Acc 0.2476
# Time taken for 1 epoch 14.686967134475708 sec
#
# Epoch 152 Loss 1.7755 Acc 0.2822
# Validation Loss 1.8526 Acc 0.2407
# Time taken for 1 epoch 14.712085723876953 sec
#
# Epoch 153 Loss 1.7586 Acc 0.2884
# Validation Loss 1.8252 Acc 0.2480
# Time taken for 1 epoch 14.658568859100342 sec
#
# Epoch 154 Loss 1.8262 Acc 0.2684
# Validation Loss 1.9049 Acc 0.2276
# Time taken for 1 epoch 14.73100233078003 sec
#
# Epoch 155 Loss 1.8590 Acc 0.2581
# Validation Loss 1.8610 Acc 0.2380
# Time taken for 1 epoch 14.67570185661316 sec
#
# Epoch 156 Loss 1.8161 Acc 0.2705
# Validation Loss 1.8551 Acc 0.2403
# Time taken for 1 epoch 14.782753467559814 sec
#
# Epoch 157 Loss 1.7796 Acc 0.2815
# Validation Loss 1.8208 Acc 0.2507
# Time taken for 1 epoch 14.707529067993164 sec
#
# Epoch 158 Loss 1.7534 Acc 0.2899
# Validation Loss 1.8266 Acc 0.2488
# Time taken for 1 epoch 14.779488563537598 sec
#
# Epoch 159 Loss 1.7891 Acc 0.2796
# Validation Loss 1.9593 Acc 0.2159
# Time taken for 1 epoch 14.687039136886597 sec
#
# Epoch 160 Loss 1.8602 Acc 0.2592
# Validation Loss 1.8314 Acc 0.2470
# Time taken for 1 epoch 14.704200983047485 sec
#
# Epoch 161 Loss 1.8896 Acc 0.2578
# Validation Loss 1.9981 Acc 0.2012
# Time taken for 1 epoch 14.721635580062866 sec
#
# Epoch 162 Loss 1.9734 Acc 0.2287
# Validation Loss 1.9286 Acc 0.2233
# Time taken for 1 epoch 14.701520919799805 sec
#
# Epoch 163 Loss 1.9322 Acc 0.2388
# Validation Loss 1.9125 Acc 0.2265
# Time taken for 1 epoch 14.687329769134521 sec
#
# Epoch 164 Loss 1.9141 Acc 0.2440
# Validation Loss 1.9084 Acc 0.2272
# Time taken for 1 epoch 14.635175228118896 sec
#
# Epoch 165 Loss 1.9006 Acc 0.2479
# Validation Loss 1.8941 Acc 0.2308
# Time taken for 1 epoch 14.675880432128906 sec
#
# Epoch 166 Loss 1.8870 Acc 0.2521
# Validation Loss 1.8793 Acc 0.2356
# Time taken for 1 epoch 14.703695058822632 sec
#
# Epoch 167 Loss 1.8766 Acc 0.2551
# Validation Loss 1.8749 Acc 0.2366
# Time taken for 1 epoch 14.662693500518799 sec
#
# Epoch 168 Loss 1.8623 Acc 0.2595
# Validation Loss 1.8693 Acc 0.2394
# Time taken for 1 epoch 14.717251062393188 sec
#
# Epoch 169 Loss 1.8553 Acc 0.2613
# Validation Loss 1.8716 Acc 0.2381
# Time taken for 1 epoch 14.652603387832642 sec
#
# Epoch 170 Loss 1.8430 Acc 0.2644
# Validation Loss 1.8443 Acc 0.2454
# Time taken for 1 epoch 14.808498620986938 sec
#
# Epoch 171 Loss 1.8256 Acc 0.2695
# Validation Loss 1.9650 Acc 0.2142
# Time taken for 1 epoch 14.700151920318604 sec
#
# Epoch 172 Loss 1.8273 Acc 0.2689
# Validation Loss 1.8326 Acc 0.2483
# Time taken for 1 epoch 14.740031003952026 sec
#
# Epoch 173 Loss 1.8088 Acc 0.2740
# Validation Loss 1.8393 Acc 0.2459
# Time taken for 1 epoch 14.788939476013184 sec
#
# Epoch 174 Loss 1.7958 Acc 0.2778
# Validation Loss 1.8306 Acc 0.2470
# Time taken for 1 epoch 14.6809983253479 sec
#
# Epoch 175 Loss 1.7972 Acc 0.2773
# Validation Loss 1.8470 Acc 0.2455
# Time taken for 1 epoch 14.667083501815796 sec
#
# Epoch 176 Loss 1.7967 Acc 0.2771
# Validation Loss 1.8298 Acc 0.2491
# Time taken for 1 epoch 14.7936270236969 sec
#
# Epoch 177 Loss 1.7801 Acc 0.2822
# Validation Loss 1.8218 Acc 0.2497
# Time taken for 1 epoch 14.728183269500732 sec
#
# Epoch 178 Loss 1.7759 Acc 0.2831
# Validation Loss 1.8236 Acc 0.2495
# Time taken for 1 epoch 14.700445890426636 sec
#
# Epoch 179 Loss 1.7758 Acc 0.2831
# Validation Loss 1.8234 Acc 0.2493
# Time taken for 1 epoch 14.780646324157715 sec
#
# Epoch 180 Loss 1.7643 Acc 0.2866
# Validation Loss 1.8262 Acc 0.2485
# Time taken for 1 epoch 14.729733943939209 sec
#
# Epoch 181 Loss 1.7798 Acc 0.2817
# Validation Loss 1.8405 Acc 0.2419
# Time taken for 1 epoch 14.695379495620728 sec
#
# Epoch 182 Loss 1.7728 Acc 0.2836
# Validation Loss 1.8251 Acc 0.2492
# Time taken for 1 epoch 14.714333534240723 sec
#
# Epoch 183 Loss 1.7590 Acc 0.2885
# Validation Loss 1.8286 Acc 0.2476
# Time taken for 1 epoch 14.678016185760498 sec
#
# Epoch 184 Loss 1.7749 Acc 0.2824
# Validation Loss 1.8406 Acc 0.2448
# Time taken for 1 epoch 14.73034381866455 sec
#
# Epoch 185 Loss 1.7655 Acc 0.2863
# Validation Loss 1.8270 Acc 0.2485
# Time taken for 1 epoch 14.774617671966553 sec
#
# Epoch 186 Loss 1.7673 Acc 0.2851
# Validation Loss 1.8301 Acc 0.2481
# Time taken for 1 epoch 14.712292671203613 sec
#
# Epoch 187 Loss 1.7563 Acc 0.2887
# Validation Loss 1.8340 Acc 0.2446
# Time taken for 1 epoch 14.70965576171875 sec
#
# Epoch 188 Loss 1.7505 Acc 0.2904
# Validation Loss 1.8333 Acc 0.2462
# Time taken for 1 epoch 14.708089113235474 sec
#
# Epoch 189 Loss 1.7496 Acc 0.2905
# Validation Loss 1.8235 Acc 0.2496
# Time taken for 1 epoch 14.735570907592773 sec
#
# Epoch 190 Loss 1.7565 Acc 0.2879
# Validation Loss 1.8436 Acc 0.2428
# Time taken for 1 epoch 14.70878791809082 sec
#
# Epoch 191 Loss 1.7520 Acc 0.2891
# Validation Loss 1.8359 Acc 0.2465
# Time taken for 1 epoch 14.788195371627808 sec
#
# Epoch 192 Loss 1.7988 Acc 0.2748
# Validation Loss 1.8581 Acc 0.2392
# Time taken for 1 epoch 14.702368259429932 sec
#
# Epoch 193 Loss 1.7683 Acc 0.2842
# Validation Loss 1.8372 Acc 0.2455
# Time taken for 1 epoch 14.660504579544067 sec
#
# Epoch 194 Loss 1.7509 Acc 0.2895
# Validation Loss 1.8284 Acc 0.2484
# Time taken for 1 epoch 14.762646436691284 sec
#
# Epoch 195 Loss 1.7401 Acc 0.2929
# Validation Loss 1.8233 Acc 0.2487
# Time taken for 1 epoch 14.780706405639648 sec
#
# Epoch 196 Loss 1.7427 Acc 0.2926
# Validation Loss 1.8281 Acc 0.2481
# Time taken for 1 epoch 14.677621603012085 sec
#
# Epoch 197 Loss 1.7416 Acc 0.2923
# Validation Loss 1.8258 Acc 0.2495
# Time taken for 1 epoch 14.781125783920288 sec
#
# Epoch 198 Loss 1.7380 Acc 0.2933
# Validation Loss 1.8463 Acc 0.2443
# Time taken for 1 epoch 14.742818117141724 sec
#
# Epoch 199 Loss 1.8825 Acc 0.2533
# Validation Loss 1.9196 Acc 0.2226
# Time taken for 1 epoch 14.723790884017944 sec
#
# Epoch 200 Loss 1.8928 Acc 0.2480
# Validation Loss 1.9005 Acc 0.2293
# Time taken for 1 epoch 14.67214584350586 sec
#
# Epoch 201 Loss 1.8866 Acc 0.2531
# Validation Loss 1.8976 Acc 0.2321
# Time taken for 1 epoch 14.735337018966675 sec
#
# Epoch 202 Loss 1.8545 Acc 0.2618
# Validation Loss 1.8572 Acc 0.2425
# Time taken for 1 epoch 14.696747541427612 sec
#
# Epoch 203 Loss 1.8198 Acc 0.2704
# Validation Loss 1.8551 Acc 0.2403
# Time taken for 1 epoch 14.770349502563477 sec
#
# Epoch 204 Loss 1.7932 Acc 0.2776
# Validation Loss 1.8476 Acc 0.2429
# Time taken for 1 epoch 14.67904782295227 sec
#
# Epoch 205 Loss 1.7791 Acc 0.2810
# Validation Loss 1.8427 Acc 0.2440
# Time taken for 1 epoch 14.683026790618896 sec
#
# Epoch 206 Loss 1.7681 Acc 0.2842
# Validation Loss 1.8340 Acc 0.2470
# Time taken for 1 epoch 14.736087083816528 sec
#
# Epoch 207 Loss 1.7611 Acc 0.2863
# Validation Loss 1.8598 Acc 0.2419
# Time taken for 1 epoch 14.743062973022461 sec
#
# Epoch 208 Loss 1.7596 Acc 0.2863
# Validation Loss 1.8269 Acc 0.2486
# Time taken for 1 epoch 14.776119709014893 sec
#
# Epoch 209 Loss 1.7539 Acc 0.2878
# Validation Loss 1.8266 Acc 0.2487
# Time taken for 1 epoch 14.79631781578064 sec
#
# Epoch 210 Loss 1.7463 Acc 0.2904
# Validation Loss 1.8389 Acc 0.2461
# Time taken for 1 epoch 14.74452829360962 sec
#
# Epoch 211 Loss 1.7503 Acc 0.2894
# Validation Loss 1.8439 Acc 0.2492
# Time taken for 1 epoch 14.744260787963867 sec
#
# Epoch 212 Loss 1.7758 Acc 0.2832
# Validation Loss 1.8227 Acc 0.2501
# Time taken for 1 epoch 14.77600646018982 sec
#
# Epoch 213 Loss 1.7558 Acc 0.2887
# Validation Loss 1.8294 Acc 0.2478
# Time taken for 1 epoch 14.778222560882568 sec
#
# Epoch 214 Loss 1.7474 Acc 0.2906
# Validation Loss 1.8304 Acc 0.2478
# Time taken for 1 epoch 14.629208087921143 sec
#
# Epoch 215 Loss 1.7502 Acc 0.2893
# Validation Loss 1.8327 Acc 0.2456
# Time taken for 1 epoch 14.835869550704956 sec
#
# Epoch 216 Loss 1.7488 Acc 0.2905
# Validation Loss 1.8234 Acc 0.2491
# Time taken for 1 epoch 14.79425573348999 sec
#
# Epoch 217 Loss 1.7450 Acc 0.2913
# Validation Loss 1.8385 Acc 0.2439
# Time taken for 1 epoch 14.733518123626709 sec
#
# Epoch 218 Loss 1.7400 Acc 0.2923
# Validation Loss 1.8260 Acc 0.2500
# Time taken for 1 epoch 14.787395715713501 sec
#
# Epoch 219 Loss 1.7368 Acc 0.2934
# Validation Loss 1.8329 Acc 0.2474
# Time taken for 1 epoch 14.751341819763184 sec
#
# Epoch 220 Loss 1.7352 Acc 0.2934
# Validation Loss 1.8477 Acc 0.2409
# Time taken for 1 epoch 14.67738151550293 sec
#
# Epoch 221 Loss 1.7397 Acc 0.2913
# Validation Loss 1.8400 Acc 0.2458
# Time taken for 1 epoch 14.704434871673584 sec
#
# Epoch 222 Loss 1.8077 Acc 0.2765
# Validation Loss 1.9480 Acc 0.2201
# Time taken for 1 epoch 14.738739252090454 sec
#
# Epoch 223 Loss 1.8741 Acc 0.2599
# Validation Loss 1.8455 Acc 0.2455
# Time taken for 1 epoch 14.692268133163452 sec
#
# Epoch 224 Loss 1.8185 Acc 0.2730
# Validation Loss 1.8376 Acc 0.2456
# Time taken for 1 epoch 14.789684772491455 sec
#
# Epoch 225 Loss 1.7937 Acc 0.2793
# Validation Loss 1.8242 Acc 0.2487
# Time taken for 1 epoch 14.732732057571411 sec
#
# Epoch 226 Loss 1.9932 Acc 0.2425
# Validation Loss 2.1061 Acc 0.1739
# Time taken for 1 epoch 14.713435411453247 sec
#
# Epoch 227 Loss 2.0825 Acc 0.2064
# Validation Loss 2.0187 Acc 0.1998
# Time taken for 1 epoch 14.806219100952148 sec
#
# Epoch 228 Loss 2.0364 Acc 0.2140
# Validation Loss 2.0063 Acc 0.2031
# Time taken for 1 epoch 14.74561333656311 sec
#
# Epoch 229 Loss 2.0206 Acc 0.2172
# Validation Loss 1.9936 Acc 0.2069
# Time taken for 1 epoch 14.753840923309326 sec
#
# Epoch 230 Loss 2.0116 Acc 0.2190
# Validation Loss 1.9851 Acc 0.2086
# Time taken for 1 epoch 14.807785511016846 sec
#
# Epoch 231 Loss 2.0030 Acc 0.2213
# Validation Loss 1.9813 Acc 0.2096
# Time taken for 1 epoch 14.7367684841156 sec
#
# Epoch 232 Loss 1.9980 Acc 0.2221
# Validation Loss 1.9772 Acc 0.2108
# Time taken for 1 epoch 14.699512004852295 sec
#
# Epoch 233 Loss 1.9954 Acc 0.2229
# Validation Loss 1.9745 Acc 0.2116
# Time taken for 1 epoch 14.735876321792603 sec
#
# Epoch 234 Loss 1.9909 Acc 0.2240
# Validation Loss 1.9713 Acc 0.2119
# Time taken for 1 epoch 14.751160621643066 sec
#
# Epoch 235 Loss 1.9870 Acc 0.2248
# Validation Loss 1.9692 Acc 0.2121
# Time taken for 1 epoch 14.654054880142212 sec
#
# Epoch 236 Loss 1.9841 Acc 0.2254
# Validation Loss 1.9670 Acc 0.2128
# Time taken for 1 epoch 14.729719161987305 sec
#
# Epoch 237 Loss 1.9805 Acc 0.2262
# Validation Loss 1.9671 Acc 0.2122
# Time taken for 1 epoch 14.70726752281189 sec
#
# Epoch 238 Loss 1.9785 Acc 0.2266
# Validation Loss 1.9649 Acc 0.2126
# Time taken for 1 epoch 14.711245775222778 sec
#
# Epoch 239 Loss 1.9745 Acc 0.2276
# Validation Loss 1.9626 Acc 0.2134
# Time taken for 1 epoch 14.741651058197021 sec
#
# Epoch 240 Loss 1.9749 Acc 0.2277
# Validation Loss 1.9585 Acc 0.2137
# Time taken for 1 epoch 14.780620813369751 sec
#
# Epoch 241 Loss 1.9711 Acc 0.2282
# Validation Loss 1.9583 Acc 0.2145
# Time taken for 1 epoch 14.698707103729248 sec
#
# Epoch 242 Loss 1.9665 Acc 0.2294
# Validation Loss 1.9559 Acc 0.2146
# Time taken for 1 epoch 14.77213430404663 sec
#
# Epoch 243 Loss 1.9667 Acc 0.2295
# Validation Loss 1.9555 Acc 0.2150
# Time taken for 1 epoch 14.68609094619751 sec
#
# Epoch 244 Loss 1.9632 Acc 0.2302
# Validation Loss 1.9449 Acc 0.2183
# Time taken for 1 epoch 14.714727640151978 sec
#
# Epoch 245 Loss 1.9614 Acc 0.2307
# Validation Loss 1.9470 Acc 0.2174
# Time taken for 1 epoch 14.77776050567627 sec
#
# Epoch 246 Loss 1.9563 Acc 0.2319
# Validation Loss 1.9424 Acc 0.2179
# Time taken for 1 epoch 14.710485696792603 sec
#
# Epoch 247 Loss 1.9545 Acc 0.2324
# Validation Loss 1.9396 Acc 0.2185
# Time taken for 1 epoch 14.695923089981079 sec
#
# Epoch 248 Loss 1.9518 Acc 0.2331
# Validation Loss 1.9375 Acc 0.2193
# Time taken for 1 epoch 14.712172985076904 sec
#
# Epoch 249 Loss 1.9495 Acc 0.2336
# Validation Loss 1.9347 Acc 0.2196
# Time taken for 1 epoch 14.778903484344482 sec
#
# Epoch 250 Loss 1.9489 Acc 0.2340
# Validation Loss 1.9312 Acc 0.2212
# Time taken for 1 epoch 14.71277642250061 sec
#
# Epoch 251 Loss 1.9487 Acc 0.2344
# Validation Loss 1.9368 Acc 0.2211
# Time taken for 1 epoch 14.783490419387817 sec
#
# Epoch 252 Loss 1.9489 Acc 0.2344
# Validation Loss 1.9284 Acc 0.2230
# Time taken for 1 epoch 14.734068155288696 sec
#
# Epoch 253 Loss 1.9453 Acc 0.2352
# Validation Loss 1.9264 Acc 0.2235
# Time taken for 1 epoch 14.706821203231812 sec
#
# Epoch 254 Loss 1.9426 Acc 0.2360
# Validation Loss 1.9213 Acc 0.2254
# Time taken for 1 epoch 14.811082124710083 sec
#
# Epoch 255 Loss 1.9398 Acc 0.2369
# Validation Loss 1.9199 Acc 0.2265
# Time taken for 1 epoch 14.715252161026001 sec
#
# Epoch 256 Loss 1.9374 Acc 0.2377
# Validation Loss 1.9153 Acc 0.2275
# Time taken for 1 epoch 14.692068576812744 sec
#
# Epoch 257 Loss 1.9352 Acc 0.2386
# Validation Loss 1.9087 Acc 0.2297
# Time taken for 1 epoch 14.79238772392273 sec
#
# Epoch 258 Loss 1.9516 Acc 0.2340
# Validation Loss 1.9205 Acc 0.2258
# Time taken for 1 epoch 14.770373344421387 sec
#
# Epoch 259 Loss 1.9303 Acc 0.2396
# Validation Loss 1.9080 Acc 0.2290
# Time taken for 1 epoch 14.739105463027954 sec
#
# Epoch 260 Loss 1.9249 Acc 0.2419
# Validation Loss 1.9061 Acc 0.2285
# Time taken for 1 epoch 14.72783613204956 sec
#
# Epoch 261 Loss 1.9241 Acc 0.2415
# Validation Loss 1.9032 Acc 0.2311
# Time taken for 1 epoch 14.70733094215393 sec
#
# Epoch 262 Loss 1.9243 Acc 0.2417
# Validation Loss 1.8999 Acc 0.2309
# Time taken for 1 epoch 14.703264474868774 sec
#
# Epoch 263 Loss 1.9201 Acc 0.2425
# Validation Loss 1.9037 Acc 0.2283
# Time taken for 1 epoch 14.81714916229248 sec
#
# Epoch 264 Loss 1.9123 Acc 0.2452
# Validation Loss 1.9367 Acc 0.2181
# Time taken for 1 epoch 14.76736855506897 sec
#
# Epoch 265 Loss 1.9084 Acc 0.2464
# Validation Loss 1.8875 Acc 0.2347
# Time taken for 1 epoch 14.697648763656616 sec
#
# Epoch 266 Loss 1.9202 Acc 0.2424
# Validation Loss 1.9170 Acc 0.2268
# Time taken for 1 epoch 14.691665649414062 sec
#
# Epoch 267 Loss 1.9172 Acc 0.2452
# Validation Loss 1.9041 Acc 0.2308
# Time taken for 1 epoch 14.665108680725098 sec
#
# Epoch 268 Loss 1.9065 Acc 0.2473
# Validation Loss 1.9072 Acc 0.2286
# Time taken for 1 epoch 14.739635944366455 sec
#
# Epoch 269 Loss 1.9150 Acc 0.2440
# Validation Loss 1.8889 Acc 0.2324
# Time taken for 1 epoch 14.656694173812866 sec
#
# Epoch 270 Loss 1.8870 Acc 0.2535
# Validation Loss 1.8790 Acc 0.2368
# Time taken for 1 epoch 14.72542929649353 sec
#
# Epoch 271 Loss 1.9167 Acc 0.2438
# Validation Loss 1.8875 Acc 0.2335
# Time taken for 1 epoch 14.735204219818115 sec
#
# Epoch 272 Loss 1.8822 Acc 0.2547
# Validation Loss 1.8750 Acc 0.2379
# Time taken for 1 epoch 14.691954851150513 sec
#
# Epoch 273 Loss 1.8947 Acc 0.2500
# Validation Loss 1.8735 Acc 0.2375
# Time taken for 1 epoch 14.686348676681519 sec
#
# Epoch 274 Loss 1.8749 Acc 0.2569
# Validation Loss 1.8874 Acc 0.2340
# Time taken for 1 epoch 14.713435411453247 sec
#
# Epoch 275 Loss 1.8735 Acc 0.2571
# Validation Loss 1.8920 Acc 0.2324
# Time taken for 1 epoch 14.64589262008667 sec
#
# Epoch 276 Loss 1.8766 Acc 0.2559
# Validation Loss 1.8921 Acc 0.2325
# Time taken for 1 epoch 14.695898532867432 sec
#
# Epoch 277 Loss 1.8658 Acc 0.2598
# Validation Loss 1.8906 Acc 0.2328
# Time taken for 1 epoch 14.650508165359497 sec
#
# Epoch 278 Loss 1.8715 Acc 0.2576
# Validation Loss 1.8609 Acc 0.2413
# Time taken for 1 epoch 14.659476041793823 sec
#
# Epoch 279 Loss 1.8678 Acc 0.2583
# Validation Loss 1.8765 Acc 0.2369
# Time taken for 1 epoch 14.668223857879639 sec
#
# Epoch 280 Loss 1.8577 Acc 0.2622
# Validation Loss 1.8587 Acc 0.2417
# Time taken for 1 epoch 14.705500364303589 sec
#
# Epoch 281 Loss 1.8652 Acc 0.2591
# Validation Loss 1.8647 Acc 0.2404
# Time taken for 1 epoch 14.715397596359253 sec
#
# Epoch 282 Loss 1.8571 Acc 0.2621
# Validation Loss 1.8592 Acc 0.2412
# Time taken for 1 epoch 14.721707105636597 sec
#
# Epoch 283 Loss 1.8613 Acc 0.2601
# Validation Loss 1.8586 Acc 0.2416
# Time taken for 1 epoch 14.664963245391846 sec
#
# Epoch 284 Loss 1.8531 Acc 0.2630
# Validation Loss 1.8569 Acc 0.2424
# Time taken for 1 epoch 14.639829874038696 sec
#
# Epoch 285 Loss 1.8591 Acc 0.2609
# Validation Loss 1.8776 Acc 0.2366
# Time taken for 1 epoch 14.721391916275024 sec
#
# Epoch 286 Loss 1.8549 Acc 0.2620
# Validation Loss 1.8688 Acc 0.2365
# Time taken for 1 epoch 14.636775016784668 sec
#
# Epoch 287 Loss 1.8519 Acc 0.2625
# Validation Loss 1.8695 Acc 0.2389
# Time taken for 1 epoch 14.707467794418335 sec
#
# Epoch 288 Loss 1.8472 Acc 0.2644
# Validation Loss 1.8757 Acc 0.2370
# Time taken for 1 epoch 14.682065486907959 sec
#
# Epoch 289 Loss 1.8568 Acc 0.2606
# Validation Loss 1.8616 Acc 0.2409
# Time taken for 1 epoch 14.652563571929932 sec
#
# Epoch 290 Loss 1.8440 Acc 0.2652
# Validation Loss 1.8688 Acc 0.2386
# Time taken for 1 epoch 14.641601800918579 sec
#
# Epoch 291 Loss 1.8494 Acc 0.2628
# Validation Loss 1.8714 Acc 0.2379
# Time taken for 1 epoch 14.702359437942505 sec
#
# Epoch 292 Loss 1.8448 Acc 0.2644
# Validation Loss 1.8869 Acc 0.2330
# Time taken for 1 epoch 14.69827127456665 sec
#
# Epoch 293 Loss 1.8483 Acc 0.2632
# Validation Loss 1.8892 Acc 0.2301
# Time taken for 1 epoch 14.753704071044922 sec
#
# Epoch 294 Loss 1.8441 Acc 0.2644
# Validation Loss 1.8706 Acc 0.2383
# Time taken for 1 epoch 14.744555950164795 sec
#
# Epoch 295 Loss 1.8431 Acc 0.2647
# Validation Loss 1.8620 Acc 0.2405
# Time taken for 1 epoch 14.71366834640503 sec
#
# Epoch 296 Loss 1.8445 Acc 0.2643
# Validation Loss 1.8561 Acc 0.2422
# Time taken for 1 epoch 14.676805257797241 sec
#
# Epoch 297 Loss 1.8657 Acc 0.2563
# Validation Loss 1.8895 Acc 0.2324
# Time taken for 1 epoch 14.614136219024658 sec
#
# Epoch 298 Loss 1.8614 Acc 0.2583
# Validation Loss 1.8542 Acc 0.2419
# Time taken for 1 epoch 14.68055510520935 sec
#
# Epoch 299 Loss 1.8372 Acc 0.2664
# Validation Loss 1.8482 Acc 0.2441
# Time taken for 1 epoch 14.6710684299469 sec
#
# Epoch 300 Loss 1.8347 Acc 0.2669
# Validation Loss 1.8474 Acc 0.2444
# Time taken for 1 epoch 14.701225280761719 sec

# %%
total_loss = 0
total_acc = 0
steps_per_epoch = 0
val_total_loss = 0
val_total_acc = 0
val_steps_per_epoch = 0

for x, y in train_dataset:
    batch_loss, batch_acc = val_step(x, y)
    total_loss += batch_loss
    total_acc += batch_acc
    steps_per_epoch += 1
    
for x, y in validation_dataset:
    val_batch_loss, val_batch_acc = val_step(x, y)
    val_total_loss += val_batch_loss
    val_total_acc += val_batch_acc
    val_steps_per_epoch += 1

print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
# Out:
# Training Loss 1.6691 Acc 0.3128
# Validation Loss 1.9899 Acc 0.2408

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
EXPERIMENT_DIR = "experiments/02_BDLSTM_headtail"
checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"/loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"/acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"/val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"/val_acc_history.npy", np.array(val_acc_history))

# %%
# EXPERIMENT_DIR = "experiments/02_BDLSTM_headtail"
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
TEST_OUTPUT_DIR = "experiments/01_BDLSTM_naive_adam/"
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=TEST_OUTPUT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=TEST_OUTPUT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 34ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 32ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1536, 53)
