# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-17 01:33:59.207540: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 01:34:02.431987: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 01:34:02.432072: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 01:34:02.432080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
EXPERIMENT_DIR = "experiments/06_BDLSTM_128-50/"

BATCH_SIZE = 512
PIECE_LEN = 128
n_feature = 43
n_hidden = 50
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# 2023-01-17 01:35:38.761031: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:38.787621: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:38.788225: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:38.789531: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 01:35:38.791393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:38.791974: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:38.792476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:41.986456: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:41.986824: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:41.987107: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 01:35:41.987318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 43)]         0
#
#  mask (Masking)              (None, 128, 43)           0
#
#  input (TimeDistributed)     (None, 128, 50)           2200
#
#  bidirectional (Bidirectiona  (None, 128, 100)         40400
#  l)
#
#  output (TimeDistributed)    (None, 128, 53)           5353
#
# =================================================================
# Total params: 47,953
# Trainable params: 47,953
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/06_BDLSTM_128-50'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# Epoch 1 Loss 2.7732 Acc 0.2421
# Validation Loss 2.5898 Acc 0.2408
# Time taken for 1 epoch 249.39799046516418 sec
#
# Epoch 2 Loss 2.5157 Acc 0.2686
# Validation Loss 2.5248 Acc 0.2500
# Time taken for 1 epoch 11.650586128234863 sec
#
# Epoch 3 Loss 2.4695 Acc 0.2750
# Validation Loss 2.4849 Acc 0.2574
# Time taken for 1 epoch 11.725160837173462 sec
#
# Epoch 4 Loss 2.4389 Acc 0.2813
# Validation Loss 2.4559 Acc 0.2666
# Time taken for 1 epoch 11.554676532745361 sec
#
# Epoch 5 Loss 2.4104 Acc 0.2901
# Validation Loss 2.4213 Acc 0.2757
# Time taken for 1 epoch 11.776878118515015 sec
#
# Epoch 6 Loss 2.3769 Acc 0.3018
# Validation Loss 2.3895 Acc 0.2874
# Time taken for 1 epoch 11.766000509262085 sec
#
# Epoch 7 Loss 2.3525 Acc 0.3099
# Validation Loss 2.3762 Acc 0.2902
# Time taken for 1 epoch 11.724704265594482 sec
#
# Epoch 8 Loss 2.3327 Acc 0.3160
# Validation Loss 2.3694 Acc 0.2910
# Time taken for 1 epoch 11.970832109451294 sec
#
# Epoch 9 Loss 2.3179 Acc 0.3195
# Validation Loss 2.3607 Acc 0.2936
# Time taken for 1 epoch 11.662607192993164 sec
#
# Epoch 10 Loss 2.3333 Acc 0.3155
# Validation Loss 2.3672 Acc 0.2924
# Time taken for 1 epoch 11.65095567703247 sec
#
# Epoch 11 Loss 2.3101 Acc 0.3214
# Validation Loss 2.3529 Acc 0.2955
# Time taken for 1 epoch 11.696505546569824 sec
#
# Epoch 12 Loss 2.3005 Acc 0.3241
# Validation Loss 2.3480 Acc 0.2970
# Time taken for 1 epoch 11.674429178237915 sec
#
# Epoch 13 Loss 2.2966 Acc 0.3251
# Validation Loss 2.3485 Acc 0.2971
# Time taken for 1 epoch 11.862522840499878 sec
#
# Epoch 14 Loss 2.2929 Acc 0.3258
# Validation Loss 2.3452 Acc 0.2975
# Time taken for 1 epoch 11.611321687698364 sec
#
# Epoch 15 Loss 2.2891 Acc 0.3267
# Validation Loss 2.3408 Acc 0.2990
# Time taken for 1 epoch 11.760315179824829 sec
#
# Epoch 16 Loss 2.2867 Acc 0.3270
# Validation Loss 2.3388 Acc 0.2996
# Time taken for 1 epoch 11.710045576095581 sec
#
# Epoch 17 Loss 2.2829 Acc 0.3278
# Validation Loss 2.3313 Acc 0.3016
# Time taken for 1 epoch 11.667505025863647 sec
#
# Epoch 18 Loss 2.2901 Acc 0.3256
# Validation Loss 2.3426 Acc 0.2991
# Time taken for 1 epoch 11.763832807540894 sec
#
# Epoch 19 Loss 2.2911 Acc 0.3251
# Validation Loss 2.3275 Acc 0.3015
# Time taken for 1 epoch 11.87908935546875 sec
#
# Epoch 20 Loss 2.2807 Acc 0.3280
# Validation Loss 2.3272 Acc 0.3016
# Time taken for 1 epoch 11.711830377578735 sec
#
# Epoch 21 Loss 2.2785 Acc 0.3285
# Validation Loss 2.3258 Acc 0.3016
# Time taken for 1 epoch 11.759862422943115 sec
#
# Epoch 22 Loss 2.2749 Acc 0.3296
# Validation Loss 2.3250 Acc 0.3019
# Time taken for 1 epoch 11.744448184967041 sec
#
# Epoch 23 Loss 2.3016 Acc 0.3218
# Validation Loss 2.3354 Acc 0.3007
# Time taken for 1 epoch 11.711702823638916 sec
#
# Epoch 24 Loss 2.2790 Acc 0.3283
# Validation Loss 2.3222 Acc 0.3019
# Time taken for 1 epoch 11.865832328796387 sec
#
# Epoch 25 Loss 2.2706 Acc 0.3305
# Validation Loss 2.3215 Acc 0.3014
# Time taken for 1 epoch 11.66959834098816 sec
#
# Epoch 26 Loss 2.3258 Acc 0.3158
# Validation Loss 2.3626 Acc 0.2873
# Time taken for 1 epoch 11.658433198928833 sec
#
# Epoch 27 Loss 2.3071 Acc 0.3200
# Validation Loss 2.3318 Acc 0.2987
# Time taken for 1 epoch 11.628648281097412 sec
#
# Epoch 28 Loss 2.2775 Acc 0.3287
# Validation Loss 2.3250 Acc 0.3017
# Time taken for 1 epoch 11.69008994102478 sec
#
# Epoch 29 Loss 2.2808 Acc 0.3275
# Validation Loss 2.3278 Acc 0.3009
# Time taken for 1 epoch 11.807536840438843 sec
#
# Epoch 30 Loss 2.2714 Acc 0.3306
# Validation Loss 2.3225 Acc 0.3018
# Time taken for 1 epoch 11.891560077667236 sec
#
# Epoch 31 Loss 2.2812 Acc 0.3275
# Validation Loss 2.3244 Acc 0.3007
# Time taken for 1 epoch 11.892104148864746 sec
#
# Epoch 32 Loss 2.2790 Acc 0.3279
# Validation Loss 2.3572 Acc 0.2947
# Time taken for 1 epoch 11.880462646484375 sec
#
# Epoch 33 Loss 2.2706 Acc 0.3302
# Validation Loss 2.3193 Acc 0.3016
# Time taken for 1 epoch 11.664578437805176 sec
#
# Epoch 34 Loss 2.2791 Acc 0.3280
# Validation Loss 2.3207 Acc 0.3025
# Time taken for 1 epoch 11.746702671051025 sec
#
# Epoch 35 Loss 2.3113 Acc 0.3201
# Validation Loss 2.3294 Acc 0.3024
# Time taken for 1 epoch 11.594360113143921 sec
#
# Epoch 36 Loss 2.2779 Acc 0.3286
# Validation Loss 2.3224 Acc 0.3028
# Time taken for 1 epoch 11.893725633621216 sec
#
# Epoch 37 Loss 2.3129 Acc 0.3201
# Validation Loss 2.3337 Acc 0.3015
# Time taken for 1 epoch 11.679378032684326 sec
#
# Epoch 38 Loss 2.2769 Acc 0.3292
# Validation Loss 2.3293 Acc 0.3017
# Time taken for 1 epoch 11.65050458908081 sec
#
# Epoch 39 Loss 2.2702 Acc 0.3311
# Validation Loss 2.3214 Acc 0.3025
# Time taken for 1 epoch 11.659145593643188 sec
#
# Epoch 40 Loss 2.3065 Acc 0.3221
# Validation Loss 2.3299 Acc 0.3010
# Time taken for 1 epoch 11.645490884780884 sec
#
# Epoch 41 Loss 2.2740 Acc 0.3301
# Validation Loss 2.3843 Acc 0.2882
# Time taken for 1 epoch 11.762606143951416 sec
#
# Epoch 42 Loss 2.2669 Acc 0.3320
# Validation Loss 2.3217 Acc 0.3020
# Time taken for 1 epoch 11.678550243377686 sec
#
# Epoch 43 Loss 2.2633 Acc 0.3327
# Validation Loss 2.3185 Acc 0.3029
# Time taken for 1 epoch 11.62704610824585 sec
#
# Epoch 44 Loss 2.2647 Acc 0.3318
# Validation Loss 2.3192 Acc 0.3005
# Time taken for 1 epoch 11.760758876800537 sec
#
# Epoch 45 Loss 2.2646 Acc 0.3319
# Validation Loss 2.3178 Acc 0.3012
# Time taken for 1 epoch 11.68143343925476 sec
#
# Epoch 46 Loss 2.2901 Acc 0.3251
# Validation Loss 2.3201 Acc 0.3021
# Time taken for 1 epoch 11.598642826080322 sec
#
# Epoch 47 Loss 2.2592 Acc 0.3332
# Validation Loss 2.3183 Acc 0.3013
# Time taken for 1 epoch 11.566638231277466 sec
#
# Epoch 48 Loss 2.2933 Acc 0.3247
# Validation Loss 2.3757 Acc 0.2901
# Time taken for 1 epoch 11.822009801864624 sec
#
# Epoch 49 Loss 2.2683 Acc 0.3305
# Validation Loss 2.3200 Acc 0.3022
# Time taken for 1 epoch 11.775499820709229 sec
#
# Epoch 50 Loss 2.2815 Acc 0.3282
# Validation Loss 2.3674 Acc 0.2939
# Time taken for 1 epoch 11.851011991500854 sec
#
# Epoch 51 Loss 2.2696 Acc 0.3305
# Validation Loss 2.3227 Acc 0.3005
# Time taken for 1 epoch 11.638402462005615 sec
#
# Epoch 52 Loss 2.2704 Acc 0.3305
# Validation Loss 2.3420 Acc 0.2940
# Time taken for 1 epoch 11.579833269119263 sec
#
# Epoch 53 Loss 2.2622 Acc 0.3323
# Validation Loss 2.3200 Acc 0.3015
# Time taken for 1 epoch 11.707598209381104 sec
#
# Epoch 54 Loss 2.3093 Acc 0.3213
# Validation Loss 2.3487 Acc 0.2952
# Time taken for 1 epoch 11.62273907661438 sec
#
# Epoch 55 Loss 2.2929 Acc 0.3238
# Validation Loss 2.3329 Acc 0.2977
# Time taken for 1 epoch 11.724131345748901 sec
#
# Epoch 56 Loss 2.2725 Acc 0.3289
# Validation Loss 2.3253 Acc 0.2998
# Time taken for 1 epoch 11.671461582183838 sec
#
# Epoch 57 Loss 2.2646 Acc 0.3319
# Validation Loss 2.3250 Acc 0.3022
# Time taken for 1 epoch 11.760404109954834 sec
#
# Epoch 58 Loss 2.2634 Acc 0.3318
# Validation Loss 2.3224 Acc 0.2998
# Time taken for 1 epoch 11.608806133270264 sec
#
# Epoch 59 Loss 2.2610 Acc 0.3324
# Validation Loss 2.3194 Acc 0.3013
# Time taken for 1 epoch 11.64287257194519 sec
#
# Epoch 60 Loss 2.2590 Acc 0.3328
# Validation Loss 2.3184 Acc 0.3019
# Time taken for 1 epoch 11.641398191452026 sec
#
# Epoch 61 Loss 2.2616 Acc 0.3318
# Validation Loss 2.3182 Acc 0.3007
# Time taken for 1 epoch 11.636313438415527 sec
#
# Epoch 62 Loss 2.2587 Acc 0.3328
# Validation Loss 2.3187 Acc 0.3004
# Time taken for 1 epoch 11.664591550827026 sec
#
# Epoch 63 Loss 2.2606 Acc 0.3319
# Validation Loss 2.3163 Acc 0.3018
# Time taken for 1 epoch 11.873740911483765 sec
#
# Epoch 64 Loss 2.2630 Acc 0.3310
# Validation Loss 2.3149 Acc 0.3031
# Time taken for 1 epoch 11.702686548233032 sec
#
# Epoch 65 Loss 2.2807 Acc 0.3264
# Validation Loss 2.3177 Acc 0.3029
# Time taken for 1 epoch 11.605433940887451 sec
#
# Epoch 66 Loss 2.2629 Acc 0.3313
# Validation Loss 2.3171 Acc 0.3015
# Time taken for 1 epoch 11.664542198181152 sec
#
# Epoch 67 Loss 2.2665 Acc 0.3305
# Validation Loss 2.3217 Acc 0.3010
# Time taken for 1 epoch 11.765084981918335 sec
#
# Epoch 68 Loss 2.2580 Acc 0.3331
# Validation Loss 2.3168 Acc 0.3026
# Time taken for 1 epoch 11.831459045410156 sec
#
# Epoch 69 Loss 2.2711 Acc 0.3292
# Validation Loss 2.3176 Acc 0.3010
# Time taken for 1 epoch 11.724583864212036 sec
#
# Epoch 70 Loss 2.2769 Acc 0.3271
# Validation Loss 2.3280 Acc 0.2994
# Time taken for 1 epoch 11.635931015014648 sec
#
# Epoch 71 Loss 2.2563 Acc 0.3338
# Validation Loss 2.3167 Acc 0.3023
# Time taken for 1 epoch 11.877650260925293 sec
#
# Epoch 72 Loss 2.2767 Acc 0.3276
# Validation Loss 2.3169 Acc 0.3018
# Time taken for 1 epoch 11.707536458969116 sec
#
# Epoch 73 Loss 2.2647 Acc 0.3310
# Validation Loss 2.3148 Acc 0.3024
# Time taken for 1 epoch 11.665551900863647 sec
#
# Epoch 74 Loss 2.2710 Acc 0.3289
# Validation Loss 2.3176 Acc 0.3026
# Time taken for 1 epoch 11.765340089797974 sec
#
# Epoch 75 Loss 2.2694 Acc 0.3298
# Validation Loss 2.3164 Acc 0.3027
# Time taken for 1 epoch 11.756726741790771 sec
#
# Epoch 76 Loss 2.2630 Acc 0.3320
# Validation Loss 2.3176 Acc 0.3019
# Time taken for 1 epoch 11.6279776096344 sec
#
# Epoch 77 Loss 2.2684 Acc 0.3300
# Validation Loss 2.3175 Acc 0.3017
# Time taken for 1 epoch 11.816940069198608 sec
#
# Epoch 78 Loss 2.2745 Acc 0.3284
# Validation Loss 2.3185 Acc 0.3021
# Time taken for 1 epoch 11.694612503051758 sec
#
# Epoch 79 Loss 2.2963 Acc 0.3228
# Validation Loss 2.3506 Acc 0.2980
# Time taken for 1 epoch 11.579020500183105 sec
#
# Epoch 80 Loss 2.2724 Acc 0.3293
# Validation Loss 2.3393 Acc 0.2997
# Time taken for 1 epoch 11.586105346679688 sec
#
# Epoch 81 Loss 2.2581 Acc 0.3339
# Validation Loss 2.3182 Acc 0.3013
# Time taken for 1 epoch 11.814923763275146 sec
#
# Epoch 82 Loss 2.2715 Acc 0.3290
# Validation Loss 2.3199 Acc 0.3012
# Time taken for 1 epoch 11.732150793075562 sec
#
# Epoch 83 Loss 2.2582 Acc 0.3332
# Validation Loss 2.3185 Acc 0.3007
# Time taken for 1 epoch 11.873114585876465 sec
#
# Epoch 84 Loss 2.2653 Acc 0.3310
# Validation Loss 2.3191 Acc 0.3016
# Time taken for 1 epoch 11.71284532546997 sec
#
# Epoch 85 Loss 2.2622 Acc 0.3321
# Validation Loss 2.3178 Acc 0.3010
# Time taken for 1 epoch 11.712203741073608 sec
#
# Epoch 86 Loss 2.2621 Acc 0.3321
# Validation Loss 2.3165 Acc 0.3009
# Time taken for 1 epoch 11.707292079925537 sec
#
# Epoch 87 Loss 2.2666 Acc 0.3304
# Validation Loss 2.3171 Acc 0.3046
# Time taken for 1 epoch 11.491135835647583 sec
#
# Epoch 88 Loss 2.2538 Acc 0.3348
# Validation Loss 2.3158 Acc 0.3021
# Time taken for 1 epoch 11.759111404418945 sec
#
# Epoch 89 Loss 2.2636 Acc 0.3311
# Validation Loss 2.3140 Acc 0.3032
# Time taken for 1 epoch 11.716463088989258 sec
#
# Epoch 90 Loss 2.2727 Acc 0.3285
# Validation Loss 2.3160 Acc 0.3029
# Time taken for 1 epoch 11.751068115234375 sec
#
# Epoch 91 Loss 2.2631 Acc 0.3315
# Validation Loss 2.3156 Acc 0.3016
# Time taken for 1 epoch 11.969761610031128 sec
#
# Epoch 92 Loss 2.2521 Acc 0.3353
# Validation Loss 2.3152 Acc 0.3010
# Time taken for 1 epoch 11.72195315361023 sec
#
# Epoch 93 Loss 2.2645 Acc 0.3309
# Validation Loss 2.3146 Acc 0.3017
# Time taken for 1 epoch 11.81424856185913 sec
#
# Epoch 94 Loss 2.2596 Acc 0.3325
# Validation Loss 2.3161 Acc 0.3008
# Time taken for 1 epoch 11.815180540084839 sec
#
# Epoch 95 Loss 2.2554 Acc 0.3337
# Validation Loss 2.3138 Acc 0.3025
# Time taken for 1 epoch 11.764517784118652 sec
#
# Epoch 96 Loss 2.2767 Acc 0.3275
# Validation Loss 2.3140 Acc 0.3040
# Time taken for 1 epoch 11.788434505462646 sec
#
# Epoch 97 Loss 2.2827 Acc 0.3263
# Validation Loss 2.3175 Acc 0.3019
# Time taken for 1 epoch 11.586578845977783 sec
#
# Epoch 98 Loss 2.2594 Acc 0.3329
# Validation Loss 2.3310 Acc 0.3000
# Time taken for 1 epoch 11.647517681121826 sec
#
# Epoch 99 Loss 2.2612 Acc 0.3323
# Validation Loss 2.3392 Acc 0.2965
# Time taken for 1 epoch 11.889920949935913 sec
#
# Epoch 100 Loss 2.2637 Acc 0.3315
# Validation Loss 2.3149 Acc 0.3027
# Time taken for 1 epoch 11.828395366668701 sec

# %% [markdown]
# 23m 30.6s used

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1536, 53)
