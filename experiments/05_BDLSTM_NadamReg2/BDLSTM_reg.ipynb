# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-17 00:10:15.077062: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 00:10:15.650138: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 00:10:15.650222: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 00:10:15.650229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
EXPERIMENT_DIR = "experiments/05_BDLSTM_NadamReg2/"

BATCH_SIZE = 512
PIECE_LEN = 1024
n_feature = 43
n_hidden = 100
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-01-17 00:10:54.454449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.481611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.482208: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.483568: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 00:10:54.485427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.486011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.486519: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.917780: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.917948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.918061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 00:10:54.918155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1024, 43)]        0
#
#  mask (Masking)              (None, 1024, 43)          0
#
#  input (TimeDistributed)     (None, 1024, 100)         4400
#
#  bidirectional_1 (Bidirectio  (None, 1024, 200)        160800
#  nal)
#
#  output (TimeDistributed)    (None, 1024, 53)          10653
#
# =================================================================
# Total params: 175,853
# Trainable params: 175,853
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/05_BDLSTM_NadamReg2'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 300

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# 2023-01-17 00:15:04.395838: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_20/output/_23'
# 2023-01-17 00:15:04.799539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-01-17 00:15:05.433337: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f6f8c006c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-17 00:15:05.433367: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-01-17 00:15:05.450993: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-17 00:15:05.598659: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:05.637239: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2023-01-17 00:15:05.637270: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-01-17 00:15:05.638430: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-01-17 00:15:05.712226: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:05.818198: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:05.932622: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.044296: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.157371: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.267187: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.380792: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.486124: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 00:15:06.588405: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# Epoch 1 Loss 2.5592 Acc 0.1747
# Validation Loss 2.3018 Acc 0.1770
# Time taken for 1 epoch 118.7224760055542 sec
#
# Epoch 2 Loss 2.2007 Acc 0.2073
# Validation Loss 2.2121 Acc 0.1912
# Time taken for 1 epoch 13.927045583724976 sec
#
# Epoch 3 Loss 2.1336 Acc 0.2146
# Validation Loss 2.1684 Acc 0.1977
# Time taken for 1 epoch 13.90257978439331 sec
#
# Epoch 4 Loss 2.0967 Acc 0.2183
# Validation Loss 2.1401 Acc 0.2007
# Time taken for 1 epoch 14.002841234207153 sec
#
# Epoch 5 Loss 2.0705 Acc 0.2209
# Validation Loss 2.1151 Acc 0.2039
# Time taken for 1 epoch 13.942875623703003 sec
#
# Epoch 6 Loss 2.0503 Acc 0.2227
# Validation Loss 2.0999 Acc 0.2054
# Time taken for 1 epoch 14.025106191635132 sec
#
# Epoch 7 Loss 2.0341 Acc 0.2247
# Validation Loss 2.0848 Acc 0.2075
# Time taken for 1 epoch 13.971882820129395 sec
#
# Epoch 8 Loss 2.0205 Acc 0.2263
# Validation Loss 2.0719 Acc 0.2096
# Time taken for 1 epoch 14.020094156265259 sec
#
# Epoch 9 Loss 2.0095 Acc 0.2277
# Validation Loss 2.0621 Acc 0.2111
# Time taken for 1 epoch 14.06262731552124 sec
#
# Epoch 10 Loss 1.9992 Acc 0.2290
# Validation Loss 2.0505 Acc 0.2129
# Time taken for 1 epoch 14.058100938796997 sec
#
# Epoch 11 Loss 1.9907 Acc 0.2302
# Validation Loss 2.0424 Acc 0.2145
# Time taken for 1 epoch 13.970924139022827 sec
#
# Epoch 12 Loss 1.9818 Acc 0.2318
# Validation Loss 2.0339 Acc 0.2157
# Time taken for 1 epoch 14.06023907661438 sec
#
# Epoch 13 Loss 1.9743 Acc 0.2331
# Validation Loss 2.0283 Acc 0.2172
# Time taken for 1 epoch 14.025657892227173 sec
#
# Epoch 14 Loss 1.9679 Acc 0.2342
# Validation Loss 2.0219 Acc 0.2178
# Time taken for 1 epoch 14.014849424362183 sec
#
# Epoch 15 Loss 1.9632 Acc 0.2353
# Validation Loss 2.0200 Acc 0.2189
# Time taken for 1 epoch 14.040709018707275 sec
#
# Epoch 16 Loss 1.9579 Acc 0.2365
# Validation Loss 2.0144 Acc 0.2203
# Time taken for 1 epoch 14.088634014129639 sec
#
# Epoch 17 Loss 1.9516 Acc 0.2379
# Validation Loss 2.0053 Acc 0.2214
# Time taken for 1 epoch 14.044947624206543 sec
#
# Epoch 18 Loss 1.9462 Acc 0.2390
# Validation Loss 2.0013 Acc 0.2217
# Time taken for 1 epoch 14.06604528427124 sec
#
# Epoch 19 Loss 1.9424 Acc 0.2396
# Validation Loss 1.9948 Acc 0.2245
# Time taken for 1 epoch 14.038577318191528 sec
#
# Epoch 20 Loss 1.9377 Acc 0.2414
# Validation Loss 1.9917 Acc 0.2251
# Time taken for 1 epoch 14.007884979248047 sec
#
# Epoch 21 Loss 1.9341 Acc 0.2419
# Validation Loss 1.9883 Acc 0.2252
# Time taken for 1 epoch 14.068141460418701 sec
#
# Epoch 22 Loss 1.9289 Acc 0.2439
# Validation Loss 1.9898 Acc 0.2241
# Time taken for 1 epoch 14.049155712127686 sec
#
# Epoch 23 Loss 1.9241 Acc 0.2449
# Validation Loss 1.9793 Acc 0.2297
# Time taken for 1 epoch 14.120927095413208 sec
#
# Epoch 24 Loss 1.9225 Acc 0.2463
# Validation Loss 1.9773 Acc 0.2301
# Time taken for 1 epoch 14.07762098312378 sec
#
# Epoch 25 Loss 1.9169 Acc 0.2472
# Validation Loss 1.9752 Acc 0.2274
# Time taken for 1 epoch 14.066142320632935 sec
#
# Epoch 26 Loss 1.9121 Acc 0.2479
# Validation Loss 1.9730 Acc 0.2317
# Time taken for 1 epoch 14.086721897125244 sec
#
# Epoch 27 Loss 1.9178 Acc 0.2480
# Validation Loss 1.9725 Acc 0.2308
# Time taken for 1 epoch 14.100419044494629 sec
#
# Epoch 28 Loss 1.9013 Acc 0.2517
# Validation Loss 1.9652 Acc 0.2300
# Time taken for 1 epoch 14.027838706970215 sec
#
# Epoch 29 Loss 1.9014 Acc 0.2520
# Validation Loss 1.9619 Acc 0.2322
# Time taken for 1 epoch 14.095937728881836 sec
#
# Epoch 30 Loss 1.8996 Acc 0.2518
# Validation Loss 1.9538 Acc 0.2366
# Time taken for 1 epoch 14.034353256225586 sec
#
# Epoch 31 Loss 1.8883 Acc 0.2553
# Validation Loss 1.9576 Acc 0.2361
# Time taken for 1 epoch 14.056152105331421 sec
#
# Epoch 32 Loss 1.8807 Acc 0.2578
# Validation Loss 1.9653 Acc 0.2329
# Time taken for 1 epoch 14.06886339187622 sec
#
# Epoch 33 Loss 1.8740 Acc 0.2597
# Validation Loss 1.9427 Acc 0.2379
# Time taken for 1 epoch 14.097437858581543 sec
#
# Epoch 34 Loss 1.8964 Acc 0.2543
# Validation Loss 1.9531 Acc 0.2378
# Time taken for 1 epoch 14.100639581680298 sec
#
# Epoch 35 Loss 1.8779 Acc 0.2595
# Validation Loss 1.9475 Acc 0.2369
# Time taken for 1 epoch 14.07913064956665 sec
#
# Epoch 36 Loss 1.8767 Acc 0.2596
# Validation Loss 1.9485 Acc 0.2334
# Time taken for 1 epoch 14.076520681381226 sec
#
# Epoch 37 Loss 1.8689 Acc 0.2613
# Validation Loss 1.9463 Acc 0.2392
# Time taken for 1 epoch 14.080715894699097 sec
#
# Epoch 38 Loss 1.8648 Acc 0.2627
# Validation Loss 1.9432 Acc 0.2400
# Time taken for 1 epoch 14.061014175415039 sec
#
# Epoch 39 Loss 1.8632 Acc 0.2628
# Validation Loss 1.9389 Acc 0.2411
# Time taken for 1 epoch 14.058595895767212 sec
#
# Epoch 40 Loss 1.8588 Acc 0.2650
# Validation Loss 1.9314 Acc 0.2425
# Time taken for 1 epoch 14.02948522567749 sec
#
# Epoch 41 Loss 1.8598 Acc 0.2638
# Validation Loss 1.9296 Acc 0.2417
# Time taken for 1 epoch 14.070034265518188 sec
#
# Epoch 42 Loss 1.8504 Acc 0.2678
# Validation Loss 1.9299 Acc 0.2423
# Time taken for 1 epoch 14.061972618103027 sec
#
# Epoch 43 Loss 1.8441 Acc 0.2696
# Validation Loss 1.9325 Acc 0.2380
# Time taken for 1 epoch 14.130916595458984 sec
#
# Epoch 44 Loss 1.8439 Acc 0.2691
# Validation Loss 1.9278 Acc 0.2396
# Time taken for 1 epoch 14.098533153533936 sec
#
# Epoch 45 Loss 1.8435 Acc 0.2687
# Validation Loss 1.9263 Acc 0.2431
# Time taken for 1 epoch 14.049752235412598 sec
#
# Epoch 46 Loss 1.8371 Acc 0.2711
# Validation Loss 1.9245 Acc 0.2432
# Time taken for 1 epoch 14.11018991470337 sec
#
# Epoch 47 Loss 1.8340 Acc 0.2719
# Validation Loss 1.9204 Acc 0.2436
# Time taken for 1 epoch 14.087510585784912 sec
#
# Epoch 48 Loss 1.8317 Acc 0.2730
# Validation Loss 1.9213 Acc 0.2416
# Time taken for 1 epoch 14.077158451080322 sec
#
# Epoch 49 Loss 1.8328 Acc 0.2718
# Validation Loss 1.9177 Acc 0.2427
# Time taken for 1 epoch 14.071344137191772 sec
#
# Epoch 50 Loss 1.8299 Acc 0.2732
# Validation Loss 1.9186 Acc 0.2428
# Time taken for 1 epoch 14.06000280380249 sec
#
# Epoch 51 Loss 1.8295 Acc 0.2728
# Validation Loss 1.9143 Acc 0.2447
# Time taken for 1 epoch 14.080523014068604 sec
#
# Epoch 52 Loss 1.8243 Acc 0.2746
# Validation Loss 1.9157 Acc 0.2446
# Time taken for 1 epoch 14.07543158531189 sec
#
# Epoch 53 Loss 1.8233 Acc 0.2749
# Validation Loss 1.9151 Acc 0.2445
# Time taken for 1 epoch 14.092729806900024 sec
#
# Epoch 54 Loss 1.8230 Acc 0.2749
# Validation Loss 1.9179 Acc 0.2427
# Time taken for 1 epoch 14.066513538360596 sec
#
# Epoch 55 Loss 1.8251 Acc 0.2743
# Validation Loss 1.9150 Acc 0.2461
# Time taken for 1 epoch 14.071219682693481 sec
#
# Epoch 56 Loss 1.8202 Acc 0.2756
# Validation Loss 1.9141 Acc 0.2432
# Time taken for 1 epoch 14.097696304321289 sec
#
# Epoch 57 Loss 1.8192 Acc 0.2756
# Validation Loss 1.9122 Acc 0.2443
# Time taken for 1 epoch 14.080796957015991 sec
#
# Epoch 58 Loss 1.8175 Acc 0.2760
# Validation Loss 1.9116 Acc 0.2445
# Time taken for 1 epoch 14.077272176742554 sec
#
# Epoch 59 Loss 1.8147 Acc 0.2766
# Validation Loss 1.9104 Acc 0.2454
# Time taken for 1 epoch 14.083730697631836 sec
#
# Epoch 60 Loss 1.8172 Acc 0.2758
# Validation Loss 1.9078 Acc 0.2455
# Time taken for 1 epoch 14.02913498878479 sec
#
# Epoch 61 Loss 1.8111 Acc 0.2777
# Validation Loss 1.9116 Acc 0.2438
# Time taken for 1 epoch 14.047074317932129 sec
#
# Epoch 62 Loss 1.8109 Acc 0.2777
# Validation Loss 1.9099 Acc 0.2445
# Time taken for 1 epoch 14.054705619812012 sec
#
# Epoch 63 Loss 1.8086 Acc 0.2785
# Validation Loss 1.9077 Acc 0.2456
# Time taken for 1 epoch 14.047901630401611 sec
#
# Epoch 64 Loss 1.8088 Acc 0.2781
# Validation Loss 1.9065 Acc 0.2456
# Time taken for 1 epoch 14.10375452041626 sec
#
# Epoch 65 Loss 1.8078 Acc 0.2785
# Validation Loss 1.9075 Acc 0.2457
# Time taken for 1 epoch 14.090783596038818 sec
#
# Epoch 66 Loss 1.8048 Acc 0.2797
# Validation Loss 1.9082 Acc 0.2453
# Time taken for 1 epoch 14.045126914978027 sec
#
# Epoch 67 Loss 1.8058 Acc 0.2791
# Validation Loss 1.9067 Acc 0.2455
# Time taken for 1 epoch 14.044098854064941 sec
#
# Epoch 68 Loss 1.8084 Acc 0.2781
# Validation Loss 1.9076 Acc 0.2456
# Time taken for 1 epoch 14.07724905014038 sec
#
# Epoch 69 Loss 1.8069 Acc 0.2784
# Validation Loss 1.9046 Acc 0.2458
# Time taken for 1 epoch 14.08411455154419 sec
#
# Epoch 70 Loss 1.8019 Acc 0.2806
# Validation Loss 1.9050 Acc 0.2462
# Time taken for 1 epoch 14.036503314971924 sec
#
# Epoch 71 Loss 1.7994 Acc 0.2809
# Validation Loss 1.9029 Acc 0.2466
# Time taken for 1 epoch 14.097841739654541 sec
#
# Epoch 72 Loss 1.8028 Acc 0.2797
# Validation Loss 1.9106 Acc 0.2446
# Time taken for 1 epoch 14.078070163726807 sec
#
# Epoch 73 Loss 1.7990 Acc 0.2810
# Validation Loss 1.9059 Acc 0.2451
# Time taken for 1 epoch 14.060776472091675 sec
#
# Epoch 74 Loss 1.7980 Acc 0.2810
# Validation Loss 1.9048 Acc 0.2454
# Time taken for 1 epoch 14.119880676269531 sec
#
# Epoch 75 Loss 1.7975 Acc 0.2813
# Validation Loss 1.9040 Acc 0.2462
# Time taken for 1 epoch 14.10392951965332 sec
#
# Epoch 76 Loss 1.7985 Acc 0.2815
# Validation Loss 1.9077 Acc 0.2465
# Time taken for 1 epoch 14.123518466949463 sec
#
# Epoch 77 Loss 1.8072 Acc 0.2794
# Validation Loss 1.9072 Acc 0.2457
# Time taken for 1 epoch 14.0992271900177 sec
#
# Epoch 78 Loss 1.8061 Acc 0.2791
# Validation Loss 1.9010 Acc 0.2467
# Time taken for 1 epoch 14.061744689941406 sec
#
# Epoch 79 Loss 1.8003 Acc 0.2810
# Validation Loss 1.9030 Acc 0.2466
# Time taken for 1 epoch 14.049795389175415 sec
#
# Epoch 80 Loss 1.7992 Acc 0.2810
# Validation Loss 1.9025 Acc 0.2471
# Time taken for 1 epoch 14.115051984786987 sec
#
# Epoch 81 Loss 1.7988 Acc 0.2810
# Validation Loss 1.9013 Acc 0.2477
# Time taken for 1 epoch 14.080904960632324 sec
#
# Epoch 82 Loss 1.7955 Acc 0.2823
# Validation Loss 1.9006 Acc 0.2473
# Time taken for 1 epoch 14.114720344543457 sec
#
# Epoch 83 Loss 1.7942 Acc 0.2827
# Validation Loss 1.9030 Acc 0.2464
# Time taken for 1 epoch 14.089339017868042 sec
#
# Epoch 84 Loss 1.7956 Acc 0.2819
# Validation Loss 1.9029 Acc 0.2473
# Time taken for 1 epoch 14.132163047790527 sec
#
# Epoch 85 Loss 1.9186 Acc 0.2491
# Validation Loss 2.0004 Acc 0.2216
# Time taken for 1 epoch 14.086617231369019 sec
#
# Epoch 86 Loss 1.9069 Acc 0.2500
# Validation Loss 1.9674 Acc 0.2331
# Time taken for 1 epoch 14.073575973510742 sec
#
# Epoch 87 Loss 1.8727 Acc 0.2612
# Validation Loss 1.9402 Acc 0.2387
# Time taken for 1 epoch 14.04458737373352 sec
#
# Epoch 88 Loss 1.8555 Acc 0.2647
# Validation Loss 1.9337 Acc 0.2373
# Time taken for 1 epoch 14.0546555519104 sec
#
# Epoch 89 Loss 1.8444 Acc 0.2674
# Validation Loss 1.9295 Acc 0.2371
# Time taken for 1 epoch 14.094389200210571 sec
#
# Epoch 90 Loss 1.8373 Acc 0.2695
# Validation Loss 1.9228 Acc 0.2434
# Time taken for 1 epoch 14.106902122497559 sec
#
# Epoch 91 Loss 1.8273 Acc 0.2729
# Validation Loss 1.9159 Acc 0.2431
# Time taken for 1 epoch 14.103220462799072 sec
#
# Epoch 92 Loss 1.8182 Acc 0.2762
# Validation Loss 1.9185 Acc 0.2406
# Time taken for 1 epoch 14.078843116760254 sec
#
# Epoch 93 Loss 1.8161 Acc 0.2763
# Validation Loss 1.9137 Acc 0.2434
# Time taken for 1 epoch 14.013892412185669 sec
#
# Epoch 94 Loss 1.8115 Acc 0.2779
# Validation Loss 1.9133 Acc 0.2453
# Time taken for 1 epoch 14.096084117889404 sec
#
# Epoch 95 Loss 1.8085 Acc 0.2790
# Validation Loss 1.9109 Acc 0.2457
# Time taken for 1 epoch 14.075406789779663 sec
#
# Epoch 96 Loss 1.8059 Acc 0.2799
# Validation Loss 1.9079 Acc 0.2465
# Time taken for 1 epoch 14.106918096542358 sec
#
# Epoch 97 Loss 1.8046 Acc 0.2801
# Validation Loss 1.9134 Acc 0.2431
# Time taken for 1 epoch 14.056199550628662 sec
#
# Epoch 98 Loss 1.8047 Acc 0.2795
# Validation Loss 1.9094 Acc 0.2453
# Time taken for 1 epoch 14.096977233886719 sec
#
# Epoch 99 Loss 1.8022 Acc 0.2808
# Validation Loss 1.9106 Acc 0.2451
# Time taken for 1 epoch 14.035894632339478 sec
#
# Epoch 100 Loss 1.8001 Acc 0.2815
# Validation Loss 1.9101 Acc 0.2448
# Time taken for 1 epoch 14.038432598114014 sec
#
# Epoch 101 Loss 1.7986 Acc 0.2818
# Validation Loss 1.9092 Acc 0.2451
# Time taken for 1 epoch 14.083520650863647 sec
#
# Epoch 102 Loss 1.7974 Acc 0.2819
# Validation Loss 1.9070 Acc 0.2459
# Time taken for 1 epoch 14.05523681640625 sec
#
# Epoch 103 Loss 1.7935 Acc 0.2835
# Validation Loss 1.9053 Acc 0.2470
# Time taken for 1 epoch 14.043129682540894 sec
#
# Epoch 104 Loss 1.7950 Acc 0.2832
# Validation Loss 1.9055 Acc 0.2467
# Time taken for 1 epoch 14.040206909179688 sec
#
# Epoch 105 Loss 1.7928 Acc 0.2836
# Validation Loss 1.9060 Acc 0.2458
# Time taken for 1 epoch 14.086885452270508 sec
#
# Epoch 106 Loss 1.7916 Acc 0.2837
# Validation Loss 1.9073 Acc 0.2460
# Time taken for 1 epoch 14.050424098968506 sec
#
# Epoch 107 Loss 1.7917 Acc 0.2835
# Validation Loss 1.9070 Acc 0.2463
# Time taken for 1 epoch 14.09083867073059 sec
#
# Epoch 108 Loss 1.7926 Acc 0.2836
# Validation Loss 1.9045 Acc 0.2471
# Time taken for 1 epoch 14.051159143447876 sec
#
# Epoch 109 Loss 1.7981 Acc 0.2822
# Validation Loss 1.9068 Acc 0.2461
# Time taken for 1 epoch 14.073419570922852 sec
#
# Epoch 110 Loss 1.7958 Acc 0.2829
# Validation Loss 1.9039 Acc 0.2469
# Time taken for 1 epoch 14.064666748046875 sec
#
# Epoch 111 Loss 1.7923 Acc 0.2836
# Validation Loss 1.9045 Acc 0.2469
# Time taken for 1 epoch 14.069496870040894 sec
#
# Epoch 112 Loss 1.7922 Acc 0.2834
# Validation Loss 1.9087 Acc 0.2454
# Time taken for 1 epoch 14.108939170837402 sec
#
# Epoch 113 Loss 1.7891 Acc 0.2843
# Validation Loss 1.9042 Acc 0.2468
# Time taken for 1 epoch 14.084841251373291 sec
#
# Epoch 114 Loss 1.7879 Acc 0.2848
# Validation Loss 1.9050 Acc 0.2472
# Time taken for 1 epoch 14.09598708152771 sec
#
# Epoch 115 Loss 1.7857 Acc 0.2855
# Validation Loss 1.9058 Acc 0.2464
# Time taken for 1 epoch 14.08630108833313 sec
#
# Epoch 116 Loss 1.7851 Acc 0.2855
# Validation Loss 1.9021 Acc 0.2469
# Time taken for 1 epoch 14.09038782119751 sec
#
# Epoch 117 Loss 1.8004 Acc 0.2813
# Validation Loss 1.9107 Acc 0.2449
# Time taken for 1 epoch 14.082058906555176 sec
#
# Epoch 118 Loss 1.7941 Acc 0.2828
# Validation Loss 1.9096 Acc 0.2458
# Time taken for 1 epoch 14.112232685089111 sec
#
# Epoch 119 Loss 1.7872 Acc 0.2850
# Validation Loss 1.9091 Acc 0.2443
# Time taken for 1 epoch 14.069364070892334 sec
#
# Epoch 120 Loss 1.7859 Acc 0.2852
# Validation Loss 1.9062 Acc 0.2469
# Time taken for 1 epoch 14.086705923080444 sec
#
# Epoch 121 Loss 1.7813 Acc 0.2869
# Validation Loss 1.9089 Acc 0.2447
# Time taken for 1 epoch 14.079877853393555 sec
#
# Epoch 122 Loss 1.7818 Acc 0.2861
# Validation Loss 1.9056 Acc 0.2469
# Time taken for 1 epoch 14.071934223175049 sec
#
# Epoch 123 Loss 1.7800 Acc 0.2865
# Validation Loss 1.9103 Acc 0.2443
# Time taken for 1 epoch 14.058606147766113 sec
#
# Epoch 124 Loss 1.7782 Acc 0.2873
# Validation Loss 1.9057 Acc 0.2471
# Time taken for 1 epoch 14.092843532562256 sec
#
# Epoch 125 Loss 1.7767 Acc 0.2876
# Validation Loss 1.9106 Acc 0.2440
# Time taken for 1 epoch 14.05484390258789 sec
#
# Epoch 126 Loss 1.7786 Acc 0.2870
# Validation Loss 1.9034 Acc 0.2482
# Time taken for 1 epoch 14.068243503570557 sec
#
# Epoch 127 Loss 1.7778 Acc 0.2874
# Validation Loss 1.9085 Acc 0.2455
# Time taken for 1 epoch 14.0671226978302 sec
#
# Epoch 128 Loss 1.7745 Acc 0.2885
# Validation Loss 1.9055 Acc 0.2471
# Time taken for 1 epoch 14.132430076599121 sec
#
# Epoch 129 Loss 1.7729 Acc 0.2887
# Validation Loss 1.9062 Acc 0.2466
# Time taken for 1 epoch 14.035892724990845 sec
#
# Epoch 130 Loss 1.7804 Acc 0.2860
# Validation Loss 1.9162 Acc 0.2445
# Time taken for 1 epoch 14.075151205062866 sec
#
# Epoch 131 Loss 1.7757 Acc 0.2882
# Validation Loss 1.9062 Acc 0.2458
# Time taken for 1 epoch 14.125286340713501 sec
#
# Epoch 132 Loss 1.7752 Acc 0.2881
# Validation Loss 1.9012 Acc 0.2485
# Time taken for 1 epoch 14.072261810302734 sec
#
# Epoch 133 Loss 1.7753 Acc 0.2881
# Validation Loss 1.9108 Acc 0.2457
# Time taken for 1 epoch 14.104092359542847 sec
#
# Epoch 134 Loss 1.7764 Acc 0.2881
# Validation Loss 1.9069 Acc 0.2474
# Time taken for 1 epoch 14.095090389251709 sec
#
# Epoch 135 Loss 1.7730 Acc 0.2886
# Validation Loss 1.9096 Acc 0.2443
# Time taken for 1 epoch 14.065927505493164 sec
#
# Epoch 136 Loss 1.7708 Acc 0.2894
# Validation Loss 1.9075 Acc 0.2463
# Time taken for 1 epoch 14.044937372207642 sec
#
# Epoch 137 Loss 1.7708 Acc 0.2897
# Validation Loss 1.9098 Acc 0.2456
# Time taken for 1 epoch 14.104669332504272 sec
#
# Epoch 138 Loss 1.7747 Acc 0.2887
# Validation Loss 1.9234 Acc 0.2429
# Time taken for 1 epoch 14.127168655395508 sec
#
# Epoch 139 Loss 1.7777 Acc 0.2877
# Validation Loss 1.9197 Acc 0.2413
# Time taken for 1 epoch 14.094094276428223 sec
#
# Epoch 140 Loss 1.8055 Acc 0.2792
# Validation Loss 1.9096 Acc 0.2443
# Time taken for 1 epoch 14.03399133682251 sec
#
# Epoch 141 Loss 1.7845 Acc 0.2858
# Validation Loss 1.9092 Acc 0.2442
# Time taken for 1 epoch 14.11670184135437 sec
#
# Epoch 142 Loss 1.7810 Acc 0.2866
# Validation Loss 1.9103 Acc 0.2448
# Time taken for 1 epoch 14.077829122543335 sec
#
# Epoch 143 Loss 1.8121 Acc 0.2771
# Validation Loss 1.9028 Acc 0.2478
# Time taken for 1 epoch 14.058416843414307 sec
#
# Epoch 144 Loss 1.7819 Acc 0.2867
# Validation Loss 1.9201 Acc 0.2405
# Time taken for 1 epoch 14.095179319381714 sec
#
# Epoch 145 Loss 1.8012 Acc 0.2817
# Validation Loss 1.9064 Acc 0.2461
# Time taken for 1 epoch 14.032336473464966 sec
#
# Epoch 146 Loss 1.7901 Acc 0.2848
# Validation Loss 1.9013 Acc 0.2479
# Time taken for 1 epoch 14.07560658454895 sec
#
# Epoch 147 Loss 1.8060 Acc 0.2800
# Validation Loss 1.9346 Acc 0.2420
# Time taken for 1 epoch 14.116346597671509 sec
#
# Epoch 148 Loss 1.8054 Acc 0.2802
# Validation Loss 1.9087 Acc 0.2444
# Time taken for 1 epoch 14.04713249206543 sec
#
# Epoch 149 Loss 1.7854 Acc 0.2848
# Validation Loss 1.9057 Acc 0.2464
# Time taken for 1 epoch 14.0690758228302 sec
#
# Epoch 150 Loss 1.7777 Acc 0.2877
# Validation Loss 1.9030 Acc 0.2469
# Time taken for 1 epoch 14.095110177993774 sec
#
# Epoch 151 Loss 1.7772 Acc 0.2881
# Validation Loss 1.9018 Acc 0.2468
# Time taken for 1 epoch 14.074165105819702 sec
#
# Epoch 152 Loss 1.7777 Acc 0.2880
# Validation Loss 1.8993 Acc 0.2507
# Time taken for 1 epoch 14.105976104736328 sec
#
# Epoch 153 Loss 1.7852 Acc 0.2857
# Validation Loss 1.9216 Acc 0.2438
# Time taken for 1 epoch 14.063871383666992 sec
#
# Epoch 154 Loss 1.8331 Acc 0.2708
# Validation Loss 1.9326 Acc 0.2411
# Time taken for 1 epoch 14.063632488250732 sec
#
# Epoch 155 Loss 1.7856 Acc 0.2852
# Validation Loss 1.9097 Acc 0.2481
# Time taken for 1 epoch 14.09332537651062 sec
#
# Epoch 156 Loss 1.7779 Acc 0.2878
# Validation Loss 1.9059 Acc 0.2480
# Time taken for 1 epoch 14.003776550292969 sec
#
# Epoch 157 Loss 1.7751 Acc 0.2889
# Validation Loss 1.9074 Acc 0.2447
# Time taken for 1 epoch 14.106284379959106 sec
#
# Epoch 158 Loss 1.7761 Acc 0.2883
# Validation Loss 1.9075 Acc 0.2474
# Time taken for 1 epoch 14.098298788070679 sec
#
# Epoch 159 Loss 1.7707 Acc 0.2900
# Validation Loss 1.9033 Acc 0.2487
# Time taken for 1 epoch 14.019917726516724 sec
#
# Epoch 160 Loss 1.7737 Acc 0.2897
# Validation Loss 1.9086 Acc 0.2482
# Time taken for 1 epoch 14.104064702987671 sec
#
# Epoch 161 Loss 1.7697 Acc 0.2908
# Validation Loss 1.9065 Acc 0.2452
# Time taken for 1 epoch 14.063153505325317 sec
#
# Epoch 162 Loss 1.7797 Acc 0.2870
# Validation Loss 1.9227 Acc 0.2378
# Time taken for 1 epoch 14.130574464797974 sec
#
# Epoch 163 Loss 1.7738 Acc 0.2885
# Validation Loss 1.9064 Acc 0.2470
# Time taken for 1 epoch 14.076338529586792 sec
#
# Epoch 164 Loss 1.7722 Acc 0.2900
# Validation Loss 1.9055 Acc 0.2480
# Time taken for 1 epoch 14.089608430862427 sec
#
# Epoch 165 Loss 1.7895 Acc 0.2844
# Validation Loss 1.9242 Acc 0.2422
# Time taken for 1 epoch 14.06691861152649 sec
#
# Epoch 166 Loss 1.7943 Acc 0.2826
# Validation Loss 1.9058 Acc 0.2482
# Time taken for 1 epoch 14.11039924621582 sec
#
# Epoch 167 Loss 1.7705 Acc 0.2898
# Validation Loss 1.9013 Acc 0.2502
# Time taken for 1 epoch 14.035227298736572 sec
#
# Epoch 168 Loss 1.7661 Acc 0.2909
# Validation Loss 1.9076 Acc 0.2471
# Time taken for 1 epoch 14.073228120803833 sec
#
# Epoch 169 Loss 1.7662 Acc 0.2908
# Validation Loss 1.9097 Acc 0.2468
# Time taken for 1 epoch 14.073402404785156 sec
#
# Epoch 170 Loss 1.7647 Acc 0.2918
# Validation Loss 1.9089 Acc 0.2468
# Time taken for 1 epoch 14.055068492889404 sec
#
# Epoch 171 Loss 1.7613 Acc 0.2925
# Validation Loss 1.9024 Acc 0.2490
# Time taken for 1 epoch 14.08272933959961 sec
#
# Epoch 172 Loss 1.7640 Acc 0.2916
# Validation Loss 1.9130 Acc 0.2445
# Time taken for 1 epoch 14.069130182266235 sec
#
# Epoch 173 Loss 1.7606 Acc 0.2928
# Validation Loss 1.9057 Acc 0.2467
# Time taken for 1 epoch 14.151532411575317 sec
#
# Epoch 174 Loss 1.7646 Acc 0.2917
# Validation Loss 1.9048 Acc 0.2484
# Time taken for 1 epoch 14.0642249584198 sec
#
# Epoch 175 Loss 1.7618 Acc 0.2923
# Validation Loss 1.9102 Acc 0.2457
# Time taken for 1 epoch 14.099966049194336 sec
#
# Epoch 176 Loss 1.7833 Acc 0.2853
# Validation Loss 1.8981 Acc 0.2507
# Time taken for 1 epoch 14.061402559280396 sec
#
# Epoch 177 Loss 1.7656 Acc 0.2916
# Validation Loss 1.9069 Acc 0.2482
# Time taken for 1 epoch 14.068942070007324 sec
#
# Epoch 178 Loss 1.7568 Acc 0.2941
# Validation Loss 1.9099 Acc 0.2484
# Time taken for 1 epoch 14.074161767959595 sec
#
# Epoch 179 Loss 1.7595 Acc 0.2931
# Validation Loss 1.9060 Acc 0.2504
# Time taken for 1 epoch 14.06126594543457 sec
#
# Epoch 180 Loss 1.7648 Acc 0.2919
# Validation Loss 1.9103 Acc 0.2480
# Time taken for 1 epoch 14.007879734039307 sec
#
# Epoch 181 Loss 1.7603 Acc 0.2932
# Validation Loss 1.9180 Acc 0.2452
# Time taken for 1 epoch 14.067380666732788 sec
#
# Epoch 182 Loss 1.7700 Acc 0.2897
# Validation Loss 1.9135 Acc 0.2458
# Time taken for 1 epoch 14.083848237991333 sec
#
# Epoch 183 Loss 1.7613 Acc 0.2926
# Validation Loss 1.9141 Acc 0.2459
# Time taken for 1 epoch 14.095069408416748 sec
#
# Epoch 184 Loss 1.7564 Acc 0.2942
# Validation Loss 1.9061 Acc 0.2488
# Time taken for 1 epoch 14.04341173171997 sec
#
# Epoch 185 Loss 1.7628 Acc 0.2931
# Validation Loss 1.9063 Acc 0.2490
# Time taken for 1 epoch 14.082757472991943 sec
#
# Epoch 186 Loss 1.7651 Acc 0.2919
# Validation Loss 1.9112 Acc 0.2467
# Time taken for 1 epoch 14.132169961929321 sec
#
# Epoch 187 Loss 1.7617 Acc 0.2929
# Validation Loss 1.9121 Acc 0.2473
# Time taken for 1 epoch 14.107254028320312 sec
#
# Epoch 188 Loss 1.7559 Acc 0.2947
# Validation Loss 1.9652 Acc 0.2326
# Time taken for 1 epoch 14.083993673324585 sec
#
# Epoch 189 Loss 1.7805 Acc 0.2868
# Validation Loss 1.9497 Acc 0.2380
# Time taken for 1 epoch 14.119179964065552 sec
#
# Epoch 190 Loss 1.7889 Acc 0.2841
# Validation Loss 1.9242 Acc 0.2422
# Time taken for 1 epoch 14.091928005218506 sec
#
# Epoch 191 Loss 1.7730 Acc 0.2891
# Validation Loss 1.9186 Acc 0.2467
# Time taken for 1 epoch 14.073373317718506 sec
#
# Epoch 192 Loss 1.7564 Acc 0.2945
# Validation Loss 1.9055 Acc 0.2492
# Time taken for 1 epoch 14.077481985092163 sec
#
# Epoch 193 Loss 1.7560 Acc 0.2943
# Validation Loss 1.9055 Acc 0.2487
# Time taken for 1 epoch 14.074802875518799 sec
#
# Epoch 194 Loss 1.7562 Acc 0.2945
# Validation Loss 1.9248 Acc 0.2420
# Time taken for 1 epoch 14.098698139190674 sec
#
# Epoch 195 Loss 1.7600 Acc 0.2933
# Validation Loss 1.9192 Acc 0.2442
# Time taken for 1 epoch 14.089232444763184 sec
#
# Epoch 196 Loss 1.7569 Acc 0.2940
# Validation Loss 1.9103 Acc 0.2488
# Time taken for 1 epoch 14.095454216003418 sec
#
# Epoch 197 Loss 1.7734 Acc 0.2895
# Validation Loss 1.9559 Acc 0.2367
# Time taken for 1 epoch 14.039201498031616 sec
#
# Epoch 198 Loss 1.7897 Acc 0.2846
# Validation Loss 1.9287 Acc 0.2415
# Time taken for 1 epoch 14.061400175094604 sec
#
# Epoch 199 Loss 1.7637 Acc 0.2916
# Validation Loss 1.9068 Acc 0.2504
# Time taken for 1 epoch 14.07941222190857 sec
#
# Epoch 200 Loss 1.7593 Acc 0.2937
# Validation Loss 1.9298 Acc 0.2440
# Time taken for 1 epoch 14.077847957611084 sec
#
# Epoch 201 Loss 1.7572 Acc 0.2940
# Validation Loss 1.9209 Acc 0.2449
# Time taken for 1 epoch 14.044913053512573 sec
#
# Epoch 202 Loss 1.8298 Acc 0.2745
# Validation Loss 1.9214 Acc 0.2460
# Time taken for 1 epoch 14.057767391204834 sec
#
# Epoch 203 Loss 1.8024 Acc 0.2830
# Validation Loss 1.9206 Acc 0.2432
# Time taken for 1 epoch 14.081888437271118 sec
#
# Epoch 204 Loss 1.8399 Acc 0.2728
# Validation Loss 1.9534 Acc 0.2382
# Time taken for 1 epoch 14.065011739730835 sec
#
# Epoch 205 Loss 1.8133 Acc 0.2789
# Validation Loss 1.9362 Acc 0.2383
# Time taken for 1 epoch 14.097012042999268 sec
#
# Epoch 206 Loss 1.7904 Acc 0.2846
# Validation Loss 1.9086 Acc 0.2490
# Time taken for 1 epoch 14.038821935653687 sec
#
# Epoch 207 Loss 1.7800 Acc 0.2883
# Validation Loss 1.9152 Acc 0.2471
# Time taken for 1 epoch 14.05303692817688 sec
#
# Epoch 208 Loss 1.7737 Acc 0.2902
# Validation Loss 1.9172 Acc 0.2463
# Time taken for 1 epoch 14.10054612159729 sec
#
# Epoch 209 Loss 1.7700 Acc 0.2915
# Validation Loss 1.9106 Acc 0.2482
# Time taken for 1 epoch 14.063301801681519 sec
#
# Epoch 210 Loss 1.7687 Acc 0.2913
# Validation Loss 1.9074 Acc 0.2496
# Time taken for 1 epoch 14.075296640396118 sec
#
# Epoch 211 Loss 1.7811 Acc 0.2875
# Validation Loss 1.9407 Acc 0.2400
# Time taken for 1 epoch 14.05350112915039 sec
#
# Epoch 212 Loss 1.7935 Acc 0.2839
# Validation Loss 1.9756 Acc 0.2278
# Time taken for 1 epoch 14.087785482406616 sec
#
# Epoch 213 Loss 1.8469 Acc 0.2696
# Validation Loss 1.9222 Acc 0.2437
# Time taken for 1 epoch 14.056705236434937 sec
#
# Epoch 214 Loss 1.8023 Acc 0.2818
# Validation Loss 1.9151 Acc 0.2465
# Time taken for 1 epoch 14.0631422996521 sec
#
# Epoch 215 Loss 1.7931 Acc 0.2847
# Validation Loss 1.9102 Acc 0.2465
# Time taken for 1 epoch 14.041563272476196 sec
#
# Epoch 216 Loss 1.7926 Acc 0.2840
# Validation Loss 1.9136 Acc 0.2454
# Time taken for 1 epoch 14.083027839660645 sec
#
# Epoch 217 Loss 1.7858 Acc 0.2863
# Validation Loss 1.9139 Acc 0.2462
# Time taken for 1 epoch 14.094818592071533 sec
#
# Epoch 218 Loss 1.7806 Acc 0.2878
# Validation Loss 1.9091 Acc 0.2477
# Time taken for 1 epoch 14.07595443725586 sec
#
# Epoch 219 Loss 1.7810 Acc 0.2876
# Validation Loss 1.9132 Acc 0.2455
# Time taken for 1 epoch 13.99190902709961 sec
#
# Epoch 220 Loss 1.7826 Acc 0.2869
# Validation Loss 1.9158 Acc 0.2442
# Time taken for 1 epoch 14.079872846603394 sec
#
# Epoch 221 Loss 1.8025 Acc 0.2817
# Validation Loss 1.9421 Acc 0.2415
# Time taken for 1 epoch 14.088785886764526 sec
#
# Epoch 222 Loss 1.8436 Acc 0.2694
# Validation Loss 1.9292 Acc 0.2452
# Time taken for 1 epoch 14.150327920913696 sec
#
# Epoch 223 Loss 1.8030 Acc 0.2818
# Validation Loss 1.9282 Acc 0.2414
# Time taken for 1 epoch 14.148823022842407 sec
#
# Epoch 224 Loss 1.7902 Acc 0.2852
# Validation Loss 1.9165 Acc 0.2459
# Time taken for 1 epoch 14.068633317947388 sec
#
# Epoch 225 Loss 1.7836 Acc 0.2871
# Validation Loss 1.9107 Acc 0.2483
# Time taken for 1 epoch 14.085517406463623 sec
#
# Epoch 226 Loss 1.7782 Acc 0.2891
# Validation Loss 1.9132 Acc 0.2473
# Time taken for 1 epoch 14.024715662002563 sec
#
# Epoch 227 Loss 1.7848 Acc 0.2872
# Validation Loss 1.9141 Acc 0.2463
# Time taken for 1 epoch 14.088873624801636 sec
#
# Epoch 228 Loss 1.7820 Acc 0.2880
# Validation Loss 1.9163 Acc 0.2463
# Time taken for 1 epoch 14.069028615951538 sec
#
# Epoch 229 Loss 1.7775 Acc 0.2895
# Validation Loss 1.9071 Acc 0.2494
# Time taken for 1 epoch 14.083930730819702 sec
#
# Epoch 230 Loss 1.8083 Acc 0.2821
# Validation Loss 1.9434 Acc 0.2430
# Time taken for 1 epoch 14.059154748916626 sec
#
# Epoch 231 Loss 1.8154 Acc 0.2797
# Validation Loss 1.9386 Acc 0.2420
# Time taken for 1 epoch 14.103146076202393 sec
#
# Epoch 232 Loss 1.7973 Acc 0.2849
# Validation Loss 1.9168 Acc 0.2486
# Time taken for 1 epoch 14.066752910614014 sec
#
# Epoch 233 Loss 1.7886 Acc 0.2871
# Validation Loss 1.9232 Acc 0.2457
# Time taken for 1 epoch 14.114130735397339 sec
#
# Epoch 234 Loss 1.8168 Acc 0.2790
# Validation Loss 1.9748 Acc 0.2336
# Time taken for 1 epoch 14.079100370407104 sec
#
# Epoch 235 Loss 1.8412 Acc 0.2736
# Validation Loss 1.9463 Acc 0.2366
# Time taken for 1 epoch 14.01859712600708 sec
#
# Epoch 236 Loss 1.8356 Acc 0.2736
# Validation Loss 1.9483 Acc 0.2389
# Time taken for 1 epoch 14.097567081451416 sec
#
# Epoch 237 Loss 1.8052 Acc 0.2817
# Validation Loss 1.9177 Acc 0.2482
# Time taken for 1 epoch 14.07965350151062 sec
#
# Epoch 238 Loss 1.7893 Acc 0.2858
# Validation Loss 1.9469 Acc 0.2364
# Time taken for 1 epoch 14.111093044281006 sec
#
# Epoch 239 Loss 1.7929 Acc 0.2851
# Validation Loss 1.9180 Acc 0.2462
# Time taken for 1 epoch 14.050638437271118 sec
#
# Epoch 240 Loss 1.7827 Acc 0.2882
# Validation Loss 1.9255 Acc 0.2442
# Time taken for 1 epoch 14.06391954421997 sec
#
# Epoch 241 Loss 1.7845 Acc 0.2877
# Validation Loss 1.9256 Acc 0.2448
# Time taken for 1 epoch 14.089856147766113 sec
#
# Epoch 242 Loss 1.7830 Acc 0.2878
# Validation Loss 1.9483 Acc 0.2387
# Time taken for 1 epoch 14.08206057548523 sec
#
# Epoch 243 Loss 1.7817 Acc 0.2880
# Validation Loss 1.9283 Acc 0.2428
# Time taken for 1 epoch 14.09976840019226 sec
#
# Epoch 244 Loss 1.7816 Acc 0.2878
# Validation Loss 1.9205 Acc 0.2453
# Time taken for 1 epoch 14.036726236343384 sec
#
# Epoch 245 Loss 1.7971 Acc 0.2837
# Validation Loss 1.9686 Acc 0.2338
# Time taken for 1 epoch 14.154412984848022 sec
#
# Epoch 246 Loss 1.8143 Acc 0.2809
# Validation Loss 1.9392 Acc 0.2395
# Time taken for 1 epoch 14.103382110595703 sec
#
# Epoch 247 Loss 1.7987 Acc 0.2833
# Validation Loss 1.9397 Acc 0.2423
# Time taken for 1 epoch 14.048609256744385 sec
#
# Epoch 248 Loss 1.7835 Acc 0.2875
# Validation Loss 1.9383 Acc 0.2405
# Time taken for 1 epoch 14.026868343353271 sec
#
# Epoch 249 Loss 1.7763 Acc 0.2895
# Validation Loss 1.9415 Acc 0.2393
# Time taken for 1 epoch 14.083009481430054 sec
#
# Epoch 250 Loss 1.7820 Acc 0.2878
# Validation Loss 1.9137 Acc 0.2501
# Time taken for 1 epoch 14.085438251495361 sec
#
# Epoch 251 Loss 1.7755 Acc 0.2903
# Validation Loss 1.9271 Acc 0.2443
# Time taken for 1 epoch 14.096240043640137 sec
#
# Epoch 252 Loss 1.7740 Acc 0.2906
# Validation Loss 1.9217 Acc 0.2464
# Time taken for 1 epoch 14.036011219024658 sec
#
# Epoch 253 Loss 1.7717 Acc 0.2906
# Validation Loss 1.9159 Acc 0.2485
# Time taken for 1 epoch 14.085937738418579 sec
#
# Epoch 254 Loss 1.7723 Acc 0.2906
# Validation Loss 1.9187 Acc 0.2461
# Time taken for 1 epoch 14.151636838912964 sec
#
# Epoch 255 Loss 1.7727 Acc 0.2902
# Validation Loss 1.9201 Acc 0.2467
# Time taken for 1 epoch 14.104483842849731 sec
#
# Epoch 256 Loss 1.7688 Acc 0.2917
# Validation Loss 1.9153 Acc 0.2484
# Time taken for 1 epoch 14.062160968780518 sec
#
# Epoch 257 Loss 1.7737 Acc 0.2908
# Validation Loss 1.9245 Acc 0.2427
# Time taken for 1 epoch 14.056415557861328 sec
#
# Epoch 258 Loss 1.7854 Acc 0.2876
# Validation Loss 1.9197 Acc 0.2454
# Time taken for 1 epoch 14.09760046005249 sec
#
# Epoch 259 Loss 1.7891 Acc 0.2864
# Validation Loss 1.9226 Acc 0.2441
# Time taken for 1 epoch 14.067773342132568 sec
#
# Epoch 260 Loss 1.7809 Acc 0.2886
# Validation Loss 1.9181 Acc 0.2459
# Time taken for 1 epoch 14.034868001937866 sec
#
# Epoch 261 Loss 1.7743 Acc 0.2907
# Validation Loss 1.9379 Acc 0.2415
# Time taken for 1 epoch 14.07999873161316 sec
#
# Epoch 262 Loss 1.7834 Acc 0.2874
# Validation Loss 1.9252 Acc 0.2468
# Time taken for 1 epoch 14.113298892974854 sec
#
# Epoch 263 Loss 1.7789 Acc 0.2889
# Validation Loss 1.9163 Acc 0.2466
# Time taken for 1 epoch 14.135503053665161 sec
#
# Epoch 264 Loss 1.7719 Acc 0.2911
# Validation Loss 1.9170 Acc 0.2470
# Time taken for 1 epoch 14.097752571105957 sec
#
# Epoch 265 Loss 1.7721 Acc 0.2906
# Validation Loss 1.9112 Acc 0.2486
# Time taken for 1 epoch 14.143712759017944 sec
#
# Epoch 266 Loss 1.7676 Acc 0.2924
# Validation Loss 1.9206 Acc 0.2446
# Time taken for 1 epoch 14.052147626876831 sec
#
# Epoch 267 Loss 1.7843 Acc 0.2872
# Validation Loss 2.0504 Acc 0.2141
# Time taken for 1 epoch 14.038709878921509 sec
#
# Epoch 268 Loss 1.8480 Acc 0.2699
# Validation Loss 1.9586 Acc 0.2381
# Time taken for 1 epoch 14.111213207244873 sec
#
# Epoch 269 Loss 1.8229 Acc 0.2759
# Validation Loss 1.9539 Acc 0.2404
# Time taken for 1 epoch 14.142502069473267 sec
#
# Epoch 270 Loss 1.8041 Acc 0.2821
# Validation Loss 1.9435 Acc 0.2357
# Time taken for 1 epoch 14.116405725479126 sec
#
# Epoch 271 Loss 1.7946 Acc 0.2850
# Validation Loss 1.9310 Acc 0.2428
# Time taken for 1 epoch 14.09701681137085 sec
#
# Epoch 272 Loss 1.7861 Acc 0.2870
# Validation Loss 1.9288 Acc 0.2458
# Time taken for 1 epoch 14.117070436477661 sec
#
# Epoch 273 Loss 1.7839 Acc 0.2878
# Validation Loss 1.9243 Acc 0.2454
# Time taken for 1 epoch 14.102921485900879 sec
#
# Epoch 274 Loss 1.7818 Acc 0.2884
# Validation Loss 1.9236 Acc 0.2475
# Time taken for 1 epoch 14.055637836456299 sec
#
# Epoch 275 Loss 1.7741 Acc 0.2909
# Validation Loss 1.9193 Acc 0.2468
# Time taken for 1 epoch 14.062336921691895 sec
#
# Epoch 276 Loss 1.7709 Acc 0.2916
# Validation Loss 1.9221 Acc 0.2460
# Time taken for 1 epoch 14.12153673171997 sec
#
# Epoch 277 Loss 1.7869 Acc 0.2865
# Validation Loss 1.9851 Acc 0.2302
# Time taken for 1 epoch 14.08753752708435 sec
#
# Epoch 278 Loss 1.8019 Acc 0.2839
# Validation Loss 1.9314 Acc 0.2440
# Time taken for 1 epoch 14.146533012390137 sec
#
# Epoch 279 Loss 1.7850 Acc 0.2870
# Validation Loss 1.9261 Acc 0.2450
# Time taken for 1 epoch 14.096334218978882 sec
#
# Epoch 280 Loss 1.7710 Acc 0.2911
# Validation Loss 1.9319 Acc 0.2434
# Time taken for 1 epoch 14.063884019851685 sec
#
# Epoch 281 Loss 1.7656 Acc 0.2930
# Validation Loss 1.9230 Acc 0.2462
# Time taken for 1 epoch 14.119370937347412 sec
#
# Epoch 282 Loss 1.7683 Acc 0.2920
# Validation Loss 1.9400 Acc 0.2392
# Time taken for 1 epoch 14.088467121124268 sec
#
# Epoch 283 Loss 1.7851 Acc 0.2868
# Validation Loss 1.9304 Acc 0.2441
# Time taken for 1 epoch 14.062715768814087 sec
#
# Epoch 284 Loss 1.7758 Acc 0.2894
# Validation Loss 1.9029 Acc 0.2514
# Time taken for 1 epoch 14.104839324951172 sec
#
# Epoch 285 Loss 1.7749 Acc 0.2908
# Validation Loss 1.9207 Acc 0.2493
# Time taken for 1 epoch 14.11160397529602 sec
#
# Epoch 286 Loss 1.7633 Acc 0.2937
# Validation Loss 1.9192 Acc 0.2478
# Time taken for 1 epoch 14.110372304916382 sec
#
# Epoch 287 Loss 1.7607 Acc 0.2944
# Validation Loss 1.9358 Acc 0.2396
# Time taken for 1 epoch 14.059254884719849 sec
#
# Epoch 288 Loss 1.7667 Acc 0.2926
# Validation Loss 1.9213 Acc 0.2468
# Time taken for 1 epoch 14.01737928390503 sec
#
# Epoch 289 Loss 1.7596 Acc 0.2945
# Validation Loss 1.9193 Acc 0.2475
# Time taken for 1 epoch 14.129958391189575 sec
#
# Epoch 290 Loss 1.9199 Acc 0.2571
# Validation Loss 2.0236 Acc 0.2171
# Time taken for 1 epoch 14.072225332260132 sec
#
# Epoch 291 Loss 1.9203 Acc 0.2470
# Validation Loss 1.9955 Acc 0.2274
# Time taken for 1 epoch 14.050770282745361 sec
#
# Epoch 292 Loss 1.8881 Acc 0.2572
# Validation Loss 1.9817 Acc 0.2309
# Time taken for 1 epoch 14.116117715835571 sec
#
# Epoch 293 Loss 1.8707 Acc 0.2633
# Validation Loss 1.9745 Acc 0.2310
# Time taken for 1 epoch 14.083571434020996 sec
#
# Epoch 294 Loss 1.8633 Acc 0.2661
# Validation Loss 1.9574 Acc 0.2387
# Time taken for 1 epoch 14.105231523513794 sec
#
# Epoch 295 Loss 1.8616 Acc 0.2665
# Validation Loss 1.9756 Acc 0.2305
# Time taken for 1 epoch 14.064311742782593 sec
#
# Epoch 296 Loss 1.8523 Acc 0.2690
# Validation Loss 1.9692 Acc 0.2299
# Time taken for 1 epoch 14.103104591369629 sec
#
# Epoch 297 Loss 1.8492 Acc 0.2699
# Validation Loss 1.9687 Acc 0.2341
# Time taken for 1 epoch 14.06399416923523 sec
#
# Epoch 298 Loss 1.8396 Acc 0.2732
# Validation Loss 1.9603 Acc 0.2383
# Time taken for 1 epoch 14.08449101448059 sec
#
# Epoch 299 Loss 1.8316 Acc 0.2748
# Validation Loss 1.9534 Acc 0.2344
# Time taken for 1 epoch 14.122792720794678 sec
#
# Epoch 300 Loss 1.8481 Acc 0.2705
# Validation Loss 1.9556 Acc 0.2383
# Time taken for 1 epoch 14.03989863395691 sec

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"/loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"/acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"/val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"/val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 31ms/step
# (1536, 53)
