# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-15 21:53:39.043847: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-15 21:53:39.618496: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-15 21:53:39.618578: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-15 21:53:39.618585: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BATCH_SIZE = 512
VALIDATION_RATIO = 0.1

PIECE_LEN = 1024
n_feature = 43
n_hidden = 100
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-01-15 21:55:01.276908: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.282722: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.282920: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.283458: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-15 21:55:01.284206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.284390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.284548: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.711079: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.712052: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.712169: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 21:55:01.712260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature))(input) # Ignore Padded Data
x = Bidirectional(LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, ))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax"))(x)
model = tf.keras.Model(inputs=input, outputs=x)

print(model.summary())

optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1024, 43)]        0
#
#  masking_4 (Masking)         (None, 1024, 43)          0
#
#  bidirectional_4 (Bidirectio  (None, 1024, 200)        115200
#  nal)
#
#  time_distributed_4 (TimeDis  (None, 1024, 53)         10653
#  tributed)
#
# =================================================================
# Total params: 125,853
# Trainable params: 125,853
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/00_BDLSTM_sinple_naive'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()
acc_history = []

# %%
# set the epochs for training
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    # saving (checkpoint) the model every 2 epochs
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    # acc_history.append(float(total_acc / steps_per_epoch))
# Out:
# Epoch 1 Loss 1.6323 Acc 0.3031
# Time taken for 1 epoch 12.375457048416138 sec
#
# Epoch 2 Loss 1.6322 Acc 0.3030
# Time taken for 1 epoch 12.368602752685547 sec
#
# Epoch 3 Loss 1.6376 Acc 0.3015
# Time taken for 1 epoch 12.438720226287842 sec
#
# Epoch 4 Loss 1.6332 Acc 0.3027
# Time taken for 1 epoch 12.479138135910034 sec
#
# Epoch 5 Loss 1.6320 Acc 0.3030
# Time taken for 1 epoch 12.463635921478271 sec
#
# Epoch 6 Loss 1.6297 Acc 0.3036
# Time taken for 1 epoch 12.496567249298096 sec
#
# Epoch 7 Loss 1.6278 Acc 0.3042
# Time taken for 1 epoch 12.500049829483032 sec
#
# Epoch 8 Loss 1.6289 Acc 0.3040
# Time taken for 1 epoch 12.49526071548462 sec
#
# Epoch 9 Loss 1.6291 Acc 0.3038
# Time taken for 1 epoch 12.499334335327148 sec
#
# Epoch 10 Loss 1.6292 Acc 0.3038
# Time taken for 1 epoch 12.523439645767212 sec
#
# Epoch 11 Loss 1.6283 Acc 0.3041
# Time taken for 1 epoch 12.49146032333374 sec
#
# Epoch 12 Loss 1.6279 Acc 0.3041
# Time taken for 1 epoch 12.5380539894104 sec
#
# Epoch 13 Loss 1.6276 Acc 0.3039
# Time taken for 1 epoch 12.588202953338623 sec
#
# Epoch 14 Loss 1.6261 Acc 0.3045
# Time taken for 1 epoch 12.509734153747559 sec
#
# Epoch 15 Loss 1.6513 Acc 0.2993
# Time taken for 1 epoch 12.584003448486328 sec
#
# Epoch 16 Loss 1.6763 Acc 0.2931
# Time taken for 1 epoch 12.568552017211914 sec
#
# Epoch 17 Loss 1.6701 Acc 0.2937
# Time taken for 1 epoch 12.52490782737732 sec
#
# Epoch 18 Loss 1.6500 Acc 0.2986
# Time taken for 1 epoch 12.526235342025757 sec
#
# Epoch 19 Loss 1.6409 Acc 0.3006
# Time taken for 1 epoch 12.482792615890503 sec
#
# Epoch 20 Loss 1.6342 Acc 0.3026
# Time taken for 1 epoch 12.545143842697144 sec
#
# Epoch 21 Loss 1.6341 Acc 0.3023
# Time taken for 1 epoch 12.534358501434326 sec
#
# Epoch 22 Loss 1.6339 Acc 0.3024
# Time taken for 1 epoch 12.516387701034546 sec
#
# Epoch 23 Loss 1.6336 Acc 0.3025
# Time taken for 1 epoch 12.53862476348877 sec
#
# Epoch 24 Loss 1.6320 Acc 0.3028
# Time taken for 1 epoch 12.550570487976074 sec
#
# Epoch 25 Loss 1.6343 Acc 0.3025
# Time taken for 1 epoch 12.475590705871582 sec
#
# Epoch 26 Loss 1.6284 Acc 0.3037
# Time taken for 1 epoch 12.513000249862671 sec
#
# Epoch 27 Loss 1.6267 Acc 0.3041
# Time taken for 1 epoch 12.535440921783447 sec
#
# Epoch 28 Loss 1.6260 Acc 0.3045
# Time taken for 1 epoch 12.536367177963257 sec
#
# Epoch 29 Loss 1.6271 Acc 0.3041
# Time taken for 1 epoch 12.552764177322388 sec
#
# Epoch 30 Loss 1.6242 Acc 0.3046
# Time taken for 1 epoch 12.582835912704468 sec
#
# Epoch 31 Loss 1.6266 Acc 0.3041
# Time taken for 1 epoch 12.554159164428711 sec
#
# Epoch 32 Loss 1.6276 Acc 0.3040
# Time taken for 1 epoch 12.577935218811035 sec
#
# Epoch 33 Loss 1.6238 Acc 0.3049
# Time taken for 1 epoch 12.512921571731567 sec
#
# Epoch 34 Loss 1.6221 Acc 0.3055
# Time taken for 1 epoch 12.523555994033813 sec
#
# Epoch 35 Loss 1.6256 Acc 0.3044
# Time taken for 1 epoch 12.540594339370728 sec
#
# Epoch 36 Loss 1.6232 Acc 0.3053
# Time taken for 1 epoch 12.557891368865967 sec
#
# Epoch 37 Loss 1.6250 Acc 0.3049
# Time taken for 1 epoch 12.525275945663452 sec
#
# Epoch 38 Loss 1.6200 Acc 0.3058
# Time taken for 1 epoch 12.566020011901855 sec
#
# Epoch 39 Loss 1.6206 Acc 0.3058
# Time taken for 1 epoch 12.561684608459473 sec
#
# Epoch 40 Loss 1.6197 Acc 0.3059
# Time taken for 1 epoch 12.631670236587524 sec
#
# Epoch 41 Loss 1.6186 Acc 0.3062
# Time taken for 1 epoch 12.508930683135986 sec
#
# Epoch 42 Loss 1.6195 Acc 0.3061
# Time taken for 1 epoch 12.501321792602539 sec
#
# Epoch 43 Loss 1.6229 Acc 0.3052
# Time taken for 1 epoch 12.583277225494385 sec
#
# Epoch 44 Loss 1.6229 Acc 0.3050
# Time taken for 1 epoch 12.583495140075684 sec
#
# Epoch 45 Loss 1.6189 Acc 0.3061
# Time taken for 1 epoch 12.490763187408447 sec
#
# Epoch 46 Loss 1.6213 Acc 0.3058
# Time taken for 1 epoch 12.507386207580566 sec
#
# Epoch 47 Loss 1.6206 Acc 0.3057
# Time taken for 1 epoch 12.547650337219238 sec
#
# Epoch 48 Loss 1.6198 Acc 0.3056
# Time taken for 1 epoch 12.538949251174927 sec
#
# Epoch 49 Loss 1.6182 Acc 0.3063
# Time taken for 1 epoch 12.582451105117798 sec
#
# Epoch 50 Loss 1.6187 Acc 0.3063
# Time taken for 1 epoch 12.5589759349823 sec
#
# Epoch 51 Loss 1.6169 Acc 0.3066
# Time taken for 1 epoch 12.523340702056885 sec
#
# Epoch 52 Loss 1.6163 Acc 0.3068
# Time taken for 1 epoch 12.494216680526733 sec
#
# Epoch 53 Loss 1.6231 Acc 0.3051
# Time taken for 1 epoch 12.563974380493164 sec
#
# Epoch 54 Loss 1.6180 Acc 0.3062
# Time taken for 1 epoch 12.488728284835815 sec
#
# Epoch 55 Loss 1.6166 Acc 0.3064
# Time taken for 1 epoch 12.592941999435425 sec
#
# Epoch 56 Loss 1.6156 Acc 0.3068
# Time taken for 1 epoch 12.537853240966797 sec
#
# Epoch 57 Loss 1.6196 Acc 0.3059
# Time taken for 1 epoch 12.48573350906372 sec
#
# Epoch 58 Loss 1.6148 Acc 0.3068
# Time taken for 1 epoch 12.519238233566284 sec
#
# Epoch 59 Loss 1.6134 Acc 0.3074
# Time taken for 1 epoch 12.53738260269165 sec
#
# Epoch 60 Loss 1.6204 Acc 0.3054
# Time taken for 1 epoch 12.508145570755005 sec
#
# Epoch 61 Loss 1.6139 Acc 0.3073
# Time taken for 1 epoch 12.513270139694214 sec
#
# Epoch 62 Loss 1.6155 Acc 0.3067
# Time taken for 1 epoch 12.512946844100952 sec
#
# Epoch 63 Loss 1.6089 Acc 0.3083
# Time taken for 1 epoch 12.537912368774414 sec
#
# Epoch 64 Loss 1.6094 Acc 0.3083
# Time taken for 1 epoch 12.550104141235352 sec
#
# Epoch 65 Loss 1.6161 Acc 0.3066
# Time taken for 1 epoch 12.56790018081665 sec
#
# Epoch 66 Loss 1.6092 Acc 0.3083
# Time taken for 1 epoch 12.54976773262024 sec
#
# Epoch 67 Loss 1.6133 Acc 0.3074
# Time taken for 1 epoch 12.556928157806396 sec
#
# Epoch 68 Loss 1.6135 Acc 0.3074
# Time taken for 1 epoch 12.490509986877441 sec
#
# Epoch 69 Loss 1.6116 Acc 0.3078
# Time taken for 1 epoch 12.53157901763916 sec
#
# Epoch 70 Loss 1.6146 Acc 0.3070
# Time taken for 1 epoch 12.560832977294922 sec
#
# Epoch 71 Loss 1.6130 Acc 0.3075
# Time taken for 1 epoch 12.559877157211304 sec
#
# Epoch 72 Loss 1.6097 Acc 0.3083
# Time taken for 1 epoch 12.567781448364258 sec
#
# Epoch 73 Loss 1.6083 Acc 0.3087
# Time taken for 1 epoch 12.582215547561646 sec
#
# Epoch 74 Loss 1.6110 Acc 0.3080
# Time taken for 1 epoch 12.542762279510498 sec
#
# Epoch 75 Loss 1.6152 Acc 0.3068
# Time taken for 1 epoch 12.581695556640625 sec
#
# Epoch 76 Loss 1.6151 Acc 0.3070
# Time taken for 1 epoch 12.546854496002197 sec
#
# Epoch 77 Loss 1.6118 Acc 0.3078
# Time taken for 1 epoch 12.56039571762085 sec
#
# Epoch 78 Loss 1.6100 Acc 0.3079
# Time taken for 1 epoch 12.51887559890747 sec
#
# Epoch 79 Loss 1.6095 Acc 0.3082
# Time taken for 1 epoch 12.569655179977417 sec
#
# Epoch 80 Loss 1.6118 Acc 0.3076
# Time taken for 1 epoch 12.555541276931763 sec
#
# Epoch 81 Loss 1.6120 Acc 0.3078
# Time taken for 1 epoch 12.53475308418274 sec
#
# Epoch 82 Loss 1.6067 Acc 0.3090
# Time taken for 1 epoch 12.522999286651611 sec
#
# Epoch 83 Loss 1.6076 Acc 0.3090
# Time taken for 1 epoch 12.527271032333374 sec
#
# Epoch 84 Loss 1.6107 Acc 0.3082
# Time taken for 1 epoch 12.52988052368164 sec
#
# Epoch 85 Loss 1.6055 Acc 0.3092
# Time taken for 1 epoch 12.54655408859253 sec
#
# Epoch 86 Loss 1.6057 Acc 0.3093
# Time taken for 1 epoch 12.503178834915161 sec
#
# Epoch 87 Loss 1.6055 Acc 0.3092
# Time taken for 1 epoch 12.472445726394653 sec
#
# Epoch 88 Loss 1.6093 Acc 0.3085
# Time taken for 1 epoch 12.556754112243652 sec
#
# Epoch 89 Loss 1.6095 Acc 0.3083
# Time taken for 1 epoch 12.508225917816162 sec
#
# Epoch 90 Loss 1.6079 Acc 0.3090
# Time taken for 1 epoch 12.52934980392456 sec
#
# Epoch 91 Loss 1.6091 Acc 0.3085
# Time taken for 1 epoch 12.527689695358276 sec
#
# Epoch 92 Loss 1.6104 Acc 0.3080
# Time taken for 1 epoch 12.488383293151855 sec
#
# Epoch 93 Loss 1.6069 Acc 0.3091
# Time taken for 1 epoch 12.491657495498657 sec
#
# Epoch 94 Loss 1.6034 Acc 0.3099
# Time taken for 1 epoch 12.576435089111328 sec
#
# Epoch 95 Loss 1.6009 Acc 0.3105
# Time taken for 1 epoch 12.51319432258606 sec
#
# Epoch 96 Loss 1.6090 Acc 0.3081
# Time taken for 1 epoch 12.51785945892334 sec
#
# Epoch 97 Loss 1.6065 Acc 0.3089
# Time taken for 1 epoch 12.539129495620728 sec
#
# Epoch 98 Loss 1.6016 Acc 0.3105
# Time taken for 1 epoch 12.501239776611328 sec
#
# Epoch 99 Loss 1.6018 Acc 0.3105
# Time taken for 1 epoch 12.522696733474731 sec
#
# Epoch 100 Loss 1.6003 Acc 0.3106
# Time taken for 1 epoch 12.529531478881836 sec

# %%
val_total_loss = 0
val_total_acc = 0
val_steps_per_epoch = 0
for x, y in validation_dataset:
    val_batch_loss, val_batch_acc = val_step(x, y)
    val_total_loss += val_batch_loss
    val_total_acc += val_batch_acc
    val_steps_per_epoch += 1
print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
# Out:
# Validation Loss 1.8856 Acc 0.2406

# %%
plt.plot(loss_history)

# %%
checkpoint.save(checkpoint_prefix)
np.save("experiments/00_BDLSTM_simple_naive/loss_history.npy", np.array(loss_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
TEST_OUTPUT_DIR = "experiments/00_BDLSTM_simple_naive/"
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_irealpro.mid")

test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=TEST_OUTPUT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=TEST_OUTPUT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=TEST_OUTPUT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 488 to (2, 1024, 43)
# 1/1 [==============================] - 0s 33ms/step
# (1560, 53)
# (1712, 43) pad by 336 to (2, 1024, 43)
# 1/1 [==============================] - 0s 34ms/step
# (1712, 53)
# (3731, 43) pad by 365 to (4, 1024, 43)
# 1/1 [==============================] - 0s 34ms/step
# (3731, 53)
# (3137, 43) pad by 959 to (4, 1024, 43)
# 1/1 [==============================] - 0s 35ms/step
# (3137, 53)
# (1536, 43) pad by 512 to (2, 1024, 43)
# 1/1 [==============================] - 0s 34ms/step
# (1536, 53)
