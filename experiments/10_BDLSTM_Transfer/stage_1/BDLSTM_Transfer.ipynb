# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-17 16:45:43.431873: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 16:45:44.004377: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 16:45:44.004459: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 16:45:44.004466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
EXPERIMENT_DIR = "experiments/10_BDLSTM_Transfer/"

BATCH_SIZE = 512
PIECE_LEN = 128
n_feature = 43
n_hidden = 50
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/irealpro_dataset_v2_simple/")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")
# Out:
# 2023-01-17 12:22:12.825138: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:12.841414: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:12.841983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:12.868041: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 12:22:12.881622: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:12.882207: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:12.882703: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:16.118067: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:16.134050: I tensorflow/compiler/xla/stream_executo
# WARNING:tensorflow:From /media/labhdd/cyc/miniconda3/envs/p3-10/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# r/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:16.134516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:22:16.140585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 43)]         0
#
#  mask (Masking)              (None, 128, 43)           0
#
#  input (TimeDistributed)     (None, 128, 50)           2200
#
#  bidirectional (Bidirectiona  (None, 128, 100)         40400
#  l)
#
#  output (TimeDistributed)    (None, 128, 53)           5353
#
# =================================================================
# Total params: 47,953
# Trainable params: 47,953
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/10_BDLSTM_Transfer'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# 2023-01-17 12:23:32.640653: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_20/output/_23'
# 2023-01-17 12:23:33.761541: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-01-17 12:23:34.561555: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7ff12c05b260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-17 12:23:34.561650: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-01-17 12:23:34.988776: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-17 12:23:37.226461: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:37.259048: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2023-01-17 12:23:37.259087: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-01-17 12:23:37.260419: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-01-17 12:23:37.479999: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:37.635274: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:37.738792: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:37.902858: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:38.008938: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:38.195509: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:38.319876: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:38.466845: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:23:38.636372: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# Epoch 1 Loss 3.1038 Acc 0.1441
# Validation Loss 3.6722 Acc 0.1571
# Time taken for 1 epoch 89.49628806114197 sec
#
# Epoch 2 Loss 2.6133 Acc 0.2332
# Validation Loss 3.5860 Acc 0.1611
# Time taken for 1 epoch 4.287164688110352 sec
#
# Epoch 3 Loss 2.4900 Acc 0.2579
# Validation Loss 3.5445 Acc 0.1620
# Time taken for 1 epoch 4.390483856201172 sec
#
# Epoch 4 Loss 2.4251 Acc 0.2721
# Validation Loss 3.5328 Acc 0.1623
# Time taken for 1 epoch 4.278323411941528 sec
#
# Epoch 5 Loss 2.3825 Acc 0.2815
# Validation Loss 3.5319 Acc 0.1617
# Time taken for 1 epoch 4.367275953292847 sec
#
# Epoch 6 Loss 2.3489 Acc 0.2890
# Validation Loss 3.5418 Acc 0.1615
# Time taken for 1 epoch 4.307679653167725 sec
#
# Epoch 7 Loss 2.3196 Acc 0.2964
# Validation Loss 3.5472 Acc 0.1609
# Time taken for 1 epoch 4.471257209777832 sec
#
# Epoch 8 Loss 2.2921 Acc 0.3034
# Validation Loss 3.5569 Acc 0.1610
# Time taken for 1 epoch 4.398480415344238 sec
#
# Epoch 9 Loss 2.2634 Acc 0.3113
# Validation Loss 3.5656 Acc 0.1611
# Time taken for 1 epoch 4.4459991455078125 sec
#
# Epoch 10 Loss 2.2379 Acc 0.3178
# Validation Loss 3.5724 Acc 0.1609
# Time taken for 1 epoch 4.362157821655273 sec
#
# Epoch 11 Loss 2.2178 Acc 0.3229
# Validation Loss 3.5851 Acc 0.1604
# Time taken for 1 epoch 4.370899200439453 sec
#
# Epoch 12 Loss 2.2011 Acc 0.3271
# Validation Loss 3.5879 Acc 0.1591
# Time taken for 1 epoch 4.343308925628662 sec
#
# Epoch 13 Loss 2.1855 Acc 0.3306
# Validation Loss 3.5979 Acc 0.1583
# Time taken for 1 epoch 4.4098968505859375 sec
#
# Epoch 14 Loss 2.1719 Acc 0.3338
# Validation Loss 3.6047 Acc 0.1589
# Time taken for 1 epoch 4.382004976272583 sec
#
# Epoch 15 Loss 2.1604 Acc 0.3364
# Validation Loss 3.6074 Acc 0.1591
# Time taken for 1 epoch 4.314901828765869 sec
#
# Epoch 16 Loss 2.1503 Acc 0.3387
# Validation Loss 3.6088 Acc 0.1607
# Time taken for 1 epoch 4.311125755310059 sec
#
# Epoch 17 Loss 2.1413 Acc 0.3410
# Validation Loss 3.6165 Acc 0.1603
# Time taken for 1 epoch 4.316852331161499 sec
#
# Epoch 18 Loss 2.1319 Acc 0.3431
# Validation Loss 3.6025 Acc 0.1611
# Time taken for 1 epoch 4.381203651428223 sec
#
# Epoch 19 Loss 2.1233 Acc 0.3453
# Validation Loss 3.6184 Acc 0.1603
# Time taken for 1 epoch 4.371068954467773 sec
#
# Epoch 20 Loss 2.1156 Acc 0.3470
# Validation Loss 3.6263 Acc 0.1605
# Time taken for 1 epoch 4.325850248336792 sec
#
# Epoch 21 Loss 2.1087 Acc 0.3484
# Validation Loss 3.6150 Acc 0.1615
# Time taken for 1 epoch 4.323944807052612 sec
#
# Epoch 22 Loss 2.1024 Acc 0.3497
# Validation Loss 3.6216 Acc 0.1628
# Time taken for 1 epoch 4.344088315963745 sec
#
# Epoch 23 Loss 2.0965 Acc 0.3510
# Validation Loss 3.6271 Acc 0.1642
# Time taken for 1 epoch 4.363275527954102 sec
#
# Epoch 24 Loss 2.0910 Acc 0.3522
# Validation Loss 3.6315 Acc 0.1669
# Time taken for 1 epoch 4.334144115447998 sec
#
# Epoch 25 Loss 2.0862 Acc 0.3533
# Validation Loss 3.6316 Acc 0.1702
# Time taken for 1 epoch 4.393910646438599 sec
#
# Epoch 26 Loss 2.0815 Acc 0.3543
# Validation Loss 3.6379 Acc 0.1697
# Time taken for 1 epoch 4.345803737640381 sec
#
# Epoch 27 Loss 2.0770 Acc 0.3554
# Validation Loss 3.6467 Acc 0.1706
# Time taken for 1 epoch 4.285398483276367 sec
#
# Epoch 28 Loss 2.0723 Acc 0.3563
# Validation Loss 3.6472 Acc 0.1713
# Time taken for 1 epoch 4.423431396484375 sec
#
# Epoch 29 Loss 2.0685 Acc 0.3571
# Validation Loss 3.6525 Acc 0.1708
# Time taken for 1 epoch 4.304024696350098 sec
#
# Epoch 30 Loss 2.0638 Acc 0.3579
# Validation Loss 3.6555 Acc 0.1720
# Time taken for 1 epoch 4.387542963027954 sec
#
# Epoch 31 Loss 2.0596 Acc 0.3586
# Validation Loss 3.6582 Acc 0.1723
# Time taken for 1 epoch 4.3604066371917725 sec
#
# Epoch 32 Loss 2.0562 Acc 0.3592
# Validation Loss 3.6623 Acc 0.1726
# Time taken for 1 epoch 4.45157265663147 sec
#
# Epoch 33 Loss 2.0524 Acc 0.3599
# Validation Loss 3.6646 Acc 0.1731
# Time taken for 1 epoch 4.325554609298706 sec
#
# Epoch 34 Loss 2.0490 Acc 0.3604
# Validation Loss 3.6592 Acc 0.1749
# Time taken for 1 epoch 4.392910957336426 sec
#
# Epoch 35 Loss 2.0454 Acc 0.3610
# Validation Loss 3.6736 Acc 0.1725
# Time taken for 1 epoch 4.4555816650390625 sec
#
# Epoch 36 Loss 2.0426 Acc 0.3616
# Validation Loss 3.6692 Acc 0.1733
# Time taken for 1 epoch 4.4491868019104 sec
#
# Epoch 37 Loss 2.0398 Acc 0.3620
# Validation Loss 3.6673 Acc 0.1738
# Time taken for 1 epoch 4.334299564361572 sec
#
# Epoch 38 Loss 2.0361 Acc 0.3627
# Validation Loss 3.6718 Acc 0.1735
# Time taken for 1 epoch 4.250743865966797 sec
#
# Epoch 39 Loss 2.0332 Acc 0.3633
# Validation Loss 3.6663 Acc 0.1732
# Time taken for 1 epoch 4.333015203475952 sec
#
# Epoch 40 Loss 2.0311 Acc 0.3635
# Validation Loss 3.6773 Acc 0.1728
# Time taken for 1 epoch 4.384612321853638 sec
#
# Epoch 41 Loss 2.0281 Acc 0.3642
# Validation Loss 3.6634 Acc 0.1735
# Time taken for 1 epoch 4.3243958950042725 sec
#
# Epoch 42 Loss 2.0257 Acc 0.3646
# Validation Loss 3.6612 Acc 0.1732
# Time taken for 1 epoch 4.376429319381714 sec
#
# Epoch 43 Loss 2.0238 Acc 0.3649
# Validation Loss 3.6608 Acc 0.1725
# Time taken for 1 epoch 4.282597780227661 sec
#
# Epoch 44 Loss 2.0222 Acc 0.3651
# Validation Loss 3.6480 Acc 0.1731
# Time taken for 1 epoch 4.416923999786377 sec
#
# Epoch 45 Loss 2.0192 Acc 0.3659
# Validation Loss 3.6551 Acc 0.1729
# Time taken for 1 epoch 4.368170976638794 sec
#
# Epoch 46 Loss 2.0172 Acc 0.3661
# Validation Loss 3.6598 Acc 0.1728
# Time taken for 1 epoch 4.2616188526153564 sec
#
# Epoch 47 Loss 2.0148 Acc 0.3667
# Validation Loss 3.6624 Acc 0.1728
# Time taken for 1 epoch 4.2936766147613525 sec
#
# Epoch 48 Loss 2.0132 Acc 0.3669
# Validation Loss 3.6621 Acc 0.1724
# Time taken for 1 epoch 4.401792049407959 sec
#
# Epoch 49 Loss 2.0116 Acc 0.3672
# Validation Loss 3.6707 Acc 0.1704
# Time taken for 1 epoch 4.046494722366333 sec
#
# Epoch 50 Loss 2.0139 Acc 0.3667
# Validation Loss 3.6510 Acc 0.1735
# Time taken for 1 epoch 4.033163070678711 sec
#
# Epoch 51 Loss 2.0081 Acc 0.3676
# Validation Loss 3.6555 Acc 0.1740
# Time taken for 1 epoch 4.049596071243286 sec
#
# Epoch 52 Loss 2.0052 Acc 0.3683
# Validation Loss 3.6626 Acc 0.1728
# Time taken for 1 epoch 4.42989706993103 sec
#
# Epoch 53 Loss 2.0034 Acc 0.3684
# Validation Loss 3.6687 Acc 0.1722
# Time taken for 1 epoch 4.385756015777588 sec
#
# Epoch 54 Loss 2.0011 Acc 0.3689
# Validation Loss 3.6595 Acc 0.1712
# Time taken for 1 epoch 4.321885824203491 sec
#
# Epoch 55 Loss 1.9994 Acc 0.3691
# Validation Loss 3.6641 Acc 0.1727
# Time taken for 1 epoch 4.298125982284546 sec
#
# Epoch 56 Loss 1.9973 Acc 0.3695
# Validation Loss 3.6602 Acc 0.1723
# Time taken for 1 epoch 4.264241933822632 sec
#
# Epoch 57 Loss 1.9957 Acc 0.3696
# Validation Loss 3.6657 Acc 0.1724
# Time taken for 1 epoch 4.510045528411865 sec
#
# Epoch 58 Loss 1.9935 Acc 0.3702
# Validation Loss 3.6525 Acc 0.1738
# Time taken for 1 epoch 4.306330442428589 sec
#
# Epoch 59 Loss 1.9914 Acc 0.3705
# Validation Loss 3.6807 Acc 0.1719
# Time taken for 1 epoch 4.399750471115112 sec
#
# Epoch 60 Loss 1.9918 Acc 0.3703
# Validation Loss 3.6534 Acc 0.1738
# Time taken for 1 epoch 4.299729347229004 sec
#
# Epoch 61 Loss 1.9889 Acc 0.3709
# Validation Loss 3.6556 Acc 0.1734
# Time taken for 1 epoch 4.301474332809448 sec
#
# Epoch 62 Loss 1.9901 Acc 0.3703
# Validation Loss 3.6509 Acc 0.1752
# Time taken for 1 epoch 4.338531732559204 sec
#
# Epoch 63 Loss 1.9860 Acc 0.3711
# Validation Loss 3.6816 Acc 0.1713
# Time taken for 1 epoch 4.357113361358643 sec
#
# Epoch 64 Loss 1.9831 Acc 0.3716
# Validation Loss 3.6652 Acc 0.1739
# Time taken for 1 epoch 4.420007228851318 sec
#
# Epoch 65 Loss 1.9809 Acc 0.3722
# Validation Loss 3.6757 Acc 0.1723
# Time taken for 1 epoch 4.348956823348999 sec
#
# Epoch 66 Loss 1.9793 Acc 0.3724
# Validation Loss 3.6696 Acc 0.1736
# Time taken for 1 epoch 4.527917861938477 sec
#
# Epoch 67 Loss 1.9771 Acc 0.3729
# Validation Loss 3.6705 Acc 0.1739
# Time taken for 1 epoch 4.4272990226745605 sec
#
# Epoch 68 Loss 1.9770 Acc 0.3726
# Validation Loss 3.6680 Acc 0.1737
# Time taken for 1 epoch 4.376741170883179 sec
#
# Epoch 69 Loss 1.9756 Acc 0.3729
# Validation Loss 3.6687 Acc 0.1743
# Time taken for 1 epoch 4.399771213531494 sec
#
# Epoch 70 Loss 1.9730 Acc 0.3735
# Validation Loss 3.6727 Acc 0.1737
# Time taken for 1 epoch 4.2746922969818115 sec
#
# Epoch 71 Loss 1.9713 Acc 0.3737
# Validation Loss 3.6709 Acc 0.1736
# Time taken for 1 epoch 4.44951605796814 sec
#
# Epoch 72 Loss 1.9695 Acc 0.3742
# Validation Loss 3.6718 Acc 0.1737
# Time taken for 1 epoch 4.349124431610107 sec
#
# Epoch 73 Loss 1.9682 Acc 0.3743
# Validation Loss 3.6776 Acc 0.1737
# Time taken for 1 epoch 4.406352281570435 sec
#
# Epoch 74 Loss 1.9677 Acc 0.3743
# Validation Loss 3.6846 Acc 0.1729
# Time taken for 1 epoch 4.27173924446106 sec
#
# Epoch 75 Loss 2.0239 Acc 0.3615
# Validation Loss 3.6425 Acc 0.1734
# Time taken for 1 epoch 4.443455696105957 sec
#
# Epoch 76 Loss 1.9968 Acc 0.3677
# Validation Loss 3.6580 Acc 0.1739
# Time taken for 1 epoch 4.452453851699829 sec
#
# Epoch 77 Loss 1.9782 Acc 0.3719
# Validation Loss 3.6734 Acc 0.1720
# Time taken for 1 epoch 4.363240003585815 sec
#
# Epoch 78 Loss 1.9706 Acc 0.3734
# Validation Loss 3.6630 Acc 0.1757
# Time taken for 1 epoch 4.3697755336761475 sec
#
# Epoch 79 Loss 1.9664 Acc 0.3743
# Validation Loss 3.6625 Acc 0.1753
# Time taken for 1 epoch 4.429682731628418 sec
#
# Epoch 80 Loss 1.9631 Acc 0.3751
# Validation Loss 3.6733 Acc 0.1747
# Time taken for 1 epoch 4.293620824813843 sec
#
# Epoch 81 Loss 1.9607 Acc 0.3756
# Validation Loss 3.6697 Acc 0.1751
# Time taken for 1 epoch 4.381844520568848 sec
#
# Epoch 82 Loss 1.9585 Acc 0.3761
# Validation Loss 3.6845 Acc 0.1735
# Time taken for 1 epoch 4.381048202514648 sec
#
# Epoch 83 Loss 1.9569 Acc 0.3763
# Validation Loss 3.6872 Acc 0.1730
# Time taken for 1 epoch 4.334123849868774 sec
#
# Epoch 84 Loss 1.9557 Acc 0.3766
# Validation Loss 3.6826 Acc 0.1741
# Time taken for 1 epoch 4.418604135513306 sec
#
# Epoch 85 Loss 1.9544 Acc 0.3769
# Validation Loss 3.6828 Acc 0.1736
# Time taken for 1 epoch 4.358929395675659 sec
#
# Epoch 86 Loss 1.9532 Acc 0.3771
# Validation Loss 3.6853 Acc 0.1733
# Time taken for 1 epoch 4.335172891616821 sec
#
# Epoch 87 Loss 1.9524 Acc 0.3773
# Validation Loss 3.6896 Acc 0.1718
# Time taken for 1 epoch 4.431441307067871 sec
#
# Epoch 88 Loss 1.9511 Acc 0.3776
# Validation Loss 3.6908 Acc 0.1721
# Time taken for 1 epoch 4.44627571105957 sec
#
# Epoch 89 Loss 1.9499 Acc 0.3779
# Validation Loss 3.6831 Acc 0.1743
# Time taken for 1 epoch 4.419419288635254 sec
#
# Epoch 90 Loss 1.9486 Acc 0.3782
# Validation Loss 3.6837 Acc 0.1738
# Time taken for 1 epoch 4.383865833282471 sec
#
# Epoch 91 Loss 1.9471 Acc 0.3784
# Validation Loss 3.6948 Acc 0.1730
# Time taken for 1 epoch 4.405156850814819 sec
#
# Epoch 92 Loss 1.9470 Acc 0.3786
# Validation Loss 3.6850 Acc 0.1741
# Time taken for 1 epoch 4.402179956436157 sec
#
# Epoch 93 Loss 1.9450 Acc 0.3789
# Validation Loss 3.6812 Acc 0.1749
# Time taken for 1 epoch 4.317402362823486 sec
#
# Epoch 94 Loss 1.9443 Acc 0.3791
# Validation Loss 3.6854 Acc 0.1746
# Time taken for 1 epoch 4.415963649749756 sec
#
# Epoch 95 Loss 1.9437 Acc 0.3792
# Validation Loss 3.6808 Acc 0.1747
# Time taken for 1 epoch 4.392836093902588 sec
#
# Epoch 96 Loss 1.9428 Acc 0.3794
# Validation Loss 3.6920 Acc 0.1724
# Time taken for 1 epoch 4.41461443901062 sec
#
# Epoch 97 Loss 1.9422 Acc 0.3795
# Validation Loss 3.6819 Acc 0.1739
# Time taken for 1 epoch 4.430266857147217 sec
#
# Epoch 98 Loss 1.9408 Acc 0.3797
# Validation Loss 3.6916 Acc 0.1732
# Time taken for 1 epoch 4.389342784881592 sec
#
# Epoch 99 Loss 1.9402 Acc 0.3799
# Validation Loss 3.6832 Acc 0.1746
# Time taken for 1 epoch 4.342965364456177 sec
#
# Epoch 100 Loss 1.9392 Acc 0.3801
# Validation Loss 3.6772 Acc 0.1756
# Time taken for 1 epoch 4.344122409820557 sec

# %% [markdown]
# 23m 30.6s used

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 104 to (13, 128, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 80 to (14, 128, 43)
# 1/1 [==============================] - 0s 16ms/step
# (1712, 53)
# (3731, 43) pad by 109 to (30, 128, 43)
# 1/1 [==============================] - 0s 17ms/step
# (3731, 53)
# (3137, 43) pad by 63 to (25, 128, 43)
# 1/1 [==============================] - 0s 17ms/step
# (3137, 53)
# (1536, 43) to (12, 128, 43)
# 1/1 [==============================] - 0s 16ms/step
# (1536, 53)
