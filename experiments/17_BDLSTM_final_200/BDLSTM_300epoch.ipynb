# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Masking, Bidirectional, LSTM, TimeDistributed, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import L2

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-19 22:30:25.816169: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
EXPERIMENT_TITLE = "18_BDLSTM_final_500/"
EXPERIMENT_DIR = "experiments/" + EXPERIMENT_TITLE

BATCH_SIZE = 512
PIECE_LEN = 128
n_feature = 43
n_hidden = 200
n_pitch = 53
learning_rate = 0.001

# %% [markdown]
# ## build dataset

# %%
def load_npy_data(x_path, y_path, offset):
    x = np.load(x_path)
    y = np.load(y_path)
    if x.shape[0] >= offset+PIECE_LEN:
        return x[offset:offset+PIECE_LEN].astype(np.float64), y[offset:offset+PIECE_LEN].astype(np.float64)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        x = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        y = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float64)
        return x, y

def generate_dataset(input_dir: str):
    x_paths = []
    y_paths = []
    offsets = []
    for file_name in sorted(os.listdir(input_dir)):
        if file_name.endswith(".ans.npy"):
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name.replace(".ans.npy", ".npy")))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    
    train_dataset = tf.data.Dataset.from_tensor_slices((x_paths, y_paths, offsets)).shuffle(100000)
    train_dataset = train_dataset.map(lambda x_path, y_path, offset: tf.numpy_function(load_npy_data, [x_path, y_path, offset], [tf.float64, tf.float64]))
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(-1).cache()
    
    return train_dataset

# %%
# train_dataset = generate_dataset("./preprocessed_dataset/irealpro_dataset_v2_simple/")
train_dataset = generate_dataset("preprocessed_dataset/augmentation_v2_simple")
validation_dataset = generate_dataset("preprocessed_dataset/midkar_v2_simple")

# %% [markdown]
# ## build model

# %%
# print("Creating model")
input = tf.keras.Input(shape=(PIECE_LEN, n_feature))  
x = Masking(mask_value=-1, input_shape=(PIECE_LEN, n_feature), name="mask")(input) # Ignore Padded Data
x = TimeDistributed(Dense(n_hidden, activation="relu", input_shape=(1, n_feature), kernel_regularizer=L2(0.001)), name="input")(x)
x = Bidirectional(tf.keras.layers.LSTM(units=n_hidden, input_shape=(1, n_feature), return_sequences=True, kernel_regularizer=L2(0.0001), recurrent_regularizer=L2(0.0001)))(x)
x = TimeDistributed(Dense(n_pitch, activation="softmax", kernel_regularizer=L2(0.001)), name="output")(x)
model = tf.keras.Model(inputs=input, outputs=x)
print(model.summary())
optimizer=tf.keras.optimizers.experimental.Nadam(learning_rate=learning_rate)
# optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 43)]         0
#
#  mask (Masking)              (None, 128, 43)           0
#
#  input (TimeDistributed)     (None, 128, 200)          8800
#
#  bidirectional_1 (Bidirectio  (None, 128, 400)         641600
#  nal)
#
#  output (TimeDistributed)    (None, 128, 53)           21253
#
# =================================================================
# Total params: 671,653
# Trainable params: 671,653
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## loss/accuracy function

# %%
@tf.function
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    loss = tf.losses.categorical_crossentropy(y_true, y_pred)
    mask = tf.cast(mask, loss.dtype)
    loss *= mask
    return tf.reduce_mean(loss)

@tf.function
def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true, axis=2), -1*n_pitch)
    acc = tf.metrics.categorical_accuracy(y_true, y_pred)
    mask = tf.cast(mask, acc.dtype)
    acc *= mask
    return tf.reduce_mean(acc)

# %% [markdown]
# ### restore checkpoint

# %%
checkpoint_dir = './checkpoints/' + EXPERIMENT_TITLE
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model=model)

# %%
# checkpoint.restore(checkpoint_prefix+"-2")

# %% [markdown]
# ## training

# %%
@tf.function
def train_step(x, y):
    loss = 0
    with tf.GradientTape() as tape:
        pred = model(x)
        
        loss = masked_loss_function(y, pred)
        weight_decay = tf.reduce_sum(model.losses)
        loss += weight_decay

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [(tf.clip_by_value(grad, clip_value_min=-1.0, clip_value_max=1.0)) for grad in gradients]

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    acc = masked_accuracy(y, pred)

    return loss, acc

# %%
@tf.function
def val_step(x, y):
    pred = model(x)
    loss = masked_loss_function(y, pred)
    weight_decay = tf.reduce_sum(model.losses)
    loss += weight_decay
    acc = masked_accuracy(y, pred)
    return loss, acc

# %%
loss_history = []
val_loss_history = []
acc_history = []
val_acc_history = []
# loss_history = np.load(EXPERIMENT_DIR+"/loss_history.npy")
# acc_history = np.load(EXPERIMENT_DIR+"/acc_history.npy")
# val_loss_history = np.load(EXPERIMENT_DIR+"/val_loss_history.npy")
# val_acc_history = np.load(EXPERIMENT_DIR+"/val_acc_history.npy")
# loss_history = np.load("experiments/BDLSTM_simple/history.npy").tolist()

# %%
# set the epochs for training
EPOCHS = 300

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    total_loss = 0
    total_acc = 0
    steps_per_epoch = 0
    val_total_loss = 0
    val_total_acc = 0
    val_steps_per_epoch = 0

    for x, y in train_dataset:
        batch_loss, batch_acc = train_step(x, y)
        total_loss += batch_loss
        total_acc += batch_acc
        steps_per_epoch += 1
    
    for x, y in validation_dataset:
        val_batch_loss, val_batch_acc = val_step(x, y)
        val_total_loss += val_batch_loss
        val_total_acc += val_batch_acc
        val_steps_per_epoch += 1
    
    print(f'Epoch {epoch+1} Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
    print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    loss_history.append(float(total_loss / steps_per_epoch))
    acc_history.append(float(total_acc / steps_per_epoch))
    val_loss_history.append(float(val_total_loss / val_steps_per_epoch))
    val_acc_history.append(float(val_total_acc / val_steps_per_epoch))

    if (epoch+1) % 100 == 0:
        checkpoint.save(checkpoint_prefix)
# Out:
# 2023-01-19 02:46:06.656483: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_20/output/_23'
# 2023-01-19 02:46:07.095494: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-01-19 02:46:07.576005: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f7ab8002be0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-19 02:46:07.576034: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-01-19 02:46:07.609695: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-19 02:46:07.877740: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:07.911877: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2023-01-19 02:46:07.911909: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-01-19 02:46:07.913103: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-01-19 02:46:08.092574: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:08.266575: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:08.449051: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:08.611529: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:08.762784: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:08.904323: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:09.004493: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:09.127185: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-19 02:46:09.230061: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# Epoch 1 Loss 2.6435 Acc 0.2664
# Validation Loss 2.5692 Acc 0.2584
# Time taken for 1 epoch 262.9879484176636 sec
#
# Epoch 2 Loss 2.4762 Acc 0.2824
# Validation Loss 2.5082 Acc 0.2661
# Time taken for 1 epoch 24.377968788146973 sec
#
# Epoch 3 Loss 2.4233 Acc 0.2917
# Validation Loss 2.4519 Acc 0.2800
# Time taken for 1 epoch 24.404058933258057 sec
#
# Epoch 4 Loss 2.3859 Acc 0.3014
# Validation Loss 2.4192 Acc 0.2875
# Time taken for 1 epoch 24.519403219223022 sec
#
# Epoch 5 Loss 2.3519 Acc 0.3102
# Validation Loss 2.3854 Acc 0.2973
# Time taken for 1 epoch 24.559274196624756 sec
#
# Epoch 6 Loss 2.3268 Acc 0.3174
# Validation Loss 2.4045 Acc 0.2935
# Time taken for 1 epoch 24.654146909713745 sec
#
# Epoch 7 Loss 2.2925 Acc 0.3269
# Validation Loss 2.3515 Acc 0.3043
# Time taken for 1 epoch 24.88696026802063 sec
#
# Epoch 8 Loss 2.2766 Acc 0.3314
# Validation Loss 2.3486 Acc 0.3048
# Time taken for 1 epoch 24.699944257736206 sec
#
# Epoch 9 Loss 2.2661 Acc 0.3340
# Validation Loss 2.3422 Acc 0.3066
# Time taken for 1 epoch 24.770674228668213 sec
#
# Epoch 10 Loss 2.2603 Acc 0.3355
# Validation Loss 2.3539 Acc 0.3037
# Time taken for 1 epoch 24.717419624328613 sec
#
# Epoch 11 Loss 2.2540 Acc 0.3376
# Validation Loss 2.3476 Acc 0.3050
# Time taken for 1 epoch 24.726165294647217 sec
#
# Epoch 12 Loss 2.2539 Acc 0.3375
# Validation Loss 2.3349 Acc 0.3086
# Time taken for 1 epoch 24.682862997055054 sec
#
# Epoch 13 Loss 2.2722 Acc 0.3327
# Validation Loss 2.3378 Acc 0.3088
# Time taken for 1 epoch 24.667343854904175 sec
#
# Epoch 14 Loss 2.2581 Acc 0.3369
# Validation Loss 2.3866 Acc 0.2951
# Time taken for 1 epoch 24.93838858604431 sec
#
# Epoch 15 Loss 2.2351 Acc 0.3431
# Validation Loss 2.3326 Acc 0.3089
# Time taken for 1 epoch 24.783666133880615 sec
#
# Epoch 16 Loss 2.2239 Acc 0.3458
# Validation Loss 2.3300 Acc 0.3092
# Time taken for 1 epoch 24.720035076141357 sec
#
# Epoch 17 Loss 2.2353 Acc 0.3423
# Validation Loss 2.3294 Acc 0.3098
# Time taken for 1 epoch 24.68307328224182 sec
#
# Epoch 18 Loss 2.2262 Acc 0.3454
# Validation Loss 2.3310 Acc 0.3097
# Time taken for 1 epoch 24.70927906036377 sec
#
# Epoch 19 Loss 2.2183 Acc 0.3476
# Validation Loss 2.3268 Acc 0.3118
# Time taken for 1 epoch 24.709023237228394 sec
#
# Epoch 20 Loss 2.2174 Acc 0.3481
# Validation Loss 2.3299 Acc 0.3093
# Time taken for 1 epoch 24.814882040023804 sec
#
# Epoch 21 Loss 2.2840 Acc 0.3300
# Validation Loss 2.3529 Acc 0.3057
# Time taken for 1 epoch 24.6911838054657 sec
#
# Epoch 22 Loss 2.2192 Acc 0.3482
# Validation Loss 2.3310 Acc 0.3114
# Time taken for 1 epoch 24.671075105667114 sec
#
# Epoch 23 Loss 2.2057 Acc 0.3524
# Validation Loss 2.3318 Acc 0.3104
# Time taken for 1 epoch 24.672513961791992 sec
#
# Epoch 24 Loss 2.2174 Acc 0.3494
# Validation Loss 2.3325 Acc 0.3120
# Time taken for 1 epoch 24.674354791641235 sec
#
# Epoch 25 Loss 2.1953 Acc 0.3555
# Validation Loss 2.3265 Acc 0.3134
# Time taken for 1 epoch 24.779868602752686 sec
#
# Epoch 26 Loss 2.2058 Acc 0.3527
# Validation Loss 2.3280 Acc 0.3116
# Time taken for 1 epoch 24.740883350372314 sec
#
# Epoch 27 Loss 2.1964 Acc 0.3555
# Validation Loss 2.3315 Acc 0.3120
# Time taken for 1 epoch 24.6803617477417 sec
#
# Epoch 28 Loss 2.1951 Acc 0.3560
# Validation Loss 2.3263 Acc 0.3129
# Time taken for 1 epoch 24.74577832221985 sec
#
# Epoch 29 Loss 2.2291 Acc 0.3464
# Validation Loss 2.3462 Acc 0.3090
# Time taken for 1 epoch 24.83632779121399 sec
#
# Epoch 30 Loss 2.1821 Acc 0.3604
# Validation Loss 2.3286 Acc 0.3125
# Time taken for 1 epoch 24.684900760650635 sec
#
# Epoch 31 Loss 2.1876 Acc 0.3591
# Validation Loss 2.3287 Acc 0.3133
# Time taken for 1 epoch 24.891136169433594 sec
#
# Epoch 32 Loss 2.1897 Acc 0.3582
# Validation Loss 2.3333 Acc 0.3111
# Time taken for 1 epoch 24.6675968170166 sec
#
# Epoch 33 Loss 2.1708 Acc 0.3640
# Validation Loss 2.3344 Acc 0.3133
# Time taken for 1 epoch 24.680691719055176 sec
#
# Epoch 34 Loss 2.1735 Acc 0.3634
# Validation Loss 2.3314 Acc 0.3134
# Time taken for 1 epoch 24.934519052505493 sec
#
# Epoch 35 Loss 2.1739 Acc 0.3635
# Validation Loss 2.3373 Acc 0.3118
# Time taken for 1 epoch 24.684303998947144 sec
#
# Epoch 36 Loss 2.1807 Acc 0.3619
# Validation Loss 2.3360 Acc 0.3139
# Time taken for 1 epoch 24.66904330253601 sec
#
# Epoch 37 Loss 2.1623 Acc 0.3673
# Validation Loss 2.3257 Acc 0.3175
# Time taken for 1 epoch 24.73624849319458 sec
#
# Epoch 38 Loss 2.1663 Acc 0.3663
# Validation Loss 2.3292 Acc 0.3159
# Time taken for 1 epoch 24.667528867721558 sec
#
# Epoch 39 Loss 2.1556 Acc 0.3694
# Validation Loss 2.3303 Acc 0.3156
# Time taken for 1 epoch 24.79166865348816 sec
#
# Epoch 40 Loss 2.1615 Acc 0.3679
# Validation Loss 2.3276 Acc 0.3171
# Time taken for 1 epoch 24.657644748687744 sec
#
# Epoch 41 Loss 2.1522 Acc 0.3711
# Validation Loss 2.3334 Acc 0.3167
# Time taken for 1 epoch 24.906531810760498 sec
#
# Epoch 42 Loss 2.1481 Acc 0.3726
# Validation Loss 2.3354 Acc 0.3156
# Time taken for 1 epoch 24.71133518218994 sec
#
# Epoch 43 Loss 2.1500 Acc 0.3720
# Validation Loss 2.3351 Acc 0.3162
# Time taken for 1 epoch 24.78502106666565 sec
#
# Epoch 44 Loss 2.1482 Acc 0.3728
# Validation Loss 2.3340 Acc 0.3190
# Time taken for 1 epoch 24.72595477104187 sec
#
# Epoch 45 Loss 2.1398 Acc 0.3759
# Validation Loss 2.3385 Acc 0.3170
# Time taken for 1 epoch 24.67514443397522 sec
#
# Epoch 46 Loss 2.1554 Acc 0.3708
# Validation Loss 2.3444 Acc 0.3146
# Time taken for 1 epoch 24.672866582870483 sec
#
# Epoch 47 Loss 2.1430 Acc 0.3746
# Validation Loss 2.3431 Acc 0.3167
# Time taken for 1 epoch 24.85043215751648 sec
#
# Epoch 48 Loss 2.1338 Acc 0.3780
# Validation Loss 2.3450 Acc 0.3144
# Time taken for 1 epoch 24.719079732894897 sec
#
# Epoch 49 Loss 2.1423 Acc 0.3752
# Validation Loss 2.3415 Acc 0.3167
# Time taken for 1 epoch 24.79267930984497 sec
#
# Epoch 50 Loss 2.1324 Acc 0.3784
# Validation Loss 2.3471 Acc 0.3168
# Time taken for 1 epoch 24.864212036132812 sec
#
# Epoch 51 Loss 2.1351 Acc 0.3779
# Validation Loss 2.3487 Acc 0.3156
# Time taken for 1 epoch 24.702969312667847 sec
#
# Epoch 52 Loss 2.1372 Acc 0.3773
# Validation Loss 2.3742 Acc 0.3099
# Time taken for 1 epoch 24.967307567596436 sec
#
# Epoch 53 Loss 2.1318 Acc 0.3796
# Validation Loss 2.3469 Acc 0.3167
# Time taken for 1 epoch 24.65248680114746 sec
#
# Epoch 54 Loss 2.1259 Acc 0.3815
# Validation Loss 2.3489 Acc 0.3170
# Time taken for 1 epoch 24.694021463394165 sec
#
# Epoch 55 Loss 2.1372 Acc 0.3781
# Validation Loss 2.3464 Acc 0.3192
# Time taken for 1 epoch 24.93546986579895 sec
#
# Epoch 56 Loss 2.1218 Acc 0.3831
# Validation Loss 2.3432 Acc 0.3186
# Time taken for 1 epoch 24.788239002227783 sec
#
# Epoch 57 Loss 2.1221 Acc 0.3831
# Validation Loss 2.3542 Acc 0.3160
# Time taken for 1 epoch 24.830021619796753 sec
#
# Epoch 58 Loss 2.1235 Acc 0.3828
# Validation Loss 2.3585 Acc 0.3159
# Time taken for 1 epoch 24.666522979736328 sec
#
# Epoch 59 Loss 2.1193 Acc 0.3843
# Validation Loss 2.3521 Acc 0.3183
# Time taken for 1 epoch 24.66551899909973 sec
#
# Epoch 60 Loss 2.1209 Acc 0.3842
# Validation Loss 2.3565 Acc 0.3150
# Time taken for 1 epoch 24.94835901260376 sec
#
# Epoch 61 Loss 2.1211 Acc 0.3843
# Validation Loss 2.3590 Acc 0.3164
# Time taken for 1 epoch 24.820335149765015 sec
#
# Epoch 62 Loss 2.1196 Acc 0.3848
# Validation Loss 2.3532 Acc 0.3175
# Time taken for 1 epoch 24.765141010284424 sec
#
# Epoch 63 Loss 2.1402 Acc 0.3790
# Validation Loss 2.3665 Acc 0.3137
# Time taken for 1 epoch 24.69663429260254 sec
#
# Epoch 64 Loss 2.1148 Acc 0.3869
# Validation Loss 2.3690 Acc 0.3133
# Time taken for 1 epoch 24.88496732711792 sec
#
# Epoch 65 Loss 2.1121 Acc 0.3877
# Validation Loss 2.3722 Acc 0.3125
# Time taken for 1 epoch 24.671972513198853 sec
#
# Epoch 66 Loss 2.1109 Acc 0.3880
# Validation Loss 2.3980 Acc 0.3080
# Time taken for 1 epoch 24.689615964889526 sec
#
# Epoch 67 Loss 2.1114 Acc 0.3883
# Validation Loss 2.3590 Acc 0.3165
# Time taken for 1 epoch 24.675230741500854 sec
#
# Epoch 68 Loss 2.1064 Acc 0.3898
# Validation Loss 2.3597 Acc 0.3176
# Time taken for 1 epoch 24.736438512802124 sec
#
# Epoch 69 Loss 2.1050 Acc 0.3902
# Validation Loss 2.3585 Acc 0.3171
# Time taken for 1 epoch 24.71876883506775 sec
#
# Epoch 70 Loss 2.1047 Acc 0.3905
# Validation Loss 2.3648 Acc 0.3177
# Time taken for 1 epoch 24.86235523223877 sec
#
# Epoch 71 Loss 2.1030 Acc 0.3912
# Validation Loss 2.3614 Acc 0.3179
# Time taken for 1 epoch 24.690768718719482 sec
#
# Epoch 72 Loss 2.1029 Acc 0.3913
# Validation Loss 2.3694 Acc 0.3159
# Time taken for 1 epoch 24.678943395614624 sec
#
# Epoch 73 Loss 2.0993 Acc 0.3926
# Validation Loss 2.3677 Acc 0.3183
# Time taken for 1 epoch 24.671669244766235 sec
#
# Epoch 74 Loss 2.0973 Acc 0.3935
# Validation Loss 2.3694 Acc 0.3167
# Time taken for 1 epoch 24.88727045059204 sec
#
# Epoch 75 Loss 2.1175 Acc 0.3878
# Validation Loss 2.3765 Acc 0.3143
# Time taken for 1 epoch 24.84863829612732 sec
#
# Epoch 76 Loss 2.1062 Acc 0.3916
# Validation Loss 2.3723 Acc 0.3151
# Time taken for 1 epoch 24.828057289123535 sec
#
# Epoch 77 Loss 2.1035 Acc 0.3921
# Validation Loss 2.3771 Acc 0.3148
# Time taken for 1 epoch 24.868067979812622 sec
#
# Epoch 78 Loss 2.0969 Acc 0.3944
# Validation Loss 2.3895 Acc 0.3113
# Time taken for 1 epoch 24.665891885757446 sec
#
# Epoch 79 Loss 2.0952 Acc 0.3949
# Validation Loss 2.3741 Acc 0.3154
# Time taken for 1 epoch 24.80910634994507 sec
#
# Epoch 80 Loss 2.0938 Acc 0.3953
# Validation Loss 2.3778 Acc 0.3164
# Time taken for 1 epoch 24.750672817230225 sec
#
# Epoch 81 Loss 2.0919 Acc 0.3962
# Validation Loss 2.3792 Acc 0.3154
# Time taken for 1 epoch 24.69533658027649 sec
#
# Epoch 82 Loss 2.0903 Acc 0.3968
# Validation Loss 2.3842 Acc 0.3146
# Time taken for 1 epoch 24.82220149040222 sec
#
# Epoch 83 Loss 2.0981 Acc 0.3949
# Validation Loss 2.3767 Acc 0.3150
# Time taken for 1 epoch 24.816953659057617 sec
#
# Epoch 84 Loss 2.0898 Acc 0.3971
# Validation Loss 2.3742 Acc 0.3181
# Time taken for 1 epoch 24.8990638256073 sec
#
# Epoch 85 Loss 2.0887 Acc 0.3978
# Validation Loss 2.3833 Acc 0.3137
# Time taken for 1 epoch 24.8201425075531 sec
#
# Epoch 86 Loss 2.0857 Acc 0.3984
# Validation Loss 2.3783 Acc 0.3173
# Time taken for 1 epoch 24.742072343826294 sec
#
# Epoch 87 Loss 2.0873 Acc 0.3983
# Validation Loss 2.3780 Acc 0.3170
# Time taken for 1 epoch 24.672248601913452 sec
#
# Epoch 88 Loss 2.0870 Acc 0.3987
# Validation Loss 2.3940 Acc 0.3139
# Time taken for 1 epoch 24.774579286575317 sec
#
# Epoch 89 Loss 2.0867 Acc 0.3988
# Validation Loss 2.3887 Acc 0.3163
# Time taken for 1 epoch 24.67753529548645 sec
#
# Epoch 90 Loss 2.0815 Acc 0.4004
# Validation Loss 2.3888 Acc 0.3159
# Time taken for 1 epoch 24.894463300704956 sec
#
# Epoch 91 Loss 2.0818 Acc 0.4003
# Validation Loss 2.3887 Acc 0.3162
# Time taken for 1 epoch 24.65453815460205 sec
#
# Epoch 92 Loss 2.0816 Acc 0.4006
# Validation Loss 2.4114 Acc 0.3109
# Time taken for 1 epoch 24.690780639648438 sec
#
# Epoch 93 Loss 2.0777 Acc 0.4016
# Validation Loss 2.3908 Acc 0.3166
# Time taken for 1 epoch 24.691660404205322 sec
#
# Epoch 94 Loss 2.0785 Acc 0.4017
# Validation Loss 2.3888 Acc 0.3175
# Time taken for 1 epoch 24.652740716934204 sec
#
# Epoch 95 Loss 2.0774 Acc 0.4022
# Validation Loss 2.4010 Acc 0.3132
# Time taken for 1 epoch 24.680933713912964 sec
#
# Epoch 96 Loss 2.0797 Acc 0.4017
# Validation Loss 2.3925 Acc 0.3157
# Time taken for 1 epoch 24.67460012435913 sec
#
# Epoch 97 Loss 2.0766 Acc 0.4025
# Validation Loss 2.3930 Acc 0.3175
# Time taken for 1 epoch 24.882903337478638 sec
#
# Epoch 98 Loss 2.0759 Acc 0.4029
# Validation Loss 2.3844 Acc 0.3178
# Time taken for 1 epoch 24.667866706848145 sec
#
# Epoch 99 Loss 2.0758 Acc 0.4029
# Validation Loss 2.4074 Acc 0.3122
# Time taken for 1 epoch 24.675219297409058 sec
#
# Epoch 100 Loss 2.0784 Acc 0.4022
# Validation Loss 2.4057 Acc 0.3125
# Time taken for 1 epoch 24.67922019958496 sec
#
# Epoch 101 Loss 2.0757 Acc 0.4033
# Validation Loss 2.3854 Acc 0.3167
# Time taken for 1 epoch 24.714601755142212 sec
#
# Epoch 102 Loss 2.0753 Acc 0.4033
# Validation Loss 2.4131 Acc 0.3121
# Time taken for 1 epoch 24.685186862945557 sec
#
# Epoch 103 Loss 2.0728 Acc 0.4041
# Validation Loss 2.3849 Acc 0.3180
# Time taken for 1 epoch 24.73090100288391 sec
#
# Epoch 104 Loss 2.0717 Acc 0.4044
# Validation Loss 2.4122 Acc 0.3125
# Time taken for 1 epoch 24.815543174743652 sec
#
# Epoch 105 Loss 2.0702 Acc 0.4052
# Validation Loss 2.3977 Acc 0.3159
# Time taken for 1 epoch 24.799984455108643 sec
#
# Epoch 106 Loss 2.0702 Acc 0.4052
# Validation Loss 2.4043 Acc 0.3155
# Time taken for 1 epoch 24.87739658355713 sec
#
# Epoch 107 Loss 2.0699 Acc 0.4055
# Validation Loss 2.4206 Acc 0.3111
# Time taken for 1 epoch 24.672065496444702 sec
#
# Epoch 108 Loss 2.0712 Acc 0.4051
# Validation Loss 2.4196 Acc 0.3109
# Time taken for 1 epoch 24.871689319610596 sec
#
# Epoch 109 Loss 2.0844 Acc 0.4018
# Validation Loss 2.3922 Acc 0.3176
# Time taken for 1 epoch 24.677558660507202 sec
#
# Epoch 110 Loss 2.0706 Acc 0.4057
# Validation Loss 2.4168 Acc 0.3113
# Time taken for 1 epoch 24.78961443901062 sec
#
# Epoch 111 Loss 2.0692 Acc 0.4060
# Validation Loss 2.3938 Acc 0.3182
# Time taken for 1 epoch 24.88574743270874 sec
#
# Epoch 112 Loss 2.0699 Acc 0.4059
# Validation Loss 2.4268 Acc 0.3088
# Time taken for 1 epoch 24.66834306716919 sec
#
# Epoch 113 Loss 2.0662 Acc 0.4069
# Validation Loss 2.4101 Acc 0.3141
# Time taken for 1 epoch 24.68462562561035 sec
#
# Epoch 114 Loss 2.0649 Acc 0.4071
# Validation Loss 2.4025 Acc 0.3151
# Time taken for 1 epoch 24.66719341278076 sec
#
# Epoch 115 Loss 2.0658 Acc 0.4069
# Validation Loss 2.4249 Acc 0.3116
# Time taken for 1 epoch 24.81592631340027 sec
#
# Epoch 116 Loss 2.0699 Acc 0.4062
# Validation Loss 2.4023 Acc 0.3172
# Time taken for 1 epoch 24.823235511779785 sec
#
# Epoch 117 Loss 2.0658 Acc 0.4073
# Validation Loss 2.4056 Acc 0.3154
# Time taken for 1 epoch 24.707510232925415 sec
#
# Epoch 118 Loss 2.0650 Acc 0.4073
# Validation Loss 2.4106 Acc 0.3139
# Time taken for 1 epoch 24.73471474647522 sec
#
# Epoch 119 Loss 2.0624 Acc 0.4086
# Validation Loss 2.4212 Acc 0.3114
# Time taken for 1 epoch 24.780412435531616 sec
#
# Epoch 120 Loss 2.0645 Acc 0.4078
# Validation Loss 2.4160 Acc 0.3133
# Time taken for 1 epoch 24.8373920917511 sec
#
# Epoch 121 Loss 2.0616 Acc 0.4084
# Validation Loss 2.4142 Acc 0.3138
# Time taken for 1 epoch 24.781458377838135 sec
#
# Epoch 122 Loss 2.0615 Acc 0.4087
# Validation Loss 2.3994 Acc 0.3181
# Time taken for 1 epoch 24.75785493850708 sec
#
# Epoch 123 Loss 2.0613 Acc 0.4090
# Validation Loss 2.4099 Acc 0.3144
# Time taken for 1 epoch 24.67370915412903 sec
#
# Epoch 124 Loss 2.0599 Acc 0.4092
# Validation Loss 2.4095 Acc 0.3159
# Time taken for 1 epoch 24.685201406478882 sec
#
# Epoch 125 Loss 2.0594 Acc 0.4096
# Validation Loss 2.4255 Acc 0.3124
# Time taken for 1 epoch 24.675781965255737 sec
#
# Epoch 126 Loss 2.0598 Acc 0.4093
# Validation Loss 2.4131 Acc 0.3153
# Time taken for 1 epoch 24.68117380142212 sec
#
# Epoch 127 Loss 2.0598 Acc 0.4093
# Validation Loss 2.4361 Acc 0.3090
# Time taken for 1 epoch 24.671250343322754 sec
#
# Epoch 128 Loss 2.0612 Acc 0.4089
# Validation Loss 2.4320 Acc 0.3116
# Time taken for 1 epoch 24.682474613189697 sec
#
# Epoch 129 Loss 2.0577 Acc 0.4103
# Validation Loss 2.4142 Acc 0.3134
# Time taken for 1 epoch 24.79152250289917 sec
#
# Epoch 130 Loss 2.0642 Acc 0.4084
# Validation Loss 2.4285 Acc 0.3105
# Time taken for 1 epoch 24.65870451927185 sec
#
# Epoch 131 Loss 2.0578 Acc 0.4100
# Validation Loss 2.4168 Acc 0.3135
# Time taken for 1 epoch 24.672209978103638 sec
#
# Epoch 132 Loss 2.0569 Acc 0.4106
# Validation Loss 2.4347 Acc 0.3091
# Time taken for 1 epoch 24.804149866104126 sec
#
# Epoch 133 Loss 2.0570 Acc 0.4104
# Validation Loss 2.4334 Acc 0.3108
# Time taken for 1 epoch 24.76586604118347 sec
#
# Epoch 134 Loss 2.0548 Acc 0.4115
# Validation Loss 2.4154 Acc 0.3144
# Time taken for 1 epoch 24.88060998916626 sec
#
# Epoch 135 Loss 2.0636 Acc 0.4084
# Validation Loss 2.4221 Acc 0.3127
# Time taken for 1 epoch 24.73010230064392 sec
#
# Epoch 136 Loss 2.0546 Acc 0.4116
# Validation Loss 2.4463 Acc 0.3087
# Time taken for 1 epoch 24.90571880340576 sec
#
# Epoch 137 Loss 2.0560 Acc 0.4110
# Validation Loss 2.4219 Acc 0.3135
# Time taken for 1 epoch 24.703640460968018 sec
#
# Epoch 138 Loss 2.0544 Acc 0.4115
# Validation Loss 2.4325 Acc 0.3116
# Time taken for 1 epoch 24.676596879959106 sec
#
# Epoch 139 Loss 2.0550 Acc 0.4116
# Validation Loss 2.4203 Acc 0.3141
# Time taken for 1 epoch 24.8779616355896 sec
#
# Epoch 140 Loss 2.0536 Acc 0.4118
# Validation Loss 2.4201 Acc 0.3144
# Time taken for 1 epoch 24.682703971862793 sec
#
# Epoch 141 Loss 2.0532 Acc 0.4121
# Validation Loss 2.4281 Acc 0.3115
# Time taken for 1 epoch 24.68047547340393 sec
#
# Epoch 142 Loss 2.0569 Acc 0.4108
# Validation Loss 2.4289 Acc 0.3112
# Time taken for 1 epoch 24.66597628593445 sec
#
# Epoch 143 Loss 2.0558 Acc 0.4113
# Validation Loss 2.4170 Acc 0.3159
# Time taken for 1 epoch 24.83877730369568 sec
#
# Epoch 144 Loss 2.0552 Acc 0.4117
# Validation Loss 2.4400 Acc 0.3094
# Time taken for 1 epoch 24.82904863357544 sec
#
# Epoch 145 Loss 2.0541 Acc 0.4119
# Validation Loss 2.4209 Acc 0.3139
# Time taken for 1 epoch 24.677353620529175 sec
#
# Epoch 146 Loss 2.0508 Acc 0.4131
# Validation Loss 2.4354 Acc 0.3110
# Time taken for 1 epoch 24.682642698287964 sec
#
# Epoch 147 Loss 2.0514 Acc 0.4126
# Validation Loss 2.4261 Acc 0.3134
# Time taken for 1 epoch 24.67977809906006 sec
#
# Epoch 148 Loss 2.0516 Acc 0.4129
# Validation Loss 2.4238 Acc 0.3144
# Time taken for 1 epoch 24.677398920059204 sec
#
# Epoch 149 Loss 2.0513 Acc 0.4129
# Validation Loss 2.4238 Acc 0.3146
# Time taken for 1 epoch 24.661134958267212 sec
#
# Epoch 150 Loss 2.0483 Acc 0.4138
# Validation Loss 2.4293 Acc 0.3116
# Time taken for 1 epoch 24.824098110198975 sec
#
# Epoch 151 Loss 2.0509 Acc 0.4130
# Validation Loss 2.4275 Acc 0.3117
# Time taken for 1 epoch 24.73333978652954 sec
#
# Epoch 152 Loss 2.0466 Acc 0.4142
# Validation Loss 2.4403 Acc 0.3092
# Time taken for 1 epoch 24.90075659751892 sec
#
# Epoch 153 Loss 2.0510 Acc 0.4129
# Validation Loss 2.4220 Acc 0.3142
# Time taken for 1 epoch 24.760021924972534 sec
#
# Epoch 154 Loss 2.0478 Acc 0.4140
# Validation Loss 2.4453 Acc 0.3093
# Time taken for 1 epoch 24.676772832870483 sec
#
# Epoch 155 Loss 2.0499 Acc 0.4137
# Validation Loss 2.4259 Acc 0.3126
# Time taken for 1 epoch 24.692503690719604 sec
#
# Epoch 156 Loss 2.0471 Acc 0.4141
# Validation Loss 2.4384 Acc 0.3112
# Time taken for 1 epoch 24.96854519844055 sec
#
# Epoch 157 Loss 2.0519 Acc 0.4128
# Validation Loss 2.4196 Acc 0.3145
# Time taken for 1 epoch 24.682161569595337 sec
#
# Epoch 158 Loss 2.0451 Acc 0.4149
# Validation Loss 2.4619 Acc 0.3068
# Time taken for 1 epoch 24.695348262786865 sec
#
# Epoch 159 Loss 2.0478 Acc 0.4142
# Validation Loss 2.4458 Acc 0.3097
# Time taken for 1 epoch 24.654690980911255 sec
#
# Epoch 160 Loss 2.0472 Acc 0.4144
# Validation Loss 2.4356 Acc 0.3102
# Time taken for 1 epoch 24.905405282974243 sec
#
# Epoch 161 Loss 2.0431 Acc 0.4154
# Validation Loss 2.4253 Acc 0.3147
# Time taken for 1 epoch 24.660312175750732 sec
#
# Epoch 162 Loss 2.0436 Acc 0.4155
# Validation Loss 2.4268 Acc 0.3130
# Time taken for 1 epoch 24.771369457244873 sec
#
# Epoch 163 Loss 2.0465 Acc 0.4147
# Validation Loss 2.4357 Acc 0.3112
# Time taken for 1 epoch 24.708039045333862 sec
#
# Epoch 164 Loss 2.0454 Acc 0.4151
# Validation Loss 2.4293 Acc 0.3118
# Time taken for 1 epoch 24.80937695503235 sec
#
# Epoch 165 Loss 2.0476 Acc 0.4144
# Validation Loss 2.4401 Acc 0.3109
# Time taken for 1 epoch 24.770222187042236 sec
#
# Epoch 166 Loss 2.0445 Acc 0.4153
# Validation Loss 2.4462 Acc 0.3107
# Time taken for 1 epoch 24.832114458084106 sec
#
# Epoch 167 Loss 2.0595 Acc 0.4109
# Validation Loss 2.4332 Acc 0.3124
# Time taken for 1 epoch 24.93558382987976 sec
#
# Epoch 168 Loss 2.0500 Acc 0.4142
# Validation Loss 2.4282 Acc 0.3130
# Time taken for 1 epoch 24.682904481887817 sec
#
# Epoch 169 Loss 2.0446 Acc 0.4157
# Validation Loss 2.4550 Acc 0.3081
# Time taken for 1 epoch 24.74410891532898 sec
#
# Epoch 170 Loss 2.0466 Acc 0.4150
# Validation Loss 2.4443 Acc 0.3101
# Time taken for 1 epoch 24.67929458618164 sec
#
# Epoch 171 Loss 2.0436 Acc 0.4162
# Validation Loss 2.4297 Acc 0.3142
# Time taken for 1 epoch 24.6529757976532 sec
#
# Epoch 172 Loss 2.0426 Acc 0.4166
# Validation Loss 2.4640 Acc 0.3075
# Time taken for 1 epoch 24.679940938949585 sec
#
# Epoch 173 Loss 2.0437 Acc 0.4161
# Validation Loss 2.4356 Acc 0.3120
# Time taken for 1 epoch 24.671684741973877 sec
#
# Epoch 174 Loss 2.0430 Acc 0.4163
# Validation Loss 2.4421 Acc 0.3090
# Time taken for 1 epoch 24.66447901725769 sec
#
# Epoch 175 Loss 2.0415 Acc 0.4167
# Validation Loss 2.4202 Acc 0.3163
# Time taken for 1 epoch 24.81534695625305 sec
#
# Epoch 176 Loss 2.0431 Acc 0.4164
# Validation Loss 2.4330 Acc 0.3135
# Time taken for 1 epoch 24.79487657546997 sec
#
# Epoch 177 Loss 2.0435 Acc 0.4165
# Validation Loss 2.4323 Acc 0.3120
# Time taken for 1 epoch 24.703749895095825 sec
#
# Epoch 178 Loss 2.0413 Acc 0.4168
# Validation Loss 2.4349 Acc 0.3131
# Time taken for 1 epoch 24.713606357574463 sec
#
# Epoch 179 Loss 2.0418 Acc 0.4168
# Validation Loss 2.4581 Acc 0.3078
# Time taken for 1 epoch 24.897237062454224 sec
#
# Epoch 180 Loss 2.0395 Acc 0.4175
# Validation Loss 2.4311 Acc 0.3139
# Time taken for 1 epoch 24.723687171936035 sec
#
# Epoch 181 Loss 2.0374 Acc 0.4179
# Validation Loss 2.4557 Acc 0.3078
# Time taken for 1 epoch 24.89311671257019 sec
#
# Epoch 182 Loss 2.0393 Acc 0.4175
# Validation Loss 2.4303 Acc 0.3124
# Time taken for 1 epoch 24.773427724838257 sec
#
# Epoch 183 Loss 2.0435 Acc 0.4162
# Validation Loss 2.4483 Acc 0.3093
# Time taken for 1 epoch 24.814438819885254 sec
#
# Epoch 184 Loss 2.0370 Acc 0.4181
# Validation Loss 2.4489 Acc 0.3101
# Time taken for 1 epoch 24.771908044815063 sec
#
# Epoch 185 Loss 2.0385 Acc 0.4176
# Validation Loss 2.4315 Acc 0.3143
# Time taken for 1 epoch 24.8069109916687 sec
#
# Epoch 186 Loss 2.0387 Acc 0.4178
# Validation Loss 2.4453 Acc 0.3099
# Time taken for 1 epoch 24.770105600357056 sec
#
# Epoch 187 Loss 2.0402 Acc 0.4173
# Validation Loss 2.4455 Acc 0.3138
# Time taken for 1 epoch 24.665748834609985 sec
#
# Epoch 188 Loss 2.0369 Acc 0.4182
# Validation Loss 2.4461 Acc 0.3120
# Time taken for 1 epoch 24.681545734405518 sec
#
# Epoch 189 Loss 2.0385 Acc 0.4181
# Validation Loss 2.4353 Acc 0.3144
# Time taken for 1 epoch 24.69674324989319 sec
#
# Epoch 190 Loss 2.0402 Acc 0.4174
# Validation Loss 2.4450 Acc 0.3106
# Time taken for 1 epoch 24.7088623046875 sec
#
# Epoch 191 Loss 2.0360 Acc 0.4186
# Validation Loss 2.5068 Acc 0.3008
# Time taken for 1 epoch 24.74085021018982 sec
#
# Epoch 192 Loss 2.0375 Acc 0.4181
# Validation Loss 2.4429 Acc 0.3099
# Time taken for 1 epoch 24.668726205825806 sec
#
# Epoch 193 Loss 2.0362 Acc 0.4186
# Validation Loss 2.4369 Acc 0.3136
# Time taken for 1 epoch 24.736093759536743 sec
#
# Epoch 194 Loss 2.0394 Acc 0.4177
# Validation Loss 2.4449 Acc 0.3104
# Time taken for 1 epoch 24.863388299942017 sec
#
# Epoch 195 Loss 2.0364 Acc 0.4187
# Validation Loss 2.4393 Acc 0.3119
# Time taken for 1 epoch 24.78672695159912 sec
#
# Epoch 196 Loss 2.0360 Acc 0.4188
# Validation Loss 2.4469 Acc 0.3110
# Time taken for 1 epoch 24.733379125595093 sec
#
# Epoch 197 Loss 2.0514 Acc 0.4148
# Validation Loss 2.4383 Acc 0.3120
# Time taken for 1 epoch 24.67049527168274 sec
#
# Epoch 198 Loss 2.0347 Acc 0.4193
# Validation Loss 2.4633 Acc 0.3073
# Time taken for 1 epoch 24.888685941696167 sec
#
# Epoch 199 Loss 2.0429 Acc 0.4168
# Validation Loss 2.4411 Acc 0.3140
# Time taken for 1 epoch 24.658146619796753 sec
#
# Epoch 200 Loss 2.0348 Acc 0.4194
# Validation Loss 2.4491 Acc 0.3077
# Time taken for 1 epoch 24.69262719154358 sec
#
# Epoch 201 Loss 2.0403 Acc 0.4178
# Validation Loss 2.4409 Acc 0.3145
# Time taken for 1 epoch 24.868797063827515 sec
#
# Epoch 202 Loss 2.0786 Acc 0.4053
# Validation Loss 2.4380 Acc 0.3142
# Time taken for 1 epoch 24.94255828857422 sec
#
# Epoch 203 Loss 2.0423 Acc 0.4174
# Validation Loss 2.4676 Acc 0.3088
# Time taken for 1 epoch 24.645713567733765 sec
#
# Epoch 204 Loss 2.0381 Acc 0.4189
# Validation Loss 2.4510 Acc 0.3102
# Time taken for 1 epoch 24.701106309890747 sec
#
# Epoch 205 Loss 2.0364 Acc 0.4192
# Validation Loss 2.4411 Acc 0.3133
# Time taken for 1 epoch 24.668102264404297 sec
#
# Epoch 206 Loss 2.0373 Acc 0.4189
# Validation Loss 2.5019 Acc 0.3012
# Time taken for 1 epoch 24.703991651535034 sec
#
# Epoch 207 Loss 2.0373 Acc 0.4188
# Validation Loss 2.4385 Acc 0.3122
# Time taken for 1 epoch 24.846636533737183 sec
#
# Epoch 208 Loss 2.0361 Acc 0.4192
# Validation Loss 2.4575 Acc 0.3092
# Time taken for 1 epoch 24.704004049301147 sec
#
# Epoch 209 Loss 2.0331 Acc 0.4200
# Validation Loss 2.4532 Acc 0.3088
# Time taken for 1 epoch 24.746784925460815 sec
#
# Epoch 210 Loss 2.0372 Acc 0.4191
# Validation Loss 2.4553 Acc 0.3102
# Time taken for 1 epoch 24.77198815345764 sec
#
# Epoch 211 Loss 2.0331 Acc 0.4201
# Validation Loss 2.4528 Acc 0.3103
# Time taken for 1 epoch 24.693711519241333 sec
#
# Epoch 212 Loss 2.0336 Acc 0.4201
# Validation Loss 2.4724 Acc 0.3065
# Time taken for 1 epoch 24.672208547592163 sec
#
# Epoch 213 Loss 2.0346 Acc 0.4199
# Validation Loss 2.4530 Acc 0.3086
# Time taken for 1 epoch 24.77476453781128 sec
#
# Epoch 214 Loss 2.0373 Acc 0.4191
# Validation Loss 2.4390 Acc 0.3137
# Time taken for 1 epoch 24.770833253860474 sec
#
# Epoch 215 Loss 2.0300 Acc 0.4212
# Validation Loss 2.4506 Acc 0.3108
# Time taken for 1 epoch 24.814692735671997 sec
#
# Epoch 216 Loss 2.0301 Acc 0.4208
# Validation Loss 2.4579 Acc 0.3096
# Time taken for 1 epoch 24.755650281906128 sec
#
# Epoch 217 Loss 2.0316 Acc 0.4205
# Validation Loss 2.4498 Acc 0.3108
# Time taken for 1 epoch 24.685913801193237 sec
#
# Epoch 218 Loss 2.0366 Acc 0.4195
# Validation Loss 2.4307 Acc 0.3157
# Time taken for 1 epoch 24.7300124168396 sec
#
# Epoch 219 Loss 2.0359 Acc 0.4195
# Validation Loss 2.4620 Acc 0.3082
# Time taken for 1 epoch 24.723151683807373 sec
#
# Epoch 220 Loss 2.0307 Acc 0.4211
# Validation Loss 2.4433 Acc 0.3134
# Time taken for 1 epoch 24.677072763442993 sec
#
# Epoch 221 Loss 2.0301 Acc 0.4213
# Validation Loss 2.4433 Acc 0.3133
# Time taken for 1 epoch 24.83768606185913 sec
#
# Epoch 222 Loss 2.0372 Acc 0.4190
# Validation Loss 2.4521 Acc 0.3109
# Time taken for 1 epoch 24.787853002548218 sec
#
# Epoch 223 Loss 2.0284 Acc 0.4220
# Validation Loss 2.4438 Acc 0.3128
# Time taken for 1 epoch 24.70317769050598 sec
#
# Epoch 224 Loss 2.0316 Acc 0.4209
# Validation Loss 2.4741 Acc 0.3073
# Time taken for 1 epoch 24.681020498275757 sec
#
# Epoch 225 Loss 2.0330 Acc 0.4205
# Validation Loss 2.4437 Acc 0.3112
# Time taken for 1 epoch 24.69042992591858 sec
#
# Epoch 226 Loss 2.0276 Acc 0.4219
# Validation Loss 2.4718 Acc 0.3069
# Time taken for 1 epoch 24.668941974639893 sec
#
# Epoch 227 Loss 2.0350 Acc 0.4194
# Validation Loss 2.4452 Acc 0.3110
# Time taken for 1 epoch 24.67828679084778 sec
#
# Epoch 228 Loss 2.0316 Acc 0.4212
# Validation Loss 2.4493 Acc 0.3111
# Time taken for 1 epoch 24.695539951324463 sec
#
# Epoch 229 Loss 2.0309 Acc 0.4212
# Validation Loss 2.4472 Acc 0.3101
# Time taken for 1 epoch 24.762514114379883 sec
#
# Epoch 230 Loss 2.0301 Acc 0.4212
# Validation Loss 2.4700 Acc 0.3079
# Time taken for 1 epoch 24.672235250473022 sec
#
# Epoch 231 Loss 2.0313 Acc 0.4211
# Validation Loss 2.4496 Acc 0.3110
# Time taken for 1 epoch 24.696663856506348 sec
#
# Epoch 232 Loss 2.0304 Acc 0.4212
# Validation Loss 2.4774 Acc 0.3062
# Time taken for 1 epoch 24.65842366218567 sec
#
# Epoch 233 Loss 2.0314 Acc 0.4211
# Validation Loss 2.4415 Acc 0.3151
# Time taken for 1 epoch 24.670620679855347 sec
#
# Epoch 234 Loss 2.0327 Acc 0.4209
# Validation Loss 2.4510 Acc 0.3115
# Time taken for 1 epoch 24.68742060661316 sec
#
# Epoch 235 Loss 2.0347 Acc 0.4201
# Validation Loss 2.4521 Acc 0.3126
# Time taken for 1 epoch 24.670090436935425 sec
#
# Epoch 236 Loss 2.0318 Acc 0.4211
# Validation Loss 2.4523 Acc 0.3110
# Time taken for 1 epoch 24.824511528015137 sec
#
# Epoch 237 Loss 2.0332 Acc 0.4209
# Validation Loss 2.4522 Acc 0.3137
# Time taken for 1 epoch 24.81013011932373 sec
#
# Epoch 238 Loss 2.0296 Acc 0.4220
# Validation Loss 2.4859 Acc 0.3039
# Time taken for 1 epoch 24.704457759857178 sec
#
# Epoch 239 Loss 2.0294 Acc 0.4216
# Validation Loss 2.4533 Acc 0.3107
# Time taken for 1 epoch 24.689878702163696 sec
#
# Epoch 240 Loss 2.0269 Acc 0.4224
# Validation Loss 2.4467 Acc 0.3140
# Time taken for 1 epoch 24.669337034225464 sec
#
# Epoch 241 Loss 2.0318 Acc 0.4214
# Validation Loss 2.4538 Acc 0.3106
# Time taken for 1 epoch 24.679337978363037 sec
#
# Epoch 242 Loss 2.0290 Acc 0.4221
# Validation Loss 2.4509 Acc 0.3137
# Time taken for 1 epoch 24.688108682632446 sec
#
# Epoch 243 Loss 2.0297 Acc 0.4218
# Validation Loss 2.4816 Acc 0.3060
# Time taken for 1 epoch 24.66391921043396 sec
#
# Epoch 244 Loss 2.0293 Acc 0.4221
# Validation Loss 2.4648 Acc 0.3097
# Time taken for 1 epoch 24.673465728759766 sec
#
# Epoch 245 Loss 2.0266 Acc 0.4228
# Validation Loss 2.4485 Acc 0.3123
# Time taken for 1 epoch 24.725542783737183 sec
#
# Epoch 246 Loss 2.0274 Acc 0.4226
# Validation Loss 2.4530 Acc 0.3097
# Time taken for 1 epoch 24.69092106819153 sec
#
# Epoch 247 Loss 2.0264 Acc 0.4229
# Validation Loss 2.4688 Acc 0.3080
# Time taken for 1 epoch 24.66961407661438 sec
#
# Epoch 248 Loss 2.0252 Acc 0.4232
# Validation Loss 2.4538 Acc 0.3117
# Time taken for 1 epoch 24.700780391693115 sec
#
# Epoch 249 Loss 2.0343 Acc 0.4203
# Validation Loss 2.4706 Acc 0.3081
# Time taken for 1 epoch 24.805359363555908 sec
#
# Epoch 250 Loss 2.0268 Acc 0.4230
# Validation Loss 2.4542 Acc 0.3116
# Time taken for 1 epoch 24.701695442199707 sec
#
# Epoch 251 Loss 2.0299 Acc 0.4218
# Validation Loss 2.4629 Acc 0.3084
# Time taken for 1 epoch 24.666024208068848 sec
#
# Epoch 252 Loss 2.0291 Acc 0.4220
# Validation Loss 2.4438 Acc 0.3141
# Time taken for 1 epoch 24.679137468338013 sec
#
# Epoch 253 Loss 2.0252 Acc 0.4233
# Validation Loss 2.4507 Acc 0.3110
# Time taken for 1 epoch 24.708214282989502 sec
#
# Epoch 254 Loss 2.0249 Acc 0.4233
# Validation Loss 2.4684 Acc 0.3086
# Time taken for 1 epoch 24.786699295043945 sec
#
# Epoch 255 Loss 2.0262 Acc 0.4231
# Validation Loss 2.4494 Acc 0.3130
# Time taken for 1 epoch 24.71842074394226 sec
#
# Epoch 256 Loss 2.0241 Acc 0.4237
# Validation Loss 2.4692 Acc 0.3073
# Time taken for 1 epoch 24.822739362716675 sec
#
# Epoch 257 Loss 2.0395 Acc 0.4189
# Validation Loss 2.4440 Acc 0.3133
# Time taken for 1 epoch 24.7789568901062 sec
#
# Epoch 258 Loss 2.0284 Acc 0.4227
# Validation Loss 2.4589 Acc 0.3094
# Time taken for 1 epoch 24.635140657424927 sec
#
# Epoch 259 Loss 2.0242 Acc 0.4235
# Validation Loss 2.4375 Acc 0.3154
# Time taken for 1 epoch 24.814104318618774 sec
#
# Epoch 260 Loss 2.0262 Acc 0.4232
# Validation Loss 2.4743 Acc 0.3069
# Time taken for 1 epoch 24.713440895080566 sec
#
# Epoch 261 Loss 2.0410 Acc 0.4185
# Validation Loss 2.4749 Acc 0.3076
# Time taken for 1 epoch 24.72726321220398 sec
#
# Epoch 262 Loss 2.0248 Acc 0.4237
# Validation Loss 2.4505 Acc 0.3146
# Time taken for 1 epoch 24.68364381790161 sec
#
# Epoch 263 Loss 2.0249 Acc 0.4234
# Validation Loss 2.4497 Acc 0.3139
# Time taken for 1 epoch 24.676884412765503 sec
#
# Epoch 264 Loss 2.0383 Acc 0.4197
# Validation Loss 2.4601 Acc 0.3094
# Time taken for 1 epoch 24.653934478759766 sec
#
# Epoch 265 Loss 2.0243 Acc 0.4241
# Validation Loss 2.4591 Acc 0.3125
# Time taken for 1 epoch 24.836103200912476 sec
#
# Epoch 266 Loss 2.0252 Acc 0.4237
# Validation Loss 2.4675 Acc 0.3089
# Time taken for 1 epoch 24.7432382106781 sec
#
# Epoch 267 Loss 2.0235 Acc 0.4241
# Validation Loss 2.4576 Acc 0.3123
# Time taken for 1 epoch 24.660289764404297 sec
#
# Epoch 268 Loss 2.0292 Acc 0.4223
# Validation Loss 2.4630 Acc 0.3099
# Time taken for 1 epoch 24.824079036712646 sec
#
# Epoch 269 Loss 2.0240 Acc 0.4239
# Validation Loss 2.4573 Acc 0.3096
# Time taken for 1 epoch 24.75734853744507 sec
#
# Epoch 270 Loss 2.0280 Acc 0.4227
# Validation Loss 2.4399 Acc 0.3155
# Time taken for 1 epoch 24.660152912139893 sec
#
# Epoch 271 Loss 2.0246 Acc 0.4241
# Validation Loss 2.4668 Acc 0.3103
# Time taken for 1 epoch 24.68205165863037 sec
#
# Epoch 272 Loss 2.0229 Acc 0.4241
# Validation Loss 2.4846 Acc 0.3064
# Time taken for 1 epoch 24.73464870452881 sec
#
# Epoch 273 Loss 2.0284 Acc 0.4229
# Validation Loss 2.4408 Acc 0.3143
# Time taken for 1 epoch 24.762116193771362 sec
#
# Epoch 274 Loss 2.0234 Acc 0.4241
# Validation Loss 2.4649 Acc 0.3114
# Time taken for 1 epoch 24.737468004226685 sec
#
# Epoch 275 Loss 2.0227 Acc 0.4249
# Validation Loss 2.4545 Acc 0.3139
# Time taken for 1 epoch 24.73715591430664 sec
#
# Epoch 276 Loss 2.0256 Acc 0.4233
# Validation Loss 2.4533 Acc 0.3128
# Time taken for 1 epoch 24.823705911636353 sec
#
# Epoch 277 Loss 2.0229 Acc 0.4245
# Validation Loss 2.4450 Acc 0.3134
# Time taken for 1 epoch 24.76437759399414 sec
#
# Epoch 278 Loss 2.0243 Acc 0.4239
# Validation Loss 2.4579 Acc 0.3123
# Time taken for 1 epoch 24.741920471191406 sec
#
# Epoch 279 Loss 2.0216 Acc 0.4247
# Validation Loss 2.4912 Acc 0.3064
# Time taken for 1 epoch 24.74001693725586 sec
#
# Epoch 280 Loss 2.0310 Acc 0.4220
# Validation Loss 2.4587 Acc 0.3124
# Time taken for 1 epoch 24.685511112213135 sec
#
# Epoch 281 Loss 2.0261 Acc 0.4236
# Validation Loss 2.4529 Acc 0.3134
# Time taken for 1 epoch 24.861712217330933 sec
#
# Epoch 282 Loss 2.0211 Acc 0.4251
# Validation Loss 2.4695 Acc 0.3098
# Time taken for 1 epoch 24.673609972000122 sec
#
# Epoch 283 Loss 2.0220 Acc 0.4250
# Validation Loss 2.5061 Acc 0.3023
# Time taken for 1 epoch 24.803579568862915 sec
#
# Epoch 284 Loss 2.0521 Acc 0.4154
# Validation Loss 2.4640 Acc 0.3094
# Time taken for 1 epoch 24.672175407409668 sec
#
# Epoch 285 Loss 2.0359 Acc 0.4217
# Validation Loss 2.4990 Acc 0.2993
# Time taken for 1 epoch 24.82315683364868 sec
#
# Epoch 286 Loss 2.0304 Acc 0.4226
# Validation Loss 2.4675 Acc 0.3098
# Time taken for 1 epoch 24.76862359046936 sec
#
# Epoch 287 Loss 2.0218 Acc 0.4249
# Validation Loss 2.4817 Acc 0.3068
# Time taken for 1 epoch 24.692128658294678 sec
#
# Epoch 288 Loss 2.0210 Acc 0.4253
# Validation Loss 2.4671 Acc 0.3108
# Time taken for 1 epoch 24.73764657974243 sec
#
# Epoch 289 Loss 2.0214 Acc 0.4249
# Validation Loss 2.4895 Acc 0.3077
# Time taken for 1 epoch 24.66286849975586 sec
#
# Epoch 290 Loss 2.0208 Acc 0.4254
# Validation Loss 2.4546 Acc 0.3129
# Time taken for 1 epoch 24.68523669242859 sec
#
# Epoch 291 Loss 2.0228 Acc 0.4245
# Validation Loss 2.4635 Acc 0.3091
# Time taken for 1 epoch 24.773518800735474 sec
#
# Epoch 292 Loss 2.0243 Acc 0.4239
# Validation Loss 2.4737 Acc 0.3084
# Time taken for 1 epoch 24.67951512336731 sec
#
# Epoch 293 Loss 2.0338 Acc 0.4216
# Validation Loss 2.4471 Acc 0.3149
# Time taken for 1 epoch 24.684743881225586 sec
#
# Epoch 294 Loss 2.0344 Acc 0.4215
# Validation Loss 2.4623 Acc 0.3089
# Time taken for 1 epoch 24.716631650924683 sec
#
# Epoch 295 Loss 2.0278 Acc 0.4228
# Validation Loss 2.4527 Acc 0.3134
# Time taken for 1 epoch 24.688429832458496 sec
#
# Epoch 296 Loss 2.0309 Acc 0.4220
# Validation Loss 2.4833 Acc 0.3069
# Time taken for 1 epoch 24.922388553619385 sec
#
# Epoch 297 Loss 2.0219 Acc 0.4250
# Validation Loss 2.4759 Acc 0.3086
# Time taken for 1 epoch 24.678160190582275 sec
#
# Epoch 298 Loss 2.0190 Acc 0.4258
# Validation Loss 2.4529 Acc 0.3147
# Time taken for 1 epoch 24.66685652732849 sec
#
# Epoch 299 Loss 2.0238 Acc 0.4243
# Validation Loss 2.4576 Acc 0.3120
# Time taken for 1 epoch 24.692261695861816 sec
#
# Epoch 300 Loss 2.0210 Acc 0.4248
# Validation Loss 2.4939 Acc 0.3059
# Time taken for 1 epoch 24.66719651222229 sec

# %%
# total_loss = 0
# total_acc = 0
# steps_per_epoch = 0
# val_total_loss = 0
# val_total_acc = 0
# val_steps_per_epoch = 0

# for x, y in train_dataset:
#     batch_loss, batch_acc = val_step(x, y)
#     total_loss += batch_loss
#     total_acc += batch_acc
#     steps_per_epoch += 1
    
# for x, y in validation_dataset:
#     val_batch_loss, val_batch_acc = val_step(x, y)
#     val_total_loss += val_batch_loss
#     val_total_acc += val_batch_acc
#     val_steps_per_epoch += 1

# print(f'Training Loss {total_loss / steps_per_epoch:.4f} Acc {total_acc / steps_per_epoch:.4f}')
# print(f'Validation Loss {val_total_loss / val_steps_per_epoch:.4f} Acc {val_total_acc / val_steps_per_epoch:.4f}')

# %%
plt.plot(loss_history, label="train_loss")
plt.plot(val_loss_history, label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(acc_history, label="train_acc")
plt.plot(val_acc_history, label="val_acc")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
# checkpoint.save(checkpoint_prefix)
np.save(EXPERIMENT_DIR+"loss_history.npy", np.array(loss_history))
np.save(EXPERIMENT_DIR+"acc_history.npy", np.array(acc_history))
np.save(EXPERIMENT_DIR+"val_loss_history.npy", np.array(val_loss_history))
np.save(EXPERIMENT_DIR+"val_acc_history.npy", np.array(val_acc_history))

# %% [markdown]
# ## predict

# %%
def slice_per_step(a):
    # add -1 to the end of each sample to make them the same length per step(piece_length)
    original_length = a.shape[0]
    pad_count = PIECE_LEN - (original_length % PIECE_LEN)
    print(a.shape, end=' ')
    if pad_count!=PIECE_LEN : 
        print('pad by',pad_count, end=' ')
        a = np.pad(a, ((0, pad_count), (0, 0)), 'constant', constant_values=-1)
    # reshape into per step
    a = np.reshape(a, (-1, PIECE_LEN, a.shape[1]))
    print('to',a.shape)
    return a, original_length

# %%
import midi_np_translation.output2midi_v2_simple as output2midi

# %%
def test_and_translate_to_midi(input_path, ref_midi_path, output_path):
    test_file = np.load(input_path)
    padded_input, original_length = slice_per_step(test_file)
    test_result = np.reshape(model.predict(padded_input), (-1, 53))[:original_length]
    print(test_result.shape)
    output2midi.output_to_midi(test_result, ref_midi_path, output_path)

# %%
test_and_translate_to_midi(input_path="preprocessed_dataset/irealpro_dataset_v2_simple/Autumn Leaves_o0.mid.npy",
                           ref_midi_path="input_midi/irealpro_transposed/Autumn Leaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_irealpro.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/dense_v2_simple/AutumnLeaves_o0.mid.npy",
                           ref_midi_path="input_midi/transpose_augmentation/AutumnLeaves_o0.mid",
                           output_path=EXPERIMENT_DIR+"autumn_arr.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/autumn_leaves_pt_dm.mid.npy",
                           ref_midi_path="input_midi/midkar/autumn_leaves_pt_dm.mid",
                           output_path=EXPERIMENT_DIR+"autumn_val.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/the_song_is_you_mw.mid.npy",
                           ref_midi_path="input_midi/midkar/the_song_is_you_mw.mid",
                           output_path=EXPERIMENT_DIR+"the_song_is_you.mid")
test_and_translate_to_midi(input_path="preprocessed_dataset/midkar_v2_simple/a_night_in_tunisia_2_jc.mid.npy",
                           ref_midi_path="input_midi/midkar/a_night_in_tunisia_2_jc.mid",
                           output_path=EXPERIMENT_DIR+"tunisia.mid")
# Out:
# (1560, 43) pad by 104 to (13, 128, 43)
# 1/1 [==============================] - 2s 2s/step
# (1560, 53)
# (1712, 43) pad by 80 to (14, 128, 43)
# 1/1 [==============================] - 0s 17ms/step
# (1712, 53)
# (3731, 43) pad by 109 to (30, 128, 43)
# 1/1 [==============================] - 0s 16ms/step
# (3731, 53)
# (3137, 43) pad by 63 to (25, 128, 43)
# 1/1 [==============================] - 0s 16ms/step
# (3137, 53)
# (1536, 43) to (12, 128, 43)
# 1/1 [==============================] - 0s 16ms/step
# (1536, 53)
