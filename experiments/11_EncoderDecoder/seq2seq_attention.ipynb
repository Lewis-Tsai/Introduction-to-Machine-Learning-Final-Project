# %%
import tensorflow as tf

import os

import numpy as np

from tqdm import tqdm
# Out:
# 2023-01-17 12:37:26.008532: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 12:37:26.641843: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 12:37:26.641924: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 12:37:26.641930: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # **Parameter**

# %%
# Original Data Info.
n_pitch = 53
n_feature = 43

# Model Parameter
input_size = n_feature
target_size = n_pitch + 4 # +4 (addition) is oneset + start correction + end correction + velocity

# Training Parameter
BATCH_SIZE = 32          # Batch Sizes
VALIDATION_RATIO = 0.1  # Validation Ratio to Input Data
learning_rate = 0.001   # Learning Rate
n_hidden = 2            # Hidden Units number

# Data Parameter
PIECE_LEN = 200          # (auto set by data) Extra +1 for START timestamp
is_onset_index = 53
start_correction_index = 54
end_correction_index = 55
velocity_index = 56

ROOT = r'.'

# %%
os.chdir(ROOT)
print(os.getcwd())
# Out:
# /media/labhdd/cyc/ML_Final

# %%
from zipfile import ZipFile
# Delete incomplete unzipped folder and run this 
if 'irealpro_dataset_v2' not in os.listdir():
    print('Creating Folder \'irealpro_dataset_v2\'')
    os.mkdir('../irealpro_dataset_v2')
    print('Extract to Folder \'irealpro_dataset_v2\'')
    with ZipFile(r"/content/drive/MyDrive/ML/irealpro_dataset_v2.zip", 'r') as zObject:
        zObject.extractall(path=r"/content/drive/MyDrive/ML/irealpro_dataset_v2")

# %%
np.random.seed(10000)

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# `MAX_DATA`: control how many songs files as the input (assign with -1 to use all songs)

# %%
MAX_DATA = -1

# %%
dec_init_input = np.zeros((1, target_size))
dec_init_input[0, start_correction_index] = 1.

count_pad = 0 
count_spilled = 0
def load_npy_data(x_path, y_path, offset):
    global count_pad, count_spilled, dec_init_input
    x = np.load(x_path)
    y = np.load(y_path)

    if offset == 0:
        Z_ = dec_init_input
    else:
        Z_ = y[offset-1].astype(np.float32)
        Z_ = np.expand_dims(Z_, axis=0)
        count_spilled += 1

    if x.shape[0] >= offset+PIECE_LEN:
        X_ = x[offset:offset+PIECE_LEN].astype(np.float32)
        Y_ = y[offset:offset+PIECE_LEN].astype(np.float32)
    else:
        pad_count = offset + PIECE_LEN - x.shape[0]
        X_ = np.pad(x[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float32)
        Y_ = np.pad(y[offset:], ((0, pad_count), (0, 0)), 'constant', constant_values=-1).astype(np.float32)
        count_pad += 1
    try:
        assert X_.shape == (PIECE_LEN, input_size)
        assert Z_.shape == (1, target_size)
        assert Y_.shape == (PIECE_LEN, target_size)
    except:
        print('You got',X_.shape, Z_.shape, Y_.shape)
        raise ValueError

    return X_, Z_, Y_

def generate_dataset(input_dir: str, data_size=-1):
    # using tf.data.Dataset API to create dataset
    x_paths = [] # input path
    y_paths = [] # ans file path
    offsets = [] # starting point of a piece
    data_cnt = 0
    for file_name in os.listdir(input_dir): # 'Scan Files'
        if data_cnt==data_size-1: break
        if file_name.endswith(".ans.npy"):
            data_cnt+=1
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name[:-8] + ".npy"))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"

            # split and pad data into PIECE_LEN
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)

    dataset = []
    for i in zip(x_paths, y_paths, offsets): # 'Read Files'
        dataset.append(load_npy_data(*i))
    print(len(dataset))
    dataset = list(zip(*dataset))
    # print(len(dataset[0]))
    # print(len(dataset[1]))
    # print(len(dataset[2]))
    encoder_input_data = np.array(dataset[0])
    decoder_input_data = np.array(dataset[1])
    decoder_target_data = np.array(dataset[2])
    
    perm_id = np.random.shuffle(np.arange(encoder_input_data.shape[0]))
    encoder_input_data = encoder_input_data[perm_id]
    decoder_input_data = decoder_input_data[perm_id]
    decoder_target_data = decoder_target_data[perm_id]
    
    print(encoder_input_data.shape)
    print(decoder_input_data.shape)
    print(decoder_target_data.shape)

    return encoder_input_data, decoder_input_data, decoder_target_data

encoder_input_data, decoder_input_data, decoder_target_data = generate_dataset(ROOT+"/preprocessed_dataset/irealpro_dataset_v2", MAX_DATA)

print('Data Padded:', count_pad)
print('Data with Non Start Decoder Input:', count_spilled)
print('Data PIECE_LEN:', PIECE_LEN)
# Out:
# 27096
# (1, 27096, 200, 43)
# (1, 27096, 1, 57)
# (1, 27096, 200, 57)
# Data Padded: 3252
# Data with Non Start Decoder Input: 23832
# Data PIECE_LEN: 200

# %%
# np.save(ROOT + '/encoder_input_data.npy', encoder_input_data)
# np.save(ROOT + '/decoder_input_data.npy', decoder_input_data)
# np.save(ROOT + '/decoder_target_data.npy', decoder_target_data)

# %%
# encoder_input_data = np.load(ROOT + '/encoder_input_data.npy', allow_pickle=True)
# decoder_input_data = np.load(ROOT + '/decoder_input_data.npy', allow_pickle=True)
# decoder_target_data = np.load(ROOT + '/decoder_target_data.npy', allow_pickle=True)

# %% [markdown]
# # **Model**

# %% [markdown]
# ## *Define Loss, Accuracy, and Optimizer*

# %%
# Define Loss, Accuracy, and Optimizer
def masked_loss_function(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true[:,:,:n_pitch], axis=2), -1*n_pitch)  # false if it is a padding time step
    pitch_loss = tf.losses.categorical_crossentropy(y_true[:,:,:n_pitch], y_pred[:,:,:n_pitch])
    onset_loss = tf.losses.binary_crossentropy(y_true[:,:,n_pitch:n_pitch+1], y_pred[:,:,n_pitch:n_pitch+1])
    start_loss = tf.square(y_true[:,:,n_pitch+1] - y_pred[:,:,n_pitch+1])
    end_loss = tf.square(y_true[:,:,n_pitch+2] - y_pred[:,:,n_pitch+2])
    velocity_loss = tf.square(y_true[:,:,n_pitch+3] - y_pred[:,:,n_pitch+3])
    total_loss = tf.reduce_sum([pitch_loss, onset_loss, start_loss, end_loss, velocity_loss], axis=0)
    total_loss *= tf.cast(mask, total_loss.dtype)
    return tf.reduce_mean(total_loss)

def masked_accuracy(y_true, y_pred):
    mask = tf.math.not_equal(tf.reduce_sum(y_true[:,:,:n_pitch], axis=2), -1*n_pitch)  # false if it is a padding time step
    mask = tf.cast(mask, tf.float32)
    pitch_acc = tf.reduce_mean(mask * tf.metrics.categorical_accuracy(y_true[:,:,:n_pitch], y_pred[:,:,:n_pitch]))
    # onset_acc = tf.reduce_mean(mask * tf.metrics.binary_accuracy(y_true[:,:,n_pitch:n_pitch+1], y_pred[:,:,n_pitch:n_pitch+1]))
    # start_loss = tf.reduce_mean(mask * tf.square(y_true[:,:,n_pitch+1] - y_pred[:,:,n_pitch+1]))
    # end_loss = tf.reduce_mean(mask * tf.square(y_true[:,:,n_pitch+2] - y_pred[:,:,n_pitch+2]))
    # velocity_loss = tf.reduce_mean(mask * tf.square(y_true[:,:,n_pitch+3] - y_pred[:,:,n_pitch+3]))

    # return pitch_acc, onset_acc, start_loss, end_loss, velocity_loss
    return pitch_acc

optimizer = tf.keras.optimizers.Adam()
# Out:
# 2023-01-17 12:47:13.652824: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.664796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.665099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.667032: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 12:47:13.668010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.668255: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.668458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.968398: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.968545: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.968651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-17 12:47:13.968773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
checkpoint_filepath = './checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    )

# %% [markdown]
# ## Reinjection Technique

# %%
from keras import Model
from keras import backend as K
from keras.layers import Input, Concatenate, Dense, LSTM, Embedding, GRU, Attention, Lambda, Permute, Flatten

# Encoder
encoder_inputs = Input(shape=(PIECE_LEN, input_size), name='Input_Encoder')
encoder = LSTM(n_hidden, return_sequences=True, return_state=True, name='Encoder')

encoder_outputs, state_h, state_c = encoder(encoder_inputs)
states = [state_h, state_c]

attention = Attention(n_hidden, name='Attention')

decoder_inputs = Input(shape=(1, target_size), name='Input_Decoder')
decoder_lstm = LSTM(n_hidden, return_sequences=True, return_state=True, name='Decoder')
decoder_dense = Dense(target_size, activation='softmax', name='Dense_Timestamp_Output')

all_outputs = []
all_attention = []
inputs = decoder_inputs
for _ in tqdm(range(PIECE_LEN)):
    # Attention Update
    # print(states.shape) 
    # print(encoder_outputs.shape)
    context_vector, attention_weights = attention([tf.expand_dims([state_h, state_c],1), encoder_outputs], return_attention_scores=True)
    all_attention.append(attention_weights)
    # context_vector = Permute((2, 1))(context_vector)
    # context_vector = Flatten()(context_vector)
    # print(inputs.shape)
    # print(context_vector.shape)
    context_vector_h, context_vector_c = Lambda(lambda x: x[:,0,:,:], output_shape=(1,) + context_vector.shape[2:], name='Split_Context')(context_vector)
    # print(context_vector_h.shape)
    # print(context_vector_c.shape)
    state_h = Concatenate(axis=-1, name='Concat_StateH_ContextH')([state_h,context_vector_h])
    state_c = Concatenate(axis=-1, name='Concat_StateC_ContextC')([state_c,context_vector_c])
    # Decoder Reinject
    outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)
    # Output
    outputs = decoder_dense(outputs)
    all_outputs.append(outputs)
    # Update Decoder Input & State
    inputs = outputs
    states = [state_h, state_c]

# Concatenate all predictions
decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1), name='Concat_Output')(all_outputs)

# Define and compile model as previously
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# Out:
# 100%|██████████| 200/200 [00:31<00:00,  6.26it/s]

# %%
model.compile(optimizer='rmsprop', 
              loss=masked_loss_function, 
            #   metrics={masked_accuracy},
              )

# %%
model.summary()
tf.keras.utils.plot_model(
    model,
    to_file='seq2seq_lstm_attention.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='LR',
    expand_nested=False,
    dpi=96,
    show_layer_activations=True
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Encoder (InputLayer)     [(None, 200, 43)]    0           []
#
#  Input_Decoder (InputLayer)     [(None, 1, 57)]      0           []
#
#  Encoder (LSTM)                 [(None, 200, 2),     368         ['Input_Encoder[0][0]']
#                                  (None, 2),
#                                  (None, 2)]
#
#  Decoder (LSTM)                 [(None, 1, 2),       480         ['Input_Decoder[0][0]',
#                                  (None, 2),                       'Encoder[0][1]',
#                                  (None, 2)]                       'Encoder[0][2]',
#                                                                   'Dense_Timestamp_Output[0][0]',
#                                                                   'Decoder[0][1]',
#                                                                   'Decoder[0][2]',
#                                                                   'Dense_Timestamp_Output[1][0]',
#                                                                   'Decoder[1][1]',
#                                                                   'Decoder[1][2]',
#                                                                   'Dense_Timestamp_Output[2][0]',
#                                                                   'Decoder[2][1]',
#                                                                   'Decoder[2][2]',
#                                                                   'Dense_Timestamp_Output[3][0]',
#                                                                   'Decoder[3][1]',
#                                                                   'Decoder[3][2]',
#                                                                   'Dense_Timestamp_Output[4][0]',
#                                                                   'Decoder[4][1]',
#                                                                   'Decoder[4][2]',
#                                                                   'Dense_Timestamp_Output[5][0]',
#                                                                   'Decoder[5][1]',
#                                                                   'Decoder[5][2]',
#                                                                   'Dense_Timestamp_Output[6][0]',
#                                                                   'Decoder[6][1]',
#                                                                   'Decoder[6][2]',
#                                                                   'Dense_Timestamp_Output[7][0]',
#                                                                   'Decoder[7][1]',
#                                                                   'Decoder[7][2]',
#                                                                   'Dense_Timestamp_Output[8][0]',
#                                                                   'Decoder[8][1]',
#                                                                   'Decoder[8][2]',
#                                                                   'Dense_Timestamp_Output[9][0]',
#                                                                   'Decoder[9][1]',
#                                                                   'Decoder[9][2]',
#                                                                   'Dense_Timestamp_Output[10][0]',
#                                                                   'Decoder[10][1]',
#                                                                   'Decoder[10][2]',
#                                                                   'Dense_Timestamp_Output[11][0]',
#                                                                   'Decoder[11][1]',
#                                                                   'Decoder[11][2]',
#                                                                   'Dense_Timestamp_Output[12][0]',
#                                                                   'Decoder[12][1]',
#                                                                   'Decoder[12][2]',
#                                                                   'Dense_Timestamp_Output[13][0]',
#                                                                   'Decoder[13][1]',
#                                                                   'Decoder[13][2]',
#                                                                   'Dense_Timestamp_Output[14][0]',
#                                                                   'Decoder[14][1]',
#                                                                   'Decoder[14][2]',
#                                                                   'Dense_Timestamp_Output[15][0]',
#                                                                   'Decoder[15][1]',
#                                                                   'Decoder[15][2]',
#                                                                   'Dense_Timestamp_Output[16][0]',
#                                                                   'Decoder[16][1]',
#                                                                   'Decoder[16][2]',
#                                                                   'Dense_Timestamp_Output[17][0]',
#                                                                   'Decoder[17][1]',
#                                                                   'Decoder[17][2]',
#                                                                   'Dense_Timestamp_Output[18][0]',
#                                                                   'Decoder[18][1]',
#                                                                   'Decoder[18][2]',
#                                                                   'Dense_Timestamp_Output[19][0]',
#                                                                   'Decoder[19][1]',
#                                                                   'Decoder[19][2]',
#                                                                   'Dense_Timestamp_Output[20][0]',
#                                                                   'Decoder[20][1]',
#                                                                   'Decoder[20][2]',
#                                                                   'Dense_Timestamp_Output[21][0]',
#                                                                   'Decoder[21][1]',
#                                                                   'Decoder[21][2]',
#                                                                   'Dense_Timestamp_Output[22][0]',
#                                                                   'Decoder[22][1]',
#                                                                   'Decoder[22][2]',
#                                                                   'Dense_Timestamp_Output[23][0]',
#                                                                   'Decoder[23][1]',
#                                                                   'Decoder[23][2]',
#                                                                   'Dense_Timestamp_Output[24][0]',
#                                                                   'Decoder[24][1]',
#                                                                   'Decoder[24][2]',
#                                                                   'Dense_Timestamp_Output[25][0]',
#                                                                   'Decoder[25][1]',
#                                                                   'Decoder[25][2]',
#                                                                   'Dense_Timestamp_Output[26][0]',
#                                                                   'Decoder[26][1]',
#                                                                   'Decoder[26][2]',
#                                                                   'Dense_Timestamp_Output[27][0]',
#                                                                   'Decoder[27][1]',
#                                                                   'Decoder[27][2]',
#                                                                   'Dense_Timestamp_Output[28][0]',
#                                                                   'Decoder[28][1]',
#                                                                   'Decoder[28][2]',
#                                                                   'Dense_Timestamp_Output[29][0]',
#                                                                   'Decoder[29][1]',
#                                                                   'Decoder[29][2]',
#                                                                   'Dense_Timestamp_Output[30][0]',
#                                                                   'Decoder[30][1]',
#                                                                   'Decoder[30][2]',
#                                                                   'Dense_Timestamp_Output[31][0]',
#                                                                   'Decoder[31][1]',
#                                                                   'Decoder[31][2]',
#                                                                   'Dense_Timestamp_Output[32][0]',
#                                                                   'Decoder[32][1]',
#                                                                   'Decoder[32][2]',
#                                                                   'Dense_Timestamp_Output[33][0]',
#                                                                   'Decoder[33][1]',
#                                                                   'Decoder[33][2]',
#                                                                   'Dense_Timestamp_Output[34][0]',
#                                                                   'Decoder[34][1]',
#                                                                   'Decoder[34][2]',
#                                                                   'Dense_Timestamp_Output[35][0]',
#                                                                   'Decoder[35][1]',
#                                                                   'Decoder[35][2]',
#                                                                   'Dense_Timestamp_Output[36][0]',
#                                                                   'Decoder[36][1]',
#                                                                   'Decoder[36][2]',
#                                                                   'Dense_Timestamp_Output[37][0]',
#                                                                   'Decoder[37][1]',
#                                                                   'Decoder[37][2]',
#                                                                   'Dense_Timestamp_Output[38][0]',
#                                                                   'Decoder[38][1]',
#                                                                   'Decoder[38][2]',
#                                                                   'Dense_Timestamp_Output[39][0]',
#                                                                   'Decoder[39][1]',
#                                                                   'Decoder[39][2]',
#                                                                   'Dense_Timestamp_Output[40][0]',
#                                                                   'Decoder[40][1]',
#                                                                   'Decoder[40][2]',
#                                                                   'Dense_Timestamp_Output[41][0]',
#                                                                   'Decoder[41][1]',
#                                                                   'Decoder[41][2]',
#                                                                   'Dense_Timestamp_Output[42][0]',
#                                                                   'Decoder[42][1]',
#                                                                   'Decoder[42][2]',
#                                                                   'Dense_Timestamp_Output[43][0]',
#                                                                   'Decoder[43][1]',
#                                                                   'Decoder[43][2]',
#                                                                   'Dense_Timestamp_Output[44][0]',
#                                                                   'Decoder[44][1]',
#                                                                   'Decoder[44][2]',
#                                                                   'Dense_Timestamp_Output[45][0]',
#                                                                   'Decoder[45][1]',
#                                                                   'Decoder[45][2]',
#                                                                   'Dense_Timestamp_Output[46][0]',
#                                                                   'Decoder[46][1]',
#                                                                   'Decoder[46][2]',
#                                                                   'Dense_Timestamp_Output[47][0]',
#                                                                   'Decoder[47][1]',
#                                                                   'Decoder[47][2]',
#                                                                   'Dense_Timestamp_Output[48][0]',
#                                                                   'Decoder[48][1]',
#                                                                   'Decoder[48][2]',
#                                                                   'Dense_Timestamp_Output[49][0]',
#                                                                   'Decoder[49][1]',
#                                                                   'Decoder[49][2]',
#                                                                   'Dense_Timestamp_Output[50][0]',
#                                                                   'Decoder[50][1]',
#                                                                   'Decoder[50][2]',
#                                                                   'Dense_Timestamp_Output[51][0]',
#                                                                   'Decoder[51][1]',
#                                                                   'Decoder[51][2]',
#                                                                   'Dense_Timestamp_Output[52][0]',
#                                                                   'Decoder[52][1]',
#                                                                   'Decoder[52][2]',
#                                                                   'Dense_Timestamp_Output[53][0]',
#                                                                   'Decoder[53][1]',
#                                                                   'Decoder[53][2]',
#                                                                   'Dense_Timestamp_Output[54][0]',
#                                                                   'Decoder[54][1]',
#                                                                   'Decoder[54][2]',
#                                                                   'Dense_Timestamp_Output[55][0]',
#                                                                   'Decoder[55][1]',
#                                                                   'Decoder[55][2]',
#                                                                   'Dense_Timestamp_Output[56][0]',
#                                                                   'Decoder[56][1]',
#                                                                   'Decoder[56][2]',
#                                                                   'Dense_Timestamp_Output[57][0]',
#                                                                   'Decoder[57][1]',
#                                                                   'Decoder[57][2]',
#                                                                   'Dense_Timestamp_Output[58][0]',
#                                                                   'Decoder[58][1]',
#                                                                   'Decoder[58][2]',
#                                                                   'Dense_Timestamp_Output[59][0]',
#                                                                   'Decoder[59][1]',
#                                                                   'Decoder[59][2]',
#                                                                   'Dense_Timestamp_Output[60][0]',
#                                                                   'Decoder[60][1]',
#                                                                   'Decoder[60][2]',
#                                                                   'Dense_Timestamp_Output[61][0]',
#                                                                   'Decoder[61][1]',
#                                                                   'Decoder[61][2]',
#                                                                   'Dense_Timestamp_Output[62][0]',
#                                                                   'Decoder[62][1]',
#                                                                   'Decoder[62][2]',
#                                                                   'Dense_Timestamp_Output[63][0]',
#                                                                   'Decoder[63][1]',
#                                                                   'Decoder[63][2]',
#                                                                   'Dense_Timestamp_Output[64][0]',
#                                                                   'Decoder[64][1]',
#                                                                   'Decoder[64][2]',
#                                                                   'Dense_Timestamp_Output[65][0]',
#                                                                   'Decoder[65][1]',
#                                                                   'Decoder[65][2]',
#                                                                   'Dense_Timestamp_Output[66][0]',
#                                                                   'Decoder[66][1]',
#                                                                   'Decoder[66][2]',
#                                                                   'Dense_Timestamp_Output[67][0]',
#                                                                   'Decoder[67][1]',
#                                                                   'Decoder[67][2]',
#                                                                   'Dense_Timestamp_Output[68][0]',
#                                                                   'Decoder[68][1]',
#                                                                   'Decoder[68][2]',
#                                                                   'Dense_Timestamp_Output[69][0]',
#                                                                   'Decoder[69][1]',
#                                                                   'Decoder[69][2]',
#                                                                   'Dense_Timestamp_Output[70][0]',
#                                                                   'Decoder[70][1]',
#                                                                   'Decoder[70][2]',
#                                                                   'Dense_Timestamp_Output[71][0]',
#                                                                   'Decoder[71][1]',
#                                                                   'Decoder[71][2]',
#                                                                   'Dense_Timestamp_Output[72][0]',
#                                                                   'Decoder[72][1]',
#                                                                   'Decoder[72][2]',
#                                                                   'Dense_Timestamp_Output[73][0]',
#                                                                   'Decoder[73][1]',
#                                                                   'Decoder[73][2]',
#                                                                   'Dense_Timestamp_Output[74][0]',
#                                                                   'Decoder[74][1]',
#                                                                   'Decoder[74][2]',
#                                                                   'Dense_Timestamp_Output[75][0]',
#                                                                   'Decoder[75][1]',
#                                                                   'Decoder[75][2]',
#                                                                   'Dense_Timestamp_Output[76][0]',
#                                                                   'Decoder[76][1]',
#                                                                   'Decoder[76][2]',
#                                                                   'Dense_Timestamp_Output[77][0]',
#                                                                   'Decoder[77][1]',
#                                                                   'Decoder[77][2]',
#                                                                   'Dense_Timestamp_Output[78][0]',
#                                                                   'Decoder[78][1]',
#                                                                   'Decoder[78][2]',
#                                                                   'Dense_Timestamp_Output[79][0]',
#                                                                   'Decoder[79][1]',
#                                                                   'Decoder[79][2]',
#                                                                   'Dense_Timestamp_Output[80][0]',
#                                                                   'Decoder[80][1]',
#                                                                   'Decoder[80][2]',
#                                                                   'Dense_Timestamp_Output[81][0]',
#                                                                   'Decoder[81][1]',
#                                                                   'Decoder[81][2]',
#                                                                   'Dense_Timestamp_Output[82][0]',
#                                                                   'Decoder[82][1]',
#                                                                   'Decoder[82][2]',
#                                                                   'Dense_Timestamp_Output[83][0]',
#                                                                   'Decoder[83][1]',
#                                                                   'Decoder[83][2]',
#                                                                   'Dense_Timestamp_Output[84][0]',
#                                                                   'Decoder[84][1]',
#                                                                   'Decoder[84][2]',
#                                                                   'Dense_Timestamp_Output[85][0]',
#                                                                   'Decoder[85][1]',
#                                                                   'Decoder[85][2]',
#                                                                   'Dense_Timestamp_Output[86][0]',
#                                                                   'Decoder[86][1]',
#                                                                   'Decoder[86][2]',
#                                                                   'Dense_Timestamp_Output[87][0]',
#                                                                   'Decoder[87][1]',
#                                                                   'Decoder[87][2]',
#                                                                   'Dense_Timestamp_Output[88][0]',
#                                                                   'Decoder[88][1]',
#                                                                   'Decoder[88][2]',
#                                                                   'Dense_Timestamp_Output[89][0]',
#                                                                   'Decoder[89][1]',
#                                                                   'Decoder[89][2]',
#                                                                   'Dense_Timestamp_Output[90][0]',
#                                                                   'Decoder[90][1]',
#                                                                   'Decoder[90][2]',
#                                                                   'Dense_Timestamp_Output[91][0]',
#                                                                   'Decoder[91][1]',
#                                                                   'Decoder[91][2]',
#                                                                   'Dense_Timestamp_Output[92][0]',
#                                                                   'Decoder[92][1]',
#                                                                   'Decoder[92][2]',
#                                                                   'Dense_Timestamp_Output[93][0]',
#                                                                   'Decoder[93][1]',
#                                                                   'Decoder[93][2]',
#                                                                   'Dense_Timestamp_Output[94][0]',
#                                                                   'Decoder[94][1]',
#                                                                   'Decoder[94][2]',
#                                                                   'Dense_Timestamp_Output[95][0]',
#                                                                   'Decoder[95][1]',
#                                                                   'Decoder[95][2]',
#                                                                   'Dense_Timestamp_Output[96][0]',
#                                                                   'Decoder[96][1]',
#                                                                   'Decoder[96][2]',
#                                                                   'Dense_Timestamp_Output[97][0]',
#                                                                   'Decoder[97][1]',
#                                                                   'Decoder[97][2]',
#                                                                   'Dense_Timestamp_Output[98][0]',
#                                                                   'Decoder[98][1]',
#                                                                   'Decoder[98][2]',
#                                                                   'Dense_Timestamp_Output[99][0]',
#                                                                   'Decoder[99][1]',
#                                                                   'Decoder[99][2]',
#                                                                   'Dense_Timestamp_Output[100][0]'
#                                                                  , 'Decoder[100][1]',
#                                                                   'Decoder[100][2]',
#                                                                   'Dense_Timestamp_Output[101][0]'
#                                                                  , 'Decoder[101][1]',
#                                                                   'Decoder[101][2]',
#                                                                   'Dense_Timestamp_Output[102][0]'
#                                                                  , 'Decoder[102][1]',
#                                                                   'Decoder[102][2]',
#                                                                   'Dense_Timestamp_Output[103][0]'
#                                                                  , 'Decoder[103][1]',
#                                                                   'Decoder[103][2]',
#                                                                   'Dense_Timestamp_Output[104][0]'
#                                                                  , 'Decoder[104][1]',
#                                                                   'Decoder[104][2]',
#                                                                   'Dense_Timestamp_Output[105][0]'
#                                                                  , 'Decoder[105][1]',
#                                                                   'Decoder[105][2]',
#                                                                   'Dense_Timestamp_Output[106][0]'
#                                                                  , 'Decoder[106][1]',
#                                                                   'Decoder[106][2]',
#                                                                   'Dense_Timestamp_Output[107][0]'
#                                                                  , 'Decoder[107][1]',
#                                                                   'Decoder[107][2]',
#                                                                   'Dense_Timestamp_Output[108][0]'
#                                                                  , 'Decoder[108][1]',
#                                                                   'Decoder[108][2]',
#                                                                   'Dense_Timestamp_Output[109][0]'
#                                                                  , 'Decoder[109][1]',
#                                                                   'Decoder[109][2]',
#                                                                   'Dense_Timestamp_Output[110][0]'
#                                                                  , 'Decoder[110][1]',
#                                                                   'Decoder[110][2]',
#                                                                   'Dense_Timestamp_Output[111][0]'
#                                                                  , 'Decoder[111][1]',
#                                                                   'Decoder[111][2]',
#                                                                   'Dense_Timestamp_Output[112][0]'
#                                                                  , 'Decoder[112][1]',
#                                                                   'Decoder[112][2]',
#                                                                   'Dense_Timestamp_Output[113][0]'
#                                                                  , 'Decoder[113][1]',
#                                                                   'Decoder[113][2]',
#                                                                   'Dense_Timestamp_Output[114][0]'
#                                                                  , 'Decoder[114][1]',
#                                                                   'Decoder[114][2]',
#                                                                   'Dense_Timestamp_Output[115][0]'
#                                                                  , 'Decoder[115][1]',
#                                                                   'Decoder[115][2]',
#                                                                   'Dense_Timestamp_Output[116][0]'
#                                                                  , 'Decoder[116][1]',
#                                                                   'Decoder[116][2]',
#                                                                   'Dense_Timestamp_Output[117][0]'
#                                                                  , 'Decoder[117][1]',
#                                                                   'Decoder[117][2]',
#                                                                   'Dense_Timestamp_Output[118][0]'
#                                                                  , 'Decoder[118][1]',
#                                                                   'Decoder[118][2]',
#                                                                   'Dense_Timestamp_Output[119][0]'
#                                                                  , 'Decoder[119][1]',
#                                                                   'Decoder[119][2]',
#                                                                   'Dense_Timestamp_Output[120][0]'
#                                                                  , 'Decoder[120][1]',
#                                                                   'Decoder[120][2]',
#                                                                   'Dense_Timestamp_Output[121][0]'
#                                                                  , 'Decoder[121][1]',
#                                                                   'Decoder[121][2]',
#                                                                   'Dense_Timestamp_Output[122][0]'
#                                                                  , 'Decoder[122][1]',
#                                                                   'Decoder[122][2]',
#                                                                   'Dense_Timestamp_Output[123][0]'
#                                                                  , 'Decoder[123][1]',
#                                                                   'Decoder[123][2]',
#                                                                   'Dense_Timestamp_Output[124][0]'
#                                                                  , 'Decoder[124][1]',
#                                                                   'Decoder[124][2]',
#                                                                   'Dense_Timestamp_Output[125][0]'
#                                                                  , 'Decoder[125][1]',
#                                                                   'Decoder[125][2]',
#                                                                   'Dense_Timestamp_Output[126][0]'
#                                                                  , 'Decoder[126][1]',
#                                                                   'Decoder[126][2]',
#                                                                   'Dense_Timestamp_Output[127][0]'
#                                                                  , 'Decoder[127][1]',
#                                                                   'Decoder[127][2]',
#                                                                   'Dense_Timestamp_Output[128][0]'
#                                                                  , 'Decoder[128][1]',
#                                                                   'Decoder[128][2]',
#                                                                   'Dense_Timestamp_Output[129][0]'
#                                                                  , 'Decoder[129][1]',
#                                                                   'Decoder[129][2]',
#                                                                   'Dense_Timestamp_Output[130][0]'
#                                                                  , 'Decoder[130][1]',
#                                                                   'Decoder[130][2]',
#                                                                   'Dense_Timestamp_Output[131][0]'
#                                                                  , 'Decoder[131][1]',
#                                                                   'Decoder[131][2]',
#                                                                   'Dense_Timestamp_Output[132][0]'
#                                                                  , 'Decoder[132][1]',
#                                                                   'Decoder[132][2]',
#                                                                   'Dense_Timestamp_Output[133][0]'
#                                                                  , 'Decoder[133][1]',
#                                                                   'Decoder[133][2]',
#                                                                   'Dense_Timestamp_Output[134][0]'
#                                                                  , 'Decoder[134][1]',
#                                                                   'Decoder[134][2]',
#                                                                   'Dense_Timestamp_Output[135][0]'
#                                                                  , 'Decoder[135][1]',
#                                                                   'Decoder[135][2]',
#                                                                   'Dense_Timestamp_Output[136][0]'
#                                                                  , 'Decoder[136][1]',
#                                                                   'Decoder[136][2]',
#                                                                   'Dense_Timestamp_Output[137][0]'
#                                                                  , 'Decoder[137][1]',
#                                                                   'Decoder[137][2]',
#                                                                   'Dense_Timestamp_Output[138][0]'
#                                                                  , 'Decoder[138][1]',
#                                                                   'Decoder[138][2]',
#                                                                   'Dense_Timestamp_Output[139][0]'
#                                                                  , 'Decoder[139][1]',
#                                                                   'Decoder[139][2]',
#                                                                   'Dense_Timestamp_Output[140][0]'
#                                                                  , 'Decoder[140][1]',
#                                                                   'Decoder[140][2]',
#                                                                   'Dense_Timestamp_Output[141][0]'
#                                                                  , 'Decoder[141][1]',
#                                                                   'Decoder[141][2]',
#                                                                   'Dense_Timestamp_Output[142][0]'
#                                                                  , 'Decoder[142][1]',
#                                                                   'Decoder[142][2]',
#                                                                   'Dense_Timestamp_Output[143][0]'
#                                                                  , 'Decoder[143][1]',
#                                                                   'Decoder[143][2]',
#                                                                   'Dense_Timestamp_Output[144][0]'
#                                                                  , 'Decoder[144][1]',
#                                                                   'Decoder[144][2]',
#                                                                   'Dense_Timestamp_Output[145][0]'
#                                                                  , 'Decoder[145][1]',
#                                                                   'Decoder[145][2]',
#                                                                   'Dense_Timestamp_Output[146][0]'
#                                                                  , 'Decoder[146][1]',
#                                                                   'Decoder[146][2]',
#                                                                   'Dense_Timestamp_Output[147][0]'
#                                                                  , 'Decoder[147][1]',
#                                                                   'Decoder[147][2]',
#                                                                   'Dense_Timestamp_Output[148][0]'
#                                                                  , 'Decoder[148][1]',
#                                                                   'Decoder[148][2]',
#                                                                   'Dense_Timestamp_Output[149][0]'
#                                                                  , 'Decoder[149][1]',
#                                                                   'Decoder[149][2]',
#                                                                   'Dense_Timestamp_Output[150][0]'
#                                                                  , 'Decoder[150][1]',
#                                                                   'Decoder[150][2]',
#                                                                   'Dense_Timestamp_Output[151][0]'
#                                                                  , 'Decoder[151][1]',
#                                                                   'Decoder[151][2]',
#                                                                   'Dense_Timestamp_Output[152][0]'
#                                                                  , 'Decoder[152][1]',
#                                                                   'Decoder[152][2]',
#                                                                   'Dense_Timestamp_Output[153][0]'
#                                                                  , 'Decoder[153][1]',
#                                                                   'Decoder[153][2]',
#                                                                   'Dense_Timestamp_Output[154][0]'
#                                                                  , 'Decoder[154][1]',
#                                                                   'Decoder[154][2]',
#                                                                   'Dense_Timestamp_Output[155][0]'
#                                                                  , 'Decoder[155][1]',
#                                                                   'Decoder[155][2]',
#                                                                   'Dense_Timestamp_Output[156][0]'
#                                                                  , 'Decoder[156][1]',
# ...
#                                                                   'Dense_Timestamp_Output[94][0]',
#                                                                   'Dense_Timestamp_Output[95][0]',
#                                                                   'Dense_Timestamp_Output[96][0]',
#                                                                   'Dense_Timestamp_Output[97][0]',
#                                                                   'Dense_Timestamp_Output[98][0]',
#                                                                   'Dense_Timestamp_Output[99][0]',
#                                                                   'Dense_Timestamp_Output[100][0]'
#                                                                  , 'Dense_Timestamp_Output[101][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[102][0]'
#                                                                  , 'Dense_Timestamp_Output[103][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[104][0]'
#                                                                  , 'Dense_Timestamp_Output[105][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[106][0]'
#                                                                  , 'Dense_Timestamp_Output[107][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[108][0]'
#                                                                  , 'Dense_Timestamp_Output[109][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[110][0]'
#                                                                  , 'Dense_Timestamp_Output[111][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[112][0]'
#                                                                  , 'Dense_Timestamp_Output[113][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[114][0]'
#                                                                  , 'Dense_Timestamp_Output[115][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[116][0]'
#                                                                  , 'Dense_Timestamp_Output[117][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[118][0]'
#                                                                  , 'Dense_Timestamp_Output[119][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[120][0]'
#                                                                  , 'Dense_Timestamp_Output[121][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[122][0]'
#                                                                  , 'Dense_Timestamp_Output[123][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[124][0]'
#                                                                  , 'Dense_Timestamp_Output[125][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[126][0]'
#                                                                  , 'Dense_Timestamp_Output[127][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[128][0]'
#                                                                  , 'Dense_Timestamp_Output[129][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[130][0]'
#                                                                  , 'Dense_Timestamp_Output[131][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[132][0]'
#                                                                  , 'Dense_Timestamp_Output[133][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[134][0]'
#                                                                  , 'Dense_Timestamp_Output[135][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[136][0]'
#                                                                  , 'Dense_Timestamp_Output[137][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[138][0]'
#                                                                  , 'Dense_Timestamp_Output[139][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[140][0]'
#                                                                  , 'Dense_Timestamp_Output[141][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[142][0]'
#                                                                  , 'Dense_Timestamp_Output[143][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[144][0]'
#                                                                  , 'Dense_Timestamp_Output[145][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[146][0]'
#                                                                  , 'Dense_Timestamp_Output[147][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[148][0]'
#                                                                  , 'Dense_Timestamp_Output[149][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[150][0]'
#                                                                  , 'Dense_Timestamp_Output[151][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[152][0]'
#                                                                  , 'Dense_Timestamp_Output[153][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[154][0]'
#                                                                  , 'Dense_Timestamp_Output[155][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[156][0]'
#                                                                  , 'Dense_Timestamp_Output[157][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[158][0]'
#                                                                  , 'Dense_Timestamp_Output[159][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[160][0]'
#                                                                  , 'Dense_Timestamp_Output[161][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[162][0]'
#                                                                  , 'Dense_Timestamp_Output[163][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[164][0]'
#                                                                  , 'Dense_Timestamp_Output[165][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[166][0]'
#                                                                  , 'Dense_Timestamp_Output[167][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[168][0]'
#                                                                  , 'Dense_Timestamp_Output[169][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[170][0]'
#                                                                  , 'Dense_Timestamp_Output[171][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[172][0]'
#                                                                  , 'Dense_Timestamp_Output[173][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[174][0]'
#                                                                  , 'Dense_Timestamp_Output[175][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[176][0]'
#                                                                  , 'Dense_Timestamp_Output[177][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[178][0]'
#                                                                  , 'Dense_Timestamp_Output[179][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[180][0]'
#                                                                  , 'Dense_Timestamp_Output[181][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[182][0]'
#                                                                  , 'Dense_Timestamp_Output[183][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[184][0]'
#                                                                  , 'Dense_Timestamp_Output[185][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[186][0]'
#                                                                  , 'Dense_Timestamp_Output[187][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[188][0]'
#                                                                  , 'Dense_Timestamp_Output[189][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[190][0]'
#                                                                  , 'Dense_Timestamp_Output[191][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[192][0]'
#                                                                  , 'Dense_Timestamp_Output[193][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[194][0]'
#                                                                  , 'Dense_Timestamp_Output[195][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[196][0]'
#                                                                  , 'Dense_Timestamp_Output[197][0]
#                                                                  ',
#                                                                   'Dense_Timestamp_Output[198][0]'
#                                                                  , 'Dense_Timestamp_Output[199][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 1,019
# Trainable params: 1,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)

if encoder_input_data.shape[0] == 1:
    encoder_input_data = tf.reshape(encoder_input_data, encoder_input_data.shape[1:])
    decoder_input_data = tf.reshape(decoder_input_data, decoder_input_data.shape[1:])
    decoder_target_data = tf.reshape(decoder_target_data, decoder_target_data.shape[1:])
    print(encoder_input_data.shape)
    print(decoder_input_data.shape)
    print(decoder_target_data.shape)

inputs = tf.data.Dataset.zip(tuple([tf.data.Dataset.from_tensor_slices((encoder_input_data)), tf.data.Dataset.from_tensor_slices((decoder_input_data))]))
outputs = tf.data.Dataset.from_tensor_slices((decoder_target_data))

train_dataset = tf.data.Dataset.zip((inputs, outputs))
train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(10)

model.fit(train_dataset,
          batch_size=BATCH_SIZE,
          epochs=10,
          verbose=1,
        )
# Out:
# (1, 27096, 200, 43)
# (1, 27096, 1, 57)
# (1, 27096, 200, 57)
# (27096, 200, 43)
# (27096, 1, 57)
# (27096, 200, 57)
# Epoch 1/10
# 2023-01-17 12:52:15.334295: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-01-17 12:52:26.564627: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f14eac63300 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-17 12:52:26.564660: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-01-17 12:52:26.568298: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-17 12:52:26.748228: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:52:26.880406: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 6.1
# 2023-01-17 12:52:26.880438: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-01-17 12:52:26.881448: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-01-17 12:52:26.945608: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:52:27.173426: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:52:27.244811: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2023-01-17 12:52:27.353475: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
#   1/847 [..............................] - ETA: 38:34:18 - loss: 10335.8135
# 2023-01-17 12:52:27.482547: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:109] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 847/847 [==============================] - 295s 155ms/step - loss: 10363.0010
# Epoch 2/10
# 847/847 [==============================] - 132s 156ms/step - loss: 10238.4551
# Epoch 3/10
# 847/847 [==============================] - 132s 156ms/step - loss: 10231.4736
# Epoch 4/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2510
# Epoch 5/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2363
# Epoch 6/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2305
# Epoch 7/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2275
# Epoch 8/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2275
# Epoch 9/10
# 847/847 [==============================] - 133s 157ms/step - loss: 10231.2266
# Epoch 10/10
# 847/847 [==============================] - 133s 158ms/step - loss: 10231.2266

# %% [markdown]
# ### Predict Function

# %%
def predict(enc_inputs):
    # Init Decoder Input
    dec_state = np.zeros((1, target_size))
    dec_state[0, start_correction_index] = 1.
    all_outputs = []
    for enc_input in enc_inputs:
        # Format Model Input: (Encoder, Decoder)
        format_enc_input = np.expand_dims(enc_input, 0)
        format_dec_state = np.expand_dims(dec_state, 0)
        # print(format_enc_input.shape)
        # print(format_dec_state.shape)

        # Model Output
        outputs = model.predict([format_enc_input, format_dec_state])
        outputs = np.squeeze(outputs)
        # print('output:', outputs.shape)
        all_outputs.append(np.squeeze(outputs))
        dec_state = outputs[-1]
        dec_state = np.expand_dims(dec_state, 0)
        # print(dec_state.shape)
    return np.concatenate(all_outputs, axis=0)

# %% [markdown]
# # **Midi Format Output**

# %%
def generate_dataset(input_dir: str, data_size=-1, batch_per_files=True):
    # using tf.data.Dataset API to create dataset
    x_paths = [] # input path
    y_paths = [] # ans file path
    offsets = [] # starting point of a piece
    titles = []
    data_cnt = 0
    for file_name in os.listdir(input_dir): # 'Scan Files'
        if data_cnt==data_size-1: break
        if file_name.endswith(".ans.npy"):
            data_cnt+=1
            y_path = str(os.path.join(input_dir, file_name))
            x_path = str(os.path.join(input_dir, file_name[:-8] + ".npy"))
            assert os.path.exists(x_path), f"corresponding input file {x_path} doesn't exist"

            # split and pad data into PIECE_LEN
            y_content = np.load(y_path)
            for offset in range(0, y_content.shape[0], PIECE_LEN):
                y_paths.append(y_path)
                x_paths.append(x_path)
                offsets.append(offset)
                titles.append(file_name[:-8])

    paths = list(zip(x_paths, y_paths, offsets))
    i = 0
    while(i < len(paths)): # Batch per Files Handler
        dataset = []
        temp_dataset = []
        flag = False
        while(i < len(paths)):
            if not batch_per_files:
                dataset.append(load_npy_data(*paths[i]))
            else:
                offset = paths[i][2]
                if offset == 0:
                    temp_dataset = load_npy_data(*paths[i])
                    flag = True
                    i += 1
                    break
                elif flag:
                    dataset = []    # Reset Batch
                    dataset.append(temp_dataset)
                    dataset.append(load_npy_data(*paths[i]))
                else:
                    dataset.append(load_npy_data(*paths[i]))
            i += 1
        
        # Skip kickstart dataset+
        if len(dataset) == 0: continue

        # Package
        dataset = list(zip(*dataset))
        encoder_input_data = np.array(dataset[0])
        decoder_input_data = np.array(dataset[1])
        decoder_target_data = np.array(dataset[2])
        print(encoder_input_data.shape)
        print(decoder_input_data.shape)
        print(decoder_target_data.shape)

        # Shuffle
        perm_id = np.random.shuffle(np.arange(encoder_input_data.shape[0]))
        encoder_input_data = encoder_input_data[perm_id]
        decoder_input_data = decoder_input_data[perm_id]
        decoder_target_data = decoder_target_data[perm_id]

        yield encoder_input_data, decoder_input_data, decoder_target_data, titles[i-1]
    yield encoder_input_data, decoder_input_data, decoder_target_data, titles[-1]

# %%
import midi_np_translation.output2midi_v2 as output2midi

for test_encoder_input_data, _, _, title in generate_dataset(ROOT+"/preprocessed_dataset/irealpro_dataset_v2", 5, batch_per_files=True):
    test_encoder_input_data = np.reshape(test_encoder_input_data, test_encoder_input_data.shape[1:])
    # print(test_encoder_input_data.shape)
    print(f'Generating: {title}')
    pred_result = predict(test_encoder_input_data)
    output2midi.output_to_midi(pred_result, output_path=f"{title}")
# Out:
# (8, 200, 43)
# (8, 1, 57)
# (8, 200, 57)
# Generating: I'll Close My Eyes_p4.mid
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 121ms/step
# (7, 200, 43)
# (7, 1, 57)
# (7, 200, 57)
# Generating: Barbara_o0.mid
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# (4, 200, 43)
# (4, 1, 57)
# (4, 200, 57)
# Generating: I Like The Likes Of You_d4.mid
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# (7, 200, 43)
# (7, 1, 57)
# (7, 200, 57)
# Generating: I Like The Likes Of You_d4.mid
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# Generating: I Like The Likes Of You_d4.mid
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step

# %%
model.save("experiments/11_EncoderDecoder/saved_model/")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input_Encoder, Input_Decoder with unsupported characters which will be renamed to input_encoder, input_decoder in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: experiments/11_EncoderDecoder/assets
# INFO:tensorflow:Assets written to: experiments/11_EncoderDecoder/assets
