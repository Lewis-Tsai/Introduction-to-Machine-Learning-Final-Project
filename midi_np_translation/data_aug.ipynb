# %%
import pretty_midi
import os

# %%
os.chdir("..")

# %% [markdown]
# ## key transposing

# %%
DATA_DIR = "./"

CHROMA_FS = 100

BASS_UPPER_BOUND = pretty_midi.note_name_to_number("Db5")
BASS_LOWER_BOUND = pretty_midi.note_name_to_number("B0")
BASS_REST_THRESH = 0.25

# %%
mdid_data = pretty_midi.PrettyMIDI("input_midi/Jazz_ML_MIDI/Jazz Midi/AllofYou.mid")

# %%
def find_bass_instrument(midi_data: pretty_midi.PrettyMIDI):
    for instr in midi_data.instruments:
        instr: pretty_midi.Instrument
        if instr.program == 32 and not instr.is_drum:
            return instr
    for instr in midi_data.instruments:
        instr: pretty_midi.Instrument
        if instr.program > 32 and instr.program <= 39 and not instr.is_drum:
            return instr

# %%
def transpose_notation(distance):
    if distance == 0:
        return "o0"
    elif distance < 0:
        return "d" + str(abs(distance))
    else:
        return "p" + str(distance)

# %%
def find_transpose_range(midi_data: pretty_midi.PrettyMIDI):
    bass_track = find_bass_instrument(midi_data)
    assert bass_track != None, "no bass"
    highest_pitch = max(bass_track.notes, key=lambda note:note.pitch).pitch
    lowest_pitch = min(bass_track.notes, key=lambda note:note.pitch).pitch
    # print(highest_pitch, lowest_pitch)
    transpose_upper_bound = min(6, BASS_UPPER_BOUND-highest_pitch)
    transpose_lower_bound = max(-5, BASS_LOWER_BOUND-lowest_pitch)
    return tuple(range(transpose_lower_bound, transpose_upper_bound+1))

find_transpose_range(mdid_data)
# Out:
# (2, 3, 4, 5, 6)

# %%
def transpose_all_instruments(midi_data: pretty_midi.PrettyMIDI, distance):
    for instr in midi_data.instruments:
        instr: pretty_midi.Instrument
        if instr.is_drum:
            continue
        for note in instr.notes:
            note: pretty_midi.Note
            note.pitch += distance
    return midi_data

# %%
def transpose_augmentation(midi_name: str, input_dir, output_dir):
    midi_data = pretty_midi.PrettyMIDI(os.path.join(input_dir, midi_name))
    transpose_range = find_transpose_range(midi_data)
    midi_data = transpose_all_instruments(midi_data, transpose_range[0])
    for d in transpose_range:
        output_midi_name = midi_name[:-4] + "_" + transpose_notation(d) + ".mid"
        midi_data.write(os.path.join(output_dir, output_midi_name))
        midi_data = transpose_all_instruments(midi_data, 1)

# %%
INPUT_DIRS = ["input_midi/Jazz_ML_MIDI/Jazz Midi/", "input_midi/jazz_standards/"]
OUTPUT_DIR = "input_midi/transpose_augmentation/"

for input_dir in INPUT_DIRS:
    for file_name in sorted(os.listdir(input_dir)):
        try:
            transpose_augmentation(file_name, input_dir, OUTPUT_DIR)
            print(input_dir + file_name)
        except AssertionError as e:
            print(input_dir + file_name + ": " + str(e))
        except Exception as e:
            print(input_dir + file_name + ": " + str(e))
# Out:
# input_midi/Jazz_ML_MIDI/Jazz Midi/2ndMovementOfSinisterFootwear.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/55Dive.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/5To10.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/634-5789.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/914.mid: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/ABC.mid: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/ACertainSmile.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/ACrush.mid: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/AFifthofBeethoven.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/AKindOfTherapy.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/ALittleBitofBlues.mid: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/
id: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/comeflywithme.mid
# input_midi/Jazz_ML_MIDI/Jazz Midi/mid: no bass
# input_midi/Jazz_ML_MIDI/Jazz Midi/onceuponatimeinspace.mid
# input_midi/jazz_standards/4on6.mid
# input_midi/jazz_standards/AFoggyDayInLondonTown.MID
# input_midi/jazz_standards/ANightInTunesiaTrio.MID
# input_midi/jazz_standards/AfroBlues.MID
# input_midi/jazz_standards/Afternoon_in_Paris.mid
# input_midi/jazz_standards/AintMisbehaving.MID
# input_midi/jazz_standards/AlicesRestaurant.MID
# input_midi/jazz_standards/AllBlues.MID
# input_midi/jazz_standards/AllMyTomorrows.MID
# input_midi/jazz_standards/AllOfMe.MID
# input_midi/jazz_standards/AllTheThingsYouAre.MID
# input_midi/jazz_standards/AloneTogether.MID
# input_midi/jazz_standards/Along_came_Betty.mid
# input_midi/jazz_standards/AlwaysWithYou.MID
# input_midi/jazz_standards/AnaMaria.MID
# input_midi/jazz_standards/AngelEyes.MID
# input_midi/jazz_standards/AnightInTunesia.MID
# input_midi/jazz_standards/Anthropology.MID
# input_midi/jazz_standards/Anything Goes.MID
# input_midi/jazz_standards/AprilInParis.MID
# input_midi/jazz_standards/AuPrivave.mid
# input_midi/jazz_standards/AutumnLeaves.MID
# input_midi/jazz_standards/BagsGroove.MID
# input_midi/jazz_standards/BbBlues.MID
# input_midi/jazz_standards/Beautiful_Love.mid
# input_midi/jazz_standards/BeautyAndTheBeast.MID
# input_midi/jazz_standards/Bebop.MID
# input_midi/jazz_standards/BerniesTune.MID
# input_midi/jazz_standards/BessiesBlues.MID
# input_midi/jazz_standards/BetterDaysAhead.MID
# input_midi/jazz_standards/BigBillBroonzy.MID
# input_midi/jazz_standards/BigTime.MID
# input_midi/jazz_standards/BilliesBounce.MID
# input_midi/jazz_standards/Birdland.MID
# input_midi/jazz_standards/BirthOfTheBlues.MID
# input_midi/jazz_standards/BlackNacissus.mid
# input_midi/jazz_standards/BlackOrpheus.mid
# input_midi/jazz_standards/BlueInGreen.MID
# input_midi/jazz_standards/BlueMonk.MID
# input_midi/jazz_standards/BlueRondo.mid
# input_midi/jazz_standards/Blue_In_Green.mid
# input_midi/jazz_standards/Chega_de_saudade2.mid
# input_midi/jazz_standards/ChegadeSaudade.mid
# input_midi/jazz_standards/ComeRainOrComeShine.mid
# input_midi/jazz_standards/DaysOfWine&Roses.mid
# input_midi/jazz_standards/Desafinado.mid
# input_midi/jazz_standards/Dig.mid: no bass
# input_midi/jazz_standards/DolphinDance.mid
# input_midi/jazz_standards/EastOfTheSun.mid: no bass
# input_midi/jazz_standards/Epistrophy.mid
# input_midi/jazz_standards/Half_nelson.mid
# input_midi/jazz_standards/HaveUmetMissJones.mid
# input_midi/jazz_standards/HeresThatRainyDay.mid
# input_midi/jazz_standards/How_Insensitive.mid
# input_midi/jazz_standards/How_high_the_moon.mid
# input_midi/jazz_standards/IConcentrateOnYou.mid
# input_midi/jazz_standards/ICouldWriteABook.mid
# input_midi/jazz_standards/IdntKnowWhatTime.mid
# input_midi/jazz_standards/IfIWereABell.mid
# input_midi/jazz_standards/IllTakeRomance.mid
# input_midi/jazz_standards/InWalkedBud.mid
# input_midi/jazz_standards/InYourOwnSweetWay.mid
# input_midi/jazz_standards/InaSentimentalMood.mid
# input_midi/jazz_standards/Invitation.mid
# input_midi/jazz_standards/Israel.mid
# input_midi/jazz_standards/ItsAllrightWithMe.mid: no bass
# input_midi/jazz_standards/Jaco.mid
# input_midi/jazz_standards/Joshua.mid
# input_midi/jazz_standards/JoySpring.mid
# input_midi/jazz_standards/JustFriends.mid
# input_midi/jazz_standards/Ladybird.mid
# input_midi/jazz_standards/LibertyCity.mid
# input_midi/jazz_standards/LushLife.mid: no bass
# input_midi/jazz_standards/MackTheKnife.mid
# input_midi/jazz_standards/Manteca.mid
# input_midi/jazz_standards/Moanin.mid
# input_midi/jazz_standards/Move.mid
# input_midi/jazz_standards/MrPC.mid
# input_midi/jazz_standards/My1&onlyLove.mid
# input_midi/jazz_standards/MyFoolisheart.mid
# input_midi/jazz_standards/MyFunnyValentine.mid
# input_midi/jazz_standards/Naima.mid
# input_midi/jazz_standards/Night_in_tunesia.mid
# input_midi/jazz_standards/NowsTheTime.mid
# input_midi/jazz_standards/Nutville.mid
# input_midi/jazz_standards/OldDevilMoon.mid
# input_midi/jazz_standards/One_Note_Samba.mid
# input_midi/jazz_standards/OpusDeFunk.mid: Could not decode key with 0 flats and mode 255
# input_midi/jazz_standards/PerisScope.mid
# input_midi/jazz_standards/Petite_fleur.mid
# input_midi/jazz_standards/PhaseDance.mid
# input_midi/jazz_standards/Poinciana.mid: Could not decode key with 0 flats and mode 2
# input_midi/jazz_standards/Recordame.mid
# input_midi/jazz_standards/Rhythm-A-Ning.mid
# input_midi/jazz_standards/RomanticWarrior.mid
# input_midi/jazz_standards/Scrapple.mid
# input_midi/jazz_standards/ShinyStockings.mid
# input_midi/jazz_standards/SinceIFell4u.mid
# input_midi/jazz_standards/SoDancoSamba.mid
# input_midi/jazz_standards/Soft_as_a_morning_sunrise.mid
# input_midi/jazz_standards/SpeakLikeAChild.mid
# input_midi/jazz_standards/SpeakLow.mid
# input_midi/jazz_standards/SpeakNoEvil.mid
# input_midi/jazz_standards/StThomas.mid
# input_midi/jazz_standards/Stella_by_Starlight.mid: no bass
# input_midi/jazz_standards/TakeFive.mid
# input_midi/jazz_standards/Take_the_A_train.mid
# input_midi/jazz_standards/Teentown.mid
# input_midi/jazz_standards/Tenderly.mid: no bass
# input_midi/jazz_standards/TheChicken.mid
# input_midi/jazz_standards/TimeAfterTime.mid
# input_midi/jazz_standards/Triste.mid: no bass
# input_midi/jazz_standards/Tristeza.mid
# input_midi/jazz_standards/VeryEarly.mid
# input_midi/jazz_standards/Waltz4Debby.mid
# input_midi/jazz_standards/WatchWhatHappens.mid
# input_midi/jazz_standards/Wave.mid: no bass
# input_midi/jazz_standards/WhisperNot(trio).mid
# input_midi/jazz_standards/WhoCanIturnTo.mid
# input_midi/jazz_standards/You&night&music.mid
# input_midi/jazz_standards/YouSteppedOutOfaDream.mid
