# %%
import midi_np_translation.midi2input as midi2input
import os
import numpy as np

# %%
input_output_directories = [
    ("input_midi/Jazz_ML_MIDI/Jazz Midi/", "preprocessed_dataset/Jazz_ML_MIDI/"), 
    ("input_midi/jazz_standards/", "preprocessed_dataset/jazz_standards/")
]

if not os.path.exists("preprocessed_dataset/Jazz_ML_MIDI/"):
    os.mkdir("preprocessed_dataset/Jazz_ML_MIDI/")
if not os.path.exists("preprocessed_dataset/jazz_standards/"):
    os.mkdir("preprocessed_dataset/jazz_standards/")

# %% [markdown]
# ### run in sequence

# %%
def run_in_sequence():
    for input_midi_dir, output_np_dir in input_output_directories:
        for midi_file_name in os.listdir(input_midi_dir):
        # print(midi_file_name)
            if not midi_file_name.lower().endswith(".mid"):
                continue
            try:
                data_rows, bass_notes = midi2input.midi_to_input(input_midi_dir + midi_file_name)
            except AssertionError as e:
                print(f"'{midi_file_name}' AssertionError: ", end="")
                print(e)
            except Exception as e:
                print(f"'{midi_file_name}' Error: ", end="")
                print(e)
            else:
                np.save(output_np_dir + midi_file_name + ".npy", data_rows)
                np.save(output_np_dir + midi_file_name + ".ans.npy", bass_notes)

# run_in_sequence()

# %% [markdown]
# ### run in parallel

# %%
def process_a_single_midi_file(args):
    input_midi_dir, output_np_dir, midi_file_name = args
    if not midi_file_name.lower().endswith(".mid"):
        return
    try:
        data_rows, bass_notes = midi2input.midi_to_input(input_midi_dir + midi_file_name)
    except AssertionError as e:
        print(f"AssertionError '{midi_file_name}': ", end="")
        print(e)
    except Exception as e:
        print(f"Error '{midi_file_name}': ", end="")
        print(e)
    else:
        np.save(output_np_dir + midi_file_name + ".npy", data_rows)
        np.save(output_np_dir + midi_file_name + ".ans.npy", bass_notes)

# %%
import multiprocess

def run_in_parallel():
    all_args = []
    for input_midi_dir, output_np_dir in input_output_directories:
        for midi_file_name in os.listdir(input_midi_dir):
            all_args.append((input_midi_dir, output_np_dir, midi_file_name))

    pool = multiprocess.Pool(3)
    _ = pool.map(process_a_single_midi_file, all_args)

run_in_parallel()
# Out:
# AssertionError 'GlasgowKiss.mid': didn't find bass instruments in midi file
# AssertionError 'SleepDirt(BlackNapkins).mid': didn't find bass instruments in midi file
# AssertionError 'TheyCantTakeThatAwayFromMe.mid': didn't find bass instruments in midi file
# AssertionError 'NoOneInTheWorld.mid': didn't find bass instruments in midi file
# AssertionError 'StateOfGrace.mid': didn't find bass instruments in midi file
# AssertionError 'Aintchagottired.mid': didn't find bass instruments in midi file
# AssertionError 'WhenTheSaintsGoMarchingIn.mid': didn't find bass instruments in midi file
# Error 'AffairInSanMiguel.mid': data byte must be in range 0..127
# AssertionError 'PijadaaKoSuga.mid': didn't find bass instruments in midi file
# AssertionError 'SilentNight.mid': didn't find bass instruments in midi file
# AssertionError 'NaturalElements.mid': didn't find bass instruments in midi file
# AssertionError 'Chinatawn.mid': didn't find bass instruments in midi file
# AssertionError 'IllSaySheDoes.mid': didn't find bass instruments in midi file
# Error 'TheCloserIGetToYou.mid': data byte must be in range 0..127
# AssertionError 'WhosSorryNow.mid': didn't find bass instruments in midi file
# AssertionError 'BigYellowTaxi.mid': didn't find bass instruments in midi file
# AssertionError 'DamageControl.mid': didn't find bass instruments in midi file
# AssertionError 'WhyCantThisNightGoOnForever.mid': didn't find bass instruments in midi file
# AssertionError 'LookAtMe.mid': didn't find bass instruments in midi file
# AssertionError 'LeftHandWarmUp.mid': didn't find bass instruments in midi file
# AssertionError 'CheekToCheek.mid': didn't find bass instruments in midi file
# AssertionError 'MyCherieAmour.mid': didn't find bass instruments in midi file
# AssertionError 'River.mid': didn't find bass instruments in midi file
# AssertionError 'BothSidesNow.mid': didn't find bass instruments in midi file
# Error 'AnyWayYouWantIt.mid': data byte must be in range 0..127
# AssertionError 'Parelima.mid': didn't find bass instruments in midi file
# AssertionError 'IfIHadYou.mid': didn't find bass instruments in midi file
# Error 'Lakes.mid': data byte must be in range 0..127
# Error 'StTropez.mid': data byte must be in range 0..127
# AssertionError 'SomewhereOutThere.mid': didn't find bass instruments in midi file
# Error 'BitterMoon.mid': list index out of range
# AssertionError 'CindyOhCindy.mid': didn't find bass instruments in midi file
# AssertionError 'CopperKettle.mid': didn't find bass instruments in midi file
# Error 'Destiny.mid': data byte must be in range 0..127
# Error 'SomethingTheBoySaid.mid': list index out of range
# AssertionError 'BuglersDream.mid': didn't find bass instruments in midi file
# AssertionError 'Whispering.mid': didn't find bass instruments in midi file
# AssertionError 'ThisCowboySong.mid': didn't find bass instruments in midi file
# AssertionError 'TigerRag.mid': didn't find bass instruments in midi file
# AssertionError 'BirthOfTheBlues.mid': didn't find bass instruments in midi file
# AssertionError 'BoogieOnRaggaeWomen.mid': didn't find bass instruments in midi file
# AssertionError 'MysticDreamExercise.mid': didn't find bass instruments in midi file
# AssertionError 'Imagine.mid': didn't find bass instruments in midi file
# AssertionError 'FatherOblivion.mid': didn't find bass instruments in midi file
# AssertionError 'OhLadyBeGood.mid': didn't find bass instruments in midi file
# AssertionError 'Silhouette.mid': didn't find bass instruments in midi fileError 'LovinTouchinSqueezin.mid':
# data byte must be in range 0..127
# Error 'MonaLisa.mid': list index out of range
# Error 'Moment.mid': data byte must be in range 0..127
# AssertionError 'JawsOfLife.mid': didn't find bass instruments in midi file
# Error 'TwentyFiveToMidnight.mid': list index out of range
# AssertionError 'Bluesette.mid': didn't find bass instruments in midi file
# AssertionError 'Bebop.mid': didn't find bass instruments in midi file
# AssertionError 'NutSundae.mid': didn't find bass instruments in midi file
# AssertionError 'WildWoodFlower.mid': didn't find bass instruments in midi file
# AssertionError 'SuicideIsPainless.mid': didn't find bass instruments in midi file
# Error 'JamaicanNights.mid': data byte must be in range 0..127
# AssertionError 'KingKongItself.mid': didn't find bass instruments in midi file
# AssertionError 'InsidePicking.mid': AssertionError 'OverTheRainbow.mid': didn't find bass instruments in midi file
# didn't find bass instruments in midi file
# AssertionError 'DizzyFingers.mid': didn't find bass instruments in midi file
# AssertionError 'KillerFlaminBuddy.mid': didn't find bass instruments in midi file
# AssertionError 'OnTheCase.mid': didn't find bass instruments in midi file
# AssertionError 'IndianSummer.mid': didn't find bass instruments in midi file
# Error 'CurvesAhead.mid': data byte must be in range 0..127
# AssertionError 'Amazinggrace.mid': didn't find bass instruments in midi file
# AssertionError 'Riderideride.mid': didn't find bass instruments in midi file
# AssertionError 'Alphonso.mid': didn't find bass instruments in midi file
# AssertionError 'HeardItThroughTheGrapevine.mid': didn't find bass instruments in midi file
# AssertionError 'NumbNubs.mid': didn't find bass instruments in midi file
# AssertionError 'Differentdums.mid': didn't find bass instruments in midi file
# AssertionError 'SomewhereOverTheSlaughterhouse.mid': didn't find bass instruments in midi file
# AssertionError 'StLouisBlues.mid': didn't find bass instruments in midi file
# AssertionError 'IntroMusic(FromRockDiscipline).mid': didn't find bass instruments in midi file
# AssertionError 'ABC.mid': didn't find bass instruments in midi file
# AssertionError 'BalladForKay.mid': didn't find bass instruments in midi file
# AssertionError 'SomethingStupid.mid': didn't find bass instruments in midi file
# AssertionError 'TwentySmallCigars.mid': didn't find bass instruments in midi file
# Error 'CantilopeIsland.mid': data byte must be in range 0..127
# AssertionError 'ColdDayInHell.mid': didn't find bass instruments in midi file
# AssertionError 'ThereWillNeverBeAnotherYou.mid': didn't find bass instruments in midi file
# AssertionError 'RecordaMe.mid': didn't find bass instruments in midi file
# AssertionError 'MisterSandman.mid': didn't find bass instruments in midi file
# AssertionError 'BeautifulGirl.mid': didn't find bass instruments in midi file
# AssertionError 'HelloDolly.mid': didn't find bass instruments in midi file
# AssertionError 'AutumnLeaves(LesFeuillesMortes).mid': didn't find bass instruments in midi file
# AssertionError 'YaketyAxe.mid': didn't find bass instruments in midi file
# AssertionError 'James.mid': didn't find bass instruments in midi file
# AssertionError 'ManhaDeCarnaval.mid': didn't find bass instruments in midi file
# AssertionError 'Marie-Mai-Encoreunenuit.mid': didn't find bass instruments in midi file
# AssertionError 'Gemini.mid': didn't find bass instruments in midi file
# AssertionError 'Koko.mid': didn't find bass instruments in midi file
# AssertionError 'TaxidermyLoaf.mid': didn't find bass instruments in midi file
# AssertionError 'BigSurMoon.mid': didn't find bass instruments in midi file
# AssertionError 'Struttin.mid': didn't find bass instruments in midi file
# AssertionError 'TakeFive.mid': didn't find bass instruments in midi file
# AssertionError 'Fresh.mid': didn't find bass instruments in midi file
# AssertionError 'Blueocean.mid': didn't find bass instruments in midi file
# AssertionError 'WhereorWhen.mid': didn't find bass instruments in midi file
# AssertionError 'GlasgowKiss(Live).mid': didn't find bass instruments in midi file
# AssertionError 'UnePetiteCantate.mid': didn't find bass instruments in midi file
# AssertionError 'Bodhisattva.mid': didn't find bass instruments in midi file
# AssertionError 'Russians.mid': didn't find bass instruments in midi file
# AssertionError 'NeverFeltThisWay.mid': didn't find bass instruments in midi file
# AssertionError 'RevengeWedge.mid': didn't find bass instruments in midi file
# AssertionError 'Bumblebee.mid': didn't find bass instruments in midi file
# AssertionError 'CosmicSquareDance.mid': didn't find bass instruments in midi file
# AssertionError 'GiveItUp.mid': didn't find bass instruments in midi file
# AssertionError 'ReachOut.mid': didn't find bass instruments in midi file
# AssertionError 'OhByJingoOhByGee.mid': didn't find bass instruments in midi file
# AssertionError 'TheTrailor.mid': didn't find bass instruments in midi file
# AssertionError 'BackhomeagaininIndiana.mid': didn't find bass instruments in midi file
# AssertionError 'Entertainer.mid': didn't find bass instruments in midi file
# Error 'NativeSonsOfADistantLand.mid': data byte must be in range 0..127
# AssertionError 'Berlin.mid': didn't find bass instruments in midi file
# Error 'ThePrincess.mid': data byte must be in range 0..127
# AssertionError 'RubyTuesday.mid': didn't find bass instruments in midi file
# AssertionError 'Hourglass.mid': didn't find bass instruments in midi file
# AssertionError 'Tarantelle.mid': didn't find bass instruments in midi file
# Error 'RoadWarriors.mid': data byte must be in range 0..127
# AssertionError 'ACrush.mid': didn't find bass instruments in midi file
# AssertionError '914.mid': didn't find bass instruments in midi file
# Error 'Lights.mid': data byte must be in range 0..127
# AssertionError 'Spain.mid': didn't find bass instruments in midi file
# AssertionError 'BlackMountainRag.mid': didn't find bass instruments in midi file
# AssertionError 'JumpJiveAndWail.mid': didn't find bass instruments in midi file
# AssertionError 'DontWalkAwayInTheMusic.mid': didn't find bass instruments in midi file
# Error 'DarnThatDream.mid': data byte must be in range 0..127
# AssertionError 'Music!Music!Music!.mid': didn't find bass instruments in midi file
# AssertionError 'DontStopBelievin.mid': didn't find bass instruments in midi file
# AssertionError 'I-5Binge.mid': didn't find bass instruments in midi file
# AssertionError 'SisireJhai.mid': didn't find bass instruments in midi file
# AssertionError 'Apostrophe.mid': didn't find bass instruments in midi file
# Error 'BraveNewWorld.mid': data byte must be in range 0..127
# AssertionError 'RockyTop.mid': didn't find bass instruments in midi file
# AssertionError 'ChickenFeed.mid': didn't find bass instruments in midi file
# AssertionError 'UncleRemus.mid': didn't find bass instruments in midi file
# AssertionError 'AllThumb.mid': didn't find bass instruments in midi file
# AssertionError 'ALittleMarkMusic.mid': didn't find bass instruments in midi file
# AssertionError 'OneMintJulep.mid': didn't find bass instruments in midi file
# AssertionError 'Cherish.mid': didn't find bass instruments in midi file
# AssertionError 'ScoopFromTheCoop.mid': didn't find bass instruments in midi file
# AssertionError 'LoveIsStrongerThanPride.mid': didn't find bass instruments in midi file
# AssertionError 'MerryChristmasMr.Lawrence.mid': didn't find bass instruments in midi file
# AssertionError 'LetsMakeTheWaterTurnBlack.mid': didn't find bass instruments in midi file
# AssertionError 'BeforeThePardadePassesMeBy.mid': didn't find bass instruments in midi file
# AssertionError 'DriveIn.mid': didn't find bass instruments in midi file
# AssertionError 'TheBlueChipBop.mid': didn't find bass instruments in midi file
# AssertionError 'DaddyDontLiveInThatNewYorkCityNoMore.mid': didn't find bass instruments in midi file
# AssertionError 'CherryPie.mid': didn't find bass instruments in midi file
# AssertionError 'UptightEverythingsAlright.mid': didn't find bass instruments in midi file
# AssertionError 'SentimentalMood.mid': didn't find bass instruments in midi file
# AssertionError 'Songbird.mid': didn't find bass instruments in midi file
# AssertionError 'LesFeuillesMortes.mid': didn't find bass instruments in midi file
# Error 'StoriesOfThePaintedDesert.mid': data byte must be in range 0..127
# AssertionError 'SiempreHayEsperanza.mid': didn't find bass instruments in midi file
# AssertionError 'St.LouisBlues.mid': didn't find bass instruments in midi file
# AssertionError 'SpeedAndTechnique.mid': didn't find bass instruments in midi file
# AssertionError 'Memory.mid': didn't find bass instruments in midi file
# AssertionError 'CityOfGoldLicks.mid': didn't find bass instruments in midi file
# AssertionError 'BiteOfTheMosquito.mid': didn't find bass instruments in midi file
# AssertionError 'AtLast.mid': didn't find bass instruments in midi file
# AssertionError 'DheraiDheraiAauncha.mid': didn't find bass instruments in midi file
# AssertionError 'MainStreetBreakdown.mid': didn't find bass instruments in midi file
# AssertionError 'ShelteringSky.mid': didn't find bass instruments in midi file
# AssertionError 'HelloMyBaby.mid': didn't find bass instruments in midi file
# AssertionError 'TheLastFarewell.mid': didn't find bass instruments in midi file
# AssertionError 'WelcomeToBucketheadland.mid': didn't find bass instruments in midi file
# AssertionError 'Criminal.mid': didn't find bass instruments in midi file
# AssertionError 'Vincent.mid': didn't find bass instruments in midi file
# AssertionError 'IveNeverBeenInLoveBefore.mid': didn't find bass instruments in midi file
# AssertionError 'Exercise.mid': didn't find bass instruments in midi file
# AssertionError 'OverTheWaves.mid': didn't find bass instruments in midi file
# AssertionError 'JasoGaraJeBhana.mid': didn't find bass instruments in midi file
# Error 'AThousandYears.mid': list index out of range
# AssertionError 'BibonoAozora.mid': didn't find bass instruments in midi file
# AssertionError 'WabashCannonBall.mid': didn't find bass instruments in midi file
# Error 'BigSky.mid': data byte must be in range 0..127
# AssertionError 'RockDiscipline.mid': didn't find bass instruments in midi file
# AssertionError 'Charade.mid': didn't find bass instruments in midi file
# AssertionError 'YouAreTheSunshineOfMyLife.mid': didn't find bass instruments in midi file
# AssertionError 'BangBang(MyBabyShotMeDown).mid': didn't find bass instruments in midi file
# AssertionError 'Maybelle.mid': didn't find bass instruments in midi file
# AssertionError 'SecretLove.mid': didn't find bass instruments in midi file
# AssertionError 'MrBojangles.mid': didn't find bass instruments in midi file
# Error 'GhostStory.mid': list index out of range
# AssertionError 'Avalon.mid': didn't find bass instruments in midi file
# AssertionError 'ClassicalGas.mid': didn't find bass instruments in midi file
# AssertionError 'TheShadowofYourSmile.mid': didn't find bass instruments in midi file
# AssertionError 'ICantGetStarted.mid.mid': didn't find bass instruments in midi file
# AssertionError 'CannedHeat.mid': didn't find bass instruments in midi file
# AssertionError 'PeepShowBinge.mid': didn't find bass instruments in midi file
# AssertionError 'Adventage.mid': didn't find bass instruments in midi file
# AssertionError 'ColorsOfTheWind.mid': didn't find bass instruments in midi file
# AssertionError 'TheLegatoTechnique.mid': didn't find bass instruments in midi file
# AssertionError 'Wobegon.mid': didn't find bass instruments in midi file
# AssertionError 'IllSeeYouInMyDreams.mid': didn't find bass instruments in midi file
# AssertionError 'YankeeDoodleDixie.mid': didn't find bass instruments in midi file
# AssertionError 'ZorbaTheGreek.mid': didn't find bass instruments in midi file
# AssertionError 'Dig.mid': didn't find bass instruments in midi file
# AssertionError 'TheyCantTakeAwayFromMe.mid': didn't find bass instruments in midi file
# AssertionError 'GiantRobotLesson.mid': didn't find bass instruments in midi file
# AssertionError 'HogBitchStomp.mid': didn't find bass instruments in midi file
# AssertionError 'Stella_by_Starlight.mid': didn't find bass instruments in midi file
# AssertionError 'Triste.mid': didn't find bass instruments in midi file
# AssertionError 'Faithfully2.mid': didn't find bass instruments in midi file
# AssertionError 'RoundMidnight.mid': didn't find bass instruments in midi file
# AssertionError 'Curve.mid': didn't find bass instruments in midi file
# AssertionError 'Nardis.mid': didn't find bass instruments in midi file
# AssertionError 'BlackPage.mid': didn't find bass instruments in midi file
# AssertionError 'WindyAndWarm.mid': didn't find bass instruments in midi file
# AssertionError 'FortressAroundYourHeart.mid': didn't find bass instruments in midi file
# AssertionError 'BlueAngel.mid': didn't find bass instruments in midi file
# AssertionError 'DreamaLittleDreamofMe.mid': didn't find bass instruments in midi file
# Error 'WeddingDressSong.mid': list index out of range
# AssertionError 'Wave.mid': didn't find bass instruments in midi file
# AssertionError 'Tenderly.mid': didn't find bass instruments in midi file
# AssertionError 'MusictoWatchGirlsby.mid': didn't find bass instruments in midi file
# AssertionError 'SinceIDontHaveYou.mid': didn't find bass instruments in midi file
# AssertionError 'AllIEverNeedIsYou.mid': didn't find bass instruments in midi file
# AssertionError 'Caravan.mid': didn't find bass instruments in midi file
# Error 'OpusDeFunk.mid': Could not decode key with 0 flats and mode 255
# AssertionError 'GabbyDance.mid': didn't find bass instruments in midi file
# AssertionError 'LushLife.mid': didn't find bass instruments in midi file
# AssertionError 'ItsAllrightWithMe.mid': didn't find bass instruments in midi file
# AssertionError 'EastOfTheSun.mid': didn't find bass instruments in midi file
# Error 'Teentown.mid': list index out of range
# AssertionError 'ALittleBitofBlues.mid': didn't find bass instruments in midi file
# Error 'Poinciana.mid': Could not decode key with 0 flats and mode 2
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]
