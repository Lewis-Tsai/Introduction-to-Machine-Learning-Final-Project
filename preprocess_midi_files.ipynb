# %%
import midi_np_translation.midi2input as midi2input
import os
import numpy as np

# %%
input_output_directories = [
    ("input_midi/Jazz_ML_MIDI/Jazz Midi/", "preprocessed_dataset/Jazz_ML_MIDI/"), 
    ("input_midi/jazz_standards/", "preprocessed_dataset/jazz_standards/")
]

if not os.path.exists("preprocessed_dataset/Jazz_ML_MIDI/"):
    os.mkdir("preprocessed_dataset/Jazz_ML_MIDI/")
if not os.path.exists("preprocessed_dataset/jazz_standards/"):
    os.mkdir("preprocessed_dataset/jazz_standards/")

# %%
for input_midi_dir, output_np_dir in input_output_directories:
    for midi_file_name in os.listdir(input_midi_dir):
        # print(midi_file_name)
        if not midi_file_name.lower().endswith(".mid"):
            continue
        try:
            data_rows, bass_notes = midi2input.midi_to_input(input_midi_dir + midi_file_name)
        except AssertionError as e:
            print(f"'{midi_file_name}' AssertionError: ", end="")
            print(e)
        except Exception as e:
            print(f"'{midi_file_name}' Error: ", end="")
            print(e)
        else:
            np.save(output_np_dir + midi_file_name + ".npy", data_rows)
            np.save(output_np_dir + midi_file_name + ".ans.npy", bass_notes)
# Out:
# 'GlasgowKiss.mid' AssertionError: didn't find bass instruments in midi file
# /usr/local/lib/python3.10/site-packages/pretty_midi/pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# 'Chinatawn.mid' AssertionError: didn't find bass instruments in midi file
# 'IllSaySheDoes.mid' AssertionError: didn't find bass instruments in midi file
# 'WhosSorryNow.mid' AssertionError: didn't find bass instruments in midi file
# 'DamageControl.mid' AssertionError: didn't find bass instruments in midi file
# 'IfIHadYou.mid' AssertionError: didn't find bass instruments in midi file
# 'Lakes.mid' Error: data byte must be in range 0..127
# 'StTropez.mid' Error: data byte must be in range 0..127
# 'BuglersDream.mid' AssertionError: didn't find bass instruments in midi file
# 'Whispering.mid' AssertionError: didn't find bass instruments in midi file
# 'ThisCowboySong.mid' AssertionError: didn't find bass instruments in midi file
# 'TigerRag.mid' AssertionError: didn't find bass instruments in midi file
# 'BirthOfTheBlues.mid' AssertionError: didn't find bass instruments in midi file
# 'MysticDreamExercise.mid' AssertionError: didn't find bass instruments in midi file
# 'Imagine.mid' AssertionError: didn't find bass instruments in midi file
# 'FatherOblivion.mid' AssertionError: didn't find bass instruments in midi file
# 'OhLadyBeGood.mid' AssertionError: didn't find bass instruments in midi file
# 'LovinTouchinSqueezin.mid' Error: data byte must be in range 0..127
# 'Moment.mid' Error: data byte must be in range 0..127
# 'InsidePicking.mid' AssertionError: didn't find bass instruments in midi file
# 'HeardItThroughTheGrapevine.mid' AssertionError: didn't find bass instruments in midi file
# 'SleepDirt(BlackNapkins).mid' AssertionError: didn't find bass instruments in midi file
# 'TheyCantTakeThatAwayFromMe.mid' AssertionError: didn't find bass instruments in midi file
# 'NoOneInTheWorld.mid' AssertionError: didn't find bass instruments in midi file
# 'StateOfGrace.mid' AssertionError: didn't find bass instruments in midi file
# 'Aintchagottired.mid' AssertionError: didn't find bass instruments in midi file
# 'PijadaaKoSuga.mid' AssertionError: didn't find bass instruments in midi file
# 'MyCherieAmour.mid' AssertionError: didn't find bass instruments in midi file
# 'BothSidesNow.mid' AssertionError: didn't find bass instruments in midi file
# 'AnyWayYouWantIt.mid' Error: data byte must be in range 0..127
# 'Parelima.mid' AssertionError: didn't find bass instruments in midi file
# 'CindyOhCindy.mid' AssertionError: didn't find bass instruments in midi file
# 'Destiny.mid' Error: data byte must be in range 0..127
# 'BoogieOnRaggaeWomen.mid' AssertionError: didn't find bass instruments in midi file
# 'Silhouette.mid' AssertionError: didn't find bass instruments in midi file
# 'Bluesette.mid' AssertionError: didn't find bass instruments in midi file
# 'Bebop.mid' AssertionError: didn't find bass instruments in midi file
# 'JamaicanNights.mid' Error: data byte must be in range 0..127
# 'KingKongItself.mid' AssertionError: didn't find bass instruments in midi file
# 'DizzyFingers.mid' AssertionError: didn't find bass instruments in midi file
# 'WhenTheSaintsGoMarchingIn.mid' AssertionError: didn't find bass instruments in midi file
# 'AffairInSanMiguel.mid' Error: data byte must be in range 0..127
# 'SilentNight.mid' AssertionError: didn't find bass instruments in midi file
# 'NaturalElements.mid' AssertionError: didn't find bass instruments in midi file
# 'TheCloserIGetToYou.mid' Error: data byte must be in range 0..127
# 'BigYellowTaxi.mid' AssertionError: didn't find bass instruments in midi file
# 'WhyCantThisNightGoOnForever.mid' AssertionError: didn't find bass instruments in midi file
# 'LookAtMe.mid' AssertionError: didn't find bass instruments in midi file
# 'LeftHandWarmUp.mid' AssertionError: didn't find bass instruments in midi file
# 'CheekToCheek.mid' AssertionError: didn't find bass instruments in midi file
# 'River.mid' AssertionError: didn't find bass instruments in midi file
# 'SomewhereOutThere.mid' AssertionError: didn't find bass instruments in midi file
# 'CopperKettle.mid' AssertionError: didn't find bass instruments in midi file
# 'JawsOfLife.mid' AssertionError: didn't find bass instruments in midi file
# 'NutSundae.mid' AssertionError: didn't find bass instruments in midi file
# 'WildWoodFlower.mid' AssertionError: didn't find bass instruments in midi file
# 'SuicideIsPainless.mid' AssertionError: didn't find bass instruments in midi file
# 'OverTheRainbow.mid' AssertionError: didn't find bass instruments in midi file
# 'OnTheCase.mid' AssertionError: didn't find bass instruments in midi file
# 'CurvesAhead.mid' Error: data byte must be in range 0..127
# 'Riderideride.mid' AssertionError: didn't find bass instruments in midi file
# 'Alphonso.mid' AssertionError: didn't find bass instruments in midi file
# 'NumbNubs.mid' AssertionError: didn't find bass instruments in midi file
# 'Differentdums.mid' AssertionError: didn't find bass instruments in midi file
# 'SomewhereOverTheSlaughterhouse.mid' AssertionError: didn't find bass instruments in midi file
# 'StLouisBlues.mid' AssertionError: didn't find bass instruments in midi file
# 'BalladForKay.mid' AssertionError: didn't find bass instruments in midi file
# 'MisterSandman.mid' AssertionError: didn't find bass instruments in midi file
# 'BeautifulGirl.mid' AssertionError: didn't find bass instruments in midi file
# 'HelloDolly.mid' AssertionError: didn't find bass instruments in midi file
# 'ManhaDeCarnaval.mid' AssertionError: didn't find bass instruments in midi file
# 'Koko.mid' AssertionError: didn't find bass instruments in midi file
# 'TaxidermyLoaf.mid' AssertionError: didn't find bass instruments in midi file
# 'TakeFive.mid' AssertionError: didn't find bass instruments in midi file
# 'Bodhisattva.mid' AssertionError: didn't find bass instruments in midi file
# 'NeverFeltThisWay.mid' AssertionError: didn't find bass instruments in midi file
# 'Bumblebee.mid' AssertionError: didn't find bass instruments in midi file
# 'GiveItUp.mid' AssertionError: didn't find bass instruments in midi file
# 'ReachOut.mid' AssertionError: didn't find bass instruments in midi file
# 'Berlin.mid' AssertionError: didn't find bass instruments in midi file
# 'Tarantelle.mid' AssertionError: didn't find bass instruments in midi file
# 'KillerFlaminBuddy.mid' AssertionError: didn't find bass instruments in midi file
# 'IndianSummer.mid' AssertionError: didn't find bass instruments in midi file
# 'Amazinggrace.mid' AssertionError: didn't find bass instruments in midi file
# 'ABC.mid' AssertionError: didn't find bass instruments in midi file
# 'CantilopeIsland.mid' Error: data byte must be in range 0..127
# 'ColdDayInHell.mid' AssertionError: didn't find bass instruments in midi file
# 'ThereWillNeverBeAnotherYou.mid' AssertionError: didn't find bass instruments in midi file
# 'AutumnLeaves(LesFeuillesMortes).mid' AssertionError: didn't find bass instruments in midi file
# 'Gemini.mid' AssertionError: didn't find bass instruments in midi file
# 'Struttin.mid' AssertionError: didn't find bass instruments in midi file
# 'Fresh.mid' AssertionError: didn't find bass instruments in midi file
# 'Blueocean.mid' AssertionError: didn't find bass instruments in midi file
# 'WhereorWhen.mid' AssertionError: didn't find bass instruments in midi file
# 'RevengeWedge.mid' AssertionError: didn't find bass instruments in midi file
# 'BackhomeagaininIndiana.mid' AssertionError: didn't find bass instruments in midi file
# 'Entertainer.mid' AssertionError: didn't find bass instruments in midi file
# 'ThePrincess.mid' Error: data byte must be in range 0..127
# 'RubyTuesday.mid' AssertionError: didn't find bass instruments in midi file
# 'Hourglass.mid' AssertionError: didn't find bass instruments in midi file
# 'IntroMusic(FromRockDiscipline).mid' AssertionError: didn't find bass instruments in midi file
# 'SomethingStupid.mid' AssertionError: didn't find bass instruments in midi file
# 'TwentySmallCigars.mid' AssertionError: didn't find bass instruments in midi file
# 'RecordaMe.mid' AssertionError: didn't find bass instruments in midi file
# 'YaketyAxe.mid' AssertionError: didn't find bass instruments in midi file
# 'James.mid' AssertionError: didn't find bass instruments in midi file
# 'Marie-Mai-Encoreunenuit.mid' AssertionError: didn't find bass instruments in midi file
# 'BigSurMoon.mid' AssertionError: didn't find bass instruments in midi file
# 'GlasgowKiss(Live).mid' AssertionError: didn't find bass instruments in midi file
# 'UnePetiteCantate.mid' AssertionError: didn't find bass instruments in midi file
# 'Russians.mid' AssertionError: didn't find bass instruments in midi file
# 'CosmicSquareDance.mid' AssertionError: didn't find bass instruments in midi file
# 'OhByJingoOhByGee.mid' AssertionError: didn't find bass instruments in midi file
# 'TheTrailor.mid' AssertionError: didn't find bass instruments in midi file
# 'NativeSonsOfADistantLand.mid' Error: data byte must be in range 0..127
# 'RoadWarriors.mid' Error: data byte must be in range 0..127
# 'Lights.mid' Error: data byte must be in range 0..127
# 'DontWalkAwayInTheMusic.mid' AssertionError: didn't find bass instruments in midi file
# 'DontStopBelievin.mid' AssertionError: didn't find bass instruments in midi file
# 'I-5Binge.mid' AssertionError: didn't find bass instruments in midi file
# 'SisireJhai.mid' AssertionError: didn't find bass instruments in midi file
# 'ACrush.mid' AssertionError: didn't find bass instruments in midi file
# '914.mid' AssertionError: didn't find bass instruments in midi file
# 'BlackMountainRag.mid' AssertionError: didn't find bass instruments in midi file
# 'JumpJiveAndWail.mid' AssertionError: didn't find bass instruments in midi file
# 'DarnThatDream.mid' Error: data byte must be in range 0..127
# 'Music!Music!Music!.mid' AssertionError: didn't find bass instruments in midi file
# 'Apostrophe.mid' AssertionError: didn't find bass instruments in midi file
# 'BraveNewWorld.mid' Error: data byte must be in range 0..127
# 'RockyTop.mid' AssertionError: didn't find bass instruments in midi file
# 'AllThumb.mid' AssertionError: didn't find bass instruments in midi file
# 'ALittleMarkMusic.mid' AssertionError: didn't find bass instruments in midi file
# 'Cherish.mid' AssertionError: didn't find bass instruments in midi file
# 'CherryPie.mid' AssertionError: didn't find bass instruments in midi file
# 'LesFeuillesMortes.mid' AssertionError: didn't find bass instruments in midi file
# 'MainStreetBreakdown.mid' AssertionError: didn't find bass instruments in midi file
# 'HelloMyBaby.mid' AssertionError: didn't find bass instruments in midi file
# 'TheLastFarewell.mid' AssertionError: didn't find bass instruments in midi file
# 'Exercise.mid' AssertionError: didn't find bass instruments in midi file
# 'OverTheWaves.mid' AssertionError: didn't find bass instruments in midi file
# 'WabashCannonBall.mid' AssertionError: didn't find bass instruments in midi file
# 'RockDiscipline.mid' AssertionError: didn't find bass instruments in midi file
# 'Charade.mid' AssertionError: didn't find bass instruments in midi file
# 'BangBang(MyBabyShotMeDown).mid' AssertionError: didn't find bass instruments in midi file
# 'Spain.mid' AssertionError: didn't find bass instruments in midi file
# 'ChickenFeed.mid' AssertionError: didn't find bass instruments in midi file
# 'UncleRemus.mid' AssertionError: didn't find bass instruments in midi file
# 'OneMintJulep.mid' AssertionError: didn't find bass instruments in midi file
# 'BeforeThePardadePassesMeBy.mid' AssertionError: didn't find bass instruments in midi file
# 'DriveIn.mid' AssertionError: didn't find bass instruments in midi file
# 'TheBlueChipBop.mid' AssertionError: didn't find bass instruments in midi file
# 'UptightEverythingsAlright.mid' AssertionError: didn't find bass instruments in midi file
# 'SentimentalMood.mid' AssertionError: didn't find bass instruments in midi file
# 'Songbird.mid' AssertionError: didn't find bass instruments in midi file
# 'SiempreHayEsperanza.mid' AssertionError: didn't find bass instruments in midi file
# 'St.LouisBlues.mid' AssertionError: didn't find bass instruments in midi file
# 'SpeedAndTechnique.mid' AssertionError: didn't find bass instruments in midi file
# 'CityOfGoldLicks.mid' AssertionError: didn't find bass instruments in midi file
# 'BiteOfTheMosquito.mid' AssertionError: didn't find bass instruments in midi file
# 'WelcomeToBucketheadland.mid' AssertionError: didn't find bass instruments in midi file
# 'Criminal.mid' AssertionError: didn't find bass instruments in midi file
# 'Vincent.mid' AssertionError: didn't find bass instruments in midi file
# 'IveNeverBeenInLoveBefore.mid' AssertionError: didn't find bass instruments in midi file
# 'JasoGaraJeBhana.mid' AssertionError: didn't find bass instruments in midi file
# 'YouAreTheSunshineOfMyLife.mid' AssertionError: didn't find bass instruments in midi file
# 'ScoopFromTheCoop.mid' AssertionError: didn't find bass instruments in midi file
# 'LoveIsStrongerThanPride.mid' AssertionError: didn't find bass instruments in midi file
# 'MerryChristmasMr.Lawrence.mid' AssertionError: didn't find bass instruments in midi file
# 'LetsMakeTheWaterTurnBlack.mid' AssertionError: didn't find bass instruments in midi file
# 'DaddyDontLiveInThatNewYorkCityNoMore.mid' AssertionError: didn't find bass instruments in midi file
# 'StoriesOfThePaintedDesert.mid' Error: data byte must be in range 0..127
# 'Memory.mid' AssertionError: didn't find bass instruments in midi file
# 'AtLast.mid' AssertionError: didn't find bass instruments in midi file
# 'DheraiDheraiAauncha.mid' AssertionError: didn't find bass instruments in midi file
# 'ShelteringSky.mid' AssertionError: didn't find bass instruments in midi file
# 'BibonoAozora.mid' AssertionError: didn't find bass instruments in midi file
# 'BigSky.mid' Error: data byte must be in range 0..127
# 'Maybelle.mid' AssertionError: didn't find bass instruments in midi file
# 'MrBojangles.mid' AssertionError: didn't find bass instruments in midi file
# 'ClassicalGas.mid' AssertionError: didn't find bass instruments in midi file
# 'TheShadowofYourSmile.mid' AssertionError: didn't find bass instruments in midi file
# 'ICantGetStarted.mid.mid' AssertionError: didn't find bass instruments in midi file
# 'PeepShowBinge.mid' AssertionError: didn't find bass instruments in midi file
# 'Adventage.mid' AssertionError: didn't find bass instruments in midi file
# 'SecretLove.mid' AssertionError: didn't find bass instruments in midi file
# 'Avalon.mid' AssertionError: didn't find bass instruments in midi file
# 'CannedHeat.mid' AssertionError: didn't find bass instruments in midi file
# 'IllSeeYouInMyDreams.mid' AssertionError: didn't find bass instruments in midi file
# 'YankeeDoodleDixie.mid' AssertionError: didn't find bass instruments in midi file
# 'ZorbaTheGreek.mid' AssertionError: didn't find bass instruments in midi file
# 'TheyCantTakeAwayFromMe.mid' AssertionError: didn't find bass instruments in midi file
# 'GiantRobotLesson.mid' AssertionError: didn't find bass instruments in midi file
# 'HogBitchStomp.mid' AssertionError: didn't find bass instruments in midi file
# 'RoundMidnight.mid' AssertionError: didn't find bass instruments in midi file
# 'FortressAroundYourHeart.mid' AssertionError: didn't find bass instruments in midi file
# 'BlueAngel.mid' AssertionError: didn't find bass instruments in midi file
# 'Caravan.mid' AssertionError: didn't find bass instruments in midi file
# 'GabbyDance.mid' AssertionError: didn't find bass instruments in midi file
# 'ALittleBitofBlues.mid' AssertionError: didn't find bass instruments in midi file
# 'ColorsOfTheWind.mid' AssertionError: didn't find bass instruments in midi file
# 'TheLegatoTechnique.mid' AssertionError: didn't find bass instruments in midi file
# 'Wobegon.mid' AssertionError: didn't find bass instruments in midi file
# 'Faithfully2.mid' AssertionError: didn't find bass instruments in midi file
# 'Curve.mid' AssertionError: didn't find bass instruments in midi file
# 'Nardis.mid' AssertionError: didn't find bass instruments in midi file
# 'BlackPage.mid' AssertionError: didn't find bass instruments in midi file
# 'WindyAndWarm.mid' AssertionError: didn't find bass instruments in midi file
# 'DreamaLittleDreamofMe.mid' AssertionError: didn't find bass instruments in midi file
# 'MusictoWatchGirlsby.mid' AssertionError: didn't find bass instruments in midi file
# 'SinceIDontHaveYou.mid' AssertionError: didn't find bass instruments in midi file
# 'AllIEverNeedIsYou.mid' AssertionError: didn't find bass instruments in midi file
# 'OpusDeFunk.mid' Error: Could not decode key with 0 flats and mode 255
# 'ItsAllrightWithMe.mid' AssertionError: didn't find bass instruments in midi file
# 'Poinciana.mid' Error: Could not decode key with 0 flats and mode 2
# 'Dig.mid' AssertionError: didn't find bass instruments in midi file
# 'Stella_by_Starlight.mid' AssertionError: didn't find bass instruments in midi file
# 'Triste.mid' AssertionError: didn't find bass instruments in midi file
# 'Wave.mid' AssertionError: didn't find bass instruments in midi file
# 'Tenderly.mid' AssertionError: didn't find bass instruments in midi file
# 'LushLife.mid' AssertionError: didn't find bass instruments in midi file
# 'EastOfTheSun.mid' AssertionError: didn't find bass instruments in midi file
